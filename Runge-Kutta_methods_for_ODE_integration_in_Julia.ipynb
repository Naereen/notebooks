# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Runge-Kutta-methods-for-ODE-integration-in-Julia" data-toc-modified-id="Runge-Kutta-methods-for-ODE-integration-in-Julia-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Runge-Kutta methods for ODE integration in Julia</a></div><div class="lev2 toc-item"><a href="#Preliminary" data-toc-modified-id="Preliminary-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Preliminary</a></div><div class="lev2 toc-item"><a href="#Runge-Kutta-method-of-order-1,-or-the-Euler-method" data-toc-modified-id="Runge-Kutta-method-of-order-1,-or-the-Euler-method-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Runge-Kutta method of order 1, or the Euler method</a></div><div class="lev2 toc-item"><a href="#Runge-Kutta-method-of-order-2" data-toc-modified-id="Runge-Kutta-method-of-order-2-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Runge-Kutta method of order 2</a></div><div class="lev2 toc-item"><a href="#Runge-Kutta-method-of-order-4,-&quot;RK4&quot;" data-toc-modified-id="Runge-Kutta-method-of-order-4,-&quot;RK4&quot;-14"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Runge-Kutta method of order 4, <em>"RK4"</em></a></div><div class="lev2 toc-item"><a href="#Comparisons" data-toc-modified-id="Comparisons-15"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Comparisons</a></div><div class="lev2 toc-item"><a href="#Comparisons-on-another-integration-problem" data-toc-modified-id="Comparisons-on-another-integration-problem-16"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Comparisons on another integration problem</a></div><div class="lev2 toc-item"><a href="#Small-benchmark" data-toc-modified-id="Small-benchmark-17"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Small benchmark</a></div><div class="lev2 toc-item"><a href="#Conclusion" data-toc-modified-id="Conclusion-18"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Conclusion</a></div>

# %% [markdown]
# # Runge-Kutta methods for ODE integration in Julia
#
# - I want to implement and illustrate the [Runge-Kutta method](https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods) (actually, different variants), in the [Julia programming language](https://www.julialang.org/).
#
# - The Runge-Kutta methods are a family of numerical iterative algorithms to approximate solutions of [Ordinary Differential Equations](https://en.wikipedia.org/wiki/Ordinary_differential_equation). I will simply implement them, for the mathematical descriptions, I let the interested reader refer to the Wikipedia page, or [any](https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods#References) [good](https://www.directtextbook.com/isbn/9780521007948) [book](https://www.decitre.fr/livres/analyse-numerique-et-equations-differentielles-9782868838919.html) or [course](https://courses.maths.ox.ac.uk/node/4294) on numerical integration of ODE.
# - I will start with the order 1 method, then the order 2 and the most famous order 4.
# - They will be compared on different ODE.

# %% [markdown]
# ## Preliminary

# %%
versioninfo()
# Out:
# Julia Version 0.6.0
# Commit 9036443 (2017-06-19 13:05 UTC)
# Platform Info:
#   OS: Linux (x86_64-pc-linux-gnu)
#   CPU: Intel(R) Core(TM) i5-6300U CPU @ 2.40GHz
#   WORD_SIZE: 64
#   BLAS: libopenblas (USE64BITINT DYNAMIC_ARCH NO_AFFINITY Haswell)
#   LAPACK: libopenblas64_
#   LIBM: libopenlibm
#   LLVM: libLLVM-3.9.1 (ORCJIT, skylake)

# %% [markdown]
# For comparison, let's use this [mature and fully featured package `DifferentialEquations`](http://docs.juliadiffeq.org/latest/) that provides a `solve` function to numerically integrate ordinary different equations, and the `Plots` package with `PyPlot` backend for plotting:

# %%
# If needed:
#Pkg.add("DifferentialEquations")
#Pkg.add("PyPlot")
#Pkg.add("Plots")

# %%
using Plots
gr()
using DifferentialEquations

# %% [markdown]
# I will use as a first example the one included in [the scipy (Python) documentation for this `odeint` function](https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.odeint.html).
#
# $$\theta''(t) + b \theta'(t) + c \sin(\theta(t)) = 0.$$
#
# If $\omega(t) := \theta'(t)$, this gives
# $$ \begin{cases}
# \theta'(t) = \omega(t) \\
# \omega'(t) = -b \omega(t) - c \sin(\theta(t))
# \end{cases} $$
#
# Vectorially, if $y(t) = [\theta(t), \omega(t)]$, then the equation is $y' = f(t, y)$ where $f(t, y) = [y_2(t), -b y_2(t) - c \sin(y_1(t))]$.

# %% [markdown]
# We assume the values of $b$ and $c$ to be known, and the starting point to be also fixed:

# %%
b = 0.25
c = 5.0
# Out:
# 5.0

# %%
y0 = [pi - 0.1; 0.0]
# Out:
# 2-element Array{Float64,1}:
#  3.04159
#  0.0

# %%
function pend(t, y, dy)
    dy[1] = y[2]
    dy[2] = (-b * y[2]) - (c * sin(y[1]))
end

function f_pend(y, t)
    return [y[2], (-b * y[2]) - (c * sin(y[1]))]
end
# Out:
# f_pend (generic function with 1 method)

# %% [markdown]
# The `solve` function from `DifferentialEquations` will be used to solve this ODE on the interval $t \in [0, 10]$.

# %%
tspan = (0.0, 10.0)
# Out:
# (0.0, 10.0)

# %% [markdown]
# It is used like this, and our implementations will follow this signature.

# %%
function odeint_1(f, y0, tspan)
    prob = ODEProblem(f, y0, tspan)
    sol = solve(prob)
    return sol.t, hcat(sol.u...)'
end
# Out:
# odeint_1 (generic function with 1 method)

# %%
function odeint(f, y0, tspan)
    t, sol = odeint_1(f, y0, tspan)
    return sol
end
# Out:
# odeint (generic function with 1 method)

# %%
t, sol = odeint_1(pend, y0, tspan)
# Out:
# ([0.0, 0.00200268, 0.0220295, 0.0813368, 0.17913, 0.306465, 0.472717, 0.676887, 0.920686, 1.19691  …  6.29546, 6.72503, 7.20537, 7.57654, 8.0385, 8.41262, 8.86583, 9.2365, 9.64917, 10.0], [3.04159 0.0; 3.04159 -0.000999424; … ; -0.500599 1.27096; 0.0236952 1.5641])

# %%
plot(t, sol[:, 1], xaxis="Time t", title="Solution to the pendulum ODE", label="\\theta (t)")
plot!(t, sol[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7100)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,320.254 572.049,320.254
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,272.976 572.049,272.976
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,225.698 572.049,225.698
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,178.42 572.049,178.42
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,131.142 572.049,131.142
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,83.8636 572.049,83.8636
#   "/>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,36.5856 572.049,36.5856
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,320.254 37.525,320.254
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,272.976 37.525,272.976
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,225.698 37.525,225.698
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,178.42 37.525,178.42
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,131.142 37.525,131.142
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,83.8636 37.525,83.8636
#   "/>
# <polyline clip-path="url(#clip7100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,36.5856 37.525,36.5856
#   "/>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 324.754)" x="23.2591" y="324.754">-3</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 277.476)" x="23.2591" y="277.476">-2</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 230.198)" x="23.2591" y="230.198">-1</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 182.92)" x="23.2591" y="182.92">0</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 135.642)" x="23.2591" y="135.642">1</text>
# </g>
# <g clip-path="url(#clip7100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 88.3636)" x="23.2591" y="88.3636">2</text>
# </g>
# <g cl

# %% [markdown]
# ----
# ## Runge-Kutta method of order 1, or the Euler method

# %% [markdown]
# The approximation is computed using this update:
# $$y_{n+1} = y_n + (t_{n+1} - t_n) f(y_n, t_n).$$
#
# The math behind this formula are the following: if $g$ is a solution to the ODE, and so far the approximation is correct, $y_n \simeq g(t_n)$, then a small step $h = t_{n+1} - t_n$ satisfy $g(t_n + h) \simeq g(t_n) + h g'(t_n) \simeq y_n + h f(g(t_n), t_n) + \simeq y_n + h f(y_n, t_n)$.

# %%
function rungekutta1(f, y0, t)
    n = length(t)
    y = zeros((n, length(y0)))
    y[1,:] = y0
    for i in 1:n-1
        h = t[i+1] - t[i]
        y[i+1,:] = y[i,:] + h * f(y[i,:], t[i])
    end
    return y
end
# Out:
# rungekutta1 (generic function with 1 method)

# %%
t = linspace(0, 10, 101);
sol = rungekutta1(f_pend, y0, t);

# %%
plot(t, sol[:, 1], xaxis="Time t", title="Solution to the pendulum ODE with Runge-Kutta 1", label="\\theta (t)")
plot!(t, sol[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7300)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,348.822 572.049,348.822
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,271.191 572.049,271.191
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.56 572.049,193.56
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,115.929 572.049,115.929
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,38.298 572.049,38.298
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,348.822 37.525,348.822
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,271.191 37.525,271.191
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.56 37.525,193.56
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,115.929 37.525,115.929
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,38.298 37.525,38.298
#   "/>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 353.322)" x="23.2591" y="353.322">-4</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 275.691)" x="23.2591" y="275.691">-2</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 198.06)" x="23.2591" y="198.06">0</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 120.429)" x="23.2591" y="120.429">2</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 42.798)" x="23.2591" y="42.798">4</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with Runge-Kutta 1</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip7302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,75.499 34.7697,75.499
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.7697,75.499 40.2803,75.6928
#   "/>
# <polyline clip-path="url(#clip7302)" style="str

# %% [markdown]
# With the same number of points, the Euler method (*i.e.* the Runge-Kutta method of order 1) is less precise than the reference `solve` method. With more points, it can give a satisfactory approximation of the solution:

# %%
t2 = linspace(0, 10, 1001);
sol2 = rungekutta1(f_pend, y0, t2);

# %%
plot(t2, sol2[:, 1], xaxis="Time t", title="Solution to the pendulum ODE with Runge-Kutta 1", label="\\theta (t)")
plot!(t2, sol2[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,358.641 572.049,358.641
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,270.126 572.049,270.126
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,181.61 572.049,181.61
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,93.0949 572.049,93.0949
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,358.641 37.525,358.641
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,270.126 37.525,270.126
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,181.61 37.525,181.61
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,93.0949 37.525,93.0949
#   "/>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 363.141)" x="23.2591" y="363.141">-4</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 274.626)" x="23.2591" y="274.626">-2</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 186.11)" x="23.2591" y="186.11">0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 97.5949)" x="23.2591" y="97.5949">2</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with Runge-Kutta 1</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip7502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,46.9964 29.8102,46.9964
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.8102,46.9964 30.3613,46.9986
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   30.3613,46.9986 30.9123,47.003
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   30.9123,47.003 31.4634,47.0096
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   31.4634,47.0096 32.0144,47.0184
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.0144,47

# %%
t3 = linspace(0, 10, 2001);
sol3 = rungekutta1(f_pend, y0, t3);

# %%
plot(t3, sol3[:, 1], xaxis="Time t", title="Solution to the pendulum ODE with Runge-Kutta 1", label="\\theta (t)")
plot!(t3, sol3[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7700)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,359.245 572.049,359.245
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,269.964 572.049,269.964
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,180.683 572.049,180.683
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,91.4027 572.049,91.4027
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,359.245 37.525,359.245
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,269.964 37.525,269.964
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,180.683 37.525,180.683
#   "/>
# <polyline clip-path="url(#clip7700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,91.4027 37.525,91.4027
#   "/>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 363.745)" x="23.2591" y="363.745">-4</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 274.464)" x="23.2591" y="274.464">-2</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 185.183)" x="23.2591" y="185.183">0</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 95.9027)" x="23.2591" y="95.9027">2</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with Runge-Kutta 1</text>
# </g>
# <g clip-path="url(#clip7700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip7702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,44.9056 29.5347,44.9056
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.5347,44.9056 29.8102,44.9062
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.8102,44.9062 30.0857,44.9073
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   30.0857,44.9073 30.3613,44.9089
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   30.3613,44.9089 30.6368,44.9112
#   "/>
# <polyline clip-path="url(#clip7702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   30

# %% [markdown]
# ----
# ## Runge-Kutta method of order 2

# %% [markdown]
# The order 2 Runge-Method uses this update:
# $$ y_{n+1} = y_n + h f(t + \frac{h}{2}, y_n + \frac{h}{2} f(t, y_n)),$$
# if $h = t_{n+1} - t_n$.

# %%
function rungekutta2(f, y0, t)
    n = length(t)
    y = zeros((n, length(y0)))
    y[1,:] = y0
    for i in 1:n-1
        h = t[i+1] - t[i]
        y[i+1,:] = y[i,:] + h * f(y[i,:] + f(y[i,:], t[i]) * h/2, t[i] + h/2)
    end
    return y
end
# Out:
# rungekutta2 (generic function with 1 method)

# %% [markdown]
# For our simple ODE example, this method is already quite efficient.

# %%
t3 = linspace(0, 10, 21);
sol3 = rungekutta2(f_pend, y0, t3);

# %%
plot(t3, sol3[:, 1], xaxis="Time t", title="Solution to the pendulum ODE with Runge-Kutta 2 (21 points)", label="\\theta (t)")
plot!(t3, sol3[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7900)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,358.964 572.049,358.964
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,275.571 572.049,275.571
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,192.178 572.049,192.178
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,108.785 572.049,108.785
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,358.964 37.525,358.964
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,275.571 37.525,275.571
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,192.178 37.525,192.178
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,108.785 37.525,108.785
#   "/>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 363.464)" x="23.2591" y="363.464">-4</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 280.071)" x="23.2591" y="280.071">-2</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 196.678)" x="23.2591" y="196.678">0</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 113.285)" x="23.2591" y="113.285">2</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with Runge-Kutta 2 (21 points)</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip7902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,65.3544 56.8119,67.9561
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.8119,67.9561 84.3647,76.7429
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   84.3647,76.7429 111.918,100.492
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   111.918,100.492 139.47,158.809
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,158.809 167.023,256.206
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" poi

# %%
t3 = linspace(0, 10, 101);
sol3 = rungekutta2(f_pend, y0, t3);

# %%
plot(t3, sol3[:, 1], xaxis="Time t", title="Solution to the pendulum ODE with Runge-Kutta 2 (101 points)", label="\\theta (t)")
plot!(t3, sol3[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,359.59 572.049,359.59
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,269.649 572.049,269.649
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,179.708 572.049,179.708
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,89.7668 572.049,89.7668
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,359.59 37.525,359.59
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,269.649 37.525,269.649
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,179.708 37.525,179.708
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,89.7668 37.525,89.7668
#   "/>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 364.09)" x="23.2591" y="364.09">-4</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 274.149)" x="23.2591" y="274.149">-2</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 184.208)" x="23.2591" y="184.208">0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 94.2668)" x="23.2591" y="94.2668">2</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with Runge-Kutta 2 (101 points)</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,42.9259 34.7697,43.0382
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.7697,43.0382 40.2803,43.3721
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.2803,43.3721 45.7908,43.9387
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7908,43.9387 51.3014,44.76
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.3014,44.76 56.8119,45.8697
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="

# %% [markdown]
# ----
# ## Runge-Kutta method of order 4, *"RK4"*

# %% [markdown]
# The order 4 Runge-Method uses this update:
# $$ y_{n+1} = y_n + \frac{h}{6} (k_1 + 2 k_2 + 2 k_3 + k_4),$$
# if $h = t_{n+1} - t_n$, and
# $$\begin{cases}
# k_1 &= f(y_n, t_n), \\
# k_2 &= f(y_n + \frac{h}{2} k_1, t_n + \frac{h}{2}), \\
# k_3 &= f(y_n + \frac{h}{2} k_2, t_n + \frac{h}{2}), \\
# k_4 &= f(y_n + h k_3, t_n + h).
# \end{cases}$$

# %%
function rungekutta4(f, y0, t)
    n = length(t)
    y = zeros((n, length(y0)))
    y[1,:] = y0
    for i in 1:n-1
        h = t[i+1] - t[i]
        k1 = f(y[i,:], t[i])
        k2 = f(y[i,:] + k1 * h/2, t[i] + h/2)
        k3 = f(y[i,:] + k2 * h/2, t[i] + h/2)
        k4 = f(y[i,:] + k3 * h, t[i] + h)
        y[i+1,:] = y[i,:] + (h/6) * (k1 + 2*k2 + 2*k3 + k4)
    end
    return y
end
# Out:
# rungekutta4 (generic function with 1 method)

# %% [markdown]
# For our simple ODE example, this method is even more efficient.

# %%
t = linspace(0, 10, 31);
sol = rungekutta4(f_pend, y0, t);

# %%
plot(t, sol[:, 1], xaxis="Time t", title="Solution to the pendulum ODE with Runge-Kutta 4 (31 points)", label="\\theta (t)")
plot!(t, sol[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,359.947 572.049,359.947
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,267.526 572.049,267.526
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,175.106 572.049,175.106
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,82.6852 572.049,82.6852
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,359.947 37.525,359.947
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,267.526 37.525,267.526
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,175.106 37.525,175.106
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,82.6852 37.525,82.6852
#   "/>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 364.447)" x="23.2591" y="364.447">-4</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 272.026)" x="23.2591" y="272.026">-2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 179.606)" x="23.2591" y="179.606">0</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 87.1852)" x="23.2591" y="87.1852">2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with Runge-Kutta 4 (31 points)</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,34.5529 47.6277,35.8585
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.6277,35.8585 65.9962,40.3427
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   65.9962,40.3427 84.3647,50.1974
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   84.3647,50.1974 102.733,70.0577
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   102.733,70.0577 121.102,107.08
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" po

# %%
t = linspace(0, 10, 101);
sol = rungekutta4(f_pend, y0, t);

# %%
plot(t, sol[:, 1], xaxis="Time t", title="Solution to the pendulum ODE with Runge-Kutta 4 (101 points)", label="\\theta (t)")
plot!(t, sol[:, 2], label="\\omega (t)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,355.137 29.2591,36.4246
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.47,355.137 139.47,36.4246
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.681,355.137 249.681,36.4246
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.893,355.137 359.893,36.4246
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.104,355.137 470.104,36.4246
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,359.91 572.049,359.91
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,269.806 572.049,269.806
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,179.701 572.049,179.701
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,89.5968 572.049,89.5968
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,355.137
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.47,360.065 139.47,355.137
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.681,360.065 249.681,355.137
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.893,360.065 359.893,355.137
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.104,360.065 470.104,355.137
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,359.91 37.525,359.91
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,269.806 37.525,269.806
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,179.701 37.525,179.701
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,89.5968 37.525,89.5968
#   "/>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 373.865)" x="29.2591" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.47, 373.865)" x="139.47" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.681, 373.865)" x="249.681" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.893, 373.865)" x="359.893" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.104, 373.865)" x="470.104" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 364.41)" x="23.2591" y="364.41">-4</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 274.306)" x="23.2591" y="274.306">-2</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 184.201)" x="23.2591" y="184.201">0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 94.0968)" x="23.2591" y="94.0968">2</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with Runge-Kutta 4 (101 points)</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip8502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,42.6708 34.7697,42.7827
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   34.7697,42.7827 40.2803,43.1205
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.2803,43.1205 45.7908,43.6951
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7908,43.6951 51.3014,44.529
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.3014,44.529 56.8119,45.6567
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="

# %% [markdown]
# ----
# ## Comparisons

# %%
methods = [rungekutta1, rungekutta2, rungekutta4]
markers = [:o, :s, :>]
# Out:
# 3-element Array{Symbol,1}:
#  :o
#  :s
#  :>

# %%
function test_1(n=101)
    t = linspace(0, 10, n)
    tspan = (0.0, 10.0)
    t1, sol = odeint_1(pend, y0, tspan)
    plt = plot(t1, sol[:, 1], marker=:d, xaxis="Time t", title="Solution to the pendulum ODE with ($n points)", label="odeint")
    for (method, m) in zip(methods, markers)
        sol = method(f_pend, y0, t)
        plot!(t, sol[:, 1], marker=m, label=string(method))
    end
    display(plt)
end
# Out:
# test_1 (generic function with 2 methods)

# %%
test_1(10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8700)" points="
# 35.8488,360.065 580.315,360.065 580.315,31.4961 35.8488,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="31" width="545" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.2582,355.137 51.2582,36.4246
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   179.67,355.137 179.67,36.4246
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   308.082,355.137 308.082,36.4246
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   436.494,355.137 436.494,36.4246
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.906,355.137 564.906,36.4246
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,329.938 572.148,329.938
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,278.382 572.148,278.382
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,226.826 572.148,226.826
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,175.27 572.148,175.27
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,123.714 572.148,123.714
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,72.1577 572.148,72.1577
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 35.8488,31.4961
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.2582,360.065 51.2582,355.137
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   179.67,360.065 179.67,355.137
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   308.082,360.065 308.082,355.137
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   436.494,360.065 436.494,355.137
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.906,360.065 564.906,355.137
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,329.938 44.0158,329.938
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,278.382 44.0158,278.382
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,226.826 44.0158,226.826
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,175.27 44.0158,175.27
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,123.714 44.0158,123.714
#   "/>
# <polyline clip-path="url(#clip8700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,72.1577 44.0158,72.1577
#   "/>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 51.2582, 373.865)" x="51.2582" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 179.67, 373.865)" x="179.67" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 308.082, 373.865)" x="308.082" y="373.865">5.0</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 436.494, 373.865)" x="436.494" y="373.865">7.5</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.906, 373.865)" x="564.906" y="373.865">10.0</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 334.438)" x="29.8488" y="334.438">-25</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 282.882)" x="29.8488" y="282.882">-20</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 231.326)" x="29.8488" y="231.326">-15</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 179.77)" x="29.8488" y="179.77">-10</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 128.214)" x="29.8488" y="128.214">-5</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 76.6577)" x="29.8488" y="76.6577">0</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 308.082, 18)" x="308.082" y="18">Solution to the pendulum ODE with (10 points)</text>
# </g>
# <g clip-path="url(#clip8700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 308.082, 397.6)" x="308.082" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip8702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.2582,40.7952 51.3611,40.7952
#   "/>
# <polyline clip-path="url(#clip8702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.3611,40.7952 52.3897,40.7964
#   "/>
# <polyline clip-p

# %%
test_1(20)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8900)" points="
# 35.8488,360.065 580.315,360.065 580.315,31.4961 35.8488,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="31" width="545" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.2582,355.137 51.2582,36.4246
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   179.67,355.137 179.67,36.4246
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   308.082,355.137 308.082,36.4246
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   436.494,355.137 436.494,36.4246
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.906,355.137 564.906,36.4246
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,355.862 572.148,355.862
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,260.507 572.148,260.507
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,165.153 572.148,165.153
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.0158,69.7981 572.148,69.7981
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 35.8488,31.4961
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.2582,360.065 51.2582,355.137
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   179.67,360.065 179.67,355.137
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   308.082,360.065 308.082,355.137
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   436.494,360.065 436.494,355.137
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.906,360.065 564.906,355.137
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,355.862 44.0158,355.862
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,260.507 44.0158,260.507
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,165.153 44.0158,165.153
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,69.7981 44.0158,69.7981
#   "/>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 51.2582, 373.865)" x="51.2582" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 179.67, 373.865)" x="179.67" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 308.082, 373.865)" x="308.082" y="373.865">5.0</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 436.494, 373.865)" x="436.494" y="373.865">7.5</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.906, 373.865)" x="564.906" y="373.865">10.0</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 360.362)" x="29.8488" y="360.362">-30</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 265.007)" x="29.8488" y="265.007">-20</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 169.653)" x="29.8488" y="169.653">-10</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 74.2981)" x="29.8488" y="74.2981">0</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 308.082, 18)" x="308.082" y="18">Solution to the pendulum ODE with (20 points)</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 308.082, 397.6)" x="308.082" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.2582,40.7952 51.3611,40.7952
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.3611,40.7952 52.3897,40.7963
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.3897,40.7963 55.436,40.8109
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.436,40.8109 60.4592,40.8714
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.4592,40.8714 66.9997,41.0217
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.9997,41.0217 75.5392,41.3554
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   75.5392,41.3554 86.0263,42.0349
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   86.0263,42.0349 98.549,43.4051
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   98.549,43.4051 112.737,46.1231
#   "/>
# <polyline clip-path="url(#clip8902)" s

# %%
test_1(100)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9100)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.8551,355.137 44.8551,36.4246
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   174.821,355.137 174.821,36.4246
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,355.137 304.787,36.4246
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   434.753,355.137 434.753,36.4246
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.719,355.137 564.719,36.4246
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,320.647 572.049,320.647
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,265.138 572.049,265.138
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,209.63 572.049,209.63
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,154.121 572.049,154.121
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,98.6126 572.049,98.6126
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,43.1039 572.049,43.1039
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.8551,360.065 44.8551,355.137
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   174.821,360.065 174.821,355.137
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,360.065 304.787,355.137
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   434.753,360.065 434.753,355.137
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.719,360.065 564.719,355.137
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,320.647 37.525,320.647
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,265.138 37.525,265.138
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,209.63 37.525,209.63
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,154.121 37.525,154.121
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,98.6126 37.525,98.6126
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,43.1039 37.525,43.1039
#   "/>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 44.8551, 373.865)" x="44.8551" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 174.821, 373.865)" x="174.821" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 373.865)" x="304.787" y="373.865">5.0</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 434.753, 373.865)" x="434.753" y="373.865">7.5</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.719, 373.865)" x="564.719" y="373.865">10.0</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 325.147)" x="23.2591" y="325.147">-2</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 269.638)" x="23.2591" y="269.638">-1</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 214.13)" x="23.2591" y="214.13">0</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 158.621)" x="23.2591" y="158.621">1</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 103.113)" x="23.2591" y="103.113">2</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 47.6039)" x="23.2591" y="47.6039">3</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with (100 points)</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip9102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.8551,40.7952 44.9592,40.7953
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.9592,40.7953 46.0003,40.8019
#   "/>
# <polyline clip-path="url(#cl

# %%
test_1(200)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9300)" points="
# 29.2591,360.065 580.315,360.065 580.315,31.4961 29.2591,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="31" width="552" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.8551,355.137 44.8551,36.4246
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   174.821,355.137 174.821,36.4246
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,355.137 304.787,36.4246
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   434.753,355.137 434.753,36.4246
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.719,355.137 564.719,36.4246
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,340.029 572.049,340.029
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,280.676 572.049,280.676
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,221.323 572.049,221.323
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,161.97 572.049,161.97
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,102.617 572.049,102.617
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,43.2638 572.049,43.2638
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,360.065 29.2591,31.4961
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.8551,360.065 44.8551,355.137
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   174.821,360.065 174.821,355.137
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,360.065 304.787,355.137
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   434.753,360.065 434.753,355.137
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.719,360.065 564.719,355.137
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,340.029 37.525,340.029
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,280.676 37.525,280.676
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,221.323 37.525,221.323
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,161.97 37.525,161.97
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,102.617 37.525,102.617
#   "/>
# <polyline clip-path="url(#clip9300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,43.2638 37.525,43.2638
#   "/>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 44.8551, 373.865)" x="44.8551" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 174.821, 373.865)" x="174.821" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 373.865)" x="304.787" y="373.865">5.0</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 434.753, 373.865)" x="434.753" y="373.865">7.5</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.719, 373.865)" x="564.719" y="373.865">10.0</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 344.529)" x="23.2591" y="344.529">-2</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 285.176)" x="23.2591" y="285.176">-1</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 225.823)" x="23.2591" y="225.823">0</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 166.47)" x="23.2591" y="166.47">1</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 107.117)" x="23.2591" y="107.117">2</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 47.7638)" x="23.2591" y="47.7638">3</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 304.787, 18)" x="304.787" y="18">Solution to the pendulum ODE with (200 points)</text>
# </g>
# <g clip-path="url(#clip9300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 304.787, 397.6)" x="304.787" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip9302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.8551,40.7952 44.9592,40.7953
#   "/>
# <polyline clip-path="url(#clip9302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.9592,40.7953 46.0003,40.8024
#   "/>
# <polyline clip-path="url(#cl

# %% [markdown]
# ## Comparisons on another integration problem

# %% [markdown]
# Consider the following ODE on $t\in[0, 1]$:
# $$
# \begin{cases}
#  y'''(t) = 12 y(t)^{4/5} + \cos(y'(t))^3 - \sin(y''(t)) \\
#  y(0) = 0, y'(0) = 1, y''(0) = 0.1
# \end{cases}
# $$
#
# It can be written in a vectorial form like the first one:

# %%
y0 = [0; 1; 0.1]
# Out:
# 3-element Array{Float64,1}:
#  0.0
#  1.0
#  0.1

# %%
function f(y, t)
    return [y[2], y[3], 12 * y[1]^(4/5) + cos(y[2])^3 - sin(y[3])]
end
# Out:
# f (generic function with 1 method)

# %%
function f_2(t, y, dy)
    dy[1] = y[2]
    dy[2] = y[3]
    dy[3] = 12 * y[1]^(4/5) + cos(y[2])^3 - sin(y[3])
end
# Out:
# f_2 (generic function with 1 method)

# %%
function test_2(n=101)
    t = linspace(0, 1, n)
    tspan = (0.0, 1.0)
    t1, sol = odeint_1(f_2, y0, tspan)
    plt = plot(t1, sol[:, 1], marker=:d, xaxis="Time t", title="Solution to an ODE with ($n points)", label="odeint")
    for (method, m) in zip(methods, markers)
        sol = method(f, y0, t)
        plot!(t, sol[:, 1], marker=m, label=string(method))
    end
    display(plt)
end
# Out:
# test_2 (generic function with 2 methods)

# %%
test_2(10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9500)" points="
# 32.2221,360.065 580.315,360.065 580.315,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="31" width="549" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.7342,355.137 47.7342,36.4246
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   177.001,355.137 177.001,36.4246
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   306.269,355.137 306.269,36.4246
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   435.536,355.137 435.536,36.4246
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.803,355.137 564.803,36.4246
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,350.766 572.094,350.766
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,257.529 572.094,257.529
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,164.291 572.094,164.291
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,71.0537 572.094,71.0537
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,360.065 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.7342,360.065 47.7342,355.137
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   177.001,360.065 177.001,355.137
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   306.269,360.065 306.269,355.137
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   435.536,360.065 435.536,355.137
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.803,360.065 564.803,355.137
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,350.766 40.4435,350.766
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,257.529 40.4435,257.529
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,164.291 40.4435,164.291
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,71.0537 40.4435,71.0537
#   "/>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 47.7342, 373.865)" x="47.7342" y="373.865">0.00</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 177.001, 373.865)" x="177.001" y="373.865">0.25</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 306.269, 373.865)" x="306.269" y="373.865">0.50</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 435.536, 373.865)" x="435.536" y="373.865">0.75</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.803, 373.865)" x="564.803" y="373.865">1.00</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 355.266)" x="26.2221" y="355.266">0.0</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 262.029)" x="26.2221" y="262.029">0.5</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 168.791)" x="26.2221" y="168.791">1.0</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 75.5537)" x="26.2221" y="75.5537">1.5</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 306.269, 18)" x="306.269" y="18">Solution to an ODE with (10 points)</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 306.269, 397.6)" x="306.269" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.7342,350.766 48.4614,350.504
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.4614,350.504 49.6796,350.065
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.6796,350.065 52.4211,349.075
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4211,349.075 57.6828,347.175
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.6828,347.175 66.8518,343.858
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.8518,343.858 81.7934,338.439
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   81.7934,338.439 105.028,329.961
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   105.028,329.961 139.545,317.194
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.545,317.194 188.585,298.454
#   "/>
# <polyline clip-path="url(#clip95

# %%
test_2(50)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9700)" points="
# 32.2221,360.065 580.315,360.065 580.315,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="31" width="549" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.7342,355.137 47.7342,36.4246
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   177.001,355.137 177.001,36.4246
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   306.269,355.137 306.269,36.4246
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   435.536,355.137 435.536,36.4246
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.803,355.137 564.803,36.4246
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,350.766 572.094,350.766
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,257.529 572.094,257.529
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,164.291 572.094,164.291
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,71.0537 572.094,71.0537
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,360.065 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.7342,360.065 47.7342,355.137
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   177.001,360.065 177.001,355.137
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   306.269,360.065 306.269,355.137
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   435.536,360.065 435.536,355.137
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.803,360.065 564.803,355.137
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,350.766 40.4435,350.766
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,257.529 40.4435,257.529
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,164.291 40.4435,164.291
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,71.0537 40.4435,71.0537
#   "/>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 47.7342, 373.865)" x="47.7342" y="373.865">0.00</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 177.001, 373.865)" x="177.001" y="373.865">0.25</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 306.269, 373.865)" x="306.269" y="373.865">0.50</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 435.536, 373.865)" x="435.536" y="373.865">0.75</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.803, 373.865)" x="564.803" y="373.865">1.00</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 355.266)" x="26.2221" y="355.266">0.0</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 262.029)" x="26.2221" y="262.029">0.5</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 168.791)" x="26.2221" y="168.791">1.0</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 75.5537)" x="26.2221" y="75.5537">1.5</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 306.269, 18)" x="306.269" y="18">Solution to an ODE with (50 points)</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 306.269, 397.6)" x="306.269" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.7342,350.766 48.4614,350.504
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.4614,350.504 49.6796,350.065
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.6796,350.065 52.4211,349.075
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4211,349.075 57.6828,347.175
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.6828,347.175 66.8518,343.858
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.8518,343.858 81.7934,338.439
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   81.7934,338.439 105.028,329.961
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   105.028,329.961 139.545,317.194
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.545,317.194 188.585,298.454
#   "/>
# <polyline clip-path="url(#clip97

# %% [markdown]
# Consider the following ODE on $t\in[0, 3]$:
# $$
# \begin{cases}
#  y''''(t) = y(t)^{-5/3} \\
#  y(0) = 10, y'(0) = -3, y''(0) = 1, y'''(0) = 1
# \end{cases}
# $$
#
# It can be written in a vectorial form like the first one:

# %%
y0 = [10.0, -3.0, 1.0, 1.0]
# Out:
# 4-element Array{Float64,1}:
#  10.0
#  -3.0
#   1.0
#   1.0

# %%
function f(y, t)
    return [y[2], y[3], y[4], y[1]^(-5/3)]
end
# Out:
# f (generic function with 1 method)

# %%
function f_2(t, y, dy)
    dy[1] = y[2]
    dy[2] = y[3]
    dy[3] = y[4]
    dy[4] = y[1]^(-5/3)
end
# Out:
# f_2 (generic function with 1 method)

# %%
function test_3(n=101)
    t = linspace(0, 1, n)
    tspan = (0.0, 1.0)
    t1, sol = odeint_1(f_2, y0, tspan)
    plt = plot(t1, sol[:, 1], marker=:d, xaxis="Time t", title="Solution to an ODE with ($n points)", label="odeint")
    for (method, m) in zip(methods, markers)
        sol = method(f, y0, t)
        plot!(t, sol[:, 1], marker=m, label=string(method))
    end
    display(plt)
end
# Out:
# test_3 (generic function with 2 methods)

# %%
test_3(10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0300)" points="
# 38.8117,360.065 580.315,360.065 580.315,31.4961 38.8117,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="38" y="31" width="543" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.1373,355.137 54.1373,36.4246
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   181.85,355.137 181.85,36.4246
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.563,355.137 309.563,36.4246
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   437.276,355.137 437.276,36.4246
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.989,355.137 564.989,36.4246
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,358.403 572.192,358.403
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,294.881 572.192,294.881
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,231.36 572.192,231.36
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,167.838 572.192,167.838
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,104.317 572.192,104.317
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,40.7952 572.192,40.7952
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,360.065 38.8117,31.4961
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.1373,360.065 54.1373,355.137
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   181.85,360.065 181.85,355.137
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.563,360.065 309.563,355.137
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   437.276,360.065 437.276,355.137
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.989,360.065 564.989,355.137
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,358.403 46.9343,358.403
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,294.881 46.9343,294.881
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,231.36 46.9343,231.36
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,167.838 46.9343,167.838
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,104.317 46.9343,104.317
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,40.7952 46.9343,40.7952
#   "/>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 54.1373, 373.865)" x="54.1373" y="373.865">0.00</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 181.85, 373.865)" x="181.85" y="373.865">0.25</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.563, 373.865)" x="309.563" y="373.865">0.50</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 437.276, 373.865)" x="437.276" y="373.865">0.75</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.989, 373.865)" x="564.989" y="373.865">1.00</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 362.903)" x="32.8117" y="362.903">7.5</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 299.381)" x="32.8117" y="299.381">8.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 235.86)" x="32.8117" y="235.86">8.5</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 172.338)" x="32.8117" y="172.338">9.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 108.817)" x="32.8117" y="108.817">9.5</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 45.2952)" x="32.8117" y="45.2952">10.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 309.563, 18)" x="309.563" y="18">Solution to an ODE with (10 points)</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 309.563, 397.6)" x="309.563" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip0302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.1373,40.7952 111.761,82.9477
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   111.761,82.9477 393.599,259.771
#   "/>
# <polyline clip-pat

# %%
test_3(50)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0500)" points="
# 38.8117,360.065 580.315,360.065 580.315,31.4961 38.8117,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="38" y="31" width="543" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.1373,355.137 54.1373,36.4246
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   181.85,355.137 181.85,36.4246
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.563,355.137 309.563,36.4246
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   437.276,355.137 437.276,36.4246
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.989,355.137 564.989,36.4246
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,304.294 572.192,304.294
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,238.419 572.192,238.419
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,172.545 572.192,172.545
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,106.67 572.192,106.67
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,40.7952 572.192,40.7952
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,360.065 38.8117,31.4961
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.1373,360.065 54.1373,355.137
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   181.85,360.065 181.85,355.137
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.563,360.065 309.563,355.137
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   437.276,360.065 437.276,355.137
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.989,360.065 564.989,355.137
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,304.294 46.9343,304.294
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,238.419 46.9343,238.419
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,172.545 46.9343,172.545
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,106.67 46.9343,106.67
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,40.7952 46.9343,40.7952
#   "/>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 54.1373, 373.865)" x="54.1373" y="373.865">0.00</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 181.85, 373.865)" x="181.85" y="373.865">0.25</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.563, 373.865)" x="309.563" y="373.865">0.50</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 437.276, 373.865)" x="437.276" y="373.865">0.75</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.989, 373.865)" x="564.989" y="373.865">1.00</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 308.794)" x="32.8117" y="308.794">8.0</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 242.919)" x="32.8117" y="242.919">8.5</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 177.045)" x="32.8117" y="177.045">9.0</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 111.17)" x="32.8117" y="111.17">9.5</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 45.2952)" x="32.8117" y="45.2952">10.0</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 309.563, 18)" x="309.563" y="18">Solution to an ODE with (50 points)</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 309.563, 397.6)" x="309.563" y="397.6">Time t</text>
# </g>
# <polyline clip-path="url(#clip0502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.1373,40.7952 111.761,84.5092
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   111.761,84.5092 393.599,267.883
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   393.599,267.883 564.989,348.08
#   "/>
# <polygon clip-path="url(#clip0502)" style="fill:#000000; fill-opacity:1" points="
#   54.1373,35.7952 49.1373,40.7952 54.1373,45.7952 59.1373,40.7952 54.1373,35.7952
#   "/>
# <polygon clip-path="url(#clip0502)" style="fill:#009af9; fill-opacity:1" points="
#   54.1373,36.7952 50.1373,40.7952 54.1373,44.7952 58.1373,40.7952 54.1373,36.7952
#   "/>
# <polygon clip-path="url(#clip0502)" style="fill:#000000; fill-opacity:1" poin
# WARNING: both OrdinaryDiffEq and StochasticDiffEq export "NLSOLVEJL_SETUP"; uses of it in module DifferentialEquations must be qualified
# search: end endof endswith ENDIAN_BOM send append! backend backends backend_name

# %% [markdown]
# Our hand-written Runge-Kutta method of order 4 seems to be as efficient as the `odeint` method from `scipy`... and that's because `odeint` basically uses a Runge-Kutta method of order 4 (with smart variants).

# %% [markdown]
# ## Small benchmark
# We can also compare their speed:

# %%
function benchmark(n=101)
    t = linspace(0, 1, n)
    tspan = (0.0, 1.0)

    print("Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...\n")
    @time t1, sol = odeint_1(f_2, y0, tspan)
    for method in methods
        print("Time of solving an ODE with the $method method for $n points ...\n")
        @time sol = method(f, y0, t)
    end
end

for n in [20, 100, 1000]
    print("\nFor $n points...\n")
    benchmark(n)
end
# Out:
# For 20 points...
# Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...
#   0.000516 seconds (634 allocations: 44.906 KiB)
# Time of solving an ODE with the rungekutta1 method for 20 points ...
#   0.000022 seconds (231 allocations: 13.266 KiB)
# Time of solving an ODE with the rungekutta2 method for 20 points ...
#   0.000032 seconds (421 allocations: 25.141 KiB)
# Time of solving an ODE with the rungekutta4 method for 20 points ...
#   0.000066 seconds (877 allocations: 57.203 KiB)
#
# For 100 points...
# Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...
#   0.000435 seconds (634 allocations: 44.906 KiB)
# Time of solving an ODE with the rungekutta1 method for 100 points ...
#   0.000090 seconds (1.19 k allocations: 68.297 KiB)
# Time of solving an ODE with the rungekutta2 method for 100 points ...
#   0.000139 seconds (2.18 k allocations: 130.172 KiB)
# Time of solving an ODE with the rungekutta4 method for 100 points ...
#   0.000317 seconds (4.56 k allocations: 297.234 KiB)
#
# For 1000 points...
# Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...
#   0.000468 seconds (634 allocations: 44.906 KiB)
# Time of solving an ODE with the rungekutta1 method for 1000 points ...
#   0.000748 seconds (13.46 k allocations: 709.891 KiB)
# Time of solving an ODE with the rungekutta2 method for 1000 points ...
#   0.001345 seconds (23.93 k allocations: 1.310 MiB)
# Time of solving an ODE with the rungekutta4 method for 1000 points ...
#   0.012061 seconds (48.89 k allocations: 2.972 MiB, 79.27% gc time)

# %% [markdown]
# Using [`BenchmarkTools.jl`](https://github.com/JuliaCI/BenchmarkTools.jl) is also interesting as it is more precise than the builtin `@time` benchmark macro.

# %%
using BenchmarkTools, Compat

# %%
function benchmark(n=101)
    t = linspace(0, 1, n)
    tspan = (0.0, 1.0)

    print("Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...\n")
    @btime t1, sol = $odeint_1($f_2, $y0, $tspan)
    for method in methods
        print("Time of solving an ODE with the $method method for $n points ...\n")
        @btime sol = $method($f, $y0, $t)
    end
end

for n in [20, 100, 1000]
    print("\nFor $n points...\n")
    benchmark(n)
end
# Out:
# For 20 points...
# Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...
#   164.017 μs (635 allocations: 44.94 KiB)
# Time of solving an ODE with the rungekutta1 method for 20 points ...
#   5.765 μs (232 allocations: 13.33 KiB)
# Time of solving an ODE with the rungekutta2 method for 20 points ...
#   10.680 μs (422 allocations: 25.20 KiB)
# Time of solving an ODE with the rungekutta4 method for 20 points ...
#   23.242 μs (878 allocations: 57.27 KiB)
#
# For 100 points...
# Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...
#   164.906 μs (635 allocations: 44.94 KiB)
# Time of solving an ODE with the rungekutta1 method for 100 points ...
#   29.808 μs (1192 allocations: 68.36 KiB)
# Time of solving an ODE with the rungekutta2 method for 100 points ...
#   57.445 μs (2182 allocations: 130.23 KiB)
# Time of solving an ODE with the rungekutta4 method for 100 points ...
#   117.637 μs (4558 allocations: 297.30 KiB)
#
# For 1000 points...
# Time of solving an ODE with the 'solve' method from 'DifferentialEquations' ...
#   165.346 μs (635 allocations: 44.94 KiB)
# Time of solving an ODE with the rungekutta1 method for 1000 points ...
#   296.730 μs (13458 allocations: 709.95 KiB)
# Time of solving an ODE with the rungekutta2 method for 1000 points ...
#   580.526 μs (23936 allocations: 1.31 MiB)
# Time of solving an ODE with the rungekutta4 method for 1000 points ...
#   1.233 ms (48888 allocations: 2.97 MiB)

# %% [markdown]
# - The order 1 method is simpler and so faster than the order 2, which itself is simpler and faster than the order 4 method.
# - And we can check that the `DifferentialEquations` implementation is much faster than our manual implentations!

# %% [markdown]
# ## Conclusion
#
# > *That's it for today, folks!* See my other notebooks, [available on GitHub](https://github.com/Naereen/notebooks/).

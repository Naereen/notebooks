# %% [markdown]
# # Brain storming - app for automatic inclusive writing

# %%
from pprint import pprint
from tqdm.notebook import tqdm

# %% [markdown]
# ## Premières expériences
#
# On va récupérer une liste de mots depuis le dictionnaire `/usr/share/dict/french` :

# %%
mots = []
with open("/usr/share/dict/french", "r") as f:
    mots = [ mot.replace("\n", "") for mot in f.readlines() ]
print(f"Il y a {len(mots)} mots différents dans ce dictionnaire.")
# Out:
# Il y a 139719 mots différents dans ce dictionnaire.

# %% [markdown]
# On peut regarder les premiers mots :

# %%
pprint(mots[:15])
# Out:
# ['a',
#  'à',
#  'abaissa',
#  'abaissaient',
#  'abaissais',
#  'abaissait',
#  'abaissant',
#  'abaisse',
#  'abaissé',
#  'abaissée',
#  'abaissées',
#  'abaissement',
#  'abaissements',
#  'abaissent',
#  'abaisser']

# %% [markdown]
# On voit qu'il n'y a pas les majuscules en début de mot, mais qu'il y a les conjugaisons.

# %% [markdown]
# On aura souvent besoin de tester si un mot est présent, et c'est environ 50 fois plus rapide de tester l'appartenance à un `set` qu'à une `list` en Python :

# %%
set_mots = frozenset(mots)  # pour des tests 'mot in mots' plus rapides

# %%
# %timeit "vociférée" in mots
# %timeit "vociférée" in set_mots
# Out:
# 1.74 ms ± 247 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 31.1 ns ± 0.5 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# On définit une constante représentant le séparateur `·`:

# %%
SEP = "-"
SEP = "."
SEP = "·"

# %% [markdown]
# On va maintenir un dictionnaire qui stockera les alternatives que l'on peut proposer pour chaque mot :

# %%
import collections
alternatives = collections.defaultdict(lambda: set())

# %%
def del_alternatives(mots):
    """ Supprime des mots du dictionnaire alternatives, sans exception si le mot n'est pas encore présent."""
    for mot in mots:
        if mot in alternatives:
            del alternatives[mot]

# %% [markdown]
# On va aussi garder une liste des mots inclusifs singuliers et pluriels créés au fur et à mesure.
# Cela permet d'afficher, à chaque traitement automatique, combien de nouveaux mots ont été créés.

# %%
mots_inclusifs_singuliers = []
mots_inclusifs_pluriels = []

# %% [markdown]
# ### Ajouter mot·e si `mot` et `mot`-e sont présents

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    mot_feminin = f"{mot}e"
    if mot_feminin in set_mots:
        mot_inclusif = f"{mot}{SEP}e"
        print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
        nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
        alternatives[mot] |= {mot_inclusif}
        alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# abaissé              / abaissée             -> abaissé·e
# abandonné            / abandonnée           -> abandonné·e
# abasourdi            / abasourdie           -> abasourdi·e
# abasourdissant       / abasourdissante      -> abasourdissant·e
# abattu               / abattue              -> abattu·e
# abdiqué              / abdiquée             -> abdiqué·e
# abdominal            / abdominale           -> abdominal·e
# aberrant             / aberrante            -> aberrant·e
# abîmé                / abîmée               -> abîmé·e
# abject               / abjecte              -> abject·e
# aboli                / abolie               -> aboli·e
# abondant             / abondante            -> abondant·e
# abonné               / abonnée              -> abonné·e
# abord                / aborde               -> abord·e
# abordé               / abordée              -> abordé·e
# abouti               / aboutie              -> abouti·e
# aboyé                / aboyée               -> aboyé·e
# abracadabrant        / abracadabrante       -> abracadabrant·e
# abrégé               / abrégée              -> abrégé·e
# abrité               / abritée              -> abrité·e
# abrogé               / abrogée              -> abrogé·e
# abrupt               / abrupte              -> abrupt·e
# abruti               / abrutie              -> abruti·e
# abrutissant          / abrutissante         -> abrutissant·e
# absent               / absente              -> absent·e
# absenté              / absentée             -> absenté·e
# absolu               / absolue              -> absolu·e
# absorbant            / absorbante           -> absorbant·e
# absorbé              / absorbée             -> absorbé·e
# abstenu              / abstenue             -> abstenu·e
# abstinent            / abstinente           -> abstinent·e
# abstrait             / abstraite            -> abstrait·e
# abus                 / abuse                -> abus·e
# abusé                / abusée               -> abusé·e
# accablant            / accablante           -> accablant·e
# accablé              / accablée             -> accablé·e
# accaparé             / accaparée            -> accaparé·e
# accéléré             / accélérée            -> accéléré·e
# accentué             / accentuée            -> accentué·e
# accepté              / acceptée             -> accepté·e
# accidenté            / accidentée           -> accidenté·e
# acclamé              / acclamée             -> acclamé·e
# acclimaté            / acclimatée           -> acclimaté·e
# accolé               / accolée              -> accolé·e
# accommodant          / accommodante         -> accommodant·e
# accommodé            / accommodée           -> accommodé·e
# accompagné           / accompagnée          -> accompagné·e
# accompli             / accomplie            -> accompli·e
# accord               / accorde              -> accord·e
# accordé              / accordée             -> accordé·e
# accosté              / accostée             -> accosté·e
# accouché             / accouchée            -> accouché·e
# accoudé              / accoudée             -> accoudé·e
# accouplé             / accouplée            -> accouplé·e
# accouru              / accourue             -> accouru·e
# accoutumé            / accoutumée           -> accoutumé·e
# accrédité            / accréditée           -> accrédité·e
# accrochant           / accrochante          -> accrochant·e
# accroché             / accrochée            -> accroché·e
# accru                / accrue               -> accru·e
# accueillant          / accueillante         -> accueillant·e
# accueilli            / accueillie           -> accueilli·e
# acculé               / acculée              -> acculé·e
# accumulé             / accumulée            -> accumulé·e
# accusé               / accusée              -> accusé·e
# acéré                / acérée               -> acéré·e
# achalandé            / achalandée           -> achalandé·e
# acharné              / acharnée             -> acharné·e
# acheminé             / acheminée            -> acheminé·e
# acheté               / achetée              -> acheté·e
# achevé               / achevée              -> achevé·e
# acidulé              / acidulée             -> acidulé·e
# acquis               / acquise              -> acquis·e
# acquitté             / acquittée            -> acquitté·e
# actionné             / actionnée            -> actionné·e
# activé               / activée              -> activé·e
# actualisé            / actualisée           -> actualisé·e
# adapté               / adaptée              -> adapté·e
# additionné           / additionnée          -> additionné·e
# adéquat              / adéquate             -> adéquat·e
# adhérent             / adhérente            -> adhérent·e
# adjacent             / adjacente            -> adjacent·e
# adjectival           / adjectivale          -> adjectival·e
# adjoint              / adjointe             -> adjoint·e
# adjugé               / adjugée              -> adjugé·e
# adjuré               / adjurée              -> adjuré·e
# adjuvant             / adjuvante            -> adjuvant·e
# administré           / administrée          -> administré·e
# admiré               / admirée              -> admiré·e
# admis                / admise               -> admis·e
# adolescent           / adolescente          -> adolescent·e
# adonné               / adonnée              -> adonné·e
# adopté               / adoptée              -> adopté·e
# adoré                / adorée               -> adoré·e
# adossé               / adossée              -> adossé·e
# adouci               / adoucie              -> adouci·e
# adoucissant          / adoucissante         -> adoucissant·e
# adressé              / adressée             -> adressé·e
# adroit               / adroite              -> adroit·e
# adultérin            / adultérine           -> adultérin·e
# advenu               / advenue              -> advenu·e
# adverbial            / adverbiale           -> adverbial·e
# aéré                 / aérée                -> aéré·e
# aéronaval            / aéronavale           -> aéronaval·e
# aéroporté            / aéroportée           -> aéroporté·e
# aérospatial          / aérospatiale         -> aérospatial·e
# affacturé            / affacturée           -> affacturé·e
# affaibli             / affaiblie            -> affaibli·e
# affairé              / affairée             -> affairé·e
# affaissé             / affaissée            -> affaissé·e
# affamé               / affamée              -> affamé·e
# affecté              / affectée             -> affecté·e
# affectionné          / affectionnée         -> affectionné·e
# afférent             / afférente            -> afférent·e
# affermi              / affermie             -> affermi·e
# affiché              / affichée             -> affiché·e
# affilié              / affiliée             -> affilié·e
# affiné               / affinée              -> affiné·e
# affirmé              / affirmée             -> affirmé·e
# affleuré             / affleurée            -> affleuré·e
# affligé              / affligée             -> affligé·e
# affligeant           / affligeante          -> affligeant·e
# affluent             / affluente            -> affluent·e
# affolant             / affolante            -> affolant·e
# affolé               / affolée              -> affolé·e
# affranchi            / affranchie           -> affranchi·e
# affrété              / affrétée             -> affrété·e
# affront              / affronte             -> affront·e
# affronté             / affrontée            -> affronté·e
# affublé              / affublée             -> affublé·e
# affûté               / affûtée              -> affûté·e
# africain             / africaine            -> africain·e
# agaçant              / agaçante             -> agaçant·e
# agacé                / agacée               -> agacé·e
# âgé                  / âgée                 -> âgé·e
# agencé               / agencée              -> agencé·e
# agenouillé           / agenouillée          -> agenouillé·e
# aggloméré            / agglomérée           -> aggloméré·e
# agglutiné            / agglutinée           -> agglutiné·e
# aggravant            / aggravante           -> aggravant·e
# aggravé              / aggravée             -> aggravé·e
# agissant             / agissante            -> agissant·e
# agit                 / agite                -> agit·e
# agité                / agitée               -> agité·e
# agonisant            / agonisante           -> agonisant·e
# agrafé               / agrafée              -> agrafé·e
# agrandi              / agrandie             -> agrandi·e
# agréé                / agréée               -> agréé·e
# agrégé               / agrégée              -> agrégé·e
# agrément             / agrémente            -> agrément·e
# agrémenté            / agrémentée           -> agrémenté·e
# agressé              / agressée             -> agressé·e
# agrippé              / agrippée             -> agrippé·e
# aguerri              / aguerrie             -> aguerri·e
# ahuri                / ahurie               -> ahuri·e
# ahurissant           / ahurissante          -> ahurissant·e
# ai                   / aie                  -> ai·e
# aidé                 / aidée                -> aidé·e
# aïeul                / aïeule               -> aïeul·e
# aigri                / aigrie               -> aigri·e
# aiguillé             / aiguillée            -> aiguillé·e
# aiguillonné          / aiguillonnée         -> aiguillonné·e
# aiguisé              / aiguisée             -> aiguisé·e
# ail                  / aile                 -> ail·e
# ailé                 / ailée                -> ailé·e
# aimant               / aimante              -> aimant·e
# aimé                 / aimée                -> aimé·e
# aîné                 / aînée                -> aîné·e
# air                  / aire                 -> air·e
# aisé                 / aisée                -> aisé·e
# ajouré               / ajourée              -> ajouré·e
# ajourné              / ajournée             -> ajourné·e
# ajout                / ajoute               -> ajout·e
# ajouté               / ajoutée              -> ajouté·e
# ajusté               / ajustée              -> ajusté·e
# alambiqué            / alambiquée           -> alambiqué·e
# alangui              / alanguie             -> alangui·e
# alarmant             / alarmante            -> alarmant·e
# alarmé               / alarmée              -> alarmé·e
# albanais             / albanaise            -> albanais·e
# alcalin              / alcaline             -> alcalin·e
# alcoolisé            / alcoolisée           -> alcoolisé·e
# alerté               / alertée              -> alerté·e
# alezan               / alezane              -> alezan·e
# aliénant             / aliénante            -> aliénant·e
# aliéné               / aliénée              -> aliéné·e
# aligné               / alignée              -> aligné·e
# aliment              / alimente             -> aliment·e
# alimenté             / alimentée            -> alimenté·e
# alité                / alitée               -> alité·e
# allait               / allaite              -> allait·e
# allaité              / allaitée             -> allaité·e
# allant               / allante              -> allant·e
# allé                 / allée                -> allé·e
# alléchant            / alléchante           -> alléchant·e
# alléché              / alléchée             -> alléché·e
# allégé               / allégée              -> allégé·e
# allégué              / alléguée             -> allégué·e
# allemand             / allemande            -> allemand·e
# allié                / alliée               -> allié·e
# allongé              / allongée             -> allongé·e
# alloué               / allouée              -> alloué·e
# allumé               / allumée              -> allumé·e
# alourdi              / alourdie             -> alourdi·e
# alpin                / alpine               -> alpin·e
# altéré               / altérée              -> altéré·e
# alterné              / alternée             -> alterné·e
# amadoué              / amadouée             -> amadoué·e
# amaigri              / amaigrie             -> amaigri·e
# amaigrissant         / amaigrissante        -> amaigrissant·e
# amalgamé             / amalgamée            -> amalgamé·e
# amarré               / amarrée              -> amarré·e
# amassé               / amassée              -> amassé·e
# ambiant              / ambiante             -> ambiant·e
# ambitionné           / ambitionnée          -> ambitionné·e
# ambré                / ambrée               -> ambré·e
# ambulant             / ambulante            -> ambulant·e
# amélioré             / améliorée            -> amélioré·e
# aménagé              / aménagée             -> aménagé·e
# amendé               / amendée              -> amendé·e
# amené                / amenée               -> amené·e
# amenuisé             / amenuisée            -> amenuisé·e
# américain            / américaine           -> américain·e
# américanisé          / américanisée         -> américanisé·e
# ameuté               / ameutée              -> ameuté·e
# ami                  / amie                 -> ami·e
# amical               / amicale              -> amical·e
# amidonné             / amidonnée            -> amidonné·e
# aminci               / amincie              -> aminci·e
# amincissant          / amincissante         -> amincissant·e
# amnistié             / amnistiée            -> amnistié·e
# amoindri             / amoindrie            -> amoindri·e
# amolli               / amollie              -> amolli·e
# amollissant          / amollissante         -> amollissant·e
# amoncelé             / amoncelée            -> amoncelé·e
# amoral               / amorale              -> amoral·e
# amorcé               / amorcée              -> amorcé·e
# amorti               / amortie              -> amorti·e
# amplifié             / amplifiée            -> amplifié·e
# ampoulé              / ampoulée             -> ampoulé·e
# amputé               / amputée              -> amputé·e
# amusant              / amusante             -> amusant·e
# amusé                / amusée               -> amusé·e
# analysé              / analysée             -> analysé·e
# ancestral            / ancestrale           -> ancestral·e
# ancré                / ancrée               -> ancré·e
# anéanti              / anéantie             -> anéanti·e
# anémié               / anémiée              -> anémié·e
# anesthésié           / anesthésiée          -> anesthésié·e
# anglais              / anglaise             -> anglais·e
# anglican             / anglicane            -> anglican·e
# anglicisé            / anglicisée           -> anglicisé·e
# angoissant           / angoissante          -> angoissant·e
# angoissé             / angoissée            -> angoissé·e
# animal               / animale              -> animal·e
# animé                / animée               -> animé·e
# ankylosé             / ankylosée            -> ankylosé·e
# annexé               / annexée              -> annexé·e
# annihilé             / annihilée            -> annihilé·e
# annoncé              / annoncée             -> annoncé·e
# annoté               / annotée              -> annoté·e
# annulé               / annulée              -> annulé·e
# anodin               / anodine              -> anodin·e
# ânonné               / ânonnée              -> ânonné·e
# anormal              / anormale             -> anormal·e
# ans                  / anse                 -> ans·e
# antérieur            / antérieure           -> antérieur·e
# anticipé             / anticipée            -> anticipé·e
# anticlérical         / anticléricale        -> anticlérical·e
# anticoagulant        / anticoagulante       -> anticoagulant·e
# antidaté             / antidatée            -> antidaté·e
# antidérapant         / antidérapante        -> antidérapant·e
# antigouvernemental   / antigouvernementale  -> antigouvernemental·e
# antisocial           / antisociale          -> antisocial·e
# apaisant             / apaisante            -> apaisant·e
# apaisé               / apaisée              -> apaisé·e
# aperçu               / aperçue              -> aperçu·e
# apeuré               / apeurée              -> apeuré·e
# apitoyé              / apitoyée             -> apitoyé·e
# aplani               / aplanie              -> aplani·e
# aplati               / aplatie              -> aplati·e
# appareillé           / appareillée          -> appareillé·e
# apparent             / apparente            -> apparent·e
# apparenté            / apparentée           -> apparenté·e
# apparié              / appariée             -> apparié·e
# appartenu            / appartenue           -> appartenu·e
# apparu               / apparue              -> apparu·e
# appât                / appâte               -> appât·e
# appâté               / appâtée              -> appâté·e
# appauvri             / appauvrie            -> appauvri·e
# appelé               / appelée              -> appelé·e
# appesanti            / appesantie           -> appesanti·e
# appétissant          / appétissante         -> appétissant·e
# applaudi             / applaudie            -> applaudi·e
# appliqué             / appliquée            -> appliqué·e
# appoint              / appointe             -> appoint·e
# appointé             / appointée            -> appointé·e
# apport               / apporte              -> apport·e
# apporté              / apportée             -> apporté·e
# apposé               / apposée              -> apposé·e
# apprécié             / appréciée            -> apprécié·e
# appréhendé           / appréhendée          -> appréhendé·e
# apprenti             / apprentie            -> apprenti·e
# apprêt               / apprête              -> apprêt·e
# apprêté              / apprêtée             -> apprêté·e
# appris               / apprise              -> appris·e
# apprivoisé           / apprivoisée          -> apprivoisé·e
# approchant           / approchante          -> approchant·e
# approché             / approchée            -> approché·e
# approfondi           / approfondie          -> approfondi·e
# approprié            / appropriée           -> approprié·e
# approuvé             / approuvée            -> approuvé·e
# approvisionné        / approvisionnée       -> approvisionné·e
# appui                / appuie               -> appui·e
# appuyé               / appuyée              -> appuyé·e
# apuré                / apurée               -> apuré·e
# arbitré              / arbitrée             -> arbitré·e
# arboré               / arborée              -> arboré·e
# arborescent          / arborescente         -> arborescent·e
# architectural        / architecturale       -> architectural·e
# architecturé         / architecturée        -> architecturé·e
# archivé              / archivée             -> archivé·e
# ardent               / ardente              -> ardent·e
# ardu                 / ardue                -> ardu·e
# argenté              / argentée             -> argenté·e
# argentin             / argentine            -> argentin·e
# argument             / argumente            -> argument·e
# argumenté            / argumentée           -> argumenté·e
# armé                 / armée                -> armé·e
# armorié              / armoriée             -> armorié·e
# aromatisé            / aromatisée           -> aromatisé·e
# arpent               / arpente              -> arpent·e
# arpenté              / arpentée             -> arpenté·e
# arraché              / arrachée             -> arraché·e
# arraisonné           / arraisonnée          -> arraisonné·e
# arrangé              / arrangée             -> arrangé·e
# arrangeant           / arrangeante          -> arrangeant·e
# arréragé             / arréragée            -> arréragé·e
# arrêt                / arrête               -> arrêt·e
# arrêté               / arrêtée              -> arrêté·e
# arriéré              / arriérée             -> arriéré·e
# arrimé               / arrimée              -> arrimé·e
# arrivé               / arrivée              -> arrivé·e
# arrogant             / arrogante            -> arrogant·e
# arrogé               / arrogée              -> arrogé·e
# arrondi              / arrondie             -> arrondi·e
# arrosé               / arrosée              -> arrosé·e
# articulé             / articulée            -> articulé·e
# artisanal            / artisanale           -> artisanal·e
# ascendant            / ascendante           -> ascendant·e
# aseptisé             / aseptisée            -> aseptisé·e
# asexué               / asexuée              -> asexué·e
# asocial              / asociale             -> asocial·e
# aspergé              / aspergée             -> aspergé·e
# asphyxiant           / asphyxiante          -> asphyxiant·e
# asphyxié             / asphyxiée            -> asphyxié·e
# aspirant             / aspirante            -> aspirant·e
# aspiré               / aspirée              -> aspiré·e
# assagi               / assagie              -> assagi·e
# assaillant           / assaillante          -> assaillant·e
# assailli             / assaillie            -> assailli·e
# assaini              / assainie             -> assaini·e
# assaisonné           / assaisonnée          -> assaisonné·e
# assassin             / assassine            -> assassin·e
# assassiné            / assassinée           -> assassiné·e
# asséché              / asséchée             -> asséché·e
# assemblé             / assemblée            -> assemblé·e
# asséné               / assénée              -> asséné·e
# assermenté           / assermentée          -> assermenté·e
# assidu               / assidue              -> assidu·e
# assiégé              / assiégée             -> assiégé·e
# assigné              / assignée             -> assigné·e
# assimilé             / assimilée            -> assimilé·e
# assis                / assise               -> assis·e
# assistant            / assistante           -> assistant·e
# assisté              / assistée             -> assisté·e
# associé              / associée             -> associé·e
# assoiffé             / assoiffée            -> assoiffé·e
# assombri             / assombrie            -> assombri·e
# assommé              / assommée             -> assommé·e
# assorti              / assortie             -> assorti·e
# assoupi              / assoupie             -> assoupi·e
# assoupli             / assouplie            -> assoupli·e
# assourdi             / assourdie            -> assourdi·e
# assourdissant        / assourdissante       -> assourdissant·e
# assouvi              / assouvie             -> assouvi·e
# assujetti            / assujettie           -> assujetti·e
# assujettissant       / assujettissante      -> assujettissant·e
# assumé               / assumée              -> assumé·e
# assuré               / assurée              -> assuré·e
# astral               / astrale              -> astral·e
# astreignant          / astreignante         -> astreignant·e
# astreint             / astreinte            -> astreint·e
# astringent           / astringente          -> astringent·e
# atomisé              / atomisée             -> atomisé·e
# atrophié             / atrophiée            -> atrophié·e
# attablé              / attablée             -> attablé·e
# attachant            / attachante           -> attachant·e
# attaché              / attachée             -> attaché·e
# attaqué              / attaquée             -> attaqué·e
# attardé              / attardée             -> attardé·e
# atteint              / atteinte             -> atteint·e
# attelé               / attelée              -> attelé·e
# attenant             / attenante            -> attenant·e
# attend               / attende              -> attend·e
# attendri             / attendrie            -> attendri·e
# attendrissant        / attendrissante       -> attendrissant·e
# attendu              / attendue             -> attendu·e
# attentionné          / attentionnée         -> attentionné·e
# atténuant            / atténuante           -> atténuant·e
# atténué              / atténuée             -> atténué·e
# atterrant            / atterrante           -> atterrant·e
# atterré              / atterrée             -> atterré·e
# attesté              / attestée             -> attesté·e
# attirant             / attirante            -> attirant·e
# attiré               / attirée              -> attiré·e
# attisé               / attisée              -> attisé·e
# attitré              / attitrée             -> attitré·e
# attrapé              / attrapée             -> attrapé·e
# attrayant            / attrayante           -> attrayant·e
# attribué             / attribuée            -> attribué·e
# attristant           / attristante          -> attristant·e
# attristé             / attristée            -> attristé·e
# attroupé             / attroupée            -> attroupé·e
# aucun                / aucune               -> aucun·e
# auditionné           / auditionnée          -> auditionné·e
# augmenté             / augmentée            -> augmenté·e
# auguré               / augurée              -> auguré·e
# auréolé              / auréolée             -> auréolé·e
# ausculté             / auscultée            -> ausculté·e
# austral              / australe             -> austral·e
# authentifié          / authentifiée         -> authentifié·e
# autocollant          / autocollante         -> autocollant·e
# auto-équilibrant     / auto-équilibrante    -> auto-équilibrant·e
# autofinancé          / autofinancée         -> autofinancé·e
# autogéré             / autogérée            -> autogéré·e
# autoguidé            / autoguidée           -> autoguidé·e
# automatisé           / automatisée          -> automatisé·e
# automnal             / automnale            -> automnal·e
# autonettoyant        / autonettoyante       -> autonettoyant·e
# autopropulsé         / autopropulsée        -> autopropulsé·e
# autorisé             / autorisée            -> autorisé·e
# avachi               / avachie              -> avachi·e
# aval                 / avale                -> aval·e
# avalé                / avalée               -> avalé·e
# avalisé              / avalisée             -> avalisé·e
# avancé               / avancée              -> avancé·e
# avantagé             / avantagée            -> avantagé·e
# avarié               / avariée              -> avarié·e
# avenant              / avenante             -> avenant·e
# aventuré             / aventurée            -> aventuré·e
# avenu                / avenue               -> avenu·e
# avéré                / avérée               -> avéré·e
# averti               / avertie              -> averti·e
# aveuglant            / aveuglante           -> aveuglant·e
# aveuglé              / aveuglée             -> aveuglé·e
# aveuli               / aveulie              -> aveuli·e
# avili                / avilie               -> avili·e
# avilissant           / avilissante          -> avilissant·e
# aviné                / avinée               -> aviné·e
# avis                 / avise                -> avis·e
# avisé                / avisée               -> avisé·e
# avivé                / avivée               -> avivé·e
# avocat               / avocate              -> avocat·e
# avoisinant           / avoisinante          -> avoisinant·e
# avoisiné             / avoisinée            -> avoisiné·e
# avorté               / avortée              -> avorté·e
# avoué                / avouée               -> avoué·e
# axé                  / axée                 -> axé·e
# azoté                / azotée               -> azoté·e
# azuré                / azurée               -> azuré·e
# bâché                / bâchée               -> bâché·e
# bâclé                / bâclée               -> bâclé·e
# badigeonné           / badigeonnée          -> badigeonné·e
# badin                / badine               -> badin·e
# bafoué               / bafouée              -> bafoué·e
# bafouillé            / bafouillée           -> bafouillé·e
# bagarré              / bagarrée             -> bagarré·e
# bagué                / baguée               -> bagué·e
# bai                  / baie                 -> bai·e
# baigné               / baignée              -> baigné·e
# bâillonné            / bâillonnée           -> bâillonné·e
# baissé               / baissée              -> baissé·e
# balafré              / balafrée             -> balafré·e
# balai                / balaie               -> balai·e
# balancé              / balancée             -> balancé·e
# balayé               / balayée              -> balayé·e
# balbutiant           / balbutiante          -> balbutiant·e
# balbutié             / balbutiée            -> balbutié·e
# balisé               / balisée              -> balisé·e
# ballant              / ballante             -> ballant·e
# ballonné             / ballonnée            -> ballonné·e
# ballotté             / ballottée            -> ballotté·e
# banal                / banale               -> banal·e
# banalisé             / banalisée            -> banalisé·e
# bancal               / bancale              -> bancal·e
# banni                / bannie               -> banni·e
# bantou               / bantoue              -> bantou·e
# baptisé              / baptisée             -> baptisé·e
# barbelé              / barbelée             -> barbelé·e
# barbouillé           / barbouillée          -> barbouillé·e
# barbu                / barbue               -> barbu·e
# bardé                / bardée               -> bardé·e
# bariolé              / bariolée             -> bariolé·e
# barré                / barrée               -> barré·e
# barricadé            / barricadée           -> barricadé·e
# bas                  / base                 -> bas·e
# basané               / basanée              -> basané·e
# basculant            / basculante           -> basculant·e
# basculé              / basculée             -> basculé·e
# basé                 / basée                -> basé·e
# bassin               / bassine              -> bassin·e
# bâtard               / bâtarde              -> bâtard·e
# bâté                 / bâtée                -> bâté·e
# bâti                 / bâtie                -> bâti·e
# battant              / battante             -> battant·e
# battu                / battue               -> battu·e
# bavard               / bavarde              -> bavard·e
# bavé                 / bavée                -> bavé·e
# béant                / béante               -> béant·e
# béat                 / béate                -> béat·e
# bêché                / bêchée               -> bêché·e
# bedonnant            / bedonnante           -> bedonnant·e
# bégayé               / bégayée              -> bégayé·e
# bêlant               / bêlante              -> bêlant·e
# belligérant          / belligérante         -> belligérant·e
# bénédictin           / bénédictine          -> bénédictin·e
# béni                 / bénie                -> béni·e
# bénit                / bénite               -> bénit·e
# benjamin             / benjamine            -> benjamin·e
# benoît               / benoîte              -> benoît·e
# bercé                / bercée               -> bercé·e
# berné                / bernée               -> berné·e
# bestial              / bestiale             -> bestial·e
# bétonné              / bétonnée             -> bétonné·e
# beurré               / beurrée              -> beurré·e
# biais                / biaise               -> biais·e
# biaisé               / biaisée              -> biaisé·e
# bidonné              / bidonnée             -> bidonné·e
# bien-aimé            / bien-aimée           -> bien-aimé·e
# bienfaisant          / bienfaisante         -> bienfaisant·e
# biennal              / biennale             -> biennal·e
# bien-pensant         / bien-pensante        -> bien-pensant·e
# bienséant            / bienséante           -> bienséant·e
# bienveillant         / bienveillante        -> bienveillant·e
# bienvenu             / bienvenue            -> bienvenu·e
# biffé                / biffée               -> biffé·e
# bigarré              / bigarrée             -> bigarré·e
# bilatéral            / bilatérale           -> bilatéral·e
# bis                  / bise                 -> bis·e
# biscornu             / biscornue            -> biscornu·e
# biseauté             / biseautée            -> biseauté·e
# bisexué              / bisexuée             -> bisexué·e
# bistré               / bistrée              -> bistré·e
# bitumé               / bitumée              -> bitumé·e
# bivalent             / bivalente            -> bivalent·e
# blafard              / blafarde             -> blafard·e
# blagué               / blaguée              -> blagué·e
# blâmé                / blâmée               -> blâmé·e
# blanchi              / blanchie             -> blanchi·e
# blasé                / blasée               -> blasé·e
# blêmi                / blêmie               -> blêmi·e
# blessant             / blessante            -> blessant·e
# blessé               / blessée              -> blessé·e
# bleu                 / bleue                -> bleu·e
# bleui                / bleuie               -> bleui·e
# bleuté               / bleutée              -> bleuté·e
# blindé               / blindée              -> blindé·e
# blond                / blonde               -> blond·e
# blondi               / blondie              -> blondi·e
# bloquant             / bloquante            -> bloquant·e
# bloqué               / bloquée              -> bloqué·e
# blotti               / blottie              -> blotti·e
# bluffant             / bluffante            -> bluffant·e
# bluffé               / bluffée              -> bluffé·e
# bogué                / boguée               -> bogué·e
# boisé                / boisée               -> boisé·e
# boit                 / boite                -> boit·e
# bombardé             / bombardée            -> bombardé·e
# bombé                / bombée               -> bombé·e
# bond                 / bonde                -> bond·e
# bondé                / bondée               -> bondé·e
# bondissant           / bondissante          -> bondissant·e
# bonifié              / bonifiée             -> bonifié·e
# bord                 / borde                -> bord·e
# bordé                / bordée               -> bordé·e
# boréal               / boréale              -> boréal·e
# borné                / bornée               -> borné·e
# bosselé              / bosselée             -> bosselé·e
# bossu                / bossue               -> bossu·e
# bouché               / bouchée              -> bouché·e
# bouclé               / bouclée              -> bouclé·e
# boudé                / boudée               -> boudé·e
# boudiné              / boudinée             -> boudiné·e
# bouffant             / bouffante            -> bouffant·e
# bouffi               / bouffie              -> bouffi·e
# bougé                / bougée               -> bougé·e
# bouillant            / bouillante           -> bouillant·e
# bouilli              / bouillie             -> bouilli·e
# bouillonnant         / bouillonnante        -> bouillonnant·e
# bouillonné           / bouillonnée          -> bouillonné·e
# bouleversant         / bouleversante        -> bouleversant·e
# bouleversé           / bouleversée          -> bouleversé·e
# bourdonnant          / bourdonnante         -> bourdonnant·e
# bourdonné            / bourdonnée           -> bourdonné·e
# bourgeois            / bourgeoise           -> bourgeois·e
# bourgeonné           / bourgeonnée          -> bourgeonné·e
# bourré               / bourrée              -> bourré·e
# bourrelé             / bourrelée            -> bourrelé·e
# bourru               / bourrue              -> bourru·e
# boursouflé           / boursouflée          -> boursouflé·e
# bous                 / bouse                -> bous·e
# bousculé             / bousculée            -> bousculé·e
# boutonné             / boutonnée            -> boutonné·e
# bovin                / bovine               -> bovin·e
# box                  / boxe                 -> box·e
# boxé                 / boxée                -> boxé·e
# boycott              / boycotte             -> boycott·e
# boycotté             / boycottée            -> boycotté·e
# bradé                / bradée               -> bradé·e
# braillard            / braillarde           -> braillard·e
# braisé               / braisée              -> braisé·e
# branché              / branchée             -> branché·e
# brandi               / brandie              -> brandi·e
# branlant             / branlante            -> branlant·e
# braqué               / braquée              -> braqué·e
# brassé               / brassée              -> brassé·e
# bravé                / bravée               -> bravé·e
# bredouillé           / bredouillée          -> bredouillé·e
# breveté              / brevetée             -> breveté·e
# bricolé              / bricolée             -> bricolé·e
# bridé                / bridée               -> bridé·e
# brigué               / briguée              -> brigué·e
# brillant             / brillante            -> brillant·e
# brimé                / brimée               -> brimé·e
# brioché              / briochée             -> brioché·e
# briqué               / briquée              -> briqué·e
# bris                 / brise                -> bris·e
# brisé                / brisée               -> brisé·e
# broché               / brochée              -> broché·e
# brodé                / brodée               -> brodé·e
# bronzé               / bronzée              -> bronzé·e
# brossé               / brossée              -> brossé·e
# brouillé             / brouillée            -> brouillé·e
# brouté               / broutée              -> brouté·e
# broyé                / broyée               -> broyé·e
# bruir                / bruire               -> bruir·e
# brûlant              / brûlante             -> brûlant·e
# brûlé                / brûlée               -> brûlé·e
# brun                 / brune                -> brun·e
# bruni                / brunie               -> bruni·e
# brusqué              / brusquée             -> brusqué·e
# brut                 / brute                -> brut·e
# brutal               / brutale              -> brutal·e
# brutalisé            / brutalisée           -> brutalisé·e
# bruyant              / bruyante             -> bruyant·e
# bu                   / bue                  -> bu·e
# buccal               / buccale              -> buccal·e
# budgétisé            / budgétisée           -> budgétisé·e
# bureaucratisé        / bureaucratisée       -> bureaucratisé·e
# buriné               / burinée              -> buriné·e
# bus                  / buse                 -> bus·e
# busqué               / busquée              -> busqué·e
# but                  / bute                 -> but·e
# buté                 / butée                -> buté·e
# byzantin             / byzantine            -> byzantin·e
# caban                / cabane               -> caban·e
# câblé                / câblée               -> câblé·e
# cabossé              / cabossée             -> cabossé·e
# cabotin              / cabotine             -> cabotin·e
# cabré                / cabrée               -> cabré·e
# cacaoté              / cacaotée             -> cacaoté·e
# caché                / cachée               -> caché·e
# cacheté              / cachetée             -> cacheté·e
# cadastral            / cadastrale           -> cadastral·e
# cadenassé            / cadenassée           -> cadenassé·e
# cadencé              / cadencée             -> cadencé·e
# cadré                / cadrée               -> cadré·e
# cahot                / cahote               -> cahot·e
# cahotant             / cahotante            -> cahotant·e
# cahoté               / cahotée              -> cahoté·e
# caillé               / caillée              -> caillé·e
# cal                  / cale                 -> cal·e
# calciné              / calcinée             -> calciné·e
# calcul               / calcule              -> calcul·e
# calculé              / calculée             -> calculé·e
# calé                 / calée                -> calé·e
# calfeutré            / calfeutrée           -> calfeutré·e
# calibré              / calibrée             -> calibré·e
# câlin                / câline               -> câlin·e
# calligraphié         / calligraphiée        -> calligraphié·e
# calmant              / calmante             -> calmant·e
# calmé                / calmée               -> calmé·e
# calomnié             / calomniée            -> calomnié·e
# calqué               / calquée              -> calqué·e
# cambré               / cambrée              -> cambré·e
# cambriolé            / cambriolée           -> cambriolé·e
# camelot              / camelote             -> camelot·e
# camouflé             / camouflée            -> camouflé·e
# camp                 / campe                -> camp·e
# campagnard           / campagnarde          -> campagnard·e
# campé                / campée               -> campé·e
# camphré              / camphrée             -> camphré·e
# canalisé             / canalisée            -> canalisé·e
# ...
# transit              / transite             -> transit·e
# transité             / transitée            -> transité·e
# transmis             / transmise            -> transmis·e
# transnational        / transnationale       -> transnational·e
# transparent          / transparente         -> transparent·e
# transparu            / transparue           -> transparu·e
# transpercé           / transpercée          -> transpercé·e
# transpiré            / transpirée           -> transpiré·e
# transplanté          / transplantée         -> transplanté·e
# transport            / transporte           -> transport·e
# transporté           / transportée          -> transporté·e
# transposé            / transposée           -> transposé·e
# transvasé            / transvasée           -> transvasé·e
# transversal          / transversale         -> transversal·e
# trapu                / trapue               -> trapu·e
# traqué               / traquée              -> traqué·e
# traumatisant         / traumatisante        -> traumatisant·e
# traumatisé           / traumatisée          -> traumatisé·e
# travaillé            / travaillée           -> travaillé·e
# travers              / traverse             -> travers·e
# traversé             / traversée            -> traversé·e
# travesti             / travestie            -> travesti·e
# trébuchant           / trébuchante          -> trébuchant·e
# tremblant            / tremblante           -> tremblant·e
# tremblé              / tremblée             -> tremblé·e
# tremblotant          / tremblotante         -> tremblotant·e
# trempé               / trempée              -> trempé·e
# trépan               / trépane              -> trépan·e
# trépané              / trépanée             -> trépané·e
# trépassé             / trépassée            -> trépassé·e
# trépidant            / trépidante           -> trépidant·e
# tressé               / tressée              -> tressé·e
# tri                  / trie                 -> tri·e
# tribal               / tribale              -> tribal·e
# tribun               / tribune              -> tribun·e
# tricot               / tricote              -> tricot·e
# tricoté              / tricotée             -> tricoté·e
# trié                 / triée                -> trié·e
# triennal             / triennale            -> triennal·e
# trilatéral           / trilatérale          -> trilatéral·e
# triomphal            / triomphale           -> triomphal·e
# triomphant           / triomphante          -> triomphant·e
# triphasé             / triphasée            -> triphasé·e
# triplé               / triplée              -> triplé·e
# trituré              / triturée             -> trituré·e
# trivial              / triviale             -> trivial·e
# trompé               / trompée              -> trompé·e
# tronçonné            / tronçonnée           -> tronçonné·e
# tronqué              / tronquée             -> tronqué·e
# trop                 / trope                -> trop·e
# tropical             / tropicale            -> tropical·e
# troqué               / troquée              -> troqué·e
# trotté               / trottée              -> trotté·e
# trou                 / troue                -> trou·e
# troublant            / troublante           -> troublant·e
# troublé              / troublée             -> troublé·e
# troué                / trouée               -> troué·e
# troussé              / troussée             -> troussé·e
# trouvé               / trouvée              -> trouvé·e
# truculent            / truculente           -> truculent·e
# truffé               / truffée              -> truffé·e
# truqué               / truquée              -> truqué·e
# trust                / truste               -> trust·e
# trusté               / trustée              -> trusté·e
# tu                   / tue                  -> tu·e
# tué                  / tuée                 -> tué·e
# tuméfié              / tuméfiée             -> tuméfié·e
# turbulent            / turbulente           -> turbulent·e
# tutoyé               / tutoyée              -> tutoyé·e
# typé                 / typée                -> typé·e
# tyrannisé            / tyrannisée           -> tyrannisé·e
# ulcéré               / ulcérée              -> ulcéré·e
# ultérieur            / ultérieure           -> ultérieur·e
# ultracourt           / ultracourte          -> ultracourt·e
# un                   / une                  -> un·e
# uni                  / unie                 -> uni·e
# unifié               / unifiée              -> unifié·e
# uniformisé           / uniformisée          -> uniformisé·e
# unilatéral           / unilatérale          -> unilatéral·e
# urbain               / urbaine              -> urbain·e
# urbanisé             / urbanisée            -> urbanisé·e
# urgé                 / urgée                -> urgé·e
# urgent               / urgente              -> urgent·e
# us                   / use                  -> us·e
# usagé                / usagée               -> usagé·e
# usant                / usante               -> usant·e
# usé                  / usée                 -> usé·e
# usiné                / usinée               -> usiné·e
# usité                / usitée               -> usité·e
# usurpé               / usurpée              -> usurpé·e
# utérin               / utérine              -> utérin·e
# utilisé              / utilisée             -> utilisé·e
# vacant               / vacante              -> vacant·e
# vaccin               / vaccine              -> vaccin·e
# vacciné              / vaccinée             -> vacciné·e
# vacillant            / vacillante           -> vacillant·e
# vagabond             / vagabonde            -> vagabond·e
# vagabondé            / vagabondée           -> vagabondé·e
# vaginal              / vaginale             -> vaginal·e
# vaillant             / vaillante            -> vaillant·e
# vain                 / vaine                -> vain·e
# vaincu               / vaincue              -> vaincu·e
# validé               / validée              -> validé·e
# vallonné             / vallonnée            -> vallonné·e
# valorisant           / valorisante          -> valorisant·e
# valorisé             / valorisée            -> valorisé·e
# vals                 / valse                -> vals·e
# valsé                / valsée               -> valsé·e
# valu                 / value                -> valu·e
# vanillé              / vanillée             -> vanillé·e
# vanné                / vannée               -> vanné·e
# vantard              / vantarde             -> vantard·e
# vanté                / vantée               -> vanté·e
# vaporisé             / vaporisée            -> vaporisé·e
# variant              / variante             -> variant·e
# varié                / variée               -> varié·e
# vas                  / vase                 -> vas·e
# vascularisé          / vascularisée         -> vascularisé·e
# vassal               / vassale              -> vassal·e
# vassalisé            / vassalisée           -> vassalisé·e
# vautré               / vautrée              -> vautré·e
# vécu                 / vécue                -> vécu·e
# végétal              / végétale             -> végétal·e
# véhément             / véhémente            -> véhément·e
# véhiculé             / véhiculée            -> véhiculé·e
# veillé               / veillée              -> veillé·e
# veiné                / veinée               -> veiné·e
# velouté              / veloutée             -> velouté·e
# velu                 / velue                -> velu·e
# vénal                / vénale               -> vénal·e
# vend                 / vende                -> vend·e
# vendu                / vendue               -> vendu·e
# vénéré               / vénérée              -> vénéré·e
# vengé                / vengée               -> vengé·e
# vent                 / vente                -> vent·e
# ventilé              / ventilée             -> ventilé·e
# ventral              / ventrale             -> ventral·e
# ventripotent         / ventripotente        -> ventripotent·e
# ventru               / ventrue              -> ventru·e
# venu                 / venue                -> venu·e
# verbal               / verbale              -> verbal·e
# verbalisé            / verbalisée           -> verbalisé·e
# verdi                / verdie               -> verdi·e
# verdoyant            / verdoyante           -> verdoyant·e
# vergeté              / vergetée             -> vergeté·e
# verglacé             / verglacée            -> verglacé·e
# vérifié              / vérifiée             -> vérifié·e
# vermoulu             / vermoulue            -> vermoulu·e
# verni                / vernie               -> verni·e
# vernissé             / vernissée            -> vernissé·e
# verrouillé           / verrouillée          -> verrouillé·e
# vers                 / verse                -> vers·e
# versé                / versée               -> versé·e
# vert                 / verte                -> vert·e
# vert-de-grisé        / vert-de-grisée       -> vert-de-grisé·e
# vertébral            / vertébrale           -> vertébral·e
# vertébré             / vertébrée            -> vertébré·e
# vertical             / verticale            -> vertical·e
# vêt                  / vête                 -> vêt·e
# vêtu                 / vêtue                -> vêtu·e
# vexant               / vexante              -> vexant·e
# vexé                 / vexée                -> vexé·e
# viabilisé            / viabilisée           -> viabilisé·e
# vibrant              / vibrante             -> vibrant·e
# vibré                / vibrée               -> vibré·e
# vice-président       / vice-présidente      -> vice-président·e
# vicié                / viciée               -> vicié·e
# vicinal              / vicinale             -> vicinal·e
# vidangé              / vidangée             -> vidangé·e
# vidé                 / vidée                -> vidé·e
# vieilli              / vieillie             -> vieilli·e
# vieillissant         / vieillissante        -> vieillissant·e
# vigilant             / vigilante            -> vigilant·e
# vil                  / vile                 -> vil·e
# vilain               / vilaine              -> vilain·e
# vilipendé            / vilipendée           -> vilipendé·e
# villageois           / villageoise          -> villageois·e
# vinaigré             / vinaigrée            -> vinaigré·e
# viol                 / viole                -> viol·e
# violacé              / violacée             -> violacé·e
# violé                / violée               -> violé·e
# violent              / violente             -> violent·e
# violenté             / violentée            -> violenté·e
# viral                / virale               -> viral·e
# viré                 / virée                -> viré·e
# virevolté            / virevoltée           -> virevolté·e
# virginal             / virginale            -> virginal·e
# viril                / virile               -> viril·e
# virilisé             / virilisée            -> virilisé·e
# virulent             / virulente            -> virulent·e
# vis                  / vise                 -> vis·e
# viscéral             / viscérale            -> viscéral·e
# visé                 / visée                -> visé·e
# visionné             / visionnée            -> visionné·e
# visité               / visitée              -> visité·e
# vissé                / vissée               -> vissé·e
# visualisé            / visualisée           -> visualisé·e
# vit                  / vite                 -> vit·e
# vital                / vitale               -> vital·e
# vitaminé             / vitaminée            -> vitaminé·e
# vitré                / vitrée               -> vitré·e
# vitrifié             / vitrifiée            -> vitrifié·e
# vitupéré             / vitupérée            -> vitupéré·e
# vivant               / vivante              -> vivant·e
# vivifiant            / vivifiante           -> vivifiant·e
# vivifié              / vivifiée             -> vivifié·e
# vocal                / vocale               -> vocal·e
# vociféré             / vociférée            -> vociféré·e
# voilé                / voilée               -> voilé·e
# voir                 / voire                -> voir·e
# voisin               / voisine              -> voisin·e
# voisiné              / voisinée             -> voisiné·e
# vol                  / vole                 -> vol·e
# volant               / volante              -> volant·e
# volatil              / volatile             -> volatil·e
# volatilisé           / volatilisée          -> volatilisé·e
# volé                 / volée                -> volé·e
# vomi                 / vomie                -> vomi·e
# votant               / votante              -> votant·e
# voté                 / votée                -> voté·e
# voué                 / vouée                -> voué·e
# voulu                / voulue               -> voulu·e
# voûté                / voûtée               -> voûté·e
# vouvoyé              / vouvoyée             -> vouvoyé·e
# voyant               / voyante              -> voyant·e
# vrai                 / vraie                -> vrai·e
# vrillé               / vrillée              -> vrillé·e
# vu                   / vue                  -> vu·e
# vulgarisé            / vulgarisée           -> vulgarisé·e
# zaïrois              / zaïroise             -> zaïrois·e
# zébré                / zébrée               -> zébré·e
# zélé                 / zélée                -> zélé·e
# zippé                / zippée               -> zippé·e
# zoné                 / zonée                -> zoné·e
#
# Cela a donné 5813 nouveaux mots singuliers.

# %% [markdown]
# On voit qu'il y a des erreurs, par exemples :
#
# - abord                / aborde               -> abord·e
#   abord est un mot masculin, aborde la conjugaison de aborder et pas la version féminine de abord, abord-e n'a aucun sens
# - ai                   / aie                  -> ai·e
#   ai est une conjugaison au présent simple, aie à l'impératif, et ai-e n'a aucun sens
# - devis                / devise               -> devis·e
#   une devise n'est pas le féminin d'un devis
# - dos                  / dose                 -> dos·e
# - dot                  / dote                 -> dot·e
# - pal                  / pale                 -> pal·e
# - et plein d'autres (corrigés manuellement plus bas).

# %% [markdown]
# Maintenant pour les mots pluriels :

# %%
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("s") and mot[:-1] in set_mots:
        mot_feminin = f"{mot[:-1]}es"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-1]}{SEP}e{SEP}s"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# abaissés             / abaissées            -> abaissé·e·s
# abandonnés           / abandonnées          -> abandonné·e·s
# abasourdis           / abasourdies          -> abasourdi·e·s
# abasourdissants      / abasourdissantes     -> abasourdissant·e·s
# abattus              / abattues             -> abattu·e·s
# abdiqués             / abdiquées            -> abdiqué·e·s
# aberrants            / aberrantes           -> aberrant·e·s
# abîmés               / abîmées              -> abîmé·e·s
# abjects              / abjectes             -> abject·e·s
# abolis               / abolies              -> aboli·e·s
# abondants            / abondantes           -> abondant·e·s
# abonnés              / abonnées             -> abonné·e·s
# abordés              / abordées             -> abordé·e·s
# abords               / abordes              -> abord·e·s
# aboutis              / abouties             -> abouti·e·s
# aboyés               / aboyées              -> aboyé·e·s
# abracadabrants       / abracadabrantes      -> abracadabrant·e·s
# abrégés              / abrégées             -> abrégé·e·s
# abrités              / abritées             -> abrité·e·s
# abrogés              / abrogées             -> abrogé·e·s
# abrupts              / abruptes             -> abrupt·e·s
# abrutis              / abruties             -> abruti·e·s
# abrutissants         / abrutissantes        -> abrutissant·e·s
# absentés             / absentées            -> absenté·e·s
# absents              / absentes             -> absent·e·s
# absolus              / absolues             -> absolu·e·s
# absorbants           / absorbantes          -> absorbant·e·s
# absorbés             / absorbées            -> absorbé·e·s
# abstenus             / abstenues            -> abstenu·e·s
# abstinents           / abstinentes          -> abstinent·e·s
# abstraits            / abstraites           -> abstrait·e·s
# abusés               / abusées              -> abusé·e·s
# accablants           / accablantes          -> accablant·e·s
# accablés             / accablées            -> accablé·e·s
# accaparés            / accaparées           -> accaparé·e·s
# accélérés            / accélérées           -> accéléré·e·s
# accentués            / accentuées           -> accentué·e·s
# acceptés             / acceptées            -> accepté·e·s
# accidentés           / accidentées          -> accidenté·e·s
# acclamés             / acclamées            -> acclamé·e·s
# acclimatés           / acclimatées          -> acclimaté·e·s
# accolés              / accolées             -> accolé·e·s
# accommodants         / accommodantes        -> accommodant·e·s
# accommodés           / accommodées          -> accommodé·e·s
# accompagnés          / accompagnées         -> accompagné·e·s
# accomplis            / accomplies           -> accompli·e·s
# accordés             / accordées            -> accordé·e·s
# accords              / accordes             -> accord·e·s
# accostés             / accostées            -> accosté·e·s
# accouchés            / accouchées           -> accouché·e·s
# accoudés             / accoudées            -> accoudé·e·s
# accouplés            / accouplées           -> accouplé·e·s
# accourus             / accourues            -> accouru·e·s
# accoutumés           / accoutumées          -> accoutumé·e·s
# accrédités           / accréditées          -> accrédité·e·s
# accrochés            / accrochées           -> accroché·e·s
# accrus               / accrues              -> accru·e·s
# accueillants         / accueillantes        -> accueillant·e·s
# accueillis           / accueillies          -> accueilli·e·s
# acculés              / acculées             -> acculé·e·s
# accumulés            / accumulées           -> accumulé·e·s
# accusés              / accusées             -> accusé·e·s
# acérés               / acérées              -> acéré·e·s
# achalandés           / achalandées          -> achalandé·e·s
# acharnés             / acharnées            -> acharné·e·s
# acheminés            / acheminées           -> acheminé·e·s
# achetés              / achetées             -> acheté·e·s
# achevés              / achevées             -> achevé·e·s
# acidulés             / acidulées            -> acidulé·e·s
# acquittés            / acquittées           -> acquitté·e·s
# actionnés            / actionnées           -> actionné·e·s
# activés              / activées             -> activé·e·s
# actualisés           / actualisées          -> actualisé·e·s
# adaptés              / adaptées             -> adapté·e·s
# additionnés          / additionnées         -> additionné·e·s
# adéquats             / adéquates            -> adéquat·e·s
# adhérents            / adhérentes           -> adhérent·e·s
# adjacents            / adjacentes           -> adjacent·e·s
# adjoints             / adjointes            -> adjoint·e·s
# adjugés              / adjugées             -> adjugé·e·s
# adjurés              / adjurées             -> adjuré·e·s
# adjuvants            / adjuvantes           -> adjuvant·e·s
# administrés          / administrées         -> administré·e·s
# admirés              / admirées             -> admiré·e·s
# adolescents          / adolescentes         -> adolescent·e·s
# adonnés              / adonnées             -> adonné·e·s
# adoptés              / adoptées             -> adopté·e·s
# adorés               / adorées              -> adoré·e·s
# adossés              / adossées             -> adossé·e·s
# adoucis              / adoucies             -> adouci·e·s
# adoucissants         / adoucissantes        -> adoucissant·e·s
# adressés             / adressées            -> adressé·e·s
# adroits              / adroites             -> adroit·e·s
# adultérins           / adultérines          -> adultérin·e·s
# advenus              / advenues             -> advenu·e·s
# aérés                / aérées               -> aéré·e·s
# aéronavals           / aéronavales          -> aéronaval·e·s
# aéroportés           / aéroportées          -> aéroporté·e·s
# affacturés           / affacturées          -> affacturé·e·s
# affaiblis            / affaiblies           -> affaibli·e·s
# affairés             / affairées            -> affairé·e·s
# affaissés            / affaissées           -> affaissé·e·s
# affamés              / affamées             -> affamé·e·s
# affectés             / affectées            -> affecté·e·s
# affectionnés         / affectionnées        -> affectionné·e·s
# afférents            / afférentes           -> afférent·e·s
# affermis             / affermies            -> affermi·e·s
# affichés             / affichées            -> affiché·e·s
# affiliés             / affiliées            -> affilié·e·s
# affinés              / affinées             -> affiné·e·s
# affirmés             / affirmées            -> affirmé·e·s
# affleurés            / affleurées           -> affleuré·e·s
# affligeants          / affligeantes         -> affligeant·e·s
# affligés             / affligées            -> affligé·e·s
# affluents            / affluentes           -> affluent·e·s
# affolants            / affolantes           -> affolant·e·s
# affolés              / affolées             -> affolé·e·s
# affranchis           / affranchies          -> affranchi·e·s
# affrétés             / affrétées            -> affrété·e·s
# affrontés            / affrontées           -> affronté·e·s
# affronts             / affrontes            -> affront·e·s
# affublés             / affublées            -> affublé·e·s
# affûtés              / affûtées             -> affûté·e·s
# africains            / africaines           -> africain·e·s
# agaçants             / agaçantes            -> agaçant·e·s
# agacés               / agacées              -> agacé·e·s
# agencés              / agencées             -> agencé·e·s
# agenouillés          / agenouillées         -> agenouillé·e·s
# âgés                 / âgées                -> âgé·e·s
# agglomérés           / agglomérées          -> aggloméré·e·s
# agglutinés           / agglutinées          -> agglutiné·e·s
# aggravants           / aggravantes          -> aggravant·e·s
# aggravés             / aggravées            -> aggravé·e·s
# agissants            / agissantes           -> agissant·e·s
# agités               / agitées              -> agité·e·s
# agonisants           / agonisantes          -> agonisant·e·s
# agrafés              / agrafées             -> agrafé·e·s
# agrandis             / agrandies            -> agrandi·e·s
# agréés               / agréées              -> agréé·e·s
# agrégés              / agrégées             -> agrégé·e·s
# agrémentés           / agrémentées          -> agrémenté·e·s
# agréments            / agrémentes           -> agrément·e·s
# agressés             / agressées            -> agressé·e·s
# agrippés             / agrippées            -> agrippé·e·s
# aguerris             / aguerries            -> aguerri·e·s
# ahuris               / ahuries              -> ahuri·e·s
# ahurissants          / ahurissantes         -> ahurissant·e·s
# aidés                / aidées               -> aidé·e·s
# aïeuls               / aïeules              -> aïeul·e·s
# aigris               / aigries              -> aigri·e·s
# aiguillés            / aiguillées           -> aiguillé·e·s
# aiguillonnés         / aiguillonnées        -> aiguillonné·e·s
# aiguisés             / aiguisées            -> aiguisé·e·s
# ailés                / ailées               -> ailé·e·s
# aimants              / aimantes             -> aimant·e·s
# aimés                / aimées               -> aimé·e·s
# aînés                / aînées               -> aîné·e·s
# airs                 / aires                -> air·e·s
# aisés                / aisées               -> aisé·e·s
# ajourés              / ajourées             -> ajouré·e·s
# ajournés             / ajournées            -> ajourné·e·s
# ajoutés              / ajoutées             -> ajouté·e·s
# ajouts               / ajoutes              -> ajout·e·s
# ajustés              / ajustées             -> ajusté·e·s
# alambiqués           / alambiquées          -> alambiqué·e·s
# alanguis             / alanguies            -> alangui·e·s
# alarmants            / alarmantes           -> alarmant·e·s
# alarmés              / alarmées             -> alarmé·e·s
# alcalins             / alcalines            -> alcalin·e·s
# alcoolisés           / alcoolisées          -> alcoolisé·e·s
# alertés              / alertées             -> alerté·e·s
# alezans              / alezanes             -> alezan·e·s
# aliénants            / aliénantes           -> aliénant·e·s
# aliénés              / aliénées             -> aliéné·e·s
# alignés              / alignées             -> aligné·e·s
# alimentés            / alimentées           -> alimenté·e·s
# aliments             / alimentes            -> aliment·e·s
# alités               / alitées              -> alité·e·s
# allaités             / allaitées            -> allaité·e·s
# allants              / allantes             -> allant·e·s
# alléchants           / alléchantes          -> alléchant·e·s
# alléchés             / alléchées            -> alléché·e·s
# allégés              / allégées             -> allégé·e·s
# allégués             / alléguées            -> allégué·e·s
# allemands            / allemandes           -> allemand·e·s
# allés                / allées               -> allé·e·s
# alliés               / alliées              -> allié·e·s
# allongés             / allongées            -> allongé·e·s
# alloués              / allouées             -> alloué·e·s
# allumés              / allumées             -> allumé·e·s
# alourdis             / alourdies            -> alourdi·e·s
# alpins               / alpines              -> alpin·e·s
# altérés              / altérées             -> altéré·e·s
# alternés             / alternées            -> alterné·e·s
# amadoués             / amadouées            -> amadoué·e·s
# amaigris             / amaigries            -> amaigri·e·s
# amaigrissants        / amaigrissantes       -> amaigrissant·e·s
# amalgamés            / amalgamées           -> amalgamé·e·s
# amarrés              / amarrées             -> amarré·e·s
# amassés              / amassées             -> amassé·e·s
# ambiants             / ambiantes            -> ambiant·e·s
# ambitionnés          / ambitionnées         -> ambitionné·e·s
# ambrés               / ambrées              -> ambré·e·s
# ambulants            / ambulantes           -> ambulant·e·s
# améliorés            / améliorées           -> amélioré·e·s
# aménagés             / aménagées            -> aménagé·e·s
# amendés              / amendées             -> amendé·e·s
# amenés               / amenées              -> amené·e·s
# amenuisés            / amenuisées           -> amenuisé·e·s
# américains           / américaines          -> américain·e·s
# américanisés         / américanisées        -> américanisé·e·s
# ameutés              / ameutées             -> ameuté·e·s
# amidonnés            / amidonnées           -> amidonné·e·s
# amincis              / amincies             -> aminci·e·s
# amincissants         / amincissantes        -> amincissant·e·s
# amis                 / amies                -> ami·e·s
# amnistiés            / amnistiées           -> amnistié·e·s
# amoindris            / amoindries           -> amoindri·e·s
# amollis              / amollies             -> amolli·e·s
# amollissants         / amollissantes        -> amollissant·e·s
# amoncelés            / amoncelées           -> amoncelé·e·s
# amorcés              / amorcées             -> amorcé·e·s
# amortis              / amorties             -> amorti·e·s
# amplifiés            / amplifiées           -> amplifié·e·s
# ampoulés             / ampoulées            -> ampoulé·e·s
# amputés              / amputées             -> amputé·e·s
# amusants             / amusantes            -> amusant·e·s
# amusés               / amusées              -> amusé·e·s
# analysés             / analysées            -> analysé·e·s
# ancrés               / ancrées              -> ancré·e·s
# anéantis             / anéanties            -> anéanti·e·s
# anémiés              / anémiées             -> anémié·e·s
# anesthésiés          / anesthésiées         -> anesthésié·e·s
# anglicans            / anglicanes           -> anglican·e·s
# anglicisés           / anglicisées          -> anglicisé·e·s
# angoissants          / angoissantes         -> angoissant·e·s
# angoissés            / angoissées           -> angoissé·e·s
# animés               / animées              -> animé·e·s
# ankylosés            / ankylosées           -> ankylosé·e·s
# annexés              / annexées             -> annexé·e·s
# annihilés            / annihilées           -> annihilé·e·s
# annoncés             / annoncées            -> annoncé·e·s
# annotés              / annotées             -> annoté·e·s
# annulés              / annulées             -> annulé·e·s
# anodins              / anodines             -> anodin·e·s
# ânonnés              / ânonnées             -> ânonné·e·s
# antérieurs           / antérieures          -> antérieur·e·s
# anticipés            / anticipées           -> anticipé·e·s
# anticoagulants       / anticoagulantes      -> anticoagulant·e·s
# antidatés            / antidatées           -> antidaté·e·s
# antidérapants        / antidérapantes       -> antidérapant·e·s
# apaisants            / apaisantes           -> apaisant·e·s
# apaisés              / apaisées             -> apaisé·e·s
# aperçus              / aperçues             -> aperçu·e·s
# apeurés              / apeurées             -> apeuré·e·s
# apitoyés             / apitoyées            -> apitoyé·e·s
# aplanis              / aplanies             -> aplani·e·s
# aplatis              / aplaties             -> aplati·e·s
# appareillés          / appareillées         -> appareillé·e·s
# apparentés           / apparentées          -> apparenté·e·s
# apparents            / apparentes           -> apparent·e·s
# appariés             / appariées            -> apparié·e·s
# appartenus           / appartenues          -> appartenu·e·s
# apparus              / apparues             -> apparu·e·s
# appâtés              / appâtées             -> appâté·e·s
# appâts               / appâtes              -> appât·e·s
# appauvris            / appauvries           -> appauvri·e·s
# appelés              / appelées             -> appelé·e·s
# appesantis           / appesanties          -> appesanti·e·s
# appétissants         / appétissantes        -> appétissant·e·s
# applaudis            / applaudies           -> applaudi·e·s
# appliqués            / appliquées           -> appliqué·e·s
# appointés            / appointées           -> appointé·e·s
# appoints             / appointes            -> appoint·e·s
# apportés             / apportées            -> apporté·e·s
# apports              / apportes             -> apport·e·s
# apposés              / apposées             -> apposé·e·s
# appréciés            / appréciées           -> apprécié·e·s
# appréhendés          / appréhendées         -> appréhendé·e·s
# apprentis            / apprenties           -> apprenti·e·s
# apprêtés             / apprêtées            -> apprêté·e·s
# apprêts              / apprêtes             -> apprêt·e·s
# apprivoisés          / apprivoisées         -> apprivoisé·e·s
# approchants          / approchantes         -> approchant·e·s
# approchés            / approchées           -> approché·e·s
# approfondis          / approfondies         -> approfondi·e·s
# appropriés           / appropriées          -> approprié·e·s
# approuvés            / approuvées           -> approuvé·e·s
# approvisionnés       / approvisionnées      -> approvisionné·e·s
# appuis               / appuies              -> appui·e·s
# appuyés              / appuyées             -> appuyé·e·s
# apurés               / apurées              -> apuré·e·s
# arbitrés             / arbitrées            -> arbitré·e·s
# arborés              / arborées             -> arboré·e·s
# arborescents         / arborescentes        -> arborescent·e·s
# architecturés        / architecturées       -> architecturé·e·s
# archivés             / archivées            -> archivé·e·s
# ardents              / ardentes             -> ardent·e·s
# ardus                / ardues               -> ardu·e·s
# argentés             / argentées            -> argenté·e·s
# argentins            / argentines           -> argentin·e·s
# argumentés           / argumentées          -> argumenté·e·s
# arguments            / argumentes           -> argument·e·s
# armés                / armées               -> armé·e·s
# armoriés             / armoriées            -> armorié·e·s
# aromatisés           / aromatisées          -> aromatisé·e·s
# arpentés             / arpentées            -> arpenté·e·s
# arpents              / arpentes             -> arpent·e·s
# arrachés             / arrachées            -> arraché·e·s
# arraisonnés          / arraisonnées         -> arraisonné·e·s
# arrangeants          / arrangeantes         -> arrangeant·e·s
# arrangés             / arrangées            -> arrangé·e·s
# arréragés            / arréragées           -> arréragé·e·s
# arrêtés              / arrêtées             -> arrêté·e·s
# arrêts               / arrêtes              -> arrêt·e·s
# arriérés             / arriérées            -> arriéré·e·s
# arrimés              / arrimées             -> arrimé·e·s
# arrivés              / arrivées             -> arrivé·e·s
# arrogants            / arrogantes           -> arrogant·e·s
# arrogés              / arrogées             -> arrogé·e·s
# arrondis             / arrondies            -> arrondi·e·s
# arrosés              / arrosées             -> arrosé·e·s
# articulés            / articulées           -> articulé·e·s
# ascendants           / ascendantes          -> ascendant·e·s
# aseptisés            / aseptisées           -> aseptisé·e·s
# asexués              / asexuées             -> asexué·e·s
# aspergés             / aspergées            -> aspergé·e·s
# asphyxiants          / asphyxiantes         -> asphyxiant·e·s
# asphyxiés            / asphyxiées           -> asphyxié·e·s
# aspirants            / aspirantes           -> aspirant·e·s
# aspirés              / aspirées             -> aspiré·e·s
# assagis              / assagies             -> assagi·e·s
# assaillants          / assaillantes         -> assaillant·e·s
# assaillis            / assaillies           -> assailli·e·s
# assainis             / assainies            -> assaini·e·s
# assaisonnés          / assaisonnées         -> assaisonné·e·s
# assassinés           / assassinées          -> assassiné·e·s
# assassins            / assassines           -> assassin·e·s
# asséchés             / asséchées            -> asséché·e·s
# assemblés            / assemblées           -> assemblé·e·s
# assénés              / assénées             -> asséné·e·s
# assermentés          / assermentées         -> assermenté·e·s
# assidus              / assidues             -> assidu·e·s
# assiégés             / assiégées            -> assiégé·e·s
# assignés             / assignées            -> assigné·e·s
# assimilés            / assimilées           -> assimilé·e·s
# assistants           / assistantes          -> assistant·e·s
# assistés             / assistées            -> assisté·e·s
# associés             / associées            -> associé·e·s
# assoiffés            / assoiffées           -> assoiffé·e·s
# assombris            / assombries           -> assombri·e·s
# assommés             / assommées            -> assommé·e·s
# assortis             / assorties            -> assorti·e·s
# assoupis             / assoupies            -> assoupi·e·s
# assouplis            / assouplies           -> assoupli·e·s
# assourdis            / assourdies           -> assourdi·e·s
# assourdissants       / assourdissantes      -> assourdissant·e·s
# assouvis             / assouvies            -> assouvi·e·s
# assujettis           / assujetties          -> assujetti·e·s
# assujettissants      / assujettissantes     -> assujettissant·e·s
# assumés              / assumées             -> assumé·e·s
# assurés              / assurées             -> assuré·e·s
# astreignants         / astreignantes        -> astreignant·e·s
# astreints            / astreintes           -> astreint·e·s
# astringents          / astringentes         -> astringent·e·s
# atomisés             / atomisées            -> atomisé·e·s
# atrophiés            / atrophiées           -> atrophié·e·s
# attablés             / attablées            -> attablé·e·s
# attachants           / attachantes          -> attachant·e·s
# attachés             / attachées            -> attaché·e·s
# attaqués             / attaquées            -> attaqué·e·s
# attardés             / attardées            -> attardé·e·s
# atteints             / atteintes            -> atteint·e·s
# attelés              / attelées             -> attelé·e·s
# attenants            / attenantes           -> attenant·e·s
# attendris            / attendries           -> attendri·e·s
# attendrissants       / attendrissantes      -> attendrissant·e·s
# attends              / attendes             -> attend·e·s
# attendus             / attendues            -> attendu·e·s
# attentionnés         / attentionnées        -> attentionné·e·s
# atténuants           / atténuantes          -> atténuant·e·s
# atténués             / atténuées            -> atténué·e·s
# atterrants           / atterrantes          -> atterrant·e·s
# atterrés             / atterrées            -> atterré·e·s
# attestés             / attestées            -> attesté·e·s
# attirants            / attirantes           -> attirant·e·s
# attirés              / attirées             -> attiré·e·s
# attisés              / attisées             -> attisé·e·s
# attitrés             / attitrées            -> attitré·e·s
# attrapés             / attrapées            -> attrapé·e·s
# attrayants           / attrayantes          -> attrayant·e·s
# attribués            / attribuées           -> attribué·e·s
# attristants          / attristantes         -> attristant·e·s
# attristés            / attristées           -> attristé·e·s
# attroupés            / attroupées           -> attroupé·e·s
# aucuns               / aucunes              -> aucun·e·s
# auditionnés          / auditionnées         -> auditionné·e·s
# augmentés            / augmentées           -> augmenté·e·s
# augurés              / augurées             -> auguré·e·s
# auréolés             / auréolées            -> auréolé·e·s
# auscultés            / auscultées           -> ausculté·e·s
# australs             / australes            -> austral·e·s
# authentifiés         / authentifiées        -> authentifié·e·s
# autocollants         / autocollantes        -> autocollant·e·s
# auto-équilibrants    / auto-équilibrantes   -> auto-équilibrant·e·s
# autofinancés         / autofinancées        -> autofinancé·e·s
# autogérés            / autogérées           -> autogéré·e·s
# autoguidés           / autoguidées          -> autoguidé·e·s
# automatisés          / automatisées         -> automatisé·e·s
# autonettoyants       / autonettoyantes      -> autonettoyant·e·s
# autopropulsés        / autopropulsées       -> autopropulsé·e·s
# autorisés            / autorisées           -> autorisé·e·s
# avachis              / avachies             -> avachi·e·s
# avalés               / avalées              -> avalé·e·s
# avalisés             / avalisées            -> avalisé·e·s
# avals                / avales               -> aval·e·s
# avancés              / avancées             -> avancé·e·s
# avantagés            / avantagées           -> avantagé·e·s
# avariés              / avariées             -> avarié·e·s
# avenants             / avenantes            -> avenant·e·s
# aventurés            / aventurées           -> aventuré·e·s
# avenus               / avenues              -> avenu·e·s
# avérés               / avérées              -> avéré·e·s
# avertis              / averties             -> averti·e·s
# aveuglants           / aveuglantes          -> aveuglant·e·s
# aveuglés             / aveuglées            -> aveuglé·e·s
# aveulis              / aveulies             -> aveuli·e·s
# avilis               / avilies              -> avili·e·s
# avilissants          / avilissantes         -> avilissant·e·s
# avinés               / avinées              -> aviné·e·s
# avisés               / avisées              -> avisé·e·s
# avivés               / avivées              -> avivé·e·s
# avocats              / avocates             -> avocat·e·s
# avoisinants          / avoisinantes         -> avoisinant·e·s
# avoisinés            / avoisinées           -> avoisiné·e·s
# avortés              / avortées             -> avorté·e·s
# avoués               / avouées              -> avoué·e·s
# axés                 / axées                -> axé·e·s
# azotés               / azotées              -> azoté·e·s
# azurés               / azurées              -> azuré·e·s
# bâchés               / bâchées              -> bâché·e·s
# bâclés               / bâclées              -> bâclé·e·s
# badigeonnés          / badigeonnées         -> badigeonné·e·s
# badins               / badines              -> badin·e·s
# bafoués              / bafouées             -> bafoué·e·s
# bafouillés           / bafouillées          -> bafouillé·e·s
# bagarrés             / bagarrées            -> bagarré·e·s
# bagués               / baguées              -> bagué·e·s
# baignés              / baignées             -> baigné·e·s
# bâillonnés           / bâillonnées          -> bâillonné·e·s
# bais                 / baies                -> bai·e·s
# baissés              / baissées             -> baissé·e·s
# balafrés             / balafrées            -> balafré·e·s
# balais               / balaies              -> balai·e·s
# balancés             / balancées            -> balancé·e·s
# balayés              / balayées             -> balayé·e·s
# balbutiants          / balbutiantes         -> balbutiant·e·s
# balbutiés            / balbutiées           -> balbutié·e·s
# balisés              / balisées             -> balisé·e·s
# ballants             / ballantes            -> ballant·e·s
# ballonnés            / ballonnées           -> ballonné·e·s
# ballottés            / ballottées           -> ballotté·e·s
# banalisés            / banalisées           -> banalisé·e·s
# banals               / banales              -> banal·e·s
# bancals              / bancales             -> bancal·e·s
# bannis               / bannies              -> banni·e·s
# bantous              / bantoues             -> bantou·e·s
# baptisés             / baptisées            -> baptisé·e·s
# barbelés             / barbelées            -> barbelé·e·s
# barbouillés          / barbouillées         -> barbouillé·e·s
# barbus               / barbues              -> barbu·e·s
# bardés               / bardées              -> bardé·e·s
# bariolés             / bariolées            -> bariolé·e·s
# barrés               / barrées              -> barré·e·s
# barricadés           / barricadées          -> barricadé·e·s
# basanés              / basanées             -> basané·e·s
# basculants           / basculantes          -> basculant·e·s
# basculés             / basculées            -> basculé·e·s
# basés                / basées               -> basé·e·s
# bassins              / bassines             -> bassin·e·s
# bâtards              / bâtardes             -> bâtard·e·s
# bâtés                / bâtées               -> bâté·e·s
# bâtis                / bâties               -> bâti·e·s
# battants             / battantes            -> battant·e·s
# battus               / battues              -> battu·e·s
# bavards              / bavardes             -> bavard·e·s
# bavés                / bavées               -> bavé·e·s
# béants               / béantes              -> béant·e·s
# béats                / béates               -> béat·e·s
# bêchés               / bêchées              -> bêché·e·s
# bedonnants           / bedonnantes          -> bedonnant·e·s
# bégayés              / bégayées             -> bégayé·e·s
# bêlants              / bêlantes             -> bêlant·e·s
# belligérants         / belligérantes        -> belligérant·e·s
# bénédictins          / bénédictines         -> bénédictin·e·s
# bénis                / bénies               -> béni·e·s
# bénits               / bénites              -> bénit·e·s
# benjamins            / benjamines           -> benjamin·e·s
# benoîts              / benoîtes             -> benoît·e·s
# bercés               / bercées              -> bercé·e·s
# bernés               / bernées              -> berné·e·s
# bétonnés             / bétonnées            -> bétonné·e·s
# beurrés              / beurrées             -> beurré·e·s
# biaisés              / biaisées             -> biaisé·e·s
# bidonnés             / bidonnées            -> bidonné·e·s
# bien-aimés           / bien-aimées          -> bien-aimé·e·s
# bienfaisants         / bienfaisantes        -> bienfaisant·e·s
# bien-pensants        / bien-pensantes       -> bien-pensant·e·s
# bienséants           / bienséantes          -> bienséant·e·s
# bienveillants        / bienveillantes       -> bienveillant·e·s
# bienvenus            / bienvenues           -> bienvenu·e·s
# biffés               / biffées              -> biffé·e·s
# bigarrés             / bigarrées            -> bigarré·e·s
# biscornus            / biscornues           -> biscornu·e·s
# biseautés            / biseautées           -> biseauté·e·s
# bisexués             / bisexuées            -> bisexué·e·s
# bistrés              / bistrées             -> bistré·e·s
# bitumés              / bitumées             -> bitumé·e·s
# bivalents            / bivalentes           -> bivalent·e·s
# blafards             / blafardes            -> blafard·e·s
# blagués              / blaguées             -> blagué·e·s
# blâmés               / blâmées              -> blâmé·e·s
# blanchis             / blanchies            -> blanchi·e·s
# blasés               / blasées              -> blasé·e·s
# blêmis               / blêmies              -> blêmi·e·s
# blessants            / blessantes           -> blessant·e·s
# blessés              / blessées             -> blessé·e·s
# bleuis               / bleuies              -> bleui·e·s
# bleus                / bleues               -> bleu·e·s
# bleutés              / bleutées             -> bleuté·e·s
# blindés              / blindées             -> blindé·e·s
# blondis              / blondies             -> blondi·e·s
# blonds               / blondes              -> blond·e·s
# bloquants            / bloquantes           -> bloquant·e·s
# bloqués              / bloquées             -> bloqué·e·s
# blottis              / blotties             -> blotti·e·s
# bluffants            / bluffantes           -> bluffant·e·s
# bogués               / boguées              -> bogué·e·s
# boisés               / boisées              -> boisé·e·s
# bombardés            / bombardées           -> bombardé·e·s
# bombés               / bombées              -> bombé·e·s
# bondés               / bondées              -> bondé·e·s
# bondissants          / bondissantes         -> bondissant·e·s
# bonds                / bondes               -> bond·e·s
# bonifiés             / bonifiées            -> bonifié·e·s
# bordés               / bordées              -> bordé·e·s
# bords                / bordes               -> bord·e·s
# boréals              / boréales             -> boréal·e·s
# bornés               / bornées              -> borné·e·s
# bosselés             / bosselées            -> bosselé·e·s
# bossus               / bossues              -> bossu·e·s
# bouchés              / bouchées             -> bouché·e·s
# bouclés              / bouclées             -> bouclé·e·s
# boudés               / boudées              -> boudé·e·s
# boudinés             / boudinées            -> boudiné·e·s
# bouffants            / bouffantes           -> bouffant·e·s
# bouffis              / bouffies             -> bouffi·e·s
# bougés               / bougées              -> bougé·e·s
# bouillants           / bouillantes          -> bouillant·e·s
# bouillis             / bouillies            -> bouilli·e·s
# bouillonnants        / bouillonnantes       -> bouillonnant·e·s
# bouillonnés          / bouillonnées         -> bouillonné·e·s
# bouleversants        / bouleversantes       -> bouleversant·e·s
# bouleversés          / bouleversées         -> bouleversé·e·s
# bourdonnants         / bourdonnantes        -> bourdonnant·e·s
# bourdonnés           / bourdonnées          -> bourdonné·e·s
# bourgeonnés          / bourgeonnées         -> bourgeonné·e·s
# bourrelés            / bourrelées           -> bourrelé·e·s
# bourrés              / bourrées             -> bourré·e·s
# bourrus              / bourrues             -> bourru·e·s
# boursouflés          / boursouflées         -> boursouflé·e·s
# bousculés            / bousculées           -> bousculé·e·s
# boutonnés            / boutonnées           -> boutonné·e·s
# bovins               / bovines              -> bovin·e·s
# boxés                / boxées               -> boxé·e·s
# boycottés            / boycottées           -> boycotté·e·s
# boycotts             / boycottes            -> boycott·e·s
# bradés               / bradées              -> bradé·e·s
# braillards           / braillardes          -> braillard·e·s
# braisés              / braisées             -> braisé·e·s
# branchés             / branchées            -> branché·e·s
# brandis              / brandies             -> brandi·e·s
# branlants            / branlantes           -> branlant·e·s
# braqués              / braquées             -> braqué·e·s
# brassés              / brassées             -> brassé·e·s
# bravés               / bravées              -> bravé·e·s
# bredouillés          / bredouillées         -> bredouillé·e·s
# brevetés             / brevetées            -> breveté·e·s
# bricolés             / bricolées            -> bricolé·e·s
# bridés               / bridées              -> bridé·e·s
# brigués              / briguées             -> brigué·e·s
# brillants            / brillantes           -> brillant·e·s
# brimés               / brimées              -> brimé·e·s
# briochés             / briochées            -> brioché·e·s
# briqués              / briquées             -> briqué·e·s
# brisés               / brisées              -> brisé·e·s
# brochés              / brochées             -> broché·e·s
# brodés               / brodées              -> brodé·e·s
# bronzés              / bronzées             -> bronzé·e·s
# brossés              / brossées             -> brossé·e·s
# brouillés            / brouillées           -> brouillé·e·s
# broutés              / broutées             -> brouté·e·s
# broyés               / broyées              -> broyé·e·s
# brûlants             / brûlantes            -> brûlant·e·s
# brûlés               / brûlées              -> brûlé·e·s
# brunis               / brunies              -> bruni·e·s
# bruns                / brunes               -> brun·e·s
# brusqués             / brusquées            -> brusqué·e·s
# brutalisés           / brutalisées          -> brutalisé·e·s
# bruts                / brutes               -> brut·e·s
# bruyants             / bruyantes            -> bruyant·e·s
# budgétisés           / budgétisées          -> budgétisé·e·s
# bureaucratisés       / bureaucratisées      -> bureaucratisé·e·s
# burinés              / burinées             -> buriné·e·s
# bus                  / bues                 -> bu·e·s
# busqués              / busquées             -> busqué·e·s
# butés                / butées               -> buté·e·s
# buts                 / butes                -> but·e·s
# byzantins            / byzantines           -> byzantin·e·s
# cabans               / cabanes              -> caban·e·s
# câblés               / câblées              -> câblé·e·s
# cabossés             / cabossées            -> cabossé·e·s
# cabotins             / cabotines            -> cabotin·e·s
# cabrés               / cabrées              -> cabré·e·s
# cacaotés             / cacaotées            -> cacaoté·e·s
# cachés               / cachées              -> caché·e·s
# cachetés             / cachetées            -> cacheté·e·s
# cadenassés           / cadenassées          -> cadenassé·e·s
# cadencés             / cadencées            -> cadencé·e·s
# cadrés               / cadrées              -> cadré·e·s
# cahotants            / cahotantes           -> cahotant·e·s
# cahotés              / cahotées             -> cahoté·e·s
# caillés              / caillées             -> caillé·e·s
# calcinés             / calcinées            -> calciné·e·s
# calculés             / calculées            -> calculé·e·s
# calculs              / calcules             -> calcul·e·s
# calés                / calées               -> calé·e·s
# calfeutrés           / calfeutrées          -> calfeutré·e·s
# calibrés             / calibrées            -> calibré·e·s
# câlins               / câlines              -> câlin·e·s
# calligraphiés        / calligraphiées       -> calligraphié·e·s
# calmants             / calmantes            -> calmant·e·s
# calmés               / calmées              -> calmé·e·s
# calomniés            / calomniées           -> calomnié·e·s
# calqués              / calquées             -> calqué·e·s
# cals                 / cales                -> cal·e·s
# cambrés              / cambrées             -> cambré·e·s
# cambriolés           / cambriolées          -> cambriolé·e·s
# camouflés            / camouflées           -> camouflé·e·s
# campagnards          / campagnardes         -> campagnard·e·s
# campés               / campées              -> campé·e·s
# camphrés             / camphrées            -> camphré·e·s
# camps                / campes               -> camp·e·s
# canalisés            / canalisées           -> canalisé·e·s
# candidats            / candidates           -> candidat·e·s
# cannelés             / cannelées            -> cannelé·e·s
# cantonnés            / cantonnées           -> cantonné·e·s
# caoutchoutés         / caoutchoutées        -> caoutchouté·e·s
# capitalisés          / capitalisées         -> capitalisé·e·s
# capitonnés           / capitonnées          -> capitonné·e·s
# capotés              / capotées             -> capoté·e·s
# capots               / capotes              -> capot·e·s
# caps                 / capes                -> cap·e·s
# capsulés             / capsulées            -> capsulé·e·s
# captés               / captées              -> capté·e·s
# captivants           / captivantes          -> captivant·e·s
# captivés             / captivées            -> captivé·e·s
# capturés             / capturées            -> capturé·e·s
# carabinés            / carabinées           -> carabiné·e·s
# caractérisés         / caractérisées        -> caractérisé·e·s
# caramélisés          / caramélisées         -> caramélisé·e·s
# carbonisés           / carbonisées          -> carbonisé·e·s
# carénés              / carénées             -> caréné·e·s
# caressants           / caressantes          -> caressant·e·s
# caressés             / caressées            -> caressé·e·s
# caricaturés          / caricaturées         -> caricaturé·e·s
# cariés               / cariées              -> carié·e·s
# carminés             / carminées            -> carminé·e·s
# carnés               / carnées              -> carné·e·s
# carrelés             / carrelées            -> carrelé·e·s
# carrés               / carrées              -> carré·e·s
# carrossés            / carrossées           -> carrossé·e·s
# cartonnés            / cartonnées           -> cartonné·e·s
# casés                / casées               -> casé·e·s
# casqués              / casquées             -> casqué·e·s
# cassants             / cassantes            -> cassant·e·s
# cassés               / cassées              -> cassé·e·s
# catalans             / catalanes            -> catalan·e·s
# catalogués           / cataloguées          -> catalogué·e·s
# catalysés            / catalysées           -> catalysé·e·s
# catapultés           / catapultées          -> catapulté·e·s
# catastrophés         / catastrophées        -> catastrophé·e·s
# catégorisés          / catégorisées         -> catégorisé·e·s
# causals              / causales             -> causal·e·s
# causants             / causantes            -> causant·e·s
# causés               / causées              -> causé·e·s
# cautérisés           / cautérisées          -> cautérisé·e·s
# cautionnés           / cautionnées          -> cautionné·e·s
# cédés                / cédées               -> cédé·e·s
# ceints               / ceintes              -> ceint·e·s
# ceinturés            / ceinturées           -> ceinturé·e·s
# célébrés             / célébrées            -> célébré·e·s
# cendrés              / cendrées             -> cendré·e·s
# censés               / censées              -> censé·e·s
# ...
# touchés              / touchées             -> touché·e·s
# touffus              / touffues             -> touffu·e·s
# tourbillonnants      / tourbillonnantes     -> tourbillonnant·e·s
# tourmentés           / tourmentées          -> tourmenté·e·s
# tourments            / tourmentes           -> tourment·e·s
# tournants            / tournantes           -> tournant·e·s
# tournés              / tournées             -> tourné·e·s
# tracassés            / tracassées           -> tracassé·e·s
# tracés               / tracées              -> tracé·e·s
# tractés              / tractées             -> tracté·e·s
# traduits             / traduites            -> traduit·e·s
# trafiqués            / trafiquées           -> trafiqué·e·s
# trahis               / trahies              -> trahi·e·s
# traînants            / traînantes           -> traînant·e·s
# traînés              / traînées             -> traîné·e·s
# traitants            / traitantes           -> traitant·e·s
# traités              / traitées             -> traité·e·s
# traits               / traites              -> trait·e·s
# tramés               / tramées              -> tramé·e·s
# trams                / trames               -> tram·e·s
# tranchants           / tranchantes          -> tranchant·e·s
# tranchés             / tranchées            -> tranché·e·s
# tranquillisants      / tranquillisantes     -> tranquillisant·e·s
# tranquillisés        / tranquillisées       -> tranquillisé·e·s
# transalpins          / transalpines         -> transalpin·e·s
# transbordés          / transbordées         -> transbordé·e·s
# transcendants        / transcendantes       -> transcendant·e·s
# transcodés           / transcodées          -> transcodé·e·s
# transcrits           / transcrites          -> transcrit·e·s
# transférés           / transférées          -> transféré·e·s
# transfigurés         / transfigurées        -> transfiguré·e·s
# transformés          / transformées         -> transformé·e·s
# transfusés           / transfusées          -> transfusé·e·s
# transgressés         / transgressées        -> transgressé·e·s
# transhumants         / transhumantes        -> transhumant·e·s
# transis              / transies             -> transi·e·s
# transistorisés       / transistorisées      -> transistorisé·e·s
# transités            / transitées           -> transité·e·s
# transits             / transites            -> transit·e·s
# transparents         / transparentes        -> transparent·e·s
# transparus           / transparues          -> transparu·e·s
# transpercés          / transpercées         -> transpercé·e·s
# transpirés           / transpirées          -> transpiré·e·s
# transplantés         / transplantées        -> transplanté·e·s
# transportés          / transportées         -> transporté·e·s
# transports           / transportes          -> transport·e·s
# transposés           / transposées          -> transposé·e·s
# transvasés           / transvasées          -> transvasé·e·s
# trapus               / trapues              -> trapu·e·s
# traqués              / traquées             -> traqué·e·s
# traumatisants        / traumatisantes       -> traumatisant·e·s
# traumatisés          / traumatisées         -> traumatisé·e·s
# travaillés           / travaillées          -> travaillé·e·s
# traversés            / traversées           -> traversé·e·s
# travestis            / travesties           -> travesti·e·s
# trébuchants          / trébuchantes         -> trébuchant·e·s
# tremblants           / tremblantes          -> tremblant·e·s
# tremblés             / tremblées            -> tremblé·e·s
# tremblotants         / tremblotantes        -> tremblotant·e·s
# trempés              / trempées             -> trempé·e·s
# trépanés             / trépanées            -> trépané·e·s
# trépassés            / trépassées           -> trépassé·e·s
# trépidants           / trépidantes          -> trépidant·e·s
# tressés              / tressées             -> tressé·e·s
# tribuns              / tribunes             -> tribun·e·s
# tricotés             / tricotées            -> tricoté·e·s
# tricots              / tricotes             -> tricot·e·s
# triés                / triées               -> trié·e·s
# triomphants          / triomphantes         -> triomphant·e·s
# triphasés            / triphasées           -> triphasé·e·s
# triplés              / triplées             -> triplé·e·s
# tris                 / tries                -> tri·e·s
# triturés             / triturées            -> trituré·e·s
# trompés              / trompées             -> trompé·e·s
# tronçonnés           / tronçonnées          -> tronçonné·e·s
# tronqués             / tronquées            -> tronqué·e·s
# troqués              / troquées             -> troqué·e·s
# trottés              / trottées             -> trotté·e·s
# troublants           / troublantes          -> troublant·e·s
# troublés             / troublées            -> troublé·e·s
# troués               / trouées              -> troué·e·s
# trous                / troues               -> trou·e·s
# troussés             / troussées            -> troussé·e·s
# trouvés              / trouvées             -> trouvé·e·s
# truculents           / truculentes          -> truculent·e·s
# truffés              / truffées             -> truffé·e·s
# truqués              / truquées             -> truqué·e·s
# trustés              / trustées             -> trusté·e·s
# trusts               / trustes              -> trust·e·s
# tués                 / tuées                -> tué·e·s
# tuméfiés             / tuméfiées            -> tuméfié·e·s
# turbulents           / turbulentes          -> turbulent·e·s
# tus                  / tues                 -> tu·e·s
# tutoyés              / tutoyées             -> tutoyé·e·s
# typés                / typées               -> typé·e·s
# tyrannisés           / tyrannisées          -> tyrannisé·e·s
# ulcérés              / ulcérées             -> ulcéré·e·s
# ultérieurs           / ultérieures          -> ultérieur·e·s
# ultracourts          / ultracourtes         -> ultracourt·e·s
# unifiés              / unifiées             -> unifié·e·s
# uniformisés          / uniformisées         -> uniformisé·e·s
# unis                 / unies                -> uni·e·s
# uns                  / unes                 -> un·e·s
# urbains              / urbaines             -> urbain·e·s
# urbanisés            / urbanisées           -> urbanisé·e·s
# urgents              / urgentes             -> urgent·e·s
# urgés                / urgées               -> urgé·e·s
# usagés               / usagées              -> usagé·e·s
# usants               / usantes              -> usant·e·s
# usés                 / usées                -> usé·e·s
# usinés               / usinées              -> usiné·e·s
# usités               / usitées              -> usité·e·s
# usurpés              / usurpées             -> usurpé·e·s
# utérins              / utérines             -> utérin·e·s
# utilisés             / utilisées            -> utilisé·e·s
# vacants              / vacantes             -> vacant·e·s
# vaccinés             / vaccinées            -> vacciné·e·s
# vaccins              / vaccines             -> vaccin·e·s
# vacillants           / vacillantes          -> vacillant·e·s
# vagabondés           / vagabondées          -> vagabondé·e·s
# vagabonds            / vagabondes           -> vagabond·e·s
# vaillants            / vaillantes           -> vaillant·e·s
# vaincus              / vaincues             -> vaincu·e·s
# vains                / vaines               -> vain·e·s
# validés              / validées             -> validé·e·s
# vallonnés            / vallonnées           -> vallonné·e·s
# valorisants          / valorisantes         -> valorisant·e·s
# valorisés            / valorisées           -> valorisé·e·s
# valsés               / valsées              -> valsé·e·s
# valus                / values               -> valu·e·s
# vanillés             / vanillées            -> vanillé·e·s
# vannés               / vannées              -> vanné·e·s
# vantards             / vantardes            -> vantard·e·s
# vantés               / vantées              -> vanté·e·s
# vaporisés            / vaporisées           -> vaporisé·e·s
# variés               / variées              -> varié·e·s
# vascularisés         / vascularisées        -> vascularisé·e·s
# vassalisés           / vassalisées          -> vassalisé·e·s
# vautrés              / vautrées             -> vautré·e·s
# vécus                / vécues               -> vécu·e·s
# véhéments            / véhémentes           -> véhément·e·s
# véhiculés            / véhiculées           -> véhiculé·e·s
# veillés              / veillées             -> veillé·e·s
# veinés               / veinées              -> veiné·e·s
# veloutés             / veloutées            -> velouté·e·s
# velus                / velues               -> velu·e·s
# vends                / vendes               -> vend·e·s
# vendus               / vendues              -> vendu·e·s
# vénérés              / vénérées             -> vénéré·e·s
# vengés               / vengées              -> vengé·e·s
# ventilés             / ventilées            -> ventilé·e·s
# ventripotents        / ventripotentes       -> ventripotent·e·s
# ventrus              / ventrues             -> ventru·e·s
# vents                / ventes               -> vent·e·s
# venus                / venues               -> venu·e·s
# verbalisés           / verbalisées          -> verbalisé·e·s
# verdis               / verdies              -> verdi·e·s
# verdoyants           / verdoyantes          -> verdoyant·e·s
# vergetés             / vergetées            -> vergeté·e·s
# verglacés            / verglacées           -> verglacé·e·s
# vérifiés             / vérifiées            -> vérifié·e·s
# vermoulus            / vermoulues           -> vermoulu·e·s
# vernis               / vernies              -> verni·e·s
# vernissés            / vernissées           -> vernissé·e·s
# verrouillés          / verrouillées         -> verrouillé·e·s
# versés               / versées              -> versé·e·s
# vert-de-grisés       / vert-de-grisées      -> vert-de-grisé·e·s
# vertébrés            / vertébrées           -> vertébré·e·s
# verts                / vertes               -> vert·e·s
# vêts                 / vêtes                -> vêt·e·s
# vêtus                / vêtues               -> vêtu·e·s
# vexants              / vexantes             -> vexant·e·s
# vexés                / vexées               -> vexé·e·s
# viabilisés           / viabilisées          -> viabilisé·e·s
# vibrants             / vibrantes            -> vibrant·e·s
# vibrés               / vibrées              -> vibré·e·s
# vice-présidents      / vice-présidentes     -> vice-président·e·s
# viciés               / viciées              -> vicié·e·s
# vidangés             / vidangées            -> vidangé·e·s
# vidés                / vidées               -> vidé·e·s
# vieillis             / vieillies            -> vieilli·e·s
# vieillissants        / vieillissantes       -> vieillissant·e·s
# vigilants            / vigilantes           -> vigilant·e·s
# vilains              / vilaines             -> vilain·e·s
# vilipendés           / vilipendées          -> vilipendé·e·s
# vils                 / viles                -> vil·e·s
# vinaigrés            / vinaigrées           -> vinaigré·e·s
# violacés             / violacées            -> violacé·e·s
# violentés            / violentées           -> violenté·e·s
# violents             / violentes            -> violent·e·s
# violés               / violées              -> violé·e·s
# viols                / violes               -> viol·e·s
# virés                / virées               -> viré·e·s
# virevoltés           / virevoltées          -> virevolté·e·s
# virilisés            / virilisées           -> virilisé·e·s
# virils               / viriles              -> viril·e·s
# virulents            / virulentes           -> virulent·e·s
# visés                / visées               -> visé·e·s
# visionnés            / visionnées           -> visionné·e·s
# visités              / visitées             -> visité·e·s
# vissés               / vissées              -> vissé·e·s
# visualisés           / visualisées          -> visualisé·e·s
# vitaminés            / vitaminées           -> vitaminé·e·s
# vitrés               / vitrées              -> vitré·e·s
# vitrifiés            / vitrifiées           -> vitrifié·e·s
# vitupérés            / vitupérées           -> vitupéré·e·s
# vivants              / vivantes             -> vivant·e·s
# vivifiants           / vivifiantes          -> vivifiant·e·s
# vivifiés             / vivifiées            -> vivifié·e·s
# vociférés            / vociférées           -> vociféré·e·s
# voilés               / voilées              -> voilé·e·s
# voisinés             / voisinées            -> voisiné·e·s
# voisins              / voisines             -> voisin·e·s
# volants              / volantes             -> volant·e·s
# volatilisés          / volatilisées         -> volatilisé·e·s
# volatils             / volatiles            -> volatil·e·s
# volés                / volées               -> volé·e·s
# vols                 / voles                -> vol·e·s
# vomis                / vomies               -> vomi·e·s
# votants              / votantes             -> votant·e·s
# votés                / votées               -> voté·e·s
# voués                / vouées               -> voué·e·s
# voulus               / voulues              -> voulu·e·s
# voûtés               / voûtées              -> voûté·e·s
# vouvoyés             / vouvoyées            -> vouvoyé·e·s
# voyants              / voyantes             -> voyant·e·s
# vrais                / vraies               -> vrai·e·s
# vrillés              / vrillées             -> vrillé·e·s
# vulgarisés           / vulgarisées          -> vulgarisé·e·s
# vus                  / vues                 -> vu·e·s
# zébrés               / zébrées              -> zébré·e·s
# zélés                / zélées               -> zélé·e·s
# zippés               / zippées              -> zippé·e·s
# zonés                / zonées               -> zoné·e·s
#
# Cela a donné 5244 nouveaux mots pluriels.

# %% [markdown]
# Encore des faux positifs :
#
# - bais                 / baies                -> bais·e·s
#   baies n'est pas la version féminine de bais...
# - vol                  / vols                 / voles                -> vol·e·s
#   voles n'est pas la version féminine de vols mais une conjugaison...
# - et plein d'autres
#
# Ces erreurs pourraient être corrigées si on avait une base de données disant si un mot est une conjugaison, un adjectif, un nom (ou plusieurs genres)...

# %% [markdown]
# On enlève tous les mots qui n'ont pas de raison d'avoir des alternatives inclusives :
# (trier à la main les ~5500 mots m'a pris environ une heure)

# %%
del_alternatives([
    "abord", "aborde", "abords", "abordes",
    "abus", "abuse", "abuss", "abuses",
    "accord", "accorde", "accords", "accordes",
    "agit", "agite", "agits", "agites",
    "agrément", "agrémente", "agréments", "agrémentes",
    "ai", "aie", "ais", "aies",
    "ail", "aile", "ails", "ailes",
    "air", "aire", "airs", "aires",
    "ajout", "ajoute", "ajouts", "ajoutes",
    "aliment", "alimente", "aliments", "alimentes",
    "allait", "allaite", "allaits", "allaites",
    "ans", "anse", "anss", "anses",
    "appoint", "appointe", "appoints", "appointes",
    "apport", "apporte", "apports", "apportes",
    "appui", "appuie", "appuis", "appuies",
    "arpent", "arpente", "arpents", "arpentes",
    "arrêt", "arrête", "arrêts", "arrêtes",
    "aval", "avale", "avals", "avales",
    "avis", "avise", "aviss", "avises",
    "bai", "baie", "bais", "baies",
    "bas", "base", "bass", "bases",
    "biais", "biaise", "biaiss", "biaises",
    "bis", "bise", "biss", "bises",
    "boit", "boite", "boits", "boites",
    "bond", "bonde", "bonds", "bondes",
    "bord", "borde", "bords", "bordes",
    "bous", "bouse", "bouss", "bouses",
    "box", "boxe", "boxs", "boxes",
    "boycott", "boycotte", "boycotts", "boycottes",
    "bris", "brise", "briss", "brises",
    "bruir", "bruire", "bruirs", "bruires",
    "bu", "bue", "bus", "bues",
    "bus", "buse", "buss", "buses",
    "but", "bute", "buts", "butes",
    "caban", "cabane", "cabans", "cabanes",
    "cahot", "cahote", "cahots", "cahotes",
    "cal", "cale", "cals", "cales",
    "calcul", "calcule", "calculs", "calcules",
    "camp", "campe", "camps", "campes",
    "cap", "cape", "caps", "capes",
    "capot", "capote", "capots", "capotes",
    "cas", "case", "cass", "cases",
    "chair", "chaire", "chairs", "chaires",
    "chais", "chaise", "chaiss", "chaises",
    "chemin", "chemine", "chemins", "chemines",
    "chut", "chute", "chuts", "chutes",
    "ciment", "cimente", "ciments", "cimentes",
    "clam", "clame", "clams", "clames",
    "clos", "close", "closs", "closes",
    "clou", "cloue", "clous", "cloues",
    "comment", "commente", "comments", "commentes",
    "complot", "complote", "complots", "complotes",
    "compost", "composte", "composts", "compostes",
    "concert", "concerte", "concerts", "concertes",
    "conduis", "conduise", "conduiss", "conduises",
    "contact", "contacte", "contacts", "contactes",
    "contredis", "contredise", "contrediss", "contredises",
    "cors", "corse", "corss", "corses",
    "coud", "coude", "couds", "coudes",
    "coudrai", "coudraie", "coudrais", "coudraies",
    "coup", "coupe", "coups", "coupes",
    "cour", "coure", "cours", "coures",
    "cours", "course", "courss", "courses",
    "court-circuit", "court-circuite", "court-circuits", "court-circuites",
    "cous", "couse", "couss", "couses",
    "coût", "coûte", "coûts", "coûtes",
    "crédit", "crédite", "crédits", "crédites",
    "crépit", "crépite", "crépits", "crépites",
    "cri", "crie", "cris", "cries",
    "cris", "crise", "criss", "crises",
    "crois", "croise", "croiss", "croises",
    "cross", "crosse", "crosss", "crosses",
    "cuir", "cuire", "cuirs", "cuires",
    "cuis", "cuise", "cuiss", "cuises",
    "cumul", "cumule", "cumuls", "cumules",
    "dans", "danse", "danss", "danses",
    "débit", "débite", "débits", "débites",
    "débours", "débourse", "débourss", "débourses",
    "début", "débute", "débuts", "débutes",
    "déclin", "décline", "déclins", "déclines",
    "dédis", "dédise", "dédiss", "dédises",
    "déduis", "déduise", "déduiss", "déduises",
    "défend", "défende", "défends", "défendes",
    "défi", "défie", "défis", "défies",
    "dégoût", "dégoûte", "dégoûts", "dégoûtes",
    "délai", "délaie", "délais", "délaies",
    "démord", "démorde", "démords", "démordes",
    "déni", "dénie", "dénis", "dénies",
    "dépend", "dépende", "dépends", "dépendes",
    "dépens", "dépense", "dépenss", "dépenses",
    "dépit", "dépite", "dépits", "dépites",
    "déplais", "déplaise", "déplaiss", "déplaises",
    "descend", "descende", "descends", "descendes",
    "désir", "désire", "désirs", "désires",
    "dessert", "desserte", "desserts", "dessertes",
    "dessin", "dessine", "dessins", "dessines",
    "destin", "destine", "destins", "destines",
    "détend", "détende", "détends", "détendes",
    "détruis", "détruise", "détruiss", "détruises",
    "dévêt", "dévête", "dévêts", "dévêtes",
    "devis", "devise", "deviss", "devises",
    "digest", "digeste", "digests", "digestes",
    "dis", "dise", "diss", "dises",
    "disert", "diserte", "diserts", "disertes",
    "dispos", "dispose", "disposs", "disposes",
    "distend", "distende", "distends", "distendes",
    "divers", "diverse", "diverss", "diverses",
    "dos", "dose", "doss", "doses",
    "dot", "dote", "dots", "dotes",
    "drain", "draine", "drains", "draines",
    "drap", "drape", "draps", "drapes",
    "droit", "droite", "droits", "droites",
    "écart", "écarte", "écarts", "écartes",
    "échafaud", "échafaude", "échafauds", "échafaudes",
    "éclair", "éclaire", "éclairs", "éclaires",
    "éclat", "éclate", "éclats", "éclates",
    "éconduis", "éconduise", "éconduiss", "éconduises",
    "édit", "édite", "édits", "édites",
    "élis", "élise", "éliss", "élises",
    "élit", "élite", "élits", "élites",
    "émeut", "émeute", "émeuts", "émeutes",
    "encart", "encarte", "encarts", "encartes",
    "encens", "encense", "encenss", "encenses",
    "enduis", "enduise", "enduiss", "enduises",
    "ensuit", "ensuite", "ensuits", "ensuites",
    "entend", "entende", "entends", "entendes",
    "envoi", "envoie", "envois", "envoies",
    "envol", "envole", "envols", "envoles",
    "épi", "épie", "épis", "épies",
    "essai", "essaie", "essais", "essaies",
    "essaim", "essaime", "essaims", "essaimes",
    "essor", "essore", "essors", "essores",
    "étai", "étaie", "étais", "étaies",
    "étal", "étale", "étals", "étales",
    "étend", "étende", "étends", "étendes",
    "exil", "exile", "exils", "exiles",
    "exploit", "exploite", "exploits", "exploites",
    "faillit", "faillite", "faillits", "faillites",
    "fan", "fane", "fans", "fanes",
    "fard", "farde", "fards", "fardes",
    "faufil", "faufile", "faufils", "faufiles",
    "faut", "faute", "fauts", "fautes",
    "favoris", "favorise", "favoriss", "favorises",
    "fend", "fende", "fends", "fendes",
    "ferment", "fermente", "ferments", "fermentes",
    "fient", "fiente", "fients", "fientes",
    "fil", "file", "fils", "files",
    "film", "filme", "films", "filmes",
    "flair", "flaire", "flairs", "flaires",
    "fleur", "fleure", "fleurs", "fleures",
    "foi", "foie", "fois", "foies",
    "fond", "fonde", "fonds", "fondes",
    "font", "fonte", "fonts", "fontes",
    "for", "fore", "fors", "fores",
    "fragment", "fragmente", "fragments", "fragmentes",
    "frais", "fraise", "fraiss", "fraises",
    "frein", "freine", "freins", "freines",
    "fris", "frise", "friss", "frises",
    "fui", "fuie", "fuis", "fuies",
    "fuit", "fuite", "fuits", "fuites",
    "gag", "gage", "gags", "gages",
    "gain", "gaine", "gains", "gaines",
    "galop", "galope", "galops", "galopes",
    "gaz", "gaze", "gazs", "gazes",
    "gît", "gîte", "gîts", "gîtes",
    "gland", "glande", "glands", "glandes",
    "golf", "golfe", "golfs", "golfes",
    "gourd", "gourde", "gourds", "gourdes",
    "goût", "goûte", "goûts", "goûtes",
    "grain", "graine", "grains", "graines",
    "granit", "granite", "granits", "granites",
    "gravit", "gravite", "gravits", "gravites",
    "grill", "grille", "grills", "grilles",
    "guérit", "guérite", "guérits", "guérites",
    "guis", "guise", "guiss", "guises",
    "habit", "habite", "habits", "habites",
    "hall", "halle", "halls", "halles",
    "handicap", "handicape", "handicaps", "handicapes",
    "hasard", "hasarde", "hasards", "hasardes",
    "heur", "heure", "heurs", "heures",
    "heurt", "heurte", "heurts", "heurtes",
    "incident", "incidente", "incidents", "incidentes",
    "index", "indexe", "indexs", "indexes",
    "indivis", "indivise", "indiviss", "indivises",
    "induis", "induise", "induiss", "induises",
    "instruis", "instruise", "instruiss", "instruises",
    "interdis", "interdise", "interdiss", "interdises",
    "interview", "interviewe", "interviews", "interviewes",
    "introduis", "introduise", "introduiss", "introduises",
    "jailli", "jaillie", "jaillis", "jaillies",
    "jardin", "jardine", "jardins", "jardines",
    "jas", "jase", "jass", "jases",
    "jerrican", "jerricane", "jerricans", "jerricanes",
    "jeun", "jeune", "jeuns", "jeunes",
    "labour", "laboure", "labours", "laboures",
    "lac", "lace", "lacs", "laces",
    "lambin", "lambine", "lambins", "lambines",
    "land", "lande", "lands", "landes",
    "leitmotiv", "leitmotive", "leitmotivs", "leitmotives",
    "lès", "lèse", "lèss", "lèses",
    "lest", "leste", "lests", "lestes",
    "lieu", "lieue", "lieus", "lieues",
    "lis", "lise", "liss", "lises",
    "lob", "lobe", "lobs", "lobes",
    "long", "longe", "longs", "longes",
    "lot", "lote", "lots", "lotes",
    "loup", "loupe", "loups", "loupes",
    "lux", "luxe", "luxs", "luxes",
    "lys", "lyse", "lyss", "lyses",
    "machin", "machine", "machins", "machines",
    "major", "majore", "majors", "majores",
    "mandat", "mandate", "mandats", "mandates",
    "mari", "marie", "maris", "maries",
    "mat", "mate", "mats", "mates",
    "médiat", "médiate", "médiats", "médiates",
    "médis", "médise", "médiss", "médises",
    "ment", "mente", "ments", "mentes",
    "mess", "messe", "messs", "messes",
    "meut", "meute", "meuts", "meutes",
    "mi", "mie", "mis", "mies",
    "microfilm", "microfilme", "microfilms", "microfilmes",
    "mil", "mile", "mils", "miles",
    "min", "mine", "mins", "mines",
    "mit", "mite", "mits", "mites",
    "mont", "monte", "monts", "montes",
    "mord", "morde", "mords", "mordes",
    "mors", "morse", "morss", "morses",
    "mur", "mure", "murs", "mures",
    "ni", "nie", "nis", "nies",
    "nuis", "nuise", "nuiss", "nuises",
    "octroi", "octroie", "octrois", "octroies",
    "os", "ose", "oss", "oses",
    "oubli", "oublie", "oublis", "oublies",
    "pal", "pale", "pals", "pales",
    "pans", "panse", "panss", "panses",
    "par", "pare", "pars", "pares",
    "parc", "parce", "parcs", "parces",
    "parfum", "parfume", "parfums", "parfumes",
    "pari", "parie", "paris", "paries",
    "parlement", "parlemente", "parlements", "parlementes",
    "part", "parte", "parts", "partes",
    "patin", "patine", "patins", "patines",
    "pavois", "pavoise", "pavoiss", "pavoises",
    "pays", "payse", "payss", "payses",
    "pend", "pende", "pends", "pendes",
    "perd", "perde", "perds", "perdes",
    "pers", "perse", "perss", "perses",
    "pivot", "pivote", "pivots", "pivotes",
    "plaid", "plaide", "plaids", "plaides",
    "plais", "plaise", "plaiss", "plaises",
    "pleur", "pleure", "pleurs", "pleures",
    "pli", "plie", "plis", "plies",
    "plomb", "plombe", "plombs", "plombes",
    "pogrom", "pogrome", "pogroms", "pogromes",
    "poignard", "poignarde", "poignards", "poignardes",
    "point", "pointe", "points", "pointes",
    "pond", "ponde", "ponds", "pondes",
    "pont", "ponte", "ponts", "pontes",
    "port", "porte", "ports", "portes",
    "pot", "pote", "pots", "potes",
    "prétend", "prétende", "prétends", "prétendes",
    "produis", "produise", "produiss", "produises",
    "profil", "profile", "profils", "profiles",
    "profit", "profite", "profits", "profites",
    "propos", "propose", "proposs", "proposes",
    "pu", "pue", "pus", "pues",
    "puis", "puise", "puiss", "puises",
    "puisqu", "puisque", "puisqus", "puisques",
    "qu", "que", "qus", "ques",
    "rabot", "rabote", "rabots", "rabotes",
    "raccord", "raccorde", "raccords", "raccordes",
    "raid", "raide", "raids", "raides",
    "rajout", "rajoute", "rajouts", "rajoutes",
    "rang", "range", "rangs", "ranges",
    "rapport", "rapporte", "rapports", "rapportes",
    "ravis", "ravise", "raviss", "ravises",
    "rebut", "rebute", "rebuts", "rebutes",
    "récit", "récite", "récits", "récites",
    "reconduis", "reconduise", "reconduiss", "reconduises",
    "reconstruis", "reconstruise", "reconstruiss", "reconstruises",
    "recru", "recrue", "recrus", "recrues",
    "recul", "recule", "reculs", "recules",
    "redis", "redise", "rediss", "redises",
    "réduis", "réduise", "réduiss", "réduises",
    "réélis", "réélise", "rééliss", "réélises",
    "refond", "refonde", "refonds", "refondes",
    "refont", "refonte", "refonts", "refontes",
    "refus", "refuse", "refuss", "refuses",
    "régal", "régale", "régals", "régales",
    "regard", "regarde", "regards", "regardes",
    "rein", "reine", "reins", "reines",
    "réintroduis", "réintroduise", "réintroduiss", "réintroduises",
    "rejailli", "rejaillie", "rejaillis", "rejaillies",
    "relis", "relise", "reliss", "relises",
    "remblai", "remblaie", "remblais", "remblaies",
    "remploi", "remploie", "remplois", "remploies",
    "rend", "rende", "rends", "rendes",
    "renvoi", "renvoie", "renvois", "renvoies",
    "répand", "répande", "répands", "répandes",
    "repart", "reparte", "reparts", "repartes",
    "repens", "repense", "repenss", "repenses",
    "reperd", "reperde", "reperds", "reperdes",
    "répond", "réponde", "réponds", "répondes",
    "report", "reporte", "reports", "reportes",
    "repos", "repose", "reposs", "reposes",
    "reproduis", "reproduise", "reproduiss", "reproduises",
    "respect", "respecte", "respects", "respectes",
    "ressent", "ressente", "ressents", "ressentes",
    "ressort", "ressorte", "ressorts", "ressortes",
    "retard", "retarde", "retards", "retardes",
    "retraduis", "retraduise", "retraduiss", "retraduises",
    "retrait", "retraite", "retraits", "retraites",
    "revend", "revende", "revends", "revendes",
    "revêt", "revête", "revêts", "revêtes",
    "rhum", "rhume", "rhums", "rhumes",
    "ri", "rie", "ris", "ries",
    "rit", "rite", "rits", "rites",
    "sabord", "saborde", "sabords", "sabordes",
    "sabot", "sabote", "sabots", "sabotes",
    "séduis", "séduise", "séduiss", "séduises",
    "sent", "sente", "sents", "sentes",
    "serin", "serine", "serins", "serines",
    "serpent", "serpente", "serpents", "serpentes",
    "signal", "signale", "signals", "signales",
    "sis", "sise", "siss", "sises",
    "ski", "skie", "skis", "skies",
    "soi", "soie", "sois", "soies",
    "sol", "sole", "sols", "soles",
    "sort", "sorte", "sorts", "sortes",
    "souci", "soucie", "soucis", "soucies",
    "souhait", "souhaite", "souhaits", "souhaites",
    "soupent", "soupente", "soupents", "soupentes",
    "soupir", "soupire", "soupirs", "soupires",
    "souri", "sourie", "souris", "souries",
    "sprint", "sprinte", "sprints", "sprintes",
    "statu", "statue", "status", "statues",
    "stock", "stocke", "stocks", "stockes",
    "su", "sue", "sus", "sues",
    "suc", "suce", "sucs", "suces",
    "suffis", "suffise", "suffiss", "suffises",
    "suint", "suinte", "suints", "suintes",
    "suit", "suite", "suits", "suites",
    "support", "supporte", "supports", "supportes",
    "sur", "sure", "surs", "sures",
    "surf", "surfe", "surfs", "surfes",
    "surgi", "surgie", "surgis", "surgies",
    "surplomb", "surplombe", "surplombs", "surplombes",
    "sursaut", "sursaute", "sursauts", "sursautes",
    "survol", "survole", "survols", "survoles",
    "suspend", "suspende", "suspends", "suspendes",
    "suspens", "suspense", "suspenss", "suspenses",
    "tais", "taise", "taiss", "taises",
    "tambourin", "tambourine", "tambourins", "tambourines",
    "tard", "tarde", "tards", "tardes",
    "tarif", "tarife", "tarifs", "tarifes",
    "tend", "tende", "tends", "tendes",
    "test", "teste", "tests", "testes",
    "tint", "tinte", "tints", "tintes",
    "tir", "tire", "tirs", "tires",
    "titan", "titane", "titans", "titanes",
    "tond", "tonde", "tonds", "tondes",
    "tord", "torde", "tords", "tordes",
    "tors", "torse", "torss", "torses",
    "tourment", "tourmente", "tourments", "tourmentes",
    "tournoi", "tournoie", "tournois", "tournoies",
    "trac", "trace", "tracs", "traces",
    "tract", "tracte", "tracts", "tractes",
    "traduis", "traduise", "traduiss", "traduises",
    "trait", "traite", "traits", "traites",
    "tram", "trame", "trams", "trames",
    "transit", "transite", "transits", "transites",
    "transport", "transporte", "transports", "transportes",
    "travers", "traverse", "traverss", "traverses",
    "trépan", "trépane", "trépans", "trépanes",
    "tri", "trie", "tris", "tries",
    "tricot", "tricote", "tricots", "tricotes",
    "trop", "trope", "trops", "tropes",
    "trou", "troue", "trous", "troues",
    "trust", "truste", "trusts", "trustes",
    "tu", "tue", "tus", "tues",
    "us", "use", "uss", "uses",
    "vaccin", "vaccine", "vaccins", "vaccines",
    "vals", "valse", "valss", "valses",
    "valu", "value", "valus", "values",
    "vas", "vase", "vass", "vases",
    "vend", "vende", "vends", "vendes",
    "vent", "vente", "vents", "ventes",
    "vers", "verse", "verss", "verses",
    "vêt", "vête", "vêts", "vêtes",
    "viol", "viole", "viols", "violes",
    "vis", "vise", "viss", "vises",
    "vit", "vite", "vits", "vites",
    "voir", "voire", "voirs", "voires",
    "vol", "vole", "vols", "voles",
])

# %% [markdown]
# Cette première passe très simple a ajouté plein de mots, c'était rapide et facile mais au prix d'avoir plein de faux positifs (des mots qui ne devraient pas être rajoutés)...

# %%
print(f"{len(mots_inclusifs_singuliers)} nouveaux mots inclusifs singuliers")  # 5813
print(f"{len(mots_inclusifs_pluriels)} nouveaux mots inclusifs pluriels")      # 5244
# Out:
# 5813 nouveaux mots inclusifs singuliers
# 5244 nouveaux mots inclusifs pluriels

# %% [markdown]
# ### Ajouter mot·x·se et mot·x·ses si `mot`-x, `mot`-se et `mot`-ses sont présents

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("x") and len(mot) > 1:
        mot_feminin = f"{mot[:-1]}se"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-1]}x{SEP}se"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}
        mot_feminin = f"{mot[:-1]}ses"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-1]}x{SEP}se{SEP}s"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# adipeux              / adipeuse             -> adipeux·se
# adipeux              / adipeuses            -> adipeux·se·s
# affectueux           / affectueuse          -> affectueux·se
# affectueux           / affectueuses         -> affectueux·se·s
# affreux              / affreuse             -> affreux·se
# affreux              / affreuses            -> affreux·se·s
# ambitieux            / ambitieuse           -> ambitieux·se
# ambitieux            / ambitieuses          -> ambitieux·se·s
# amoureux             / amoureuse            -> amoureux·se
# amoureux             / amoureuses           -> amoureux·se·s
# anguleux             / anguleuse            -> anguleux·se
# anguleux             / anguleuses           -> anguleux·se·s
# anticancéreux        / anticancéreuse       -> anticancéreux·se
# anticancéreux        / anticancéreuses      -> anticancéreux·se·s
# antireligieux        / antireligieuse       -> antireligieux·se
# antireligieux        / antireligieuses      -> antireligieux·se·s
# antituberculeux      / antituberculeuse     -> antituberculeux·se
# antituberculeux      / antituberculeuses    -> antituberculeux·se·s
# antivenimeux         / antivenimeuse        -> antivenimeux·se
# antivenimeux         / antivenimeuses       -> antivenimeux·se·s
# anxieux              / anxieuse             -> anxieux·se
# anxieux              / anxieuses            -> anxieux·se·s
# aqueux               / aqueuse              -> aqueux·se
# aqueux               / aqueuses             -> aqueux·se·s
# argileux             / argileuse            -> argileux·se
# argileux             / argileuses           -> argileux·se·s
# artificieux          / artificieuse         -> artificieux·se
# artificieux          / artificieuses        -> artificieux·se·s
# astucieux            / astucieuse           -> astucieux·se
# astucieux            / astucieuses          -> astucieux·se·s
# audacieux            / audacieuse           -> audacieux·se
# audacieux            / audacieuses          -> audacieux·se·s
# avantageux           / avantageuse          -> avantageux·se
# avantageux           / avantageuses         -> avantageux·se·s
# aventureux           / aventureuse          -> aventureux·se
# aventureux           / aventureuses         -> aventureux·se·s
# baveux               / baveuse              -> baveux·se
# baveux               / baveuses             -> baveux·se·s
# belliqueux           / belliqueuse          -> belliqueux·se
# belliqueux           / belliqueuses         -> belliqueux·se·s
# besogneux            / besogneuse           -> besogneux·se
# besogneux            / besogneuses          -> besogneux·se·s
# bienheureux          / bienheureuse         -> bienheureux·se
# bienheureux          / bienheureuses        -> bienheureux·se·s
# bilieux              / bilieuse             -> bilieux·se
# bilieux              / bilieuses            -> bilieux·se·s
# boiteux              / boiteuse             -> boiteux·se
# boiteux              / boiteuses            -> boiteux·se·s
# boueux               / boueuse              -> boueux·se
# boueux               / boueuses             -> boueux·se·s
# bourbeux             / bourbeuse            -> bourbeux·se
# bourbeux             / bourbeuses           -> bourbeux·se·s
# boutonneux           / boutonneuse          -> boutonneux·se
# boutonneux           / boutonneuses         -> boutonneux·se·s
# bronchiteux          / bronchiteuse         -> bronchiteux·se
# bronchiteux          / bronchiteuses        -> bronchiteux·se·s
# broussailleux        / broussailleuse       -> broussailleux·se
# broussailleux        / broussailleuses      -> broussailleux·se·s
# brumeux              / brumeuse             -> brumeux·se
# brumeux              / brumeuses            -> brumeux·se·s
# buissonneux          / buissonneuse         -> buissonneux·se
# buissonneux          / buissonneuses        -> buissonneux·se·s
# bulbeux              / bulbeuse             -> bulbeux·se
# bulbeux              / bulbeuses            -> bulbeux·se·s
# cadavéreux           / cadavéreuse          -> cadavéreux·se
# cadavéreux           / cadavéreuses         -> cadavéreux·se·s
# cafardeux            / cafardeuse           -> cafardeux·se
# cafardeux            / cafardeuses          -> cafardeux·se·s
# cagneux              / cagneuse             -> cagneux·se
# cagneux              / cagneuses            -> cagneux·se·s
# cahoteux             / cahoteuse            -> cahoteux·se
# cahoteux             / cahoteuses           -> cahoteux·se·s
# caillouteux          / caillouteuse         -> caillouteux·se
# caillouteux          / caillouteuses        -> caillouteux·se·s
# calamiteux           / calamiteuse          -> calamiteux·se
# calamiteux           / calamiteuses         -> calamiteux·se·s
# calleux              / calleuse             -> calleux·se
# calleux              / calleuses            -> calleux·se·s
# calomnieux           / calomnieuse          -> calomnieux·se
# calomnieux           / calomnieuses         -> calomnieux·se·s
# cancéreux            / cancéreuse           -> cancéreux·se
# cancéreux            / cancéreuses          -> cancéreux·se·s
# caoutchouteux        / caoutchouteuse       -> caoutchouteux·se
# caoutchouteux        / caoutchouteuses      -> caoutchouteux·se·s
# capiteux             / capiteuse            -> capiteux·se
# capiteux             / capiteuses           -> capiteux·se·s
# capricieux           / capricieuse          -> capricieux·se
# capricieux           / capricieuses         -> capricieux·se·s
# cartilagineux        / cartilagineuse       -> cartilagineux·se
# cartilagineux        / cartilagineuses      -> cartilagineux·se·s
# caverneux            / caverneuse           -> caverneux·se
# caverneux            / caverneuses          -> caverneux·se·s
# cérémonieux          / cérémonieuse         -> cérémonieux·se
# cérémonieux          / cérémonieuses        -> cérémonieux·se·s
# chaleureux           / chaleureuse          -> chaleureux·se
# chaleureux           / chaleureuses         -> chaleureux·se·s
# chanceux             / chanceuse            -> chanceux·se
# chanceux             / chanceuses           -> chanceux·se·s
# charbonneux          / charbonneuse         -> charbonneux·se
# charbonneux          / charbonneuses        -> charbonneux·se·s
# chartreux            / chartreuse           -> chartreux·se
# chartreux            / chartreuses          -> chartreux·se·s
# chatouilleux         / chatouilleuse        -> chatouilleux·se
# chatouilleux         / chatouilleuses       -> chatouilleux·se·s
# cireux               / cireuse              -> cireux·se
# cireux               / cireuses             -> cireux·se·s
# coléreux             / coléreuse            -> coléreux·se
# coléreux             / coléreuses           -> coléreux·se·s
# comateux             / comateuse            -> comateux·se
# comateux             / comateuses           -> comateux·se·s
# consciencieux        / consciencieuse       -> consciencieux·se
# consciencieux        / consciencieuses      -> consciencieux·se·s
# contagieux           / contagieuse          -> contagieux·se
# contagieux           / contagieuses         -> contagieux·se·s
# contentieux          / contentieuse         -> contentieux·se
# contentieux          / contentieuses        -> contentieux·se·s
# copieux              / copieuse             -> copieux·se
# copieux              / copieuses            -> copieux·se·s
# cotonneux            / cotonneuse           -> cotonneux·se
# cotonneux            / cotonneuses          -> cotonneux·se·s
# courageux            / courageuse           -> courageux·se
# courageux            / courageuses          -> courageux·se·s
# coûteux              / coûteuse             -> coûteux·se
# coûteux              / coûteuses            -> coûteux·se·s
# crapuleux            / crapuleuse           -> crapuleux·se
# crapuleux            / crapuleuses          -> crapuleux·se·s
# crasseux             / crasseuse            -> crasseux·se
# crasseux             / crasseuses           -> crasseux·se·s
# crayeux              / crayeuse             -> crayeux·se
# crayeux              / crayeuses            -> crayeux·se·s
# crémeux              / crémeuse             -> crémeux·se
# crémeux              / crémeuses            -> crémeux·se·s
# creux                / creuse               -> creux·se
# creux                / creuses              -> creux·se·s
# croix                / croise               -> croix·se
# croix                / croises              -> croix·se·s
# cuivreux             / cuivreuse            -> cuivreux·se
# cuivreux             / cuivreuses           -> cuivreux·se·s
# curieux              / curieuse             -> curieux·se
# curieux              / curieuses            -> curieux·se·s
# dangereux            / dangereuse           -> dangereux·se
# dangereux            / dangereuses          -> dangereux·se·s
# dédaigneux           / dédaigneuse          -> dédaigneux·se
# dédaigneux           / dédaigneuses         -> dédaigneux·se·s
# défectueux           / défectueuse          -> défectueux·se
# défectueux           / défectueuses         -> défectueux·se·s
# délicieux            / délicieuse           -> délicieux·se
# délicieux            / délicieuses          -> délicieux·se·s
# délictueux           / délictueuse          -> délictueux·se
# délictueux           / délictueuses         -> délictueux·se·s
# désastreux           / désastreuse          -> désastreux·se
# désastreux           / désastreuses         -> désastreux·se·s
# désavantageux        / désavantageuse       -> désavantageux·se
# désavantageux        / désavantageuses      -> désavantageux·se·s
# désireux             / désireuse            -> désireux·se
# désireux             / désireuses           -> désireux·se·s
# disgracieux          / disgracieuse         -> disgracieux·se
# disgracieux          / disgracieuses        -> disgracieux·se·s
# dispendieux          / dispendieuse         -> dispendieux·se
# dispendieux          / dispendieuses        -> dispendieux·se·s
# dix                  / dise                 -> dix·se
# dix                  / dises                -> dix·se·s
# doucereux            / doucereuse           -> doucereux·se
# doucereux            / doucereuses          -> doucereux·se·s
# douloureux           / douloureuse          -> douloureux·se
# douloureux           / douloureuses         -> douloureux·se·s
# douteux              / douteuse             -> douteux·se
# douteux              / douteuses            -> douteux·se·s
# duveteux             / duveteuse            -> duveteux·se
# duveteux             / duveteuses           -> duveteux·se·s
# écumeux              / écumeuse             -> écumeux·se
# écumeux              / écumeuses            -> écumeux·se·s
# eczémateux           / eczémateuse          -> eczémateux·se
# eczémateux           / eczémateuses         -> eczémateux·se·s
# élogieux             / élogieuse            -> élogieux·se
# élogieux             / élogieuses           -> élogieux·se·s
# ennuyeux             / ennuyeuse            -> ennuyeux·se
# ennuyeux             / ennuyeuses           -> ennuyeux·se·s
# envieux              / envieuse             -> envieux·se
# envieux              / envieuses            -> envieux·se·s
# épineux              / épineuse             -> épineux·se
# épineux              / épineuses            -> épineux·se·s
# époux                / épouse               -> époux·se
# époux                / épouses              -> époux·se·s
# fabuleux             / fabuleuse            -> fabuleux·se
# fabuleux             / fabuleuses           -> fabuleux·se·s
# facétieux            / facétieuse           -> facétieux·se
# facétieux            / facétieuses          -> facétieux·se·s
# fâcheux              / fâcheuse             -> fâcheux·se
# fâcheux              / fâcheuses            -> fâcheux·se·s
# factieux             / factieuse            -> factieux·se
# factieux             / factieuses           -> factieux·se·s
# fallacieux           / fallacieuse          -> fallacieux·se
# fallacieux           / fallacieuses         -> fallacieux·se·s
# fameux               / fameuse              -> fameux·se
# fameux               / fameuses             -> fameux·se·s
# fangeux              / fangeuse             -> fangeux·se
# fangeux              / fangeuses            -> fangeux·se·s
# faramineux           / faramineuse          -> faramineux·se
# faramineux           / faramineuses         -> faramineux·se·s
# farineux             / farineuse            -> farineux·se
# farineux             / farineuses           -> farineux·se·s
# fastidieux           / fastidieuse          -> fastidieux·se
# fastidieux           / fastidieuses         -> fastidieux·se·s
# fastueux             / fastueuse            -> fastueux·se
# fastueux             / fastueuses           -> fastueux·se·s
# ferrugineux          / ferrugineuse         -> ferrugineux·se
# ferrugineux          / ferrugineuses        -> ferrugineux·se·s
# fibreux              / fibreuse             -> fibreux·se
# fibreux              / fibreuses            -> fibreux·se·s
# fielleux             / fielleuse            -> fielleux·se
# fielleux             / fielleuses           -> fielleux·se·s
# fiévreux             / fiévreuse            -> fiévreux·se
# fiévreux             / fiévreuses           -> fiévreux·se·s
# filamenteux          / filamenteuse         -> filamenteux·se
# filamenteux          / filamenteuses        -> filamenteux·se·s
# filandreux           / filandreuse          -> filandreux·se
# filandreux           / filandreuses         -> filandreux·se·s
# floconneux           / floconneuse          -> floconneux·se
# floconneux           / floconneuses         -> floconneux·se·s
# fougueux             / fougueuse            -> fougueux·se
# fougueux             / fougueuses           -> fougueux·se·s
# frauduleux           / frauduleuse          -> frauduleux·se
# frauduleux           / frauduleuses         -> frauduleux·se·s
# frileux              / frileuse             -> frileux·se
# frileux              / frileuses            -> frileux·se·s
# fructueux            / fructueuse           -> fructueux·se
# fructueux            / fructueuses          -> fructueux·se·s
# fuligineux           / fuligineuse          -> fuligineux·se
# fuligineux           / fuligineuses         -> fuligineux·se·s
# furieux              / furieuse             -> furieux·se
# furieux              / furieuses            -> furieux·se·s
# galeux               / galeuse              -> galeux·se
# galeux               / galeuses             -> galeux·se·s
# gâteux               / gâteuse              -> gâteux·se
# gâteux               / gâteuses             -> gâteux·se·s
# gazeux               / gazeuse              -> gazeux·se
# gazeux               / gazeuses             -> gazeux·se·s
# gélatineux           / gélatineuse          -> gélatineux·se
# gélatineux           / gélatineuses         -> gélatineux·se·s
# généreux             / généreuse            -> généreux·se
# généreux             / généreuses           -> généreux·se·s
# giboyeux             / giboyeuse            -> giboyeux·se
# giboyeux             / giboyeuses           -> giboyeux·se·s
# glaireux             / glaireuse            -> glaireux·se
# glaireux             / glaireuses           -> glaireux·se·s
# glaiseux             / glaiseuse            -> glaiseux·se
# glaiseux             / glaiseuses           -> glaiseux·se·s
# globuleux            / globuleuse           -> globuleux·se
# globuleux            / globuleuses          -> globuleux·se·s
# glorieux             / glorieuse            -> glorieux·se
# glorieux             / glorieuses           -> glorieux·se·s
# goitreux             / goitreuse            -> goitreux·se
# goitreux             / goitreuses           -> goitreux·se·s
# gommeux              / gommeuse             -> gommeux·se
# gommeux              / gommeuses            -> gommeux·se·s
# goudronneux          / goudronneuse         -> goudronneux·se
# goudronneux          / goudronneuses        -> goudronneux·se·s
# gracieux             / gracieuse            -> gracieux·se
# gracieux             / gracieuses           -> gracieux·se·s
# graisseux            / graisseuse           -> graisseux·se
# graisseux            / graisseuses          -> graisseux·se·s
# granuleux            / granuleuse           -> granuleux·se
# granuleux            / granuleuses          -> granuleux·se·s
# graveleux            / graveleuse           -> graveleux·se
# graveleux            / graveleuses          -> graveleux·se·s
# grincheux            / grincheuse           -> grincheux·se
# grincheux            / grincheuses          -> grincheux·se·s
# grumeleux            / grumeleuse           -> grumeleux·se
# grumeleux            / grumeleuses          -> grumeleux·se·s
# haineux              / haineuse             -> haineux·se
# haineux              / haineuses            -> haineux·se·s
# hargneux             / hargneuse            -> hargneux·se
# hargneux             / hargneuses           -> hargneux·se·s
# harmonieux           / harmonieuse          -> harmonieux·se
# harmonieux           / harmonieuses         -> harmonieux·se·s
# hasardeux            / hasardeuse           -> hasardeux·se
# hasardeux            / hasardeuses          -> hasardeux·se·s
# herbeux              / herbeuse             -> herbeux·se
# herbeux              / herbeuses            -> herbeux·se·s
# heureux              / heureuse             -> heureux·se
# heureux              / heureuses            -> heureux·se·s
# hideux               / hideuse              -> hideux·se
# hideux               / hideuses             -> hideux·se·s
# honteux              / honteuse             -> honteux·se
# honteux              / honteuses            -> honteux·se·s
# houleux              / houleuse             -> houleux·se
# houleux              / houleuses            -> houleux·se·s
# huileux              / huileuse             -> huileux·se
# huileux              / huileuses            -> huileux·se·s
# hypernerveux         / hypernerveuse        -> hypernerveux·se
# hypernerveux         / hypernerveuses       -> hypernerveux·se·s
# ignominieux          / ignominieuse         -> ignominieux·se
# ignominieux          / ignominieuses        -> ignominieux·se·s
# impécunieux          / impécunieuse         -> impécunieux·se
# impécunieux          / impécunieuses        -> impécunieux·se·s
# impérieux            / impérieuse           -> impérieux·se
# impérieux            / impérieuses          -> impérieux·se·s
# impétueux            / impétueuse           -> impétueux·se
# impétueux            / impétueuses          -> impétueux·se·s
# incestueux           / incestueuse          -> incestueux·se
# incestueux           / incestueuses         -> incestueux·se·s
# industrieux          / industrieuse         -> industrieux·se
# industrieux          / industrieuses        -> industrieux·se·s
# infectieux           / infectieuse          -> infectieux·se
# infectieux           / infectieuses         -> infectieux·se·s
# infructueux          / infructueuse         -> infructueux·se
# infructueux          / infructueuses        -> infructueux·se·s
# ingénieux            / ingénieuse           -> ingénieux·se
# ingénieux            / ingénieuses          -> ingénieux·se·s
# inharmonieux         / inharmonieuse        -> inharmonieux·se
# inharmonieux         / inharmonieuses       -> inharmonieux·se·s
# injurieux            / injurieuse           -> injurieux·se
# injurieux            / injurieuses          -> injurieux·se·s
# insidieux            / insidieuse           -> insidieux·se
# insidieux            / insidieuses          -> insidieux·se·s
# insoucieux           / insoucieuse          -> insoucieux·se
# insoucieux           / insoucieuses         -> insoucieux·se·s
# intraveineux         / intraveineuse        -> intraveineux·se
# intraveineux         / intraveineuses       -> intraveineux·se·s
# irréligieux          / irréligieuse         -> irréligieux·se
# irréligieux          / irréligieuses        -> irréligieux·se·s
# irrespectueux        / irrespectueuse       -> irrespectueux·se
# irrespectueux        / irrespectueuses      -> irrespectueux·se·s
# irrévérencieux       / irrévérencieuse      -> irrévérencieux·se
# irrévérencieux       / irrévérencieuses     -> irrévérencieux·se·s
# jaloux               / jalouse              -> jaloux·se
# jaloux               / jalouses             -> jaloux·se·s
# joyeux               / joyeuse              -> joyeux·se
# joyeux               / joyeuses             -> joyeux·se·s
# judicieux            / judicieuse           -> judicieux·se
# judicieux            / judicieuses          -> judicieux·se·s
# juteux               / juteuse              -> juteux·se
# juteux               / juteuses             -> juteux·se·s
# laborieux            / laborieuse           -> laborieux·se
# laborieux            / laborieuses          -> laborieux·se·s
# laineux              / laineuse             -> laineux·se
# laineux              / laineuses            -> laineux·se·s
# laiteux              / laiteuse             -> laiteux·se
# laiteux              / laiteuses            -> laiteux·se·s
# langoureux           / langoureuse          -> langoureux·se
# langoureux           / langoureuses         -> langoureux·se·s
# lépreux              / lépreuse             -> lépreux·se
# lépreux              / lépreuses            -> lépreux·se·s
# libidineux           / libidineuse          -> libidineux·se
# libidineux           / libidineuses         -> libidineux·se·s
# licencieux           / licencieuse          -> licencieux·se
# licencieux           / licencieuses         -> licencieux·se·s
# lieux                / lieuse               -> lieux·se
# lieux                / lieuses              -> lieux·se·s
# ligamenteux          / ligamenteuse         -> ligamenteux·se
# ligamenteux          / ligamenteuses        -> ligamenteux·se·s
# ligneux              / ligneuse             -> ligneux·se
# ligneux              / ligneuses            -> ligneux·se·s
# limoneux             / limoneuse            -> limoneux·se
# limoneux             / limoneuses           -> limoneux·se·s
# liquoreux            / liquoreuse           -> liquoreux·se
# liquoreux            / liquoreuses          -> liquoreux·se·s
# litigieux            / litigieuse           -> litigieux·se
# litigieux            / litigieuses          -> litigieux·se·s
# loqueteux            / loqueteuse           -> loqueteux·se
# loqueteux            / loqueteuses          -> loqueteux·se·s
# lumineux             / lumineuse            -> lumineux·se
# lumineux             / lumineuses           -> lumineux·se·s
# luxueux              / luxueuse             -> luxueux·se
# luxueux              / luxueuses            -> luxueux·se·s
# luxurieux            / luxurieuse           -> luxurieux·se
# luxurieux            / luxurieuses          -> luxurieux·se·s
# majestueux           / majestueuse          -> majestueux·se
# majestueux           / majestueuses         -> majestueux·se·s
# malchanceux          / malchanceuse         -> malchanceux·se
# malchanceux          / malchanceuses        -> malchanceux·se·s
# malencontreux        / malencontreuse       -> malencontreux·se
# malencontreux        / malencontreuses      -> malencontreux·se·s
# malheureux           / malheureuse          -> malheureux·se
# malheureux           / malheureuses         -> malheureux·se·s
# malicieux            / malicieuse           -> malicieux·se
# malicieux            / malicieuses          -> malicieux·se·s
# marécageux           / marécageuse          -> marécageux·se
# marécageux           / marécageuses         -> marécageux·se·s
# marneux              / marneuse             -> marneux·se
# marneux              / marneuses            -> marneux·se·s
# matheux              / matheuse             -> matheux·se
# matheux              / matheuses            -> matheux·se·s
# médicamenteux        / médicamenteuse       -> médicamenteux·se
# médicamenteux        / médicamenteuses      -> médicamenteux·se·s
# mélodieux            / mélodieuse           -> mélodieux·se
# mélodieux            / mélodieuses          -> mélodieux·se·s
# membraneux           / membraneuse          -> membraneux·se
# membraneux           / membraneuses         -> membraneux·se·s
# merveilleux          / merveilleuse         -> merveilleux·se
# merveilleux          / merveilleuses        -> merveilleux·se·s
# méticuleux           / méticuleuse          -> méticuleux·se
# méticuleux           / méticuleuses         -> méticuleux·se·s
# mielleux             / mielleuse            -> mielleux·se
# mielleux             / mielleuses           -> mielleux·se·s
# migraineux           / migraineuse          -> migraineux·se
# migraineux           / migraineuses         -> migraineux·se·s
# minutieux            / minutieuse           -> minutieux·se
# minutieux            / minutieuses          -> minutieux·se·s
# miraculeux           / miraculeuse          -> miraculeux·se
# miraculeux           / miraculeuses         -> miraculeux·se·s
# miséreux             / miséreuse            -> miséreux·se
# miséreux             / miséreuses           -> miséreux·se·s
# miséricordieux       / miséricordieuse      -> miséricordieux·se
# miséricordieux       / miséricordieuses     -> miséricordieux·se·s
# miteux               / miteuse              -> miteux·se
# miteux               / miteuses             -> miteux·se·s
# moelleux             / moelleuse            -> moelleux·se
# moelleux             / moelleuses           -> moelleux·se·s
# molletonneux         / molletonneuse        -> molletonneux·se
# molletonneux         / molletonneuses       -> molletonneux·se·s
# monstrueux           / monstrueuse          -> monstrueux·se
# monstrueux           / monstrueuses         -> monstrueux·se·s
# montagneux           / montagneuse          -> montagneux·se
# montagneux           / montagneuses         -> montagneux·se·s
# morveux              / morveuse             -> morveux·se
# morveux              / morveuses            -> morveux·se·s
# mousseux             / mousseuse            -> mousseux·se
# mousseux             / mousseuses           -> mousseux·se·s
# moyenâgeux           / moyenâgeuse          -> moyenâgeux·se
# moyenâgeux           / moyenâgeuses         -> moyenâgeux·se·s
# mystérieux           / mystérieuse          -> mystérieux·se
# mystérieux           / mystérieuses         -> mystérieux·se·s
# nauséeux             / nauséeuse            -> nauséeux·se
# nauséeux             / nauséeuses           -> nauséeux·se·s
# nébuleux             / nébuleuse            -> nébuleux·se
# nébuleux             / nébuleuses           -> nébuleux·se·s
# nécessiteux          / nécessiteuse         -> nécessiteux·se
# nécessiteux          / nécessiteuses        -> nécessiteux·se·s
# neigeux              / neigeuse             -> neigeux·se
# neigeux              / neigeuses            -> neigeux·se·s
# nerveux              / nerveuse             -> nerveux·se
# nerveux              / nerveuses            -> nerveux·se·s
# noix                 / noise                -> noix·se
# noix                 / noises               -> noix·se·s
# nombreux             / nombreuse            -> nombreux·se
# nombreux             / nombreuses           -> nombreux·se·s
# noueux               / noueuse              -> noueux·se
# noueux               / noueuses             -> noueux·se·s
# nuageux              / nuageuse             -> nuageux·se
# nuageux              / nuageuses            -> nuageux·se·s
# obséquieux           / obséquieuse          -> obséquieux·se
# obséquieux           / obséquieuses         -> obséquieux·se·s
# odieux               / odieuse              -> odieux·se
# odieux               / odieuses             -> odieux·se·s
# oedémateux           / oedémateuse          -> oedémateux·se
# oedémateux           / oedémateuses         -> oedémateux·se·s
# officieux            / officieuse           -> officieux·se
# officieux            / officieuses          -> officieux·se·s
# oiseux               / oiseuse              -> oiseux·se
# oiseux               / oiseuses             -> oiseux·se·s
# oléagineux           / oléagineuse          -> oléagineux·se
# oléagineux           / oléagineuses         -> oléagineux·se·s
# ombrageux            / ombrageuse           -> ombrageux·se
# ombrageux            / ombrageuses          -> ombrageux·se·s
# onctueux             / onctueuse            -> onctueux·se
# onctueux             / onctueuses           -> onctueux·se·s
# onduleux             / onduleuse            -> onduleux·se
# onduleux             / onduleuses           -> onduleux·se·s
# onéreux              / onéreuse             -> onéreux·se
# onéreux              / onéreuses            -> onéreux·se·s
# orageux              / orageuse             -> orageux·se
# orageux              / orageuses            -> orageux·se·s
# orgueilleux          / orgueilleuse         -> orgueilleux·se
# orgueilleux          / orgueilleuses        -> orgueilleux·se·s
# osseux               / osseuse              -> osseux·se
# osseux               / osseuses             -> osseux·se·s
# oublieux             / oublieuse            -> oublieux·se
# oublieux             / oublieuses           -> oublieux·se·s
# outrageux            / outrageuse           -> outrageux·se
# outrageux            / outrageuses          -> outrageux·se·s
# parcimonieux         / parcimonieuse        -> parcimonieux·se
# parcimonieux         / parcimonieuses       -> parcimonieux·se·s
# paresseux            / paresseuse           -> paresseux·se
# paresseux            / paresseuses          -> paresseux·se·s
# pâteux               / pâteuse              -> pâteux·se
# pâteux               / pâteuses             -> pâteux·se·s
# pelucheux            / pelucheuse           -> pelucheux·se
# pelucheux            / pelucheuses          -> pelucheux·se·s
# périlleux            / périlleuse           -> périlleux·se
# périlleux            / périlleuses          -> périlleux·se·s
# pernicieux           / pernicieuse          -> pernicieux·se
# pernicieux           / pernicieuses         -> pernicieux·se·s
# peureux              / peureuse             -> peureux·se
# peureux              / peureuses            -> peureux·se·s
# pierreux             / pierreuse            -> pierreux·se
# pierreux             / pierreuses           -> pierreux·se·s
# pieux                / pieuse               -> pieux·se
# pieux                / pieuses              -> pieux·se·s
# pileux               / pileuse              -> pileux·se
# pileux               / pileuses             -> pileux·se·s
# piteux               / piteuse              -> piteux·se
# piteux               / piteuses             -> piteux·se·s
# plantureux           / plantureuse          -> plantureux·se
# plantureux           / plantureuses         -> plantureux·se·s
# pluvieux             / pluvieuse            -> pluvieux·se
# pluvieux             / pluvieuses           -> pluvieux·se·s
# pointilleux          / pointilleuse         -> pointilleux·se
# pointilleux          / pointilleuses        -> pointilleux·se·s
# poisseux             / poisseuse            -> poisseux·se
# poisseux             / poisseuses           -> poisseux·se·s
# poissonneux          / poissonneuse         -> poissonneux·se
# poissonneux          / poissonneuses        -> poissonneux·se·s
# pompeux              / pompeuse             -> pompeux·se
# pompeux              / pompeuses            -> pompeux·se·s
# pondéreux            / pondéreuse           -> pondéreux·se
# pondéreux            / pondéreuses          -> pondéreux·se·s
# populeux             / populeuse            -> populeux·se
# populeux             / populeuses           -> populeux·se·s
# poreux               / poreuse              -> poreux·se
# poreux               / poreuses             -> poreux·se·s
# poudreux             / poudreuse            -> poudreux·se
# poudreux             / poudreuses           -> poudreux·se·s
# pouilleux            / pouilleuse           -> pouilleux·se
# pouilleux            / pouilleuses          -> pouilleux·se·s
# poussiéreux          / poussiéreuse         -> poussiéreux·se
# poussiéreux          / poussiéreuses        -> poussiéreux·se·s
# précautionneux       / précautionneuse      -> précautionneux·se
# précautionneux       / précautionneuses     -> précautionneux·se·s
# précieux             / précieuse            -> précieux·se
# précieux             / précieuses           -> précieux·se·s
# présomptueux         / présomptueuse        -> présomptueux·se
# présomptueux         / présomptueuses       -> présomptueux·se·s
# prestigieux          / prestigieuse         -> prestigieux·se
# prestigieux          / prestigieuses        -> prestigieux·se·s
# prétentieux          / prétentieuse         -> prétentieux·se
# prétentieux          / prétentieuses        -> prétentieux·se·s
# prix                 / prise                -> prix·se
# prix                 / prises               -> prix·se·s
# prodigieux           / prodigieuse          -> prodigieux·se
# prodigieux           / prodigieuses         -> prodigieux·se·s
# pustuleux            / pustuleuse           -> pustuleux·se
# pustuleux            / pustuleuses          -> pustuleux·se·s
# raboteux             / raboteuse            -> raboteux·se
# raboteux             / raboteuses           -> raboteux·se·s
# radieux              / radieuse             -> radieux·se
# radieux              / radieuses            -> radieux·se·s
# râpeux               / râpeuse              -> râpeux·se
# râpeux               / râpeuses             -> râpeux·se·s
# religieux            / religieuse           -> religieux·se
# religieux            / religieuses          -> religieux·se·s
# résineux             / résineuse            -> résineux·se
# résineux             / résineuses           -> résineux·se·s
# respectueux          / respectueuse         -> respectueux·se
# respectueux          / respectueuses        -> respectueux·se·s
# révérencieux         / révérencieuse        -> révérencieux·se
# révérencieux         / révérencieuses       -> révérencieux·se·s
# rigoureux            / rigoureuse           -> rigoureux·se
# rigoureux            / rigoureuses          -> rigoureux·se·s
# rocailleux           / rocailleuse          -> rocailleux·se
# rocailleux           / rocailleuses         -> rocailleux·se·s
# rocheux              / rocheuse             -> rocheux·se
# rocheux              / rocheuses            -> rocheux·se·s
# rugueux              / rugueuse             -> rugueux·se
# rugueux              / rugueuses            -> rugueux·se·s
# ruineux              / ruineuse             -> ruineux·se
# ruineux              / ruineuses            -> ruineux·se·s
# sableux              / sableuse             -> sableux·se
# sableux              / sableuses            -> sableux·se·s
# sablonneux           / sablonneuse          -> sablonneux·se
# sablonneux           / sablonneuses         -> sablonneux·se·s
# savonneux            / savonneuse           -> savonneux·se
# savonneux            / savonneuses          -> savonneux·se·s
# savoureux            / savoureuse           -> savoureux·se
# savoureux            / savoureuses          -> savoureux·se·s
# scabreux             / scabreuse            -> scabreux·se
# scabreux             / scabreuses           -> scabreux·se·s
# scandaleux           / scandaleuse          -> scandaleux·se
# scandaleux           / scandaleuses         -> scandaleux·se·s
# schisteux            / schisteuse           -> schisteux·se
# schisteux            / schisteuses          -> schisteux·se·s
# scrupuleux           / scrupuleuse          -> scrupuleux·se
# scrupuleux           / scrupuleuses         -> scrupuleux·se·s
# séditieux            / séditieuse           -> séditieux·se
# séditieux            / séditieuses          -> séditieux·se·s
# sentencieux          / sentencieuse         -> sentencieux·se
# sentencieux          / sentencieuses        -> sentencieux·se·s
# séreux               / séreuse              -> séreux·se
# séreux               / séreuses             -> séreux·se·s
# sérieux              / sérieuse             -> sérieux·se
# sérieux              / sérieuses            -> sérieux·se·s
# silencieux           / silencieuse          -> silencieux·se
# silencieux           / silencieuses         -> silencieux·se·s
# sinueux              / sinueuse             -> sinueux·se
# sinueux              / sinueuses            -> sinueux·se·s
# sirupeux             / sirupeuse            -> sirupeux·se
# sirupeux             / sirupeuses           -> sirupeux·se·s
# six                  / sise                 -> six·se
# six                  / sises                -> six·se·s
# soigneux             / soigneuse            -> soigneux·se
# soigneux             / soigneuses           -> soigneux·se·s
# somptueux            / somptueuse           -> somptueux·se
# somptueux            / somptueuses          -> somptueux·se·s
# soucieux             / soucieuse            -> soucieux·se
# soucieux             / soucieuses           -> soucieux·se·s
# souffreteux          / souffreteuse         -> souffreteux·se
# souffreteux          / souffreteuses        -> souffreteux·se·s
# soupçonneux          / soupçonneuse         -> soupçonneux·se
# soupçonneux          / soupçonneuses        -> soupçonneux·se·s
# sourcilleux          / sourcilleuse         -> sourcilleux·se
# sourcilleux          / sourcilleuses        -> sourcilleux·se·s
# soyeux               / soyeuse              -> soyeux·se
# soyeux               / soyeuses             -> soyeux·se·s
# spacieux             / spacieuse            -> spacieux·se
# spacieux             / spacieuses           -> spacieux·se·s
# spécieux             / spécieuse            -> spécieux·se
# spécieux             / spécieuses           -> spécieux·se·s
# spongieux            / spongieuse           -> spongieux·se
# spongieux            / spongieuses          -> spongieux·se·s
# studieux             / studieuse            -> studieux·se
# studieux             / studieuses           -> studieux·se·s
# superstitieux        / superstitieuse       -> superstitieux·se
# superstitieux        / superstitieuses      -> superstitieux·se·s
# talentueux           / talentueuse          -> talentueux·se
# talentueux           / talentueuses         -> talentueux·se·s
# tempétueux           / tempétueuse          -> tempétueux·se
# tempétueux           / tempétueuses         -> tempétueux·se·s
# tendancieux          / tendancieuse         -> tendancieux·se
# tendancieux          / tendancieuses        -> tendancieux·se·s
# tendineux            / tendineuse           -> tendineux·se
# tendineux            / tendineuses          -> tendineux·se·s
# ténébreux            / ténébreuse           -> ténébreux·se
# ténébreux            / ténébreuses          -> ténébreux·se·s
# terreux              / terreuse             -> terreux·se
# terreux              / terreuses            -> terreux·se·s
# torrentueux          / torrentueuse         -> torrentueux·se
# torrentueux          / torrentueuses        -> torrentueux·se·s
# tortueux             / tortueuse            -> tortueux·se
# tortueux             / tortueuses           -> tortueux·se·s
# tourbeux             / tourbeuse            -> tourbeux·se
# tourbeux             / tourbeuses           -> tourbeux·se·s
# tuberculeux          / tuberculeuse         -> tuberculeux·se
# tuberculeux          / tuberculeuses        -> tuberculeux·se·s
# tumultueux           / tumultueuse          -> tumultueux·se
# tumultueux           / tumultueuses         -> tumultueux·se·s
# valeureux            / valeureuse           -> valeureux·se
# valeureux            / valeureuses          -> valeureux·se·s
# vaniteux             / vaniteuse            -> vaniteux·se
# vaniteux             / vaniteuses           -> vaniteux·se·s
# vaporeux             / vaporeuse            -> vaporeux·se
# vaporeux             / vaporeuses           -> vaporeux·se·s
# variqueux            / variqueuse           -> variqueux·se
# variqueux            / variqueuses          -> variqueux·se·s
# vaseux               / vaseuse              -> vaseux·se
# vaseux               / vaseuses             -> vaseux·se·s
# veineux              / veineuse             -> veineux·se
# veineux              / veineuses            -> veineux·se·s
# vénéneux             / vénéneuse            -> vénéneux·se
# vénéneux             / vénéneuses           -> vénéneux·se·s
# venimeux             / venimeuse            -> venimeux·se
# venimeux             / venimeuses           -> venimeux·se·s
# venteux              / venteuse             -> venteux·se
# venteux              / venteuses            -> venteux·se·s
# verbeux              / verbeuse             -> verbeux·se
# verbeux              / verbeuses            -> verbeux·se·s
# véreux               / véreuse              -> véreux·se
# véreux               / véreuses             -> véreux·se·s
# vertigineux          / vertigineuse         -> vertigineux·se
# vertigineux          / vertigineuses        -> vertigineux·se·s
# vertueux             / vertueuse            -> vertueux·se
# vertueux             / vertueuses           -> vertueux·se·s
# vétilleux            / vétilleuse           -> vétilleux·se
# vétilleux            / vétilleuses          -> vétilleux·se·s
# vicieux              / vicieuse             -> vicieux·se
# vicieux              / vicieuses            -> vicieux·se·s
# victorieux           / victorieuse          -> victorieux·se
# victorieux           / victorieuses         -> victorieux·se·s
# vigoureux            / vigoureuse           -> vigoureux·se
# vigoureux            / vigoureuses          -> vigoureux·se·s
# vineux               / vineuse              -> vineux·se
# vineux               / vineuses             -> vineux·se·s
# visqueux             / visqueuse            -> visqueux·se
# visqueux             / visqueuses           -> visqueux·se·s
# vitreux              / vitreuse             -> vitreux·se
# vitreux              / vitreuses            -> vitreux·se·s
# volumineux           / volumineuse          -> volumineux·se
# volumineux           / volumineuses         -> volumineux·se·s
# voluptueux           / voluptueuse          -> voluptueux·se
# voluptueux           / voluptueuses         -> voluptueux·se·s
#
# Cela a donné 340 nouveaux mots singuliers.
# Cela a donné 340 nouveaux mots pluriels.

# %% [markdown]
# Je pense qu'il n'y a pas d'erreurs sur ces 340 mots.

# %% [markdown]
# ### Ajouter mot·teur·trice et mot·teur·trice·s si `mot`-teur, `mot`-teurs, `mot`-trice et `mot`-trices sont présents

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("teur") and len(mot) > 4 and mot + "s" in set_mots:
        mot_feminin = f"{mot[:-4]}trice"
        if mot_feminin in set_mots:
            for mot_inclusif in [
                f"{mot[:-4]}teur{SEP}trice",
                f"{mot[:-4]}trice{SEP}teur",  # on autorise les deux sens ici
            ]:
                print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
                nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
                alternatives[mot] |= {mot_inclusif}
                alternatives[mot_feminin] |= {mot_inclusif}
        mot_feminin = f"{mot[:-4]}trices"
        if mot_feminin in set_mots:
            for mot_inclusif in [
                f"{mot[:-4]}teur{SEP}trice{SEP}s",
                f"{mot[:-4]}trice{SEP}teur{SEP}s",  # on autorise les deux sens ici
            ]:
                print(f"{mot + 's':<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
                nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
                alternatives[f"{mot + 's'}"] |= {mot_inclusif}
                alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# accélérateur         / accélératrice        -> accélérateur·trice
# accélérateur         / accélératrice        -> accélératrice·teur
# accélérateurs        / accélératrices       -> accélérateur·trice·s
# accélérateurs        / accélératrices       -> accélératrice·teur·s
# accompagnateur       / accompagnatrice      -> accompagnateur·trice
# accompagnateur       / accompagnatrice      -> accompagnatrice·teur
# accompagnateurs      / accompagnatrices     -> accompagnateur·trice·s
# accompagnateurs      / accompagnatrices     -> accompagnatrice·teur·s
# accusateur           / accusatrice          -> accusateur·trice
# accusateur           / accusatrice          -> accusatrice·teur
# accusateurs          / accusatrices         -> accusateur·trice·s
# accusateurs          / accusatrices         -> accusatrice·teur·s
# acteur               / actrice              -> acteur·trice
# acteur               / actrice              -> actrice·teur
# acteurs              / actrices             -> acteur·trice·s
# acteurs              / actrices             -> actrice·teur·s
# acuponcteur          / acuponctrice         -> acuponcteur·trice
# acuponcteur          / acuponctrice         -> acuponctrice·teur
# acuponcteurs         / acuponctrices        -> acuponcteur·trice·s
# acuponcteurs         / acuponctrices        -> acuponctrice·teur·s
# acupuncteur          / acupunctrice         -> acupuncteur·trice
# acupuncteur          / acupunctrice         -> acupunctrice·teur
# acupuncteurs         / acupunctrices        -> acupuncteur·trice·s
# acupuncteurs         / acupunctrices        -> acupunctrice·teur·s
# adaptateur           / adaptatrice          -> adaptateur·trice
# adaptateur           / adaptatrice          -> adaptatrice·teur
# adaptateurs          / adaptatrices         -> adaptateur·trice·s
# adaptateurs          / adaptatrices         -> adaptatrice·teur·s
# administrateur       / administratrice      -> administrateur·trice
# administrateur       / administratrice      -> administratrice·teur
# administrateurs      / administratrices     -> administrateur·trice·s
# administrateurs      / administratrices     -> administratrice·teur·s
# admirateur           / admiratrice          -> admirateur·trice
# admirateur           / admiratrice          -> admiratrice·teur
# admirateurs          / admiratrices         -> admirateur·trice·s
# admirateurs          / admiratrices         -> admiratrice·teur·s
# adorateur            / adoratrice           -> adorateur·trice
# adorateur            / adoratrice           -> adoratrice·teur
# adorateurs           / adoratrices          -> adorateur·trice·s
# adorateurs           / adoratrices          -> adoratrice·teur·s
# agriculteur          / agricultrice         -> agriculteur·trice
# agriculteur          / agricultrice         -> agricultrice·teur
# agriculteurs         / agricultrices        -> agriculteur·trice·s
# agriculteurs         / agricultrices        -> agricultrice·teur·s
# amplificateur        / amplificatrice       -> amplificateur·trice
# amplificateur        / amplificatrice       -> amplificatrice·teur
# amplificateurs       / amplificatrices      -> amplificateur·trice·s
# amplificateurs       / amplificatrices      -> amplificatrice·teur·s
# animateur            / animatrice           -> animateur·trice
# animateur            / animatrice           -> animatrice·teur
# animateurs           / animatrices          -> animateur·trice·s
# animateurs           / animatrices          -> animatrice·teur·s
# annonciateur         / annonciatrice        -> annonciateur·trice
# annonciateur         / annonciatrice        -> annonciatrice·teur
# annonciateurs        / annonciatrices       -> annonciateur·trice·s
# annonciateurs        / annonciatrices       -> annonciatrice·teur·s
# approbateur          / approbatrice         -> approbateur·trice
# approbateur          / approbatrice         -> approbatrice·teur
# approbateurs         / approbatrices        -> approbateur·trice·s
# approbateurs         / approbatrices        -> approbatrice·teur·s
# arboriculteur        / arboricultrice       -> arboriculteur·trice
# arboriculteur        / arboricultrice       -> arboricultrice·teur
# arboriculteurs       / arboricultrices      -> arboriculteur·trice·s
# arboriculteurs       / arboricultrices      -> arboricultrice·teur·s
# auditeur             / auditrice            -> auditeur·trice
# auditeur             / auditrice            -> auditrice·teur
# auditeurs            / auditrices           -> auditeur·trice·s
# auditeurs            / auditrices           -> auditrice·teur·s
# autodestructeur      / autodestructrice     -> autodestructeur·trice
# autodestructeur      / autodestructrice     -> autodestructrice·teur
# autodestructeurs     / autodestructrices    -> autodestructeur·trice·s
# autodestructeurs     / autodestructrices    -> autodestructrice·teur·s
# aviateur             / aviatrice            -> aviateur·trice
# aviateur             / aviatrice            -> aviatrice·teur
# aviateurs            / aviatrices           -> aviateur·trice·s
# aviateurs            / aviatrices           -> aviatrice·teur·s
# aviculteur           / avicultrice          -> aviculteur·trice
# aviculteur           / avicultrice          -> avicultrice·teur
# aviculteurs          / avicultrices         -> aviculteur·trice·s
# aviculteurs          / avicultrices         -> avicultrice·teur·s
# bienfaiteur          / bienfaitrice         -> bienfaiteur·trice
# bienfaiteur          / bienfaitrice         -> bienfaitrice·teur
# bienfaiteurs         / bienfaitrices        -> bienfaiteur·trice·s
# bienfaiteurs         / bienfaitrices        -> bienfaitrice·teur·s
# blasphémateur        / blasphématrice       -> blasphémateur·trice
# blasphémateur        / blasphématrice       -> blasphématrice·teur
# blasphémateurs       / blasphématrices      -> blasphémateur·trice·s
# blasphémateurs       / blasphématrices      -> blasphématrice·teur·s
# calculateur          / calculatrice         -> calculateur·trice
# calculateur          / calculatrice         -> calculatrice·teur
# calculateurs         / calculatrices        -> calculateur·trice·s
# calculateurs         / calculatrices        -> calculatrice·teur·s
# calomniateur         / calomniatrice        -> calomniateur·trice
# calomniateur         / calomniatrice        -> calomniatrice·teur
# calomniateurs        / calomniatrices       -> calomniateur·trice·s
# calomniateurs        / calomniatrices       -> calomniatrice·teur·s
# castrateur           / castratrice          -> castrateur·trice
# castrateur           / castratrice          -> castratrice·teur
# castrateurs          / castratrices         -> castrateur·trice·s
# castrateurs          / castratrices         -> castratrice·teur·s
# centralisateur       / centralisatrice      -> centralisateur·trice
# centralisateur       / centralisatrice      -> centralisatrice·teur
# centralisateurs      / centralisatrices     -> centralisateur·trice·s
# centralisateurs      / centralisatrices     -> centralisatrice·teur·s
# civilisateur         / civilisatrice        -> civilisateur·trice
# civilisateur         / civilisatrice        -> civilisatrice·teur
# civilisateurs        / civilisatrices       -> civilisateur·trice·s
# civilisateurs        / civilisatrices       -> civilisatrice·teur·s
# classificateur       / classificatrice      -> classificateur·trice
# classificateur       / classificatrice      -> classificatrice·teur
# classificateurs      / classificatrices     -> classificateur·trice·s
# classificateurs      / classificatrices     -> classificatrice·teur·s
# coadministrateur     / coadministratrice    -> coadministrateur·trice
# coadministrateur     / coadministratrice    -> coadministratrice·teur
# coadministrateurs    / coadministratrices   -> coadministrateur·trice·s
# coadministrateurs    / coadministratrices   -> coadministratrice·teur·s
# codébiteur           / codébitrice          -> codébiteur·trice
# codébiteur           / codébitrice          -> codébitrice·teur
# codébiteurs          / codébitrices         -> codébiteur·trice·s
# codébiteurs          / codébitrices         -> codébitrice·teur·s
# codétenteur          / codétentrice         -> codétenteur·trice
# codétenteur          / codétentrice         -> codétentrice·teur
# codétenteurs         / codétentrices        -> codétenteur·trice·s
# codétenteurs         / codétentrices        -> codétentrice·teur·s
# codirecteur          / codirectrice         -> codirecteur·trice
# codirecteur          / codirectrice         -> codirectrice·teur
# codirecteurs         / codirectrices        -> codirecteur·trice·s
# codirecteurs         / codirectrices        -> codirectrice·teur·s
# collaborateur        / collaboratrice       -> collaborateur·trice
# collaborateur        / collaboratrice       -> collaboratrice·teur
# collaborateurs       / collaboratrices      -> collaborateur·trice·s
# collaborateurs       / collaboratrices      -> collaboratrice·teur·s
# colonisateur         / colonisatrice        -> colonisateur·trice
# colonisateur         / colonisatrice        -> colonisatrice·teur
# colonisateurs        / colonisatrices       -> colonisateur·trice·s
# colonisateurs        / colonisatrices       -> colonisatrice·teur·s
# commentateur         / commentatrice        -> commentateur·trice
# commentateur         / commentatrice        -> commentatrice·teur
# commentateurs        / commentatrices       -> commentateur·trice·s
# commentateurs        / commentatrices       -> commentatrice·teur·s
# compensateur         / compensatrice        -> compensateur·trice
# compensateur         / compensatrice        -> compensatrice·teur
# compensateurs        / compensatrices       -> compensateur·trice·s
# compensateurs        / compensatrices       -> compensatrice·teur·s
# compétiteur          / compétitrice         -> compétiteur·trice
# compétiteur          / compétitrice         -> compétitrice·teur
# compétiteurs         / compétitrices        -> compétiteur·trice·s
# compétiteurs         / compétitrices        -> compétitrice·teur·s
# compilateur          / compilatrice         -> compilateur·trice
# compilateur          / compilatrice         -> compilatrice·teur
# compilateurs         / compilatrices        -> compilateur·trice·s
# compilateurs         / compilatrices        -> compilatrice·teur·s
# compositeur          / compositrice         -> compositeur·trice
# compositeur          / compositrice         -> compositrice·teur
# compositeurs         / compositrices        -> compositeur·trice·s
# compositeurs         / compositrices        -> compositrice·teur·s
# concepteur           / conceptrice          -> concepteur·trice
# concepteur           / conceptrice          -> conceptrice·teur
# concepteurs          / conceptrices         -> concepteur·trice·s
# concepteurs          / conceptrices         -> conceptrice·teur·s
# conciliateur         / conciliatrice        -> conciliateur·trice
# conciliateur         / conciliatrice        -> conciliatrice·teur
# conciliateurs        / conciliatrices       -> conciliateur·trice·s
# conciliateurs        / conciliatrices       -> conciliatrice·teur·s
# conducteur           / conductrice          -> conducteur·trice
# conducteur           / conductrice          -> conductrice·teur
# conducteurs          / conductrices         -> conducteur·trice·s
# conducteurs          / conductrices         -> conductrice·teur·s
# conservateur         / conservatrice        -> conservateur·trice
# conservateur         / conservatrice        -> conservatrice·teur
# conservateurs        / conservatrices       -> conservateur·trice·s
# conservateurs        / conservatrices       -> conservatrice·teur·s
# consommateur         / consommatrice        -> consommateur·trice
# consommateur         / consommatrice        -> consommatrice·teur
# consommateurs        / consommatrices       -> consommateur·trice·s
# consommateurs        / consommatrices       -> consommatrice·teur·s
# conspirateur         / conspiratrice        -> conspirateur·trice
# conspirateur         / conspiratrice        -> conspiratrice·teur
# conspirateurs        / conspiratrices       -> conspirateur·trice·s
# conspirateurs        / conspiratrices       -> conspiratrice·teur·s
# constructeur         / constructrice        -> constructeur·trice
# constructeur         / constructrice        -> constructrice·teur
# constructeurs        / constructrices       -> constructeur·trice·s
# constructeurs        / constructrices       -> constructrice·teur·s
# contempteur          / contemptrice         -> contempteur·trice
# contempteur          / contemptrice         -> contemptrice·teur
# contempteurs         / contemptrices        -> contempteur·trice·s
# contempteurs         / contemptrices        -> contemptrice·teur·s
# continuateur         / continuatrice        -> continuateur·trice
# continuateur         / continuatrice        -> continuatrice·teur
# continuateurs        / continuatrices       -> continuateur·trice·s
# continuateurs        / continuatrices       -> continuatrice·teur·s
# contributeur         / contributrice        -> contributeur·trice
# contributeur         / contributrice        -> contributrice·teur
# contributeurs        / contributrices       -> contributeur·trice·s
# contributeurs        / contributrices       -> contributrice·teur·s
# coopérateur          / coopératrice         -> coopérateur·trice
# coopérateur          / coopératrice         -> coopératrice·teur
# coopérateurs         / coopératrices        -> coopérateur·trice·s
# coopérateurs         / coopératrices        -> coopératrice·teur·s
# coordinateur         / coordinatrice        -> coordinateur·trice
# coordinateur         / coordinatrice        -> coordinatrice·teur
# coordinateurs        / coordinatrices       -> coordinateur·trice·s
# coordinateurs        / coordinatrices       -> coordinatrice·teur·s
# coordonnateur        / coordonnatrice       -> coordonnateur·trice
# coordonnateur        / coordonnatrice       -> coordonnatrice·teur
# coordonnateurs       / coordonnatrices      -> coordonnateur·trice·s
# coordonnateurs       / coordonnatrices      -> coordonnatrice·teur·s
# correcteur           / correctrice          -> correcteur·trice
# correcteur           / correctrice          -> correctrice·teur
# correcteurs          / correctrices         -> correcteur·trice·s
# correcteurs          / correctrices         -> correctrice·teur·s
# corrupteur           / corruptrice          -> corrupteur·trice
# corrupteur           / corruptrice          -> corruptrice·teur
# corrupteurs          / corruptrices         -> corrupteur·trice·s
# corrupteurs          / corruptrices         -> corruptrice·teur·s
# créateur             / créatrice            -> créateur·trice
# créateur             / créatrice            -> créatrice·teur
# créateurs            / créatrices           -> créateur·trice·s
# créateurs            / créatrices           -> créatrice·teur·s
# créditeur            / créditrice           -> créditeur·trice
# créditeur            / créditrice           -> créditrice·teur
# créditeurs           / créditrices          -> créditeur·trice·s
# créditeurs           / créditrices          -> créditrice·teur·s
# cultivateur          / cultivatrice         -> cultivateur·trice
# cultivateur          / cultivatrice         -> cultivatrice·teur
# cultivateurs         / cultivatrices        -> cultivateur·trice·s
# cultivateurs         / cultivatrices        -> cultivatrice·teur·s
# curateur             / curatrice            -> curateur·trice
# curateur             / curatrice            -> curatrice·teur
# curateurs            / curatrices           -> curateur·trice·s
# curateurs            / curatrices           -> curatrice·teur·s
# débiteur             / débitrice            -> débiteur·trice
# débiteur             / débitrice            -> débitrice·teur
# débiteurs            / débitrices           -> débiteur·trice·s
# débiteurs            / débitrices           -> débitrice·teur·s
# décentralisateur     / décentralisatrice    -> décentralisateur·trice
# décentralisateur     / décentralisatrice    -> décentralisatrice·teur
# décentralisateurs    / décentralisatrices   -> décentralisateur·trice·s
# décentralisateurs    / décentralisatrices   -> décentralisatrice·teur·s
# décorateur           / décoratrice          -> décorateur·trice
# décorateur           / décoratrice          -> décoratrice·teur
# décorateurs          / décoratrices         -> décorateur·trice·s
# décorateurs          / décoratrices         -> décoratrice·teur·s
# délateur             / délatrice            -> délateur·trice
# délateur             / délatrice            -> délatrice·teur
# délateurs            / délatrices           -> délateur·trice·s
# délateurs            / délatrices           -> délatrice·teur·s
# démobilisateur       / démobilisatrice      -> démobilisateur·trice
# démobilisateur       / démobilisatrice      -> démobilisatrice·teur
# démobilisateurs      / démobilisatrices     -> démobilisateur·trice·s
# démobilisateurs      / démobilisatrices     -> démobilisatrice·teur·s
# démonstrateur        / démonstratrice       -> démonstrateur·trice
# démonstrateur        / démonstratrice       -> démonstratrice·teur
# démonstrateurs       / démonstratrices      -> démonstrateur·trice·s
# démonstrateurs       / démonstratrices      -> démonstratrice·teur·s
# démoralisateur       / démoralisatrice      -> démoralisateur·trice
# démoralisateur       / démoralisatrice      -> démoralisatrice·teur
# démoralisateurs      / démoralisatrices     -> démoralisateur·trice·s
# démoralisateurs      / démoralisatrices     -> démoralisatrice·teur·s
# démystificateur      / démystificatrice     -> démystificateur·trice
# démystificateur      / démystificatrice     -> démystificatrice·teur
# démystificateurs     / démystificatrices    -> démystificateur·trice·s
# démystificateurs     / démystificatrices    -> démystificatrice·teur·s
# dénonciateur         / dénonciatrice        -> dénonciateur·trice
# dénonciateur         / dénonciatrice        -> dénonciatrice·teur
# dénonciateurs        / dénonciatrices       -> dénonciateur·trice·s
# dénonciateurs        / dénonciatrices       -> dénonciatrice·teur·s
# déprédateur          / déprédatrice         -> déprédateur·trice
# déprédateur          / déprédatrice         -> déprédatrice·teur
# déprédateurs         / déprédatrices        -> déprédateur·trice·s
# déprédateurs         / déprédatrices        -> déprédatrice·teur·s
# désapprobateur       / désapprobatrice      -> désapprobateur·trice
# désapprobateur       / désapprobatrice      -> désapprobatrice·teur
# désapprobateurs      / désapprobatrices     -> désapprobateur·trice·s
# désapprobateurs      / désapprobatrices     -> désapprobatrice·teur·s
# dessinateur          / dessinatrice         -> dessinateur·trice
# dessinateur          / dessinatrice         -> dessinatrice·teur
# dessinateurs         / dessinatrices        -> dessinateur·trice·s
# dessinateurs         / dessinatrices        -> dessinatrice·teur·s
# déstabilisateur      / déstabilisatrice     -> déstabilisateur·trice
# déstabilisateur      / déstabilisatrice     -> déstabilisatrice·teur
# déstabilisateurs     / déstabilisatrices    -> déstabilisateur·trice·s
# déstabilisateurs     / déstabilisatrices    -> déstabilisatrice·teur·s
# destructeur          / destructrice         -> destructeur·trice
# destructeur          / destructrice         -> destructrice·teur
# destructeurs         / destructrices        -> destructeur·trice·s
# destructeurs         / destructrices        -> destructrice·teur·s
# détenteur            / détentrice           -> détenteur·trice
# détenteur            / détentrice           -> détentrice·teur
# détenteurs           / détentrices          -> détenteur·trice·s
# détenteurs           / détentrices          -> détentrice·teur·s
# détracteur           / détractrice          -> détracteur·trice
# détracteur           / détractrice          -> détractrice·teur
# détracteurs          / détractrices         -> détracteur·trice·s
# détracteurs          / détractrices         -> détractrice·teur·s
# dévastateur          / dévastatrice         -> dévastateur·trice
# dévastateur          / dévastatrice         -> dévastatrice·teur
# dévastateurs         / dévastatrices        -> dévastateur·trice·s
# dévastateurs         / dévastatrices        -> dévastatrice·teur·s
# diffamateur          / diffamatrice         -> diffamateur·trice
# diffamateur          / diffamatrice         -> diffamatrice·teur
# diffamateurs         / diffamatrices        -> diffamateur·trice·s
# diffamateurs         / diffamatrices        -> diffamatrice·teur·s
# directeur            / directrice           -> directeur·trice
# directeur            / directrice           -> directrice·teur
# directeurs           / directrices          -> directeur·trice·s
# directeurs           / directrices          -> directrice·teur·s
# dispensateur         / dispensatrice        -> dispensateur·trice
# dispensateur         / dispensatrice        -> dispensatrice·teur
# dispensateurs        / dispensatrices       -> dispensateur·trice·s
# dispensateurs        / dispensatrices       -> dispensatrice·teur·s
# dissimulateur        / dissimulatrice       -> dissimulateur·trice
# dissimulateur        / dissimulatrice       -> dissimulatrice·teur
# dissimulateurs       / dissimulatrices      -> dissimulateur·trice·s
# dissimulateurs       / dissimulatrices      -> dissimulatrice·teur·s
# dissipateur          / dissipatrice         -> dissipateur·trice
# dissipateur          / dissipatrice         -> dissipatrice·teur
# dissipateurs         / dissipatrices        -> dissipateur·trice·s
# dissipateurs         / dissipatrices        -> dissipatrice·teur·s
# distributeur         / distributrice        -> distributeur·trice
# distributeur         / distributrice        -> distributrice·teur
# distributeurs        / distributrices       -> distributeur·trice·s
# distributeurs        / distributrices       -> distributrice·teur·s
# dominateur           / dominatrice          -> dominateur·trice
# dominateur           / dominatrice          -> dominatrice·teur
# dominateurs          / dominatrices         -> dominateur·trice·s
# dominateurs          / dominatrices         -> dominatrice·teur·s
# donateur             / donatrice            -> donateur·trice
# donateur             / donatrice            -> donatrice·teur
# donateurs            / donatrices           -> donateur·trice·s
# donateurs            / donatrices           -> donatrice·teur·s
# éditeur              / éditrice             -> éditeur·trice
# éditeur              / éditrice             -> éditrice·teur
# éditeurs             / éditrices            -> éditeur·trice·s
# éditeurs             / éditrices            -> éditrice·teur·s
# éducateur            / éducatrice           -> éducateur·trice
# éducateur            / éducatrice           -> éducatrice·teur
# éducateurs           / éducatrices          -> éducateur·trice·s
# éducateurs           / éducatrices          -> éducatrice·teur·s
# égalisateur          / égalisatrice         -> égalisateur·trice
# égalisateur          / égalisatrice         -> égalisatrice·teur
# égalisateurs         / égalisatrices        -> égalisateur·trice·s
# égalisateurs         / égalisatrices        -> égalisatrice·teur·s
# électeur             / électrice            -> électeur·trice
# électeur             / électrice            -> électrice·teur
# électeurs            / électrices           -> électeur·trice·s
# électeurs            / électrices           -> électrice·teur·s
# élévateur            / élévatrice           -> élévateur·trice
# élévateur            / élévatrice           -> élévatrice·teur
# élévateurs           / élévatrices          -> élévateur·trice·s
# élévateurs           / élévatrices          -> élévatrice·teur·s
# émancipateur         / émancipatrice        -> émancipateur·trice
# émancipateur         / émancipatrice        -> émancipatrice·teur
# émancipateurs        / émancipatrices       -> émancipateur·trice·s
# émancipateurs        / émancipatrices       -> émancipatrice·teur·s
# émetteur             / émettrice            -> émetteur·trice
# émetteur             / émettrice            -> émettrice·teur
# émetteurs            / émettrices           -> émetteur·trice·s
# émetteurs            / émettrices           -> émettrice·teur·s
# évacuateur           / évacuatrice          -> évacuateur·trice
# évacuateur           / évacuatrice          -> évacuatrice·teur
# évacuateurs          / évacuatrices         -> évacuateur·trice·s
# évacuateurs          / évacuatrices         -> évacuatrice·teur·s
# évangélisateur       / évangélisatrice      -> évangélisateur·trice
# évangélisateur       / évangélisatrice      -> évangélisatrice·teur
# évangélisateurs      / évangélisatrices     -> évangélisateur·trice·s
# évangélisateurs      / évangélisatrices     -> évangélisatrice·teur·s
# évocateur            / évocatrice           -> évocateur·trice
# évocateur            / évocatrice           -> évocatrice·teur
# évocateurs           / évocatrices          -> évocateur·trice·s
# évocateurs           / évocatrices          -> évocatrice·teur·s
# examinateur          / examinatrice         -> examinateur·trice
# examinateur          / examinatrice         -> examinatrice·teur
# examinateurs         / examinatrices        -> examinateur·trice·s
# examinateurs         / examinatrices        -> examinatrice·teur·s
# excavateur           / excavatrice          -> excavateur·trice
# excavateur           / excavatrice          -> excavatrice·teur
# excavateurs          / excavatrices         -> excavateur·trice·s
# excavateurs          / excavatrices         -> excavatrice·teur·s
# exécuteur            / exécutrice           -> exécuteur·trice
# exécuteur            / exécutrice           -> exécutrice·teur
# exécuteurs           / exécutrices          -> exécuteur·trice·s
# exécuteurs           / exécutrices          -> exécutrice·teur·s
# expéditeur           / expéditrice          -> expéditeur·trice
# expéditeur           / expéditrice          -> expéditrice·teur
# expéditeurs          / expéditrices         -> expéditeur·trice·s
# expéditeurs          / expéditrices         -> expéditrice·teur·s
# expérimentateur      / expérimentatrice     -> expérimentateur·trice
# expérimentateur      / expérimentatrice     -> expérimentatrice·teur
# expérimentateurs     / expérimentatrices    -> expérimentateur·trice·s
# expérimentateurs     / expérimentatrices    -> expérimentatrice·teur·s
# explorateur          / exploratrice         -> explorateur·trice
# explorateur          / exploratrice         -> exploratrice·teur
# explorateurs         / exploratrices        -> explorateur·trice·s
# explorateurs         / exploratrices        -> exploratrice·teur·s
# exportateur          / exportatrice         -> exportateur·trice
# exportateur          / exportatrice         -> exportatrice·teur
# exportateurs         / exportatrices        -> exportateur·trice·s
# exportateurs         / exportatrices        -> exportatrice·teur·s
# exterminateur        / exterminatrice       -> exterminateur·trice
# exterminateur        / exterminatrice       -> exterminatrice·teur
# exterminateurs       / exterminatrices      -> exterminateur·trice·s
# exterminateurs       / exterminatrices      -> exterminatrice·teur·s
# fabulateur           / fabulatrice          -> fabulateur·trice
# fabulateur           / fabulatrice          -> fabulatrice·teur
# fabulateurs          / fabulatrices         -> fabulateur·trice·s
# fabulateurs          / fabulatrices         -> fabulatrice·teur·s
# falsificateur        / falsificatrice       -> falsificateur·trice
# falsificateur        / falsificatrice       -> falsificatrice·teur
# falsificateurs       / falsificatrices      -> falsificateur·trice·s
# falsificateurs       / falsificatrices      -> falsificatrice·teur·s
# fédérateur           / fédératrice          -> fédérateur·trice
# fédérateur           / fédératrice          -> fédératrice·teur
# fédérateurs          / fédératrices         -> fédérateur·trice·s
# fédérateurs          / fédératrices         -> fédératrice·teur·s
# fondateur            / fondatrice           -> fondateur·trice
# fondateur            / fondatrice           -> fondatrice·teur
# fondateurs           / fondatrices          -> fondateur·trice·s
# fondateurs           / fondatrices          -> fondatrice·teur·s
# formateur            / formatrice           -> formateur·trice
# formateur            / formatrice           -> formatrice·teur
# formateurs           / formatrices          -> formateur·trice·s
# formateurs           / formatrices          -> formatrice·teur·s
# générateur           / génératrice          -> générateur·trice
# générateur           / génératrice          -> génératrice·teur
# générateurs          / génératrices         -> générateur·trice·s
# générateurs          / génératrices         -> génératrice·teur·s
# géniteur             / génitrice            -> géniteur·trice
# géniteur             / génitrice            -> génitrice·teur
# géniteurs            / génitrices           -> géniteur·trice·s
# géniteurs            / génitrices           -> génitrice·teur·s
# illustrateur         / illustratrice        -> illustrateur·trice
# illustrateur         / illustratrice        -> illustratrice·teur
# illustrateurs        / illustratrices       -> illustrateur·trice·s
# illustrateurs        / illustratrices       -> illustratrice·teur·s
# imitateur            / imitatrice           -> imitateur·trice
# imitateur            / imitatrice           -> imitatrice·teur
# imitateurs           / imitatrices          -> imitateur·trice·s
# imitateurs           / imitatrices          -> imitatrice·teur·s
# importateur          / importatrice         -> importateur·trice
# importateur          / importatrice         -> importatrice·teur
# importateurs         / importatrices        -> importateur·trice·s
# importateurs         / importatrices        -> importatrice·teur·s
# improvisateur        / improvisatrice       -> improvisateur·trice
# improvisateur        / improvisatrice       -> improvisatrice·teur
# improvisateurs       / improvisatrices      -> improvisateur·trice·s
# improvisateurs       / improvisatrices      -> improvisatrice·teur·s
# incitateur           / incitatrice          -> incitateur·trice
# incitateur           / incitatrice          -> incitatrice·teur
# incitateurs          / incitatrices         -> incitateur·trice·s
# incitateurs          / incitatrices         -> incitatrice·teur·s
# indicateur           / indicatrice          -> indicateur·trice
# indicateur           / indicatrice          -> indicatrice·teur
# indicateurs          / indicatrices         -> indicateur·trice·s
# indicateurs          / indicatrices         -> indicatrice·teur·s
# informateur          / informatrice         -> informateur·trice
# informateur          / informatrice         -> informatrice·teur
# informateurs         / informatrices        -> informateur·trice·s
# informateurs         / informatrices        -> informatrice·teur·s
# initiateur           / initiatrice          -> initiateur·trice
# initiateur           / initiatrice          -> initiatrice·teur
# initiateurs          / initiatrices         -> initiateur·trice·s
# initiateurs          / initiatrices         -> initiatrice·teur·s
# innovateur           / innovatrice          -> innovateur·trice
# innovateur           / innovatrice          -> innovatrice·teur
# innovateurs          / innovatrices         -> innovateur·trice·s
# innovateurs          / innovatrices         -> innovatrice·teur·s
# inquisiteur          / inquisitrice         -> inquisiteur·trice
# inquisiteur          / inquisitrice         -> inquisitrice·teur
# inquisiteurs         / inquisitrices        -> inquisiteur·trice·s
# inquisiteurs         / inquisitrices        -> inquisitrice·teur·s
# inspecteur           / inspectrice          -> inspecteur·trice
# inspecteur           / inspectrice          -> inspectrice·teur
# inspecteurs          / inspectrices         -> inspecteur·trice·s
# inspecteurs          / inspectrices         -> inspectrice·teur·s
# inspirateur          / inspiratrice         -> inspirateur·trice
# inspirateur          / inspiratrice         -> inspiratrice·teur
# inspirateurs         / inspiratrices        -> inspirateur·trice·s
# inspirateurs         / inspiratrices        -> inspiratrice·teur·s
# instigateur          / instigatrice         -> instigateur·trice
# instigateur          / instigatrice         -> instigatrice·teur
# instigateurs         / instigatrices        -> instigateur·trice·s
# instigateurs         / instigatrices        -> instigatrice·teur·s
# instituteur          / institutrice         -> instituteur·trice
# instituteur          / institutrice         -> institutrice·teur
# instituteurs         / institutrices        -> instituteur·trice·s
# instituteurs         / institutrices        -> institutrice·teur·s
# interlocuteur        / interlocutrice       -> interlocuteur·trice
# interlocuteur        / interlocutrice       -> interlocutrice·teur
# interlocuteurs       / interlocutrices      -> interlocuteur·trice·s
# interlocuteurs       / interlocutrices      -> interlocutrice·teur·s
# interpellateur       / interpellatrice      -> interpellateur·trice
# interpellateur       / interpellatrice      -> interpellatrice·teur
# interpellateurs      / interpellatrices     -> interpellateur·trice·s
# interpellateurs      / interpellatrices     -> interpellatrice·teur·s
# interpolateur        / interpolatrice       -> interpolateur·trice
# interpolateur        / interpolatrice       -> interpolatrice·teur
# interpolateurs       / interpolatrices      -> interpolateur·trice·s
# interpolateurs       / interpolatrices      -> interpolatrice·teur·s
# interrogateur        / interrogatrice       -> interrogateur·trice
# interrogateur        / interrogatrice       -> interrogatrice·teur
# interrogateurs       / interrogatrices      -> interrogateur·trice·s
# interrogateurs       / interrogatrices      -> interrogatrice·teur·s
# interrupteur         / interruptrice        -> interrupteur·trice
# interrupteur         / interruptrice        -> interruptrice·teur
# interrupteurs        / interruptrices       -> interrupteur·trice·s
# interrupteurs        / interruptrices       -> interruptrice·teur·s
# intimidateur         / intimidatrice        -> intimidateur·trice
# intimidateur         / intimidatrice        -> intimidatrice·teur
# intimidateurs        / intimidatrices       -> intimidateur·trice·s
# intimidateurs        / intimidatrices       -> intimidatrice·teur·s
# introducteur         / introductrice        -> introducteur·trice
# introducteur         / introductrice        -> introductrice·teur
# introducteurs        / introductrices       -> introducteur·trice·s
# introducteurs        / introductrices       -> introductrice·teur·s
# inventeur            / inventrice           -> inventeur·trice
# inventeur            / inventrice           -> inventrice·teur
# inventeurs           / inventrices          -> inventeur·trice·s
# inventeurs           / inventrices          -> inventrice·teur·s
# investigateur        / investigatrice       -> investigateur·trice
# investigateur        / investigatrice       -> investigatrice·teur
# investigateurs       / investigatrices      -> investigateur·trice·s
# investigateurs       / investigatrices      -> investigatrice·teur·s
# lecteur              / lectrice             -> lecteur·trice
# lecteur              / lectrice             -> lectrice·teur
# lecteurs             / lectrices            -> lecteur·trice·s
# lecteurs             / lectrices            -> lectrice·teur·s
# législateur          / législatrice         -> législateur·trice
# législateur          / législatrice         -> législatrice·teur
# législateurs         / législatrices        -> législateur·trice·s
# législateurs         / législatrices        -> législatrice·teur·s
# libérateur           / libératrice          -> libérateur·trice
# libérateur           / libératrice          -> libératrice·teur
# libérateurs          / libératrices         -> libérateur·trice·s
# libérateurs          / libératrices         -> libératrice·teur·s
# liquidateur          / liquidatrice         -> liquidateur·trice
# liquidateur          / liquidatrice         -> liquidatrice·teur
# liquidateurs         / liquidatrices        -> liquidateur·trice·s
# liquidateurs         / liquidatrices        -> liquidatrice·teur·s
# locomoteur           / locomotrice          -> locomoteur·trice
# locomoteur           / locomotrice          -> locomotrice·teur
# locomoteurs          / locomotrices         -> locomoteur·trice·s
# locomoteurs          / locomotrices         -> locomotrice·teur·s
# locuteur             / locutrice            -> locuteur·trice
# locuteur             / locutrice            -> locutrice·teur
# locuteurs            / locutrices           -> locuteur·trice·s
# locuteurs            / locutrices           -> locutrice·teur·s
# manipulateur         / manipulatrice        -> manipulateur·trice
# manipulateur         / manipulatrice        -> manipulatrice·teur
# manipulateurs        / manipulatrices       -> manipulateur·trice·s
# manipulateurs        / manipulatrices       -> manipulatrice·teur·s
# marémoteur           / marémotrice          -> marémoteur·trice
# marémoteur           / marémotrice          -> marémotrice·teur
# marémoteurs          / marémotrices         -> marémoteur·trice·s
# marémoteurs          / marémotrices         -> marémotrice·teur·s
# médiateur            / médiatrice           -> médiateur·trice
# médiateur            / médiatrice           -> médiatrice·teur
# médiateurs           / médiatrices          -> médiateur·trice·s
# médiateurs           / médiatrices          -> médiatrice·teur·s
# migrateur            / migratrice           -> migrateur·trice
# migrateur            / migratrice           -> migratrice·teur
# migrateurs           / migratrices          -> migrateur·trice·s
# migrateurs           / migratrices          -> migratrice·teur·s
# mobilisateur         / mobilisatrice        -> mobilisateur·trice
# mobilisateur         / mobilisatrice        -> mobilisatrice·teur
# mobilisateurs        / mobilisatrices       -> mobilisateur·trice·s
# mobilisateurs        / mobilisatrices       -> mobilisatrice·teur·s
# modérateur           / modératrice          -> modérateur·trice
# modérateur           / modératrice          -> modératrice·teur
# modérateurs          / modératrices         -> modérateur·trice·s
# modérateurs          / modératrices         -> modératrice·teur·s
# modificateur         / modificatrice        -> modificateur·trice
# modificateur         / modificatrice        -> modificatrice·teur
# modificateurs        / modificatrices       -> modificateur·trice·s
# modificateurs        / modificatrices       -> modificatrice·teur·s
# moniteur             / monitrice            -> moniteur·trice
# moniteur             / monitrice            -> monitrice·teur
# moniteurs            / monitrices           -> moniteur·trice·s
# moniteurs            / monitrices           -> monitrice·teur·s
# moralisateur         / moralisatrice        -> moralisateur·trice
# moralisateur         / moralisatrice        -> moralisatrice·teur
# moralisateurs        / moralisatrices       -> moralisateur·trice·s
# moralisateurs        / moralisatrices       -> moralisatrice·teur·s
# moteur               / motrice              -> moteur·trice
# moteur               / motrice              -> motrice·teur
# moteurs              / motrices             -> moteur·trice·s
# moteurs              / motrices             -> motrice·teur·s
# mystificateur        / mystificatrice       -> mystificateur·trice
# mystificateur        / mystificatrice       -> mystificatrice·teur
# mystificateurs       / mystificatrices      -> mystificateur·trice·s
# mystificateurs       / mystificatrices      -> mystificatrice·teur·s
# narrateur            / narratrice           -> narrateur·trice
# narrateur            / narratrice           -> narratrice·teur
# narrateurs           / narratrices          -> narrateur·trice·s
# narrateurs           / narratrices          -> narratrice·teur·s
# négociateur          / négociatrice         -> négociateur·trice
# négociateur          / négociatrice         -> négociatrice·teur
# négociateurs         / négociatrices        -> négociateur·trice·s
# négociateurs         / négociatrices        -> négociatrice·teur·s
# novateur             / novatrice            -> novateur·trice
# novateur             / novatrice            -> novatrice·teur
# novateurs            / novatrices           -> novateur·trice·s
# novateurs            / novatrices           -> novatrice·teur·s
# observateur          / observatrice         -> observateur·trice
# observateur          / observatrice         -> observatrice·teur
# observateurs         / observatrices        -> observateur·trice·s
# observateurs         / observatrices        -> observatrice·teur·s
# oléiculteur          / oléicultrice         -> oléiculteur·trice
# oléiculteur          / oléicultrice         -> oléicultrice·teur
# oléiculteurs         / oléicultrices        -> oléiculteur·trice·s
# oléiculteurs         / oléicultrices        -> oléicultrice·teur·s
# opérateur            / opératrice           -> opérateur·trice
# opérateur            / opératrice           -> opératrice·teur
# opérateurs           / opératrices          -> opérateur·trice·s
# opérateurs           / opératrices          -> opératrice·teur·s
# ordonnateur          / ordonnatrice         -> ordonnateur·trice
# ordonnateur          / ordonnatrice         -> ordonnatrice·teur
# ordonnateurs         / ordonnatrices        -> ordonnateur·trice·s
# ordonnateurs         / ordonnatrices        -> ordonnatrice·teur·s
# organisateur         / organisatrice        -> organisateur·trice
# organisateur         / organisatrice        -> organisatrice·teur
# organisateurs        / organisatrices       -> organisateur·trice·s
# organisateurs        / organisatrices       -> organisatrice·teur·s
# orienteur            / orientrice           -> orienteur·trice
# orienteur            / orientrice           -> orientrice·teur
# orienteurs           / orientrices          -> orienteur·trice·s
# orienteurs           / orientrices          -> orientrice·teur·s
# ostréiculteur        / ostréicultrice       -> ostréiculteur·trice
# ostréiculteur        / ostréicultrice       -> ostréicultrice·teur
# ostréiculteurs       / ostréicultrices      -> ostréiculteur·trice·s
# ostréiculteurs       / ostréicultrices      -> ostréicultrice·teur·s
# pacificateur         / pacificatrice        -> pacificateur·trice
# pacificateur         / pacificatrice        -> pacificatrice·teur
# pacificateurs        / pacificatrices       -> pacificateur·trice·s
# pacificateurs        / pacificatrices       -> pacificatrice·teur·s
# perforateur          / perforatrice         -> perforateur·trice
# perforateur          / perforatrice         -> perforatrice·teur
# perforateurs         / perforatrices        -> perforateur·trice·s
# perforateurs         / perforatrices        -> perforatrice·teur·s
# persécuteur          / persécutrice         -> persécuteur·trice
# persécuteur          / persécutrice         -> persécutrice·teur
# persécuteurs         / persécutrices        -> persécuteur·trice·s
# persécuteurs         / persécutrices        -> persécutrice·teur·s
# perturbateur         / perturbatrice        -> perturbateur·trice
# perturbateur         / perturbatrice        -> perturbatrice·teur
# perturbateurs        / perturbatrices       -> perturbateur·trice·s
# perturbateurs        / perturbatrices       -> perturbatrice·teur·s
# planificateur        / planificatrice       -> planificateur·trice
# planificateur        / planificatrice       -> planificatrice·teur
# planificateurs       / planificatrices      -> planificateur·trice·s
# planificateurs       / planificatrices      -> planificatrice·teur·s
# précepteur           / préceptrice          -> précepteur·trice
# précepteur           / préceptrice          -> préceptrice·teur
# précepteurs          / préceptrices         -> précepteur·trice·s
# précepteurs          / préceptrices         -> préceptrice·teur·s
# prédateur            / prédatrice           -> prédateur·trice
# prédateur            / prédatrice           -> prédatrice·teur
# prédateurs           / prédatrices          -> prédateur·trice·s
# prédateurs           / prédatrices          -> prédatrice·teur·s
# prédicateur          / prédicatrice         -> prédicateur·trice
# prédicateur          / prédicatrice         -> prédicatrice·teur
# prédicateurs         / prédicatrices        -> prédicateur·trice·s
# prédicateurs         / prédicatrices        -> prédicatrice·teur·s
# préparateur          / préparatrice         -> préparateur·trice
# préparateur          / préparatrice         -> préparatrice·teur
# préparateurs         / préparatrices        -> préparateur·trice·s
# préparateurs         / préparatrices        -> préparatrice·teur·s
# présentateur         / présentatrice        -> présentateur·trice
# présentateur         / présentatrice        -> présentatrice·teur
# présentateurs        / présentatrices       -> présentateur·trice·s
# présentateurs        / présentatrices       -> présentatrice·teur·s
# prévaricateur        / prévaricatrice       -> prévaricateur·trice
# prévaricateur        / prévaricatrice       -> prévaricatrice·teur
# prévaricateurs       / prévaricatrices      -> prévaricateur·trice·s
# prévaricateurs       / prévaricatrices      -> prévaricatrice·teur·s
# procréateur          / procréatrice         -> procréateur·trice
# procréateur          / procréatrice         -> procréatrice·teur
# procréateurs         / procréatrices        -> procréateur·trice·s
# procréateurs         / procréatrices        -> procréatrice·teur·s
# producteur           / productrice          -> producteur·trice
# producteur           / productrice          -> productrice·teur
# producteurs          / productrices         -> producteur·trice·s
# producteurs          / productrices         -> productrice·teur·s
# profanateur          / profanatrice         -> profanateur·trice
# profanateur          / profanatrice         -> profanatrice·teur
# profanateurs         / profanatrices        -> profanateur·trice·s
# profanateurs         / profanatrices        -> profanatrice·teur·s
# promoteur            / promotrice           -> promoteur·trice
# promoteur            / promotrice           -> promotrice·teur
# promoteurs           / promotrices          -> promoteur·trice·s
# promoteurs           / promotrices          -> promotrice·teur·s
# propagateur          / propagatrice         -> propagateur·trice
# propagateur          / propagatrice         -> propagatrice·teur
# propagateurs         / propagatrices        -> propagateur·trice·s
# propagateurs         / propagatrices        -> propagatrice·teur·s
# prospecteur          / prospectrice         -> prospecteur·trice
# prospecteur          / prospectrice         -> prospectrice·teur
# prospecteurs         / prospectrices        -> prospecteur·trice·s
# prospecteurs         / prospectrices        -> prospectrice·teur·s
# protecteur           / protectrice          -> protecteur·trice
# protecteur           / protectrice          -> protectrice·teur
# protecteurs          / protectrices         -> protecteur·trice·s
# protecteurs          / protectrices         -> protectrice·teur·s
# provocateur          / provocatrice         -> provocateur·trice
# provocateur          / provocatrice         -> provocatrice·teur
# provocateurs         / provocatrices        -> provocateur·trice·s
# provocateurs         / provocatrices        -> provocatrice·teur·s
# psychomoteur         / psychomotrice        -> psychomoteur·trice
# psychomoteur         / psychomotrice        -> psychomotrice·teur
# psychomoteurs        / psychomotrices       -> psychomoteur·trice·s
# psychomoteurs        / psychomotrices       -> psychomotrice·teur·s
# purificateur         / purificatrice        -> purificateur·trice
# purificateur         / purificatrice        -> purificatrice·teur
# purificateurs        / purificatrices       -> purificateur·trice·s
# purificateurs        / purificatrices       -> purificatrice·teur·s
# réalisateur          / réalisatrice         -> réalisateur·trice
# réalisateur          / réalisatrice         -> réalisatrice·teur
# réalisateurs         / réalisatrices        -> réalisateur·trice·s
# réalisateurs         / réalisatrices        -> réalisatrice·teur·s
# récepteur            / réceptrice           -> récepteur·trice
# récepteur            / réceptrice           -> réceptrice·teur
# récepteurs           / réceptrices          -> récepteur·trice·s
# récepteurs           / réceptrices          -> réceptrice·teur·s
# récriminateur        / récriminatrice       -> récriminateur·trice
# récriminateur        / récriminatrice       -> récriminatrice·teur
# récriminateurs       / récriminatrices      -> récriminateur·trice·s
# récriminateurs       / récriminatrices      -> récriminatrice·teur·s
# récupérateur         / récupératrice        -> récupérateur·trice
# récupérateur         / récupératrice        -> récupératrice·teur
# récupérateurs        / récupératrices       -> récupérateur·trice·s
# récupérateurs        / récupératrices       -> récupératrice·teur·s
# rédacteur            / rédactrice           -> rédacteur·trice
# rédacteur            / rédactrice           -> rédactrice·teur
# rédacteurs           / rédactrices          -> rédacteur·trice·s
# rédacteurs           / rédactrices          -> rédactrice·teur·s
# rédempteur           / rédemptrice          -> rédempteur·trice
# rédempteur           / rédemptrice          -> rédemptrice·teur
# rédempteurs          / rédemptrices         -> rédempteur·trice·s
# rédempteurs          / rédemptrices         -> rédemptrice·teur·s
# réducteur            / réductrice           -> réducteur·trice
# réducteur            / réductrice           -> réductrice·teur
# réducteurs           / réductrices          -> réducteur·trice·s
# réducteurs           / réductrices          -> réductrice·teur·s
# réformateur          / réformatrice         -> réformateur·trice
# réformateur          / réformatrice         -> réformatrice·teur
# réformateurs         / réformatrices        -> réformateur·trice·s
# réformateurs         / réformatrices        -> réformatrice·teur·s
# régénérateur         / régénératrice        -> régénérateur·trice
# régénérateur         / régénératrice        -> régénératrice·teur
# régénérateurs        / régénératrices       -> régénérateur·trice·s
# régénérateurs        / régénératrices       -> régénératrice·teur·s
# régulateur           / régulatrice          -> régulateur·trice
# régulateur           / régulatrice          -> régulatrice·teur
# régulateurs          / régulatrices         -> régulateur·trice·s
# régulateurs          / régulatrices         -> régulatrice·teur·s
# rémunérateur         / rémunératrice        -> rémunérateur·trice
# rémunérateur         / rémunératrice        -> rémunératrice·teur
# rémunérateurs        / rémunératrices       -> rémunérateur·trice·s
# rémunérateurs        / rémunératrices       -> rémunératrice·teur·s
# rénovateur           / rénovatrice          -> rénovateur·trice
# rénovateur           / rénovatrice          -> rénovatrice·teur
# rénovateurs          / rénovatrices         -> rénovateur·trice·s
# rénovateurs          / rénovatrices         -> rénovatrice·teur·s
# réparateur           / réparatrice          -> réparateur·trice
# réparateur           / réparatrice          -> réparatrice·teur
# réparateurs          / réparatrices         -> réparateur·trice·s
# réparateurs          / réparatrices         -> réparatrice·teur·s
# répétiteur           / répétitrice          -> répétiteur·trice
# répétiteur           / répétitrice          -> répétitrice·teur
# répétiteurs          / répétitrices         -> répétiteur·trice·s
# répétiteurs          / répétitrices         -> répétitrice·teur·s
# réprobateur          / réprobatrice         -> réprobateur·trice
# réprobateur          / réprobatrice         -> réprobatrice·teur
# réprobateurs         / réprobatrices        -> réprobateur·trice·s
# réprobateurs         / réprobatrices        -> réprobatrice·teur·s
# reproducteur         / reproductrice        -> reproducteur·trice
# reproducteur         / reproductrice        -> reproductrice·teur
# reproducteurs        / reproductrices       -> reproducteur·trice·s
# reproducteurs        / reproductrices       -> reproductrice·teur·s
# retardateur          / retardatrice         -> retardateur·trice
# retardateur          / retardatrice         -> retardatrice·teur
# retardateurs         / retardatrices        -> retardateur·trice·s
# retardateurs         / retardatrices        -> retardatrice·teur·s
# révélateur           / révélatrice          -> révélateur·trice
# révélateur           / révélatrice          -> révélatrice·teur
# révélateurs          / révélatrices         -> révélateur·trice·s
# révélateurs          / révélatrices         -> révélatrice·teur·s
# salvateur            / salvatrice           -> salvateur·trice
# salvateur            / salvatrice           -> salvatrice·teur
# salvateurs           / salvatrices          -> salvateur·trice·s
# salvateurs           / salvatrices          -> salvatrice·teur·s
# scrutateur           / scrutatrice          -> scrutateur·trice
# scrutateur           / scrutatrice          -> scrutatrice·teur
# scrutateurs          / scrutatrices         -> scrutateur·trice·s
# scrutateurs          / scrutatrices         -> scrutatrice·teur·s
# séducteur            / séductrice           -> séducteur·trice
# séducteur            / séductrice           -> séductrice·teur
# séducteurs           / séductrices          -> séducteur·trice·s
# séducteurs           / séductrices          -> séductrice·teur·s
# simplificateur       / simplificatrice      -> simplificateur·trice
# simplificateur       / simplificatrice      -> simplificatrice·teur
# simplificateurs      / simplificatrices     -> simplificateur·trice·s
# simplificateurs      / simplificatrices     -> simplificatrice·teur·s
# simulateur           / simulatrice          -> simulateur·trice
# simulateur           / simulatrice          -> simulatrice·teur
# simulateurs          / simulatrices         -> simulateur·trice·s
# simulateurs          / simulatrices         -> simulatrice·teur·s
# sous-directeur       / sous-directrice      -> sous-directeur·trice
# sous-directeur       / sous-directrice      -> sous-directrice·teur
# sous-directeurs      / sous-directrices     -> sous-directeur·trice·s
# sous-directeurs      / sous-directrices     -> sous-directrice·teur·s
# spectateur           / spectatrice          -> spectateur·trice
# spectateur           / spectatrice          -> spectatrice·teur
# spectateurs          / spectatrices         -> spectateur·trice·s
# spectateurs          / spectatrices         -> spectatrice·teur·s
# spéculateur          / spéculatrice         -> spéculateur·trice
# spéculateur          / spéculatrice         -> spéculatrice·teur
# spéculateurs         / spéculatrices        -> spéculateur·trice·s
# spéculateurs         / spéculatrices        -> spéculatrice·teur·s
# spoliateur           / spoliatrice          -> spoliateur·trice
# spoliateur           / spoliatrice          -> spoliatrice·teur
# spoliateurs          / spoliatrices         -> spoliateur·trice·s
# spoliateurs          / spoliatrices         -> spoliatrice·teur·s
# stabilisateur        / stabilisatrice       -> stabilisateur·trice
# stabilisateur        / stabilisatrice       -> stabilisatrice·teur
# stabilisateurs       / stabilisatrices      -> stabilisateur·trice·s
# stabilisateurs       / stabilisatrices      -> stabilisatrice·teur·s
# tabulateur           / tabulatrice          -> tabulateur·trice
# tabulateur           / tabulatrice          -> tabulatrice·teur
# tabulateurs          / tabulatrices         -> tabulateur·trice·s
# tabulateurs          / tabulatrices         -> tabulatrice·teur·s
# téléspectateur       / téléspectatrice      -> téléspectateur·trice
# téléspectateur       / téléspectatrice      -> téléspectatrice·teur
# téléspectateurs      / téléspectatrices     -> téléspectateur·trice·s
# téléspectateurs      / téléspectatrices     -> téléspectatrice·teur·s
# temporisateur        / temporisatrice       -> temporisateur·trice
# temporisateur        / temporisatrice       -> temporisatrice·teur
# temporisateurs       / temporisatrices      -> temporisateur·trice·s
# temporisateurs       / temporisatrices      -> temporisatrice·teur·s
# tentateur            / tentatrice           -> tentateur·trice
# tentateur            / tentatrice           -> tentatrice·teur
# tentateurs           / tentatrices          -> tentateur·trice·s
# tentateurs           / tentatrices          -> tentatrice·teur·s
# testateur            / testatrice           -> testateur·trice
# testateur            / testatrice           -> testatrice·teur
# testateurs           / testatrices          -> testateur·trice·s
# testateurs           / testatrices          -> testatrice·teur·s
# traducteur           / traductrice          -> traducteur·trice
# traducteur           / traductrice          -> traductrice·teur
# traducteurs          / traductrices         -> traducteur·trice·s
# traducteurs          / traductrices         -> traductrice·teur·s
# triomphateur         / triomphatrice        -> triomphateur·trice
# triomphateur         / triomphatrice        -> triomphatrice·teur
# triomphateurs        / triomphatrices       -> triomphateur·trice·s
# triomphateurs        / triomphatrices       -> triomphatrice·teur·s
# tuteur               / tutrice              -> tuteur·trice
# tuteur               / tutrice              -> tutrice·teur
# tuteurs              / tutrices             -> tuteur·trice·s
# tuteurs              / tutrices             -> tutrice·teur·s
# unificateur          / unificatrice         -> unificateur·trice
# unificateur          / unificatrice         -> unificatrice·teur
# unificateurs         / unificatrices        -> unificateur·trice·s
# unificateurs         / unificatrices        -> unificatrice·teur·s
# usurpateur           / usurpatrice          -> usurpateur·trice
# usurpateur           / usurpatrice          -> usurpatrice·teur
# usurpateurs          / usurpatrices         -> usurpateur·trice·s
# usurpateurs          / usurpatrices         -> usurpatrice·teur·s
# utilisateur          / utilisatrice         -> utilisateur·trice
# utilisateur          / utilisatrice         -> utilisatrice·teur
# utilisateurs         / utilisatrices        -> utilisateur·trice·s
# utilisateurs         / utilisatrices        -> utilisatrice·teur·s
# vasoconstricteur     / vasoconstrictrice    -> vasoconstricteur·trice
# vasoconstricteur     / vasoconstrictrice    -> vasoconstrictrice·teur
# vasoconstricteurs    / vasoconstrictrices   -> vasoconstricteur·trice·s
# vasoconstricteurs    / vasoconstrictrices   -> vasoconstrictrice·teur·s
# vasodilatateur       / vasodilatatrice      -> vasodilatateur·trice
# vasodilatateur       / vasodilatatrice      -> vasodilatatrice·teur
# vasodilatateurs      / vasodilatatrices     -> vasodilatateur·trice·s
# vasodilatateurs      / vasodilatatrices     -> vasodilatatrice·teur·s
# vérificateur         / vérificatrice        -> vérificateur·trice
# vérificateur         / vérificatrice        -> vérificatrice·teur
# vérificateurs        / vérificatrices       -> vérificateur·trice·s
# vérificateurs        / vérificatrices       -> vérificatrice·teur·s
# violateur            / violatrice           -> violateur·trice
# violateur            / violatrice           -> violatrice·teur
# violateurs           / violatrices          -> violateur·trice·s
# violateurs           / violatrices          -> violatrice·teur·s
# vociférateur         / vocifératrice        -> vociférateur·trice
# vociférateur         / vocifératrice        -> vocifératrice·teur
# vociférateurs        / vocifératrices       -> vociférateur·trice·s
# vociférateurs        / vocifératrices       -> vocifératrice·teur·s
# vulgarisateur        / vulgarisatrice       -> vulgarisateur·trice
# vulgarisateur        / vulgarisatrice       -> vulgarisatrice·teur
# vulgarisateurs       / vulgarisatrices      -> vulgarisateur·trice·s
# vulgarisateurs       / vulgarisatrices      -> vulgarisatrice·teur·s
#
# Cela a donné 448 nouveaux mots singuliers.
# Cela a donné 448 nouveaux mots pluriels.

# %% [markdown]
# Je pense qu'il n'y a pas d'erreurs sur ces 448 mots.

# %% [markdown]
# On voit qu'il manque des mots : "auteure" ou "autrice" n'est pas présent, car "auteure" n'est pas présent dans le dictionnaire chargé au début.

# %%
alternatives["auteur"] |= {"auteur·e", "auteur·trice"}
alternatives["auteurs"] |= {"auteur·e·s", "auteur·trice·smots"}
alternatives["auteure"] |= {"auteur·e", "auteur·trice"}
alternatives["auteures"] |= {"auteur·e·s", "auteur·trice·smots"}

# %% [markdown]
# ### Ajouter mot·eau·elle et mot·eaux·elles si `mot`-eau, `mot`-eaux, `mot`-elle et `mot`-elles sont présents

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("eau") and len(mot) > 3 and mot + "x" in set_mots:
        mot_feminin = f"{mot[:-3]}elle"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-3]}eau{SEP}elle"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}
        mot_feminin = f"{mot[:-3]}elles"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-3]}eaux{SEP}elles"
            print(f"{mot + 'x':<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
            alternatives[mot + "x"] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# beau                 / belle                -> beau·elle
# beaux                / belles               -> beaux·elles
# carreau              / carrelle             -> carreau·elle
# carreaux             / carrelles            -> carreaux·elles
# cerveau              / cervelle             -> cerveau·elle
# cerveaux             / cervelles            -> cerveaux·elles
# chapeau              / chapelle             -> chapeau·elle
# chapeaux             / chapelles            -> chapeaux·elles
# jouvenceau           / jouvencelle          -> jouvenceau·elle
# jouvenceaux          / jouvencelles         -> jouvenceaux·elles
# jumeau               / jumelle              -> jumeau·elle
# jumeaux              / jumelles             -> jumeaux·elles
# morceau              / morcelle             -> morceau·elle
# morceaux             / morcelles            -> morceaux·elles
# museau               / muselle              -> museau·elle
# museaux              / muselles             -> museaux·elles
# niveau               / nivelle              -> niveau·elle
# niveaux              / nivelles             -> niveaux·elles
# nouveau              / nouvelle             -> nouveau·elle
# nouveaux             / nouvelles            -> nouveaux·elles
# passereau            / passerelle           -> passereau·elle
# passereaux           / passerelles          -> passereaux·elles
# peau                 / pelle                -> peau·elle
# peaux                / pelles               -> peaux·elles
# pruneau              / prunelle             -> pruneau·elle
# pruneaux             / prunelles            -> pruneaux·elles
# puceau               / pucelle              -> puceau·elle
# puceaux              / pucelles             -> puceaux·elles
# renouveau            / renouvelle           -> renouveau·elle
# renouveaux           / renouvelles          -> renouveaux·elles
# rideau               / ridelle              -> rideau·elle
# rideaux              / ridelles             -> rideaux·elles
# rondeau              / rondelle             -> rondeau·elle
# rondeaux             / rondelles            -> rondeaux·elles
# ruisseau             / ruisselle            -> ruisseau·elle
# sceau                / scelle               -> sceau·elle
# sceaux               / scelles              -> sceaux·elles
# seau                 / selle                -> seau·elle
# seaux                / selles               -> seaux·elles
# tonneau              / tonnelle             -> tonneau·elle
# tonneaux             / tonnelles            -> tonneaux·elles
# tourtereau           / tourterelle          -> tourtereau·elle
# tourtereaux          / tourterelles         -> tourtereaux·elles
# vaisseau             / vaisselle            -> vaisseau·elle
# vaisseaux            / vaisselles           -> vaisseaux·elles
#
# Cela a donné 23 nouveaux mots singuliers.
# Cela a donné 22 nouveaux mots pluriels.

# %% [markdown]
# On voit que là aussi ça donne plein d'erreur !
# Seuls les mots suivants fonts sens :
#
# - beau                 / belle                -> b·eau·elle
# - jumeau               / jumelle              -> jum·eau·elle
# - nouveau              / nouvelle             -> nouv·eau·elle
# - puceau               / pucelle              -> puc·eau·elle

# %%
del_alternatives([
    "carreau", "carrelle", "carreaux", "carrelles",
    "cerveau", "cervelle", "cerveaux", "cervelles",
    "chapeau", "chapelle", "chapeaux", "chapelles",
    "jouvenceau", "jouvencelle", "jouvenceaux", "jouvencelles",
    "morceau", "morcelle", "morceaux", "morcelles",
    "museau", "muselle", "museaux", "muselles",
    "niveau", "nivelle", "niveaux", "nivelles",
    "passereau", "passerelle", "passereaux", "passerelles",
    "peau", "pelle", "peaux", "pelles",
    "pruneau", "prunelle", "pruneaux", "prunelles",
    "renouveau", "renouvelle", "renouveaux", "renouvelles",
    "rideau", "ridelle", "rideaux", "ridelles",
    "rondeau", "rondelle", "rondeaux", "rondelles",
    "ruisseau", "ruisselle", "ruisseaux", "ruisselles",
    "sceau", "scelles", "sceaux", "scelless",
    "seau", "selles", "seaux", "selless",
    "tonneau", "tonnelles", "tonneaux", "tonnelless",
    "tourtereau", "tourterelles", "tourtereaux", "tourterelless",
    "vaisseau", "vaisselles", "vaisseaux", "vaisselless",
])

# %% [markdown]
# Et aussi mot-au-elle et mot-aux-elles si mot-au, mot-aux, mot-elle et mot-elles sont présents ?

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("au") and len(mot) > 2 and mot + "x" in set_mots:
        mot_feminin = f"{mot[:-2]}elle"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-2]}au{SEP}elle"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}
        mot_feminin = f"{mot[:-2]}elles"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-2]}aux{SEP}elle{SEP}s"
            print(f"{mot + 'x':<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
            alternatives[mot + "x"] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# matériau             / matérielle           -> matériau·elle
# matériaux            / matérielles          -> matériaux·elle·s
#
# Cela a donné 1 nouveaux mots singuliers.
# Cela a donné 1 nouveaux mots pluriels.

# %% [markdown]
# Ce dernier test est clairement une mauvaise idée, matérielle n'est PAS le féminin de matériau.

# %%
del_alternatives([
    "matériau", "matérielle", "matériaux", "matérielles",
])

# %% [markdown]
# ### Ajouter mot·er·ère et mot·er·ère·s si `mot`-er, `mot`-ers, `mot`-ère et `mot`-ères sont présents

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("er") and len(mot) > 2:
        mot_feminin = f"{mot[:-2]}ère"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-2]}er{SEP}ère"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}
        mot_feminin = f"{mot[:-2]}ères"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-2]}er{SEP}ère{SEP}s"
            print(f"{mot + 's':<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
            alternatives[mot + "s"] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# alter                / altère               -> alter·ère
# alters               / altères              -> alter·ère·s
# altier               / altière              -> altier·ère
# altiers              / altières             -> altier·ère·s
# amer                 / amère                -> amer·ère
# amers                / amères               -> amer·ère·s
# avant-dernier        / avant-dernière       -> avant-dernier·ère
# avant-derniers       / avant-dernières      -> avant-dernier·ère·s
# aventurier           / aventurière          -> aventurier·ère
# aventuriers          / aventurières         -> aventurier·ère·s
# bachelier            / bachelière           -> bachelier·ère
# bacheliers           / bachelières          -> bachelier·ère·s
# baleinier            / baleinière           -> baleinier·ère
# baleiniers           / baleinières          -> baleinier·ère·s
# bélier               / bélière              -> bélier·ère
# béliers              / bélières             -> bélier·ère·s
# berger               / bergère              -> berger·ère
# bergers              / bergères             -> berger·ère·s
# betteravier          / betteravière         -> betteravier·ère
# betteraviers         / betteravières        -> betteravier·ère·s
# bijoutier            / bijoutière           -> bijoutier·ère
# bijoutiers           / bijoutières          -> bijoutier·ère·s
# bonnetier            / bonnetière           -> bonnetier·ère
# bonnetiers           / bonnetières          -> bonnetier·ère·s
# boucher              / bouchère             -> boucher·ère
# bouchers             / bouchères            -> boucher·ère·s
# boulanger            / boulangère           -> boulanger·ère
# boulangers           / boulangères          -> boulanger·ère·s
# boursier             / boursière            -> boursier·ère
# boursiers            / boursières           -> boursier·ère·s
# cachottier           / cachottière          -> cachottier·ère
# cachottiers          / cachottières         -> cachottier·ère·s
# cafetier             / cafetière            -> cafetier·ère
# cafetiers            / cafetières           -> cafetier·ère·s
# caissier             / caissière            -> caissier·ère
# caissiers            / caissières           -> caissier·ère·s
# cancanier            / cancanière           -> cancanier·ère
# cancaniers           / cancanières          -> cancanier·ère·s
# cantinier            / cantinière           -> cantinier·ère
# cantiniers           / cantinières          -> cantinier·ère·s
# carnassier           / carnassière          -> carnassier·ère
# carnassiers          / carnassières         -> carnassier·ère·s
# carrier              / carrière             -> carrier·ère
# carriers             / carrières            -> carrier·ère·s
# casanier             / casanière            -> casanier·ère
# casaniers            / casanières           -> casanier·ère·s
# cavalier             / cavalière            -> cavalier·ère
# cavaliers            / cavalières           -> cavalier·ère·s
# céréalier            / céréalière           -> céréalier·ère
# céréaliers           / céréalières          -> céréalier·ère·s
# chansonnier          / chansonnière         -> chansonnier·ère
# chansonniers         / chansonnières        -> chansonnier·ère·s
# charcutier           / charcutière          -> charcutier·ère
# charcutiers          / charcutières         -> charcutier·ère·s
# charnier             / charnière            -> charnier·ère
# charniers            / charnières           -> charnier·ère·s
# chemisier            / chemisière           -> chemisier·ère
# chemisiers           / chemisières          -> chemisier·ère·s
# cher                 / chère                -> cher·ère
# chers                / chères               -> cher·ère·s
# chevalier            / chevalière           -> chevalier·ère
# chevaliers           / chevalières          -> chevalier·ère·s
# chicanier            / chicanière           -> chicanier·ère
# chicaniers           / chicanières          -> chicanier·ère·s
# cocardier            / cocardière           -> cocardier·ère
# cocardiers           / cocardières          -> cocardier·ère·s
# cocher               / cochère              -> cocher·ère
# cochers              / cochères             -> cocher·ère·s
# coéquipier           / coéquipière          -> coéquipier·ère
# coéquipiers          / coéquipières         -> coéquipier·ère·s
# cohéritier           / cohéritière          -> cohéritier·ère
# cohéritiers          / cohéritières         -> cohéritier·ère·s
# conférencier         / conférencière        -> conférencier·ère
# conférenciers        / conférencières       -> conférencier·ère·s
# conseiller           / conseillère          -> conseiller·ère
# conseillers          / conseillères         -> conseiller·ère·s
# costumier            / costumière           -> costumier·ère
# costumiers           / costumières          -> costumier·ère·s
# côtier               / côtière              -> côtier·ère
# côtiers              / côtières             -> côtier·ère·s
# coutumier            / coutumière           -> coutumier·ère
# coutumiers           / coutumières          -> coutumier·ère·s
# couturier            / couturière           -> couturier·ère
# couturiers           / couturières          -> couturier·ère·s
# créancier            / créancière           -> créancier·ère
# créanciers           / créancières          -> créancier·ère·s
# crémier              / crémière             -> crémier·ère
# crémiers             / crémières            -> crémier·ère·s
# cuiller              / cuillère             -> cuiller·ère
# cuillers             / cuillères            -> cuiller·ère·s
# cuisinier            / cuisinière           -> cuisinier·ère
# cuisiniers           / cuisinières          -> cuisinier·ère·s
# dépensier            / dépensière           -> dépensier·ère
# dépensiers           / dépensières          -> dépensier·ère·s
# dernier              / dernière             -> dernier·ère
# derniers             / dernières            -> dernier·ère·s
# devancier            / devancière           -> devancier·ère
# devanciers           / devancières          -> devancier·ère·s
# douanier             / douanière            -> douanier·ère
# douaniers            / douanières           -> douanier·ère·s
# drapier              / drapière             -> drapier·ère
# drapiers             / drapières            -> drapier·ère·s
# droitier             / droitière            -> droitier·ère
# droitiers            / droitières           -> droitier·ère·s
# échotier             / échotière            -> échotier·ère
# échotiers            / échotières           -> échotier·ère·s
# éclusier             / éclusière            -> éclusier·ère
# éclusiers            / éclusières           -> éclusier·ère·s
# écolier              / écolière             -> écolier·ère
# écoliers             / écolières            -> écolier·ère·s
# écuyer               / écuyère              -> écuyer·ère
# écuyers              / écuyères             -> écuyer·ère·s
# émeutier             / émeutière            -> émeutier·ère
# émeutiers            / émeutières           -> émeutier·ère·s
# entier               / entière              -> entier·ère
# entiers              / entières             -> entier·ère·s
# épicier              / épicière             -> épicier·ère
# épiciers             / épicières            -> épicier·ère·s
# équipier             / équipière            -> équipier·ère
# équipiers            / équipières           -> équipier·ère·s
# étager               / étagère              -> étager·ère
# étagers              / étagères             -> étager·ère·s
# étranger             / étrangère            -> étranger·ère
# étrangers            / étrangères           -> étranger·ère·s
# façonnier            / façonnière           -> façonnier·ère
# façonniers           / façonnières          -> façonnier·ère·s
# familier             / familière            -> familier·ère
# familiers            / familières           -> familier·ère·s
# fermier              / fermière             -> fermier·ère
# fermiers             / fermières            -> fermier·ère·s
# fessier              / fessière             -> fessier·ère
# fessiers             / fessières            -> fessier·ère·s
# fier                 / fière                -> fier·ère
# fiers                / fières               -> fier·ère·s
# financier            / financière           -> financier·ère
# financiers           / financières          -> financier·ère·s
# foncier              / foncière             -> foncier·ère
# fonciers             / foncières            -> foncier·ère·s
# forestier            / forestière           -> forestier·ère
# forestiers           / forestières          -> forestier·ère·s
# fouger               / fougère              -> fouger·ère
# fougers              / fougères             -> fouger·ère·s
# fourmilier           / fourmilière          -> fourmilier·ère
# fourmiliers          / fourmilières         -> fourmilier·ère·s
# fourrager            / fourragère           -> fourrager·ère
# fourragers           / fourragères          -> fourrager·ère·s
# fourrier             / fourrière            -> fourrier·ère
# fourriers            / fourrières           -> fourrier·ère·s
# fripier              / fripière             -> fripier·ère
# fripiers             / fripières            -> fripier·ère·s
# fromager             / fromagère            -> fromager·ère
# fromagers            / fromagères           -> fromager·ère·s
# frontalier           / frontalière          -> frontalier·ère
# frontaliers          / frontalières         -> frontalier·ère·s
# fruitier             / fruitière            -> fruitier·ère
# fruitiers            / fruitières           -> fruitier·ère·s
# gantier              / gantière             -> gantier·ère
# gantiers             / gantières            -> gantier·ère·s
# gaucher              / gauchère             -> gaucher·ère
# gauchers             / gauchères            -> gaucher·ère·s
# gazier               / gazière              -> gazier·ère
# gaziers              / gazières             -> gazier·ère·s
# geôlier              / geôlière             -> geôlier·ère
# geôliers             / geôlières            -> geôlier·ère·s
# glacier              / glacière             -> glacier·ère
# glaciers             / glacières            -> glacier·ère·s
# grimacier            / grimacière           -> grimacier·ère
# grimaciers           / grimacières          -> grimacier·ère·s
# grossier             / grossière            -> grossier·ère
# grossiers            / grossières           -> grossier·ère·s
# guerrier             / guerrière            -> guerrier·ère
# guerriers            / guerrières           -> guerrier·ère·s
# héritier             / héritière            -> héritier·ère
# héritiers            / héritières           -> héritier·ère·s
# hospitalier          / hospitalière         -> hospitalier·ère
# hospitaliers         / hospitalières        -> hospitalier·ère·s
# hôtelier             / hôtelière            -> hôtelier·ère
# hôteliers            / hôtelières           -> hôtelier·ère·s
# houiller             / houillère            -> houiller·ère
# houillers            / houillères           -> houiller·ère·s
# immobilier           / immobilière          -> immobilier·ère
# immobiliers          / immobilières         -> immobilier·ère·s
# infirmier            / infirmière           -> infirmier·ère
# infirmiers           / infirmières          -> infirmier·ère·s
# inhospitalier        / inhospitalière       -> inhospitalier·ère
# inhospitaliers       / inhospitalières      -> inhospitalier·ère·s
# irrégulier           / irrégulière          -> irrégulier·ère
# irréguliers          / irrégulières         -> irrégulier·ère·s
# jardinier            / jardinière           -> jardinier·ère
# jardiniers           / jardinières          -> jardinier·ère·s
# joaillier            / joaillière           -> joaillier·ère
# joailliers           / joaillières          -> joaillier·ère·s
# journalier           / journalière          -> journalier·ère
# journaliers          / journalières         -> journalier·ère·s
# justicier            / justicière           -> justicier·ère
# justiciers           / justicières          -> justicier·ère·s
# lacer                / lacère               -> lacer·ère
# lacers               / lacères              -> lacer·ère·s
# lainier              / lainière             -> lainier·ère
# lainiers             / lainières            -> lainier·ère·s
# laitier              / laitière             -> laitier·ère
# laitiers             / laitières            -> laitier·ère·s
# léger                / légère               -> léger·ère
# légers               / légères              -> léger·ère·s
# lunetier             / lunetière            -> lunetier·ère
# lunetiers            / lunetières           -> lunetier·ère·s
# manier               / manière              -> manier·ère
# maniers              / manières             -> manier·ère·s
# manoeuvrier          / manoeuvrière         -> manoeuvrier·ère
# manoeuvriers         / manoeuvrières        -> manoeuvrier·ère·s
# maraîcher            / maraîchère           -> maraîcher·ère
# maraîchers           / maraîchères          -> maraîcher·ère·s
# marbrier             / marbrière            -> marbrier·ère
# marbriers            / marbrières           -> marbrier·ère·s
# marinier             / marinière            -> marinier·ère
# mariniers            / marinières           -> marinier·ère·s
# matelassier          / matelassière         -> matelassier·ère
# matelassiers         / matelassières        -> matelassier·ère·s
# ménager              / ménagère             -> ménager·ère
# ménagers             / ménagères            -> ménager·ère·s
# mensonger            / mensongère           -> mensonger·ère
# mensongers           / mensongères          -> mensonger·ère·s
# mer                  / mère                 -> mer·ère
# mers                 / mères                -> mer·ère·s
# mercier              / mercière             -> mercier·ère
# merciers             / mercières            -> mercier·ère·s
# messager             / messagère            -> messager·ère
# messagers            / messagères           -> messager·ère·s
# métayer              / métayère             -> métayer·ère
# métayers             / métayères            -> métayer·ère·s
# meunier              / meunière             -> meunier·ère
# meuniers             / meunières            -> meunier·ère·s
# meurtrier            / meurtrière           -> meurtrier·ère
# meurtriers           / meurtrières          -> meurtrier·ère·s
# minier               / minière              -> minier·ère
# miniers              / minières             -> minier·ère·s
# miser                / misère               -> miser·ère
# misers               / misères              -> miser·ère·s
# mobilier             / mobilière            -> mobilier·ère
# mobiliers            / mobilières           -> mobilier·ère·s
# moutonnier           / moutonnière          -> moutonnier·ère
# moutonniers          / moutonnières         -> moutonnier·ère·s
# muletier             / muletière            -> muletier·ère
# muletiers            / muletières           -> muletier·ère·s
# nourricier           / nourricière          -> nourricier·ère
# nourriciers          / nourricières         -> nourricier·ère·s
# oiselier             / oiselière            -> oiselier·ère
# oiseliers            / oiselières           -> oiselier·ère·s
# ordurier             / ordurière            -> ordurier·ère
# orduriers            / ordurières           -> ordurier·ère·s
# outrancier           / outrancière          -> outrancier·ère
# outranciers          / outrancières         -> outrancier·ère·s
# ouvrier              / ouvrière             -> ouvrier·ère
# ouvriers             / ouvrières            -> ouvrier·ère·s
# palier               / palière              -> palier·ère
# paliers              / palières             -> palier·ère·s
# paperassier          / paperassière         -> paperassier·ère
# paperassiers         / paperassières        -> paperassier·ère·s
# papetier             / papetière            -> papetier·ère
# papetiers            / papetières           -> papetier·ère·s
# particulier          / particulière         -> particulier·ère
# particuliers         / particulières        -> particulier·ère·s
# passager             / passagère            -> passager·ère
# passagers            / passagères           -> passager·ère·s
# pâtissier            / pâtissière           -> pâtissier·ère
# pâtissiers           / pâtissières          -> pâtissier·ère·s
# pelletier            / pelletière           -> pelletier·ère
# pelletiers           / pelletières          -> pelletier·ère·s
# pétrolier            / pétrolière           -> pétrolier·ère
# pétroliers           / pétrolières          -> pétrolier·ère·s
# piétonnier           / piétonnière          -> piétonnier·ère
# piétonniers          / piétonnières         -> piétonnier·ère·s
# plénier              / plénière             -> plénier·ère
# pléniers             / plénières            -> plénier·ère·s
# poissonnier          / poissonnière         -> poissonnier·ère
# poissonniers         / poissonnières        -> poissonnier·ère·s
# poivrier             / poivrière            -> poivrier·ère
# poivriers            / poivrières           -> poivrier·ère·s
# policier             / policière            -> policier·ère
# policiers            / policières           -> policier·ère·s
# pompier              / pompière             -> pompier·ère
# pompiers             / pompières            -> pompier·ère·s
# populacier           / populacière          -> populacier·ère
# populaciers          / populacières         -> populacier·ère·s
# portier              / portière             -> portier·ère
# portiers             / portières            -> portier·ère·s
# postier              / postière             -> postier·ère
# postiers             / postières            -> postier·ère·s
# potager              / potagère             -> potager·ère
# potagers             / potagères            -> potager·ère·s
# poudrier             / poudrière            -> poudrier·ère
# poudriers            / poudrières           -> poudrier·ère·s
# poussier             / poussière            -> poussier·ère
# poussiers            / poussières           -> poussier·ère·s
# premier              / première             -> premier·ère
# premiers             / premières            -> premier·ère·s
# prier                / prière               -> prier·ère
# priers               / prières              -> prier·ère·s
# primesautier         / primesautière        -> primesautier·ère
# primesautiers        / primesautières       -> primesautier·ère·s
# princier             / princière            -> princier·ère
# princiers            / princières           -> princier·ère·s
# printanier           / printanière          -> printanier·ère
# printaniers          / printanières         -> printanier·ère·s
# prisonnier           / prisonnière          -> prisonnier·ère
# prisonniers          / prisonnières         -> prisonnier·ère·s
# rancunier            / rancunière           -> rancunier·ère
# rancuniers           / rancunières          -> rancunier·ère·s
# régulier             / régulière            -> régulier·ère
# réguliers            / régulières           -> régulier·ère·s
# rentier              / rentière             -> rentier·ère
# rentiers             / rentières            -> rentier·ère·s
# romancier            / romancière           -> romancier·ère
# romanciers           / romancières          -> romancier·ère·s
# rosier               / rosière              -> rosier·ère
# rosiers              / rosières             -> rosier·ère·s
# roturier             / roturière            -> roturier·ère
# roturiers            / roturières           -> roturier·ère·s
# routier              / routière             -> routier·ère
# routiers             / routières            -> routier·ère·s
# routinier            / routinière           -> routinier·ère
# routiniers           / routinières          -> routinier·ère·s
# sablier              / sablière             -> sablier·ère
# sabliers             / sablières            -> sablier·ère·s
# saisonnier           / saisonnière          -> saisonnier·ère
# saisonniers          / saisonnières         -> saisonnier·ère·s
# séculier             / séculière            -> séculier·ère
# séculiers            / séculières           -> séculier·ère·s
# singulier            / singulière           -> singulier·ère
# singuliers           / singulières          -> singulier·ère·s
# sorcier              / sorcière             -> sorcier·ère
# sorciers             / sorcières            -> sorcier·ère·s
# sucrier              / sucrière             -> sucrier·ère
# sucriers             / sucrières            -> sucrier·ère·s
# teinturier           / teinturière          -> teinturier·ère
# teinturiers          / teinturières         -> teinturier·ère·s
# tenancier            / tenancière           -> tenancier·ère
# tenanciers           / tenancières          -> tenancier·ère·s
# théier               / théière              -> théier·ère
# théiers              / théières             -> théier·ère·s
# torcher              / torchère             -> torcher·ère
# torchers             / torchères            -> torcher·ère·s
# tracassier           / tracassière          -> tracassier·ère
# tracassiers          / tracassières         -> tracassier·ère·s
# trésorier            / trésorière           -> trésorier·ère
# trésoriers           / trésorières          -> trésorier·ère·s
# usufruitier          / usufruitière         -> usufruitier·ère
# usufruitiers         / usufruitières        -> usufruitier·ère·s
# vacher               / vachère              -> vacher·ère
# vachers              / vachères             -> vacher·ère·s
# verrier              / verrière             -> verrier·ère
# verriers             / verrières            -> verrier·ère·s
# viager               / viagère              -> viager·ère
# viagers              / viagères             -> viager·ère·s
# vivrier              / vivrière             -> vivrier·ère
# vivriers             / vivrières            -> vivrier·ère·s
#
# Cela a donné 178 nouveaux mots singuliers.
# Cela a donné 178 nouveaux mots pluriels.

# %% [markdown]
# On voit que là aussi ça donne des erreurs :
# - alter                / altère               -> alter·ère
#   alter est un mot latin, altère un nom qui n'a pas de forme féminine
# - carrier              / carrière             -> carrier·ère
#   rien à voir
# - fouger               / fougère              -> fouger·ère
#   rien à voir
# - lacer                / lacère               -> lacer·ère
#   lacer est un verbe, lacère la conjugaison de lacérer
# - mer                  / mère                 -> mer·ère
#   mer et mère n'ont rien à voir
# - miser                / misère               -> miser·ère
#   là encore, rien à voir
#
# Ces erreurs pourraient être évitées si on disposait d'étiquettes sur chaque mot (verbe, nom, adjectif, etc).

# %%
del_alternatives([
    "alter", "altère", "alters", "altères",
    "carrier", "carrière", "carriers", "carrières",
    "fouger", "fougère", "fougers", "fougères",
    "lacer", "lacère", "lacers", "lacères",
    "mer", "mère", "mers", "mères",
    "miser", "misère", "misers", "misères",
])

# %% [markdown]
# ### Ajouter mot-l·le et mot-n·ne si `mot`-l, `mot`-lle ou `mot`-n et `mot`-nne sont présents (et pluriels)

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("n") and len(mot) > 1 and mot + "s" in set_mots:
        mot_feminin = f"{mot[:-1]}nne"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-1]}n{SEP}ne"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}
        mot_feminin = f"{mot[:-1]}nnes"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-1]}n{SEP}ne{SEP}s"
            print(f"{mot + 's':<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
            alternatives[mot + "s"] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# abandon              / abandonne            -> abandon·ne
# abandons             / abandonnes           -> abandon·ne·s
# académicien          / académicienne        -> académicien·ne
# académiciens         / académiciennes       -> académicien·ne·s
# action               / actionne             -> action·ne
# actions              / actionnes            -> action·ne·s
# addition             / additionne           -> addition·ne
# additions            / additionnes          -> addition·ne·s
# aérien               / aérienne             -> aérien·ne
# aériens              / aériennes            -> aérien·ne·s
# affection            / affectionne          -> affection·ne
# affections           / affectionnes         -> affection·ne·s
# aiguillon            / aiguillonne          -> aiguillon·ne
# aiguillons           / aiguillonnes         -> aiguillon·ne·s
# algérien             / algérienne           -> algérien·ne
# algériens            / algériennes          -> algérien·ne·s
# alsacien             / alsacienne           -> alsacien·ne
# ambition             / ambitionne           -> ambition·ne
# ambitions            / ambitionnes          -> ambition·ne·s
# ancien               / ancienne             -> ancien·ne
# anciens              / anciennes            -> ancien·ne·s
# anglo-saxon          / anglo-saxonne        -> anglo-saxon·ne
# anglo-saxons         / anglo-saxonnes       -> anglo-saxon·ne·s
# ânon                 / ânonne               -> ânon·ne
# ânons                / ânonnes              -> ânon·ne·s
# antédiluvien         / antédiluvienne       -> antédiluvien·ne
# antédiluviens        / antédiluviennes      -> antédiluvien·ne·s
# antiaérien           / antiaérienne         -> antiaérien·ne
# antiaériens          / antiaériennes        -> antiaérien·ne·s
# audition             / auditionne           -> audition·ne
# auditions            / auditionnes          -> audition·ne·s
# autrichien           / autrichienne         -> autrichien·ne
# autrichiens          / autrichiennes        -> autrichien·ne·s
# bactérien            / bactérienne          -> bactérien·ne
# bactériens           / bactériennes         -> bactérien·ne·s
# badigeon             / badigeonne           -> badigeon·ne
# badigeons            / badigeonnes          -> badigeon·ne·s
# bâillon              / bâillonne            -> bâillon·ne
# bâillons             / bâillonnes           -> bâillon·ne·s
# baron                / baronne              -> baron·ne
# barons               / baronnes             -> baron·ne·s
# béotien              / béotienne            -> béotien·ne
# béotiens             / béotiennes           -> béotien·ne·s
# bohémien             / bohémienne           -> bohémien·ne
# bohémiens            / bohémiennes          -> bohémien·ne·s
# bon                  / bonne                -> bon·ne
# bons                 / bonnes               -> bon·ne·s
# bonbon               / bonbonne             -> bonbon·ne
# bonbons              / bonbonnes            -> bonbon·ne·s
# booléen              / booléenne            -> booléen·ne
# booléens             / booléennes           -> booléen·ne·s
# bouffon              / bouffonne            -> bouffon·ne
# bouffons             / bouffonnes           -> bouffon·ne·s
# bougon               / bougonne             -> bougon·ne
# bougons              / bougonnes            -> bougon·ne·s
# bouillon             / bouillonne           -> bouillon·ne
# bourdon              / bourdonne            -> bourdon·ne
# bourgeon             / bourgeonne           -> bourgeon·ne
# bourguignon          / bourguignonne        -> bourguignon·ne
# bourguignons         / bourguignonnes       -> bourguignon·ne·s
# bouton               / boutonne             -> bouton·ne
# boutons              / boutonnes            -> bouton·ne·s
# breton               / bretonne             -> breton·ne
# bretons              / bretonnes            -> breton·ne·s
# brouillon            / brouillonne          -> brouillon·ne
# brouillons           / brouillonnes         -> brouillon·ne·s
# canadien             / canadienne           -> canadien·ne
# canadiens            / canadiennes          -> canadien·ne·s
# canton               / cantonne             -> canton·ne
# cantons              / cantonnes            -> canton·ne·s
# cartésien            / cartésienne          -> cartésien·ne
# cartésiens           / cartésiennes         -> cartésien·ne·s
# carton               / cartonne             -> carton·ne
# cartons              / cartonnes            -> carton·ne·s
# caution              / cautionne            -> caution·ne
# cautions             / cautionnes           -> caution·ne·s
# champion             / championne           -> champion·ne
# champions            / championnes          -> champion·ne·s
# chien                / chienne              -> chien·ne
# chiens               / chiennes             -> chien·ne·s
# chiffon              / chiffonne            -> chiffon·ne
# chiffons             / chiffonnes           -> chiffon·ne·s
# chilien              / chilienne            -> chilien·ne
# chiliens             / chiliennes           -> chilien·ne·s
# chiromancien         / chiromancienne       -> chiromancien·ne
# chiromanciens        / chiromanciennes      -> chiromancien·ne·s
# chrétien             / chrétienne           -> chrétien·ne
# chrétiens            / chrétiennes          -> chrétien·ne·s
# citoyen              / citoyenne            -> citoyen·ne
# citoyens             / citoyennes           -> citoyen·ne·s
# clairon              / claironne            -> clairon·ne
# clairons             / claironnes           -> clairon·ne·s
# cloison              / cloisonne            -> cloison·ne
# cloisons             / cloisonnes           -> cloison·ne·s
# collation            / collationne          -> collation·ne
# collations           / collationnes         -> collation·ne·s
# collection           / collectionne         -> collection·ne
# collections          / collectionnes        -> collection·ne·s
# collégien            / collégienne          -> collégien·ne
# collégiens           / collégiennes         -> collégien·ne·s
# colon                / colonne              -> colon·ne
# colons               / colonnes             -> colon·ne·s
# comédien             / comédienne           -> comédien·ne
# comédiens            / comédiennes          -> comédien·ne·s
# con                  / conne                -> con·ne
# cons                 / connes               -> con·ne·s
# concitoyen           / concitoyenne         -> concitoyen·ne
# concitoyens          / concitoyennes        -> concitoyen·ne·s
# condition            / conditionne          -> condition·ne
# conditions           / conditionnes         -> condition·ne·s
# confection           / confectionne         -> confection·ne
# confections          / confectionnes        -> confection·ne·s
# congestion           / congestionne         -> congestion·ne
# convention           / conventionne         -> convention·ne
# conventions          / conventionnes        -> convention·ne·s
# corallien            / corallienne          -> corallien·ne
# coralliens           / coralliennes         -> corallien·ne·s
# crampon              / cramponne            -> crampon·ne
# crampons             / cramponnes           -> crampon·ne·s
# crânien              / crânienne            -> crânien·ne
# crâniens             / crâniennes           -> crânien·ne·s
# cybernéticien        / cybernéticienne      -> cybernéticien·ne
# cybernéticiens       / cybernéticiennes     -> cybernéticien·ne·s
# daltonien            / daltonienne          -> daltonien·ne
# daltoniens           / daltoniennes         -> daltonien·ne·s
# démission            / démissionne          -> démission·ne
# démissions           / démissionnes         -> démission·ne·s
# diététicien          / diététicienne        -> diététicien·ne
# diététiciens         / diététiciennes       -> diététicien·ne·s
# diluvien             / diluvienne           -> diluvien·ne
# diluviens            / diluviennes          -> diluvien·ne·s
# don                  / donne                -> don·ne
# dons                 / donnes               -> don·ne·s
# doyen                / doyenne              -> doyen·ne
# doyens               / doyennes             -> doyen·ne·s
# draconien            / draconienne          -> draconien·ne
# draconiens           / draconiennes         -> draconien·ne·s
# dragon               / dragonne             -> dragon·ne
# dragons              / dragonnes            -> dragon·ne·s
# échantillon          / échantillonne        -> échantillon·ne
# échantillons         / échantillonnes       -> échantillon·ne·s
# échelon              / échelonne            -> échelon·ne
# échelons             / échelonnes           -> échelon·ne·s
# égyptien             / égyptienne           -> égyptien·ne
# égyptiens            / égyptiennes          -> égyptien·ne·s
# électricien          / électricienne        -> électricien·ne
# électriciens         / électriciennes       -> électricien·ne·s
# électronicien        / électronicienne      -> électronicien·ne
# électroniciens       / électroniciennes     -> électronicien·ne·s
# émotion              / émotionne            -> émotion·ne
# émotions             / émotionnes           -> émotion·ne·s
# endocrinien          / endocrinienne        -> endocrinien·ne
# endocriniens         / endocriniennes       -> endocrinien·ne·s
# entretien            / entretienne          -> entretien·ne
# entretiens           / entretiennes         -> entretien·ne·s
# environ              / environne            -> environ·ne
# épicurien            / épicurienne          -> épicurien·ne
# épicuriens           / épicuriennes         -> épicurien·ne·s
# espion               / espionne             -> espion·ne
# espions              / espionnes            -> espion·ne·s
# esthéticien          / esthéticienne        -> esthéticien·ne
# esthéticiens         / esthéticiennes       -> esthéticien·ne·s
# étalon               / étalonne             -> étalon·ne
# étalons              / étalonnes            -> étalon·ne·s
# euclidien            / euclidienne          -> euclidien·ne
# euclidiens           / euclidiennes         -> euclidien·ne·s
# eurasien             / eurasienne           -> eurasien·ne
# eurasiens            / eurasiennes          -> eurasien·ne·s
# européen             / européenne           -> européen·ne
# européens            / européennes          -> européen·ne·s
# façon                / façonne              -> façon·ne
# façons               / façonnes             -> façon·ne·s
# fanfaron             / fanfaronne           -> fanfaron·ne
# fanfarons            / fanfaronnes          -> fanfaron·ne·s
# félon                / félonne              -> félon·ne
# félons               / félonnes             -> félon·ne·s
# fonction             / fonctionne           -> fonction·ne
# fonctions            / fonctionnes          -> fonction·ne·s
# fraction             / fractionne           -> fraction·ne
# fractions            / fractionnes          -> fraction·ne·s
# francilien           / francilienne         -> francilien·ne
# franciliens          / franciliennes        -> francilien·ne·s
# friction             / frictionne           -> friction·ne
# frictions            / frictionnes          -> friction·ne·s
# fripon               / friponne             -> fripon·ne
# fripons              / friponnes            -> fripon·ne·s
# frisson              / frissonne            -> frisson·ne
# frissons             / frissonnes           -> frisson·ne·s
# fusion               / fusionne             -> fusion·ne
# fusions              / fusionnes            -> fusion·ne·s
# garçon               / garçonne             -> garçon·ne
# garçons              / garçonnes            -> garçon·ne·s
# gardien              / gardienne            -> gardien·ne
# gardiens             / gardiennes           -> gardien·ne·s
# glouton              / gloutonne            -> glouton·ne
# gloutons             / gloutonnes           -> glouton·ne·s
# goudron              / goudronne            -> goudron·ne
# goudrons             / goudronnes           -> goudron·ne·s
# grammairien          / grammairienne        -> grammairien·ne
# grammairiens         / grammairiennes       -> grammairien·ne·s
# grégorien            / grégorienne          -> grégorien·ne
# grégoriens           / grégoriennes         -> grégorien·ne·s
# griffon              / griffonne            -> griffon·ne
# griffons             / griffonnes           -> griffon·ne·s
# grognon              / grognonne            -> grognon·ne
# grognons             / grognonnes           -> grognon·ne·s
# harpon               / harponne             -> harpon·ne
# harpons              / harponnes            -> harpon·ne·s
# herculéen            / herculéenne          -> herculéen·ne
# herculéens           / herculéennes         -> herculéen·ne·s
# historien            / historienne          -> historien·ne
# historiens           / historiennes         -> historien·ne·s
# illusion             / illusionne           -> illusion·ne
# illusions            / illusionnes          -> illusion·ne·s
# impression           / impressionne         -> impression·ne
# impressions          / impressionnes        -> impression·ne·s
# indien               / indienne             -> indien·ne
# indiens              / indiennes            -> indien·ne·s
# informaticien        / informaticienne      -> informaticien·ne
# informaticiens       / informaticiennes     -> informaticien·ne·s
# israélien            / israélienne          -> israélien·ne
# israéliens           / israéliennes         -> israélien·ne·s
# italien              / italienne            -> italien·ne
# italiens             / italiennes           -> italien·ne·s
# ivoirien             / ivoirienne           -> ivoirien·ne
# ivoiriens            / ivoiriennes          -> ivoirien·ne·s
# jalon                / jalonne              -> jalon·ne
# jalons               / jalonnes             -> jalon·ne·s
# kolkhozien           / kolkhozienne         -> kolkhozien·ne
# kolkhoziens          / kolkhoziennes        -> kolkhozien·ne·s
# laryngien            / laryngienne          -> laryngien·ne
# laryngiens           / laryngiennes         -> laryngien·ne·s
# lilliputien          / lilliputienne        -> lilliputien·ne
# lilliputiens         / lilliputiennes       -> lilliputien·ne·s
# lion                 / lionne               -> lion·ne
# lions                / lionnes              -> lion·ne·s
# logicien             / logicienne           -> logicien·ne
# logiciens            / logiciennes          -> logicien·ne·s
# luron                / luronne              -> luron·ne
# lurons               / luronnes             -> luron·ne·s
# luthérien            / luthérienne          -> luthérien·ne
# luthériens           / luthériennes         -> luthérien·ne·s
# lycéen               / lycéenne             -> lycéen·ne
# lycéens              / lycéennes            -> lycéen·ne·s
# magicien             / magicienne           -> magicien·ne
# magiciens            / magiciennes          -> magicien·ne·s
# maigrichon           / maigrichonne         -> maigrichon·ne
# maigrichons          / maigrichonnes        -> maigrichon·ne·s
# maintien             / maintienne           -> maintien·ne
# maintiens            / maintiennes          -> maintien·ne·s
# malthusien           / malthusienne         -> malthusien·ne
# malthusiens          / malthusiennes        -> malthusien·ne·s
# manichéen            / manichéenne          -> manichéen·ne
# manichéens           / manichéennes         -> manichéen·ne·s
# marron               / marronne             -> marron·ne
# marrons              / marronnes            -> marron·ne·s
# martien              / martienne            -> martien·ne
# martiens             / martiennes           -> martien·ne·s
# mathématicien        / mathématicienne      -> mathématicien·ne
# mathématiciens       / mathématiciennes     -> mathématicien·ne·s
# mécanicien           / mécanicienne         -> mécanicien·ne
# mécaniciens          / mécaniciennes        -> mécanicien·ne·s
# méditerranéen        / méditerranéenne      -> méditerranéen·ne
# méditerranéens       / méditerranéennes     -> méditerranéen·ne·s
# mention              / mentionne            -> mention·ne
# mentions             / mentionnes           -> mention·ne·s
# microbien            / microbienne          -> microbien·ne
# microbiens           / microbiennes         -> microbien·ne·s
# mien                 / mienne               -> mien·ne
# miens                / miennes              -> mien·ne·s
# mignon               / mignonne             -> mignon·ne
# mignons              / mignonnes            -> mignon·ne·s
# milicien             / milicienne           -> milicien·ne
# miliciens            / miliciennes          -> milicien·ne·s
# mitoyen              / mitoyenne            -> mitoyen·ne
# mitoyens             / mitoyennes           -> mitoyen·ne·s
# mongolien            / mongolienne          -> mongolien·ne
# mongoliens           / mongoliennes         -> mongolien·ne·s
# moyen                / moyenne              -> moyen·ne
# moyens               / moyennes             -> moyen·ne·s
# musicien             / musicienne           -> musicien·ne
# musiciens            / musiciennes          -> musicien·ne·s
# napoléonien          / napoléonienne        -> napoléonien·ne
# napoléoniens         / napoléoniennes       -> napoléonien·ne·s
# négrillon            / négrillonne          -> négrillon·ne
# négrillons           / négrillonnes         -> négrillon·ne·s
# nord-coréen          / nord-coréenne        -> nord-coréen·ne
# nord-coréens         / nord-coréennes       -> nord-coréen·ne·s
# normalien            / normalienne          -> normalien·ne
# normaliens           / normaliennes         -> normalien·ne·s
# norvégien            / norvégienne          -> norvégien·ne
# norvégiens           / norvégiennes         -> norvégien·ne·s
# obstétricien         / obstétricienne       -> obstétricien·ne
# obstétriciens        / obstétriciennes      -> obstétricien·ne·s
# occasion             / occasionne           -> occasion·ne
# occasions            / occasionnes          -> occasion·ne·s
# oedipien             / oedipienne           -> oedipien·ne
# oedipiens            / oedipiennes          -> oedipien·ne·s
# olympien             / olympienne           -> olympien·ne
# olympiens            / olympiennes          -> olympien·ne·s
# omnipraticien        / omnipraticienne      -> omnipraticien·ne
# omnipraticiens       / omnipraticiennes     -> omnipraticien·ne·s
# opticien             / opticienne           -> opticien·ne
# opticiens            / opticiennes          -> opticien·ne·s
# ovarien              / ovarienne            -> ovarien·ne
# ovariens             / ovariennes           -> ovarien·ne·s
# ovation              / ovationne            -> ovation·ne
# ovations             / ovationnes           -> ovation·ne·s
# païen                / païenne              -> païen·ne
# païens               / païennes             -> païen·ne·s
# pan                  / panne                -> pan·ne
# pans                 / pannes               -> pan·ne·s
# paon                 / paonne               -> paon·ne
# paons                / paonnes              -> paon·ne·s
# papillon             / papillonne           -> papillon·ne
# papillons            / papillonnes          -> papillon·ne·s
# pardon               / pardonne             -> pardon·ne
# pardons              / pardonnes            -> pardon·ne·s
# parisien             / parisienne           -> parisien·ne
# parisiens            / parisiennes          -> parisien·ne·s
# paroissien           / paroissienne         -> paroissien·ne
# paroissiens          / paroissiennes        -> paroissien·ne·s
# passion              / passionne            -> passion·ne
# passions             / passionnes           -> passion·ne·s
# patron               / patronne             -> patron·ne
# patrons              / patronnes            -> patron·ne·s
# paysan               / paysanne             -> paysan·ne
# paysans              / paysannes            -> paysan·ne·s
# peloton              / pelotonne            -> peloton·ne
# pelotons             / pelotonnes           -> peloton·ne·s
# percheron            / percheronne          -> percheron·ne
# percherons           / percheronnes         -> percheron·ne·s
# perfection           / perfectionne         -> perfection·ne
# perfections          / perfectionnes        -> perfection·ne·s
# perquisition         / perquisitionne       -> perquisition·ne
# perquisitions        / perquisitionnes      -> perquisition·ne·s
# péruvien             / péruvienne           -> péruvien·ne
# péruviens            / péruviennes          -> péruvien·ne·s
# pharmacien           / pharmacienne         -> pharmacien·ne
# pharmaciens          / pharmaciennes        -> pharmacien·ne·s
# phonéticien          / phonéticienne        -> phonéticien·ne
# phonéticiens         / phonéticiennes       -> phonéticien·ne·s
# piéton               / piétonne             -> piéton·ne
# piétons              / piétonnes            -> piéton·ne·s
# pigeon               / pigeonne             -> pigeon·ne
# pigeons              / pigeonnes            -> pigeon·ne·s
# pilon                / pilonne              -> pilon·ne
# pilons               / pilonnes             -> pilon·ne·s
# poinçon              / poinçonne            -> poinçon·ne
# poinçons             / poinçonnes           -> poinçon·ne·s
# poissonnien          / poissonnienne        -> poissonnien·ne
# poissonniens         / poissonniennes       -> poissonnien·ne·s
# polisson             / polissonne           -> polisson·ne
# polissons            / polissonnes          -> polisson·ne·s
# politicien           / politicienne         -> politicien·ne
# politiciens          / politiciennes        -> politicien·ne·s
# poltron              / poltronne            -> poltron·ne
# poltrons             / poltronnes           -> poltron·ne·s
# polytechnicien       / polytechnicienne     -> polytechnicien·ne
# polytechniciens      / polytechniciennes    -> polytechnicien·ne·s
# ponction             / ponctionne           -> ponction·ne
# ponctions            / ponctionnes          -> ponction·ne·s
# position             / positionne           -> position·ne
# positions            / positionnes          -> position·ne·s
# précaution           / précautionne         -> précaution·ne
# précautions          / précautionnes        -> précaution·ne·s
# prolétarien          / prolétarienne        -> prolétarien·ne
# prolétariens         / prolétariennes       -> prolétarien·ne·s
# provision            / provisionne          -> provision·ne
# provisions           / provisionnes         -> provision·ne·s
# question             / questionne           -> question·ne
# questions            / questionnes          -> question·ne·s
# quotidien            / quotidienne          -> quotidien·ne
# quotidiens           / quotidiennes         -> quotidien·ne·s
# raison               / raisonne             -> raison·ne
# raisons              / raisonnes            -> raison·ne·s
# rançon               / rançonne             -> rançon·ne
# ration               / rationne             -> ration·ne
# rations              / rationnes            -> ration·ne·s
# rayon                / rayonne              -> rayon·ne
# rayons               / rayonnes             -> rayon·ne·s
# réception            / réceptionne          -> réception·ne
# réceptions           / réceptionnes         -> réception·ne·s
# réquisition          / réquisitionne        -> réquisition·ne
# réquisitions         / réquisitionnes       -> réquisition·ne·s
# rétinien             / rétinienne           -> rétinien·ne
# rétiniens            / rétiniennes          -> rétinien·ne·s
# réveillon            / réveillonne          -> réveillon·ne
# réveillons           / réveillonnes         -> réveillon·ne·s
# révolution           / révolutionne         -> révolution·ne
# révolutions          / révolutionnes        -> révolution·ne·s
# ronchon              / ronchonne            -> ronchon·ne
# ronchons             / ronchonnes           -> ronchon·ne·s
# ronron               / ronronne             -> ronron·ne
# sanction             / sanctionne           -> sanction·ne
# sanctions            / sanctionnes          -> sanction·ne·s
# saoudien             / saoudienne           -> saoudien·ne
# saoudiens            / saoudiennes          -> saoudien·ne·s
# sauvageon            / sauvageonne          -> sauvageon·ne
# sauvageons           / sauvageonnes         -> sauvageon·ne·s
# savon                / savonne              -> savon·ne
# savons               / savonnes             -> savon·ne·s
# saxon                / saxonne              -> saxon·ne
# saxons               / saxonnes             -> saxon·ne·s
# section              / sectionne            -> section·ne
# sections             / sectionnes           -> section·ne·s
# sélection            / sélectionne          -> sélection·ne
# sélections           / sélectionnes         -> sélection·ne·s
# sermon               / sermonne             -> sermon·ne
# sermons              / sermonnes            -> sermon·ne·s
# sibérien             / sibérienne           -> sibérien·ne
# sibériens            / sibériennes          -> sibérien·ne·s
# sien                 / sienne               -> sien·ne
# siens                / siennes              -> sien·ne·s
# sillon               / sillonne             -> sillon·ne
# sillons              / sillonnes            -> sillon·ne·s
# solution             / solutionne           -> solution·ne
# solutions            / solutionnes          -> solution·ne·s
# son                  / sonne                -> son·ne
# sons                 / sonnes               -> son·ne·s
# soumission           / soumissionne         -> soumission·ne
# soumissions          / soumissionnes        -> soumission·ne·s
# soupçon              / soupçonne            -> soupçon·ne
# soupçons             / soupçonnes           -> soupçon·ne·s
# soutien              / soutienne            -> soutien·ne
# soutiens             / soutiennes           -> soutien·ne·s
# stalinien            / stalinienne          -> stalinien·ne
# staliniens           / staliniennes         -> stalinien·ne·s
# station              / stationne            -> station·ne
# stations             / stationnes           -> station·ne·s
# subvention           / subventionne         -> subvention·ne
# subventions          / subventionnes        -> subvention·ne·s
# sud-coréen           / sud-coréenne         -> sud-coréen·ne
# sud-coréens          / sud-coréennes        -> sud-coréen·ne·s
# suggestion           / suggestionne         -> suggestion·ne
# suggestions          / suggestionnes        -> suggestion·ne·s
# syrien               / syrienne             -> syrien·ne
# syriens              / syriennes            -> syrien·ne·s
# talon                / talonne              -> talon·ne
# talons               / talonnes             -> talon·ne·s
# tampon               / tamponne             -> tampon·ne
# tampons              / tamponnes            -> tampon·ne·s
# tatillon             / tatillonne           -> tatillon·ne
# tatillons            / tatillonnes          -> tatillon·ne·s
# technicien           / technicienne         -> technicien·ne
# techniciens          / techniciennes        -> technicien·ne·s
# terrien              / terrienne            -> terrien·ne
# terriens             / terriennes           -> terrien·ne·s
# thyroïdien           / thyroïdienne         -> thyroïdien·ne
# thyroïdiens          / thyroïdiennes        -> thyroïdien·ne·s
# tien                 / tienne               -> tien·ne
# tiens                / tiennes              -> tien·ne·s
# ton                  / tonne                -> ton·ne
# tons                 / tonnes               -> ton·ne·s
# tourbillon           / tourbillonne         -> tourbillon·ne
# tragédien            / tragédienne          -> tragédien·ne
# tragédiens           / tragédiennes         -> tragédien·ne·s
# transsaharien        / transsaharienne      -> transsaharien·ne
# transsahariens       / transsahariennes     -> transsaharien·ne·s
# tronçon              / tronçonne            -> tronçon·ne
# tunisien             / tunisienne           -> tunisien·ne
# tunisiens            / tunisiennes          -> tunisien·ne·s
# uruguayen            / uruguayenne          -> uruguayen·ne
# uruguayens           / uruguayennes         -> uruguayen·ne·s
# van                  / vanne                -> van·ne
# vans                 / vannes               -> van·ne·s
# vaurien              / vaurienne            -> vaurien·ne
# végétarien           / végétarienne         -> végétarien·ne
# végétariens          / végétariennes        -> végétarien·ne·s
# vénérien             / vénérienne           -> vénérien·ne
# vénériens            / vénériennes          -> vénérien·ne·s
# vénitien             / vénitienne           -> vénitien·ne
# vénitiens            / vénitiennes          -> vénitien·ne·s
# vietnamien           / vietnamienne         -> vietnamien·ne
# vietnamiens          / vietnamiennes        -> vietnamien·ne·s
# vision               / visionne             -> vision·ne
# visions              / visionnes            -> vision·ne·s
# wallon               / wallonne             -> wallon·ne
# wallons              / wallonnes            -> wallon·ne·s
# zambien              / zambienne            -> zambien·ne
# zambiens             / zambiennes           -> zambien·ne·s
#
# Cela a donné 246 nouveaux mots singuliers.
# Cela a donné 235 nouveaux mots pluriels.

# %% [markdown]
# On voit que là aussi ça donne PLEIN d'erreurs :
#
# - abandon              / abandonne            -> abandon·ne
# - action               / actionne             -> action·ne
# - addition             / additionne           -> addition·ne
# - affection            / affectionne          -> affection·ne
# - ambition             / ambitionne           -> ambition·ne
# - audition             / auditionne           -> audition·ne
# - badigeon             / badigeonne           -> badigeon·ne
# - bâillon              / bâillonne            -> bâillon·ne
# - béton                / bétonne              -> béton·ne
# - bonbon               / bonbonne             -> bonbon·ne
# - bouillon             / bouillonne           -> bouillon·ne
# - bourdon              / bourdonne            -> bourdon·ne
# - bourgeon             / bourgeonne           -> bourgeon·ne
# - bouton               / boutonne             -> bouton·ne
# - brouillon            / brouillonne          -> brouillon·ne
# - canton               / cantonne             -> canton·ne
# - carton               / cartonne             -> carton·ne
# - caution              / cautionne            -> caution·ne
# - chiffon              / chiffonne            -> chiffon·ne
# - clairon              / claironne            -> clairon·ne
# - cloison              / cloisonne            -> cloison·ne
# - collation            / collationne          -> collation·ne
# - collection           / collectionne         -> collection·ne
# - colon                / colonne              -> colon·ne
# - condition            / conditionne          -> condition·ne
# - confection           / confectionne         -> confection·ne
# - congestion           / congestionne         -> congestion·ne
# - convention           / conventionne         -> convention·ne
# - crampon              / cramponne            -> crampon·ne
# - démission            / démissionne          -> démission·ne
# - don                  / donne                -> don·ne
# - échantillon          / échantillonne        -> échantillon·ne
# - échelon              / échelonne            -> échelon·ne
# - émotion              / émotionne            -> émotion·ne
# - environ              / environne            -> environ·ne
# - façon                / façonne              -> façon·ne
# - foison               / foisonne             -> foison·ne
# - fonction             / fonctionne           -> fonction·ne
# - fraction             / fractionne           -> fraction·ne
# - frisson              / frissonne            -> frisson·ne
# - fusion               / fusionne             -> fusion·ne
# - goudron              / goudronne            -> goudron·ne
# - illusion             / illusionne           -> illusion·ne
# - impression           / impressionne         -> impression·ne
# - jalon                / jalonne              -> jalon·ne
# - maintien             / maintienne           -> maintien·ne
# - man                  / manne                -> man·ne
# - manutention          / manutentionne        -> manutention·ne
# - marron               / marronne             -> marron·ne
# - mention              / mentionne            -> mention·ne
# - moyen                / moyenne              -> moyen·ne
# - non                  / nonne                -> non·ne
# - occasion             / occasionne           -> occasion·ne·s
# - ovation              / ovationne            -> ovation·ne·s
# - pan                  / panne                -> pan·ne
# - papillon             / papillonne           -> papillon·ne·s
# - pardon               / pardonne             -> pardon·ne·s
# - passion              / passionne            -> passion·ne·s
# - peloton              / pelotonne            -> peloton·ne·s
# - perfection           / perfectionne         -> perfection·ne
# - perquisition         / perquisitionne       -> perquisition·ne
# - pilon                / pilonne              -> pilon·ne·s
# - ponction             / ponctionne           -> ponction·ne·s
# - position             / positionne           -> position·ne·s
# - précaution           / précautionne         -> précaution·ne
# - provision            / provisionne          -> provision·ne
# - question             / questionne           -> question·ne
# - raison               / raisonne             -> raison·ne
# - rançon               / rançonne             -> rançon·ne
# - ration               / rationne             -> ration·ne
# - rayon                / rayonne              -> rayon·ne
# - réception            / réceptionne          -> réception·ne
# - réquisition          / réquisitionne        -> réquisition·ne
# - réveillon            / réveillonne          -> réveillon·ne
# - révolution           / révolutionne         -> révolution·ne
# - ronchon              / ronchonne            -> ronchon·ne
# - sanction             / sanctionne           -> sanction·ne
# - savon                / savonne              -> savon·ne
# - section              / sectionne            -> section·ne
# - sélection            / sélectionne          -> sélection·ne
# - sermon               / sermonne             -> sermon·ne·s
# - sillon               / sillonne             -> sillon·ne
# - solution             / solutionne           -> solution·ne
# - son                  / sonne                -> son·ne
# - soumission           / soumissionne         -> soumission·ne
# - soupçon              / soupçonne            -> soupçon·ne
# - station              / stationne            -> station·ne
# - subvention           / subventionne         -> subvention·ne
# - suggestion           / suggestionne         -> suggestion·ne
# - tampon               / tamponne             -> tampon·ne
# - ton                  / tonne                -> ton·ne·s
# - tronçon              / tronçonne            -> tronçon·ne
# - van                  / vanne                -> van·ne
# - vision               / visionne             -> vision·ne
#
# Ces erreurs pourraient être évitées si on disposait d'étiquettes sur chaque mot (verbe, nom, adjectif, etc).
# La plupart des erreurs viennent de mots qui sont un nom au masculin (sermon) et un verbe conjugué au présent de l'indicatif qui ressemble à une forme féminine du mot (sermonne).

# %%
del_alternatives([
    "abandon", "abandonne", "abandons", "abandonnes",
    "action", "actionne", "actions", "actionnes",
    "addition", "additionne", "additions", "additionnes",
    "affection", "affectionne", "affections", "affectionnes",
    "ambition", "ambitionne", "ambitions", "ambitionnes",
    "audition", "auditionne", "auditions", "auditionnes",
    "badigeon", "badigeonne", "badigeons", "badigeonnes",
    "bâillon", "bâillonne", "bâillons", "bâillonnes",
    "béton", "bétonne", "bétons", "bétonnes",
    "bonbon", "bonbonne", "bonbons", "bonbonnes",
    "bouillon", "bouillonne", "bouillons", "bouillonnes",
    "bourdon", "bourdonne", "bourdons", "bourdonnes",
    "bourgeon", "bourgeonne", "bourgeons", "bourgeonnes",
    "bouton", "boutonne", "boutons", "boutonnes",
    "brouillon", "brouillonne", "brouillons", "brouillonnes",
    "canton", "cantonne", "cantons", "cantonnes",
    "carton", "cartonne", "cartons", "cartonnes",
    "caution", "cautionne", "cautions", "cautionnes",
    "chiffon", "chiffonne", "chiffons", "chiffonnes",
    "clairon", "claironne", "clairons", "claironnes",
    "cloison", "cloisonne", "cloisons", "cloisonnes",
    "collation", "collationne", "collations", "collationnes",
    "collection", "collectionne", "collections", "collectionnes",
    "colon", "colonne", "colons", "colonnes",
    "condition", "conditionne", "conditions", "conditionnes",
    "confection", "confectionne", "confections", "confectionnes",
    "congestion", "congestionne", "congestions", "congestionnes",
    "convention", "conventionne", "conventions", "conventionnes",
    "crampon", "cramponne", "crampons", "cramponnes",
    "démission", "démissionne", "démissions", "démissionnes",
    "don", "donne", "dons", "donnes",
    "échantillon", "échantillonne", "échantillons", "échantillonnes",
    "échelon", "échelonne", "échelons", "échelonnes",
    "émotion", "émotionne", "émotions", "émotionnes",
    "environ", "environne", "environs", "environnes",
    "façon", "façonne", "façons", "façonnes",
    "foison", "foisonne", "foisons", "foisonnes",
    "fonction", "fonctionne", "fonctions", "fonctionnes",
    "fraction", "fractionne", "fractions", "fractionnes",
    "frisson", "frissonne", "frissons", "frissonnes",
    "fusion", "fusionne", "fusions", "fusionnes",
    "goudron", "goudronne", "goudrons", "goudronnes",
    "illusion", "illusionne", "illusions", "illusionnes",
    "impression", "impressionne", "impressions", "impressionnes",
    "jalon", "jalonne", "jalons", "jalonnes",
    "maintien", "maintienne", "maintiens", "maintiennes",
    "man", "manne", "mans", "mannes",
    "manutention", "manutentionne", "manutentions", "manutentionnes",
    "marron", "marronne", "marrons", "marronnes",
    "mention", "mentionne", "mentions", "mentionnes",
    "moyen", "moyenne", "moyens", "moyennes",
    "non", "nonne", "nons", "nonnes",
    "occasion", "occasionne", "occasions", "occasionnes",
    "ovation", "ovationne", "ovations", "ovationnes",
    "pan", "panne", "pans", "pannes",
    "papillon", "papillonne", "papillons", "papillonnes",
    "pardon", "pardonne", "pardons", "pardonnes",
    "passion", "passionne", "passions", "passionnes",
    "peloton", "pelotonne", "pelotons", "pelotonnes",
    "perfection", "perfectionne", "perfections", "perfectionnes",
    "perquisition", "perquisitionne", "perquisitions", "perquisitionnes",
    "pilon", "pilonne", "pilons", "pilonnes",
    "ponction", "ponctionne", "ponctions", "ponctionnes",
    "position", "positionne", "positions", "positionnes",
    "précaution", "précautionne", "précautions", "précautionnes",
    "provision", "provisionne", "provisions", "provisionnes",
    "question", "questionne", "questions", "questionnes",
    "raison", "raisonne", "raisons", "raisonnes",
    "rançon", "rançonne", "rançons", "rançonnes",
    "ration", "rationne", "rations", "rationnes",
    "rayon", "rayonne", "rayons", "rayonnes",
    "réception", "réceptionne", "réceptions", "réceptionnes",
    "réquisition", "réquisitionne", "réquisitions", "réquisitionnes",
    "réveillon", "réveillonne", "réveillons", "réveillonnes",
    "révolution", "révolutionne", "révolutions", "révolutionnes",
    "ronchon", "ronchonne", "ronchons", "ronchonnes",
    "sanction", "sanctionne", "sanctions", "sanctionnes",
    "savon", "savonne", "savons", "savonnes",
    "section", "sectionne", "sections", "sectionnes",
    "sélection", "sélectionne", "sélections", "sélectionnes",
    "sermon", "sermonne", "sermons", "sermonnes",
    "sillon", "sillonne", "sillons", "sillonnes",
    "solution", "solutionne", "solutions", "solutionnes",
    "son", "sonne", "sons", "sonnes",
    "soumission", "soumissionne", "soumissions", "soumissionnes",
    "soupçon", "soupçonne", "soupçons", "soupçonnes",
    "station", "stationne", "stations", "stationnes",
    "subvention", "subventionne", "subventions", "subventionnes",
    "suggestion", "suggestionne", "suggestions", "suggestionnes",
    "tampon", "tamponne", "tampons", "tamponnes",
    "ton", "tonne", "tons", "tonnes",
    "tronçon", "tronçonne", "tronçons", "tronçonnes",
    "van", "vanne", "vans", "vannes",
    "vision", "visionne", "visions", "visionnes",
])

# %% [markdown]
# Et pour les mots en `mot`-l et `mot`-lle :

# %%
nouveaux_mots_inclusifs_singuliers = []
nouveaux_mots_inclusifs_pluriels = []

for mot in tqdm(mots):
    if mot.endswith("l") and len(mot) > 1 and mot + "s" in set_mots:
        mot_feminin = f"{mot[:-1]}lle"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-1]}l{SEP}le"
            print(f"{mot:<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_singuliers.append(mot_inclusif)
            alternatives[mot] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}
        mot_feminin = f"{mot[:-1]}lles"
        if mot_feminin in set_mots:
            mot_inclusif = f"{mot[:-1]}l{SEP}le{SEP}s"
            print(f"{mot + 's':<20} / {mot_feminin:<20} -> {mot_inclusif:<20}")
            nouveaux_mots_inclusifs_pluriels.append(mot_inclusif)
            alternatives[mot + "s"] |= {mot_inclusif}
            alternatives[mot_feminin] |= {mot_inclusif}

# on garde les mots nouveaux
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_singuliers) - set(mots_inclusifs_singuliers))} nouveaux mots singuliers.")
mots_inclusifs_singuliers = list(set(mots_inclusifs_singuliers + nouveaux_mots_inclusifs_singuliers))
print(f"Cela a donné {len(set(nouveaux_mots_inclusifs_pluriels) - set(mots_inclusifs_pluriels))} nouveaux mots pluriels.")
mots_inclusifs_pluriels = list(set(mots_inclusifs_pluriels + nouveaux_mots_inclusifs_pluriels))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=139719.0), HTML(value='')))
# accidentel           / accidentelle         -> accidentel·le
# accidentels          / accidentelles        -> accidentel·le·s
# accueil              / accueille            -> accueil·le
# accueils             / accueilles           -> accueil·le·s
# actuariel            / actuarielle          -> actuariel·le
# actuariels           / actuarielles         -> actuariel·le·s
# actuel               / actuelle             -> actuel·le
# actuels              / actuelles            -> actuel·le·s
# additionnel          / additionnelle        -> additionnel·le
# additionnels         / additionnelles       -> additionnel·le·s
# annuel               / annuelle             -> annuel·le
# annuels              / annuelles            -> annuel·le·s
# anticonceptionnel    / anticonceptionnelle  -> anticonceptionnel·le
# anticonceptionnels   / anticonceptionnelles -> anticonceptionnel·le·s
# anticonstitutionnel  / anticonstitutionnelle -> anticonstitutionnel·le
# anticonstitutionnels / anticonstitutionnelles -> anticonstitutionnel·le·s
# appareil             / appareille           -> appareil·le
# appareils            / appareilles          -> appareil·le·s
# appel                / appelle              -> appel·le
# appels               / appelles             -> appel·le·s
# artériel             / artérielle           -> artériel·le
# artériels            / artérielles          -> artériel·le·s
# artificiel           / artificielle         -> artificiel·le
# artificiels          / artificielles        -> artificiel·le·s
# ascensionnel         / ascensionnelle       -> ascensionnel·le
# ascensionnels        / ascensionnelles      -> ascensionnel·le·s
# atemporel            / atemporelle          -> atemporel·le
# atemporels           / atemporelles         -> atemporel·le·s
# audiovisuel          / audiovisuelle        -> audiovisuel·le
# audiovisuels         / audiovisuelles       -> audiovisuel·le·s
# bal                  / balle                -> bal·le
# bals                 / balles               -> bal·le·s
# bimensuel            / bimensuelle          -> bimensuel·le
# bimensuels           / bimensuelles         -> bimensuel·le·s
# bimestriel           / bimestrielle         -> bimestriel·le
# bimestriels          / bimestrielles        -> bimestriel·le·s
# bisannuel            / bisannuelle          -> bisannuel·le
# bisannuels           / bisannuelles         -> bisannuel·le·s
# bisexuel             / bisexuelle           -> bisexuel·le
# bisexuels            / bisexuelles          -> bisexuel·le·s
# caractériel          / caractérielle        -> caractériel·le
# caractériels         / caractérielles       -> caractériel·le·s
# carentiel            / carentielle          -> carentiel·le
# carentiels           / carentielles         -> carentiel·le·s
# catégoriel           / catégorielle         -> catégoriel·le
# catégoriels          / catégorielles        -> catégoriel·le·s
# charnel              / charnelle            -> charnel·le
# charnels             / charnelles           -> charnel·le·s
# chenil               / chenille             -> chenil·le
# chenils              / chenilles            -> chenil·le·s
# cicatriciel          / cicatricielle        -> cicatriciel·le
# cicatriciels         / cicatricielles       -> cicatriciel·le·s
# circonstanciel       / circonstancielle     -> circonstanciel·le
# circonstanciels      / circonstancielles    -> circonstanciel·le·s
# col                  / colle                -> col·le
# cols                 / colles               -> col·le·s
# conceptuel           / conceptuelle         -> conceptuel·le
# conceptuels          / conceptuelles        -> conceptuel·le·s
# concurrentiel        / concurrentielle      -> concurrentiel·le
# concurrentiels       / concurrentielles     -> concurrentiel·le·s
# conditionnel         / conditionnelle       -> conditionnel·le
# conditionnels        / conditionnelles      -> conditionnel·le·s
# confessionnel        / confessionnelle      -> confessionnel·le
# confessionnels       / confessionnelles     -> confessionnel·le·s
# confidentiel         / confidentielle       -> confidentiel·le
# confidentiels        / confidentielles      -> confidentiel·le·s
# conflictuel          / conflictuelle        -> conflictuel·le
# conflictuels         / conflictuelles       -> conflictuel·le·s
# confraternel         / confraternelle       -> confraternel·le
# confraternels        / confraternelles      -> confraternel·le·s
# conjoncturel         / conjoncturelle       -> conjoncturel·le
# conjoncturels        / conjoncturelles      -> conjoncturel·le·s
# conseil              / conseille            -> conseil·le
# conseils             / conseilles           -> conseil·le·s
# consensuel           / consensuelle         -> consensuel·le
# consensuels          / consensuelles        -> consensuel·le·s
# constitutionnel      / constitutionnelle    -> constitutionnel·le
# constitutionnels     / constitutionnelles   -> constitutionnel·le·s
# contextuel           / contextuelle         -> contextuel·le
# contextuels          / contextuelles        -> contextuel·le·s
# continuel            / continuelle          -> continuel·le
# continuels           / continuelles         -> continuel·le·s
# contractuel          / contractuelle        -> contractuel·le
# contractuels         / contractuelles       -> contractuel·le·s
# conventionnel        / conventionnelle      -> conventionnel·le
# conventionnels       / conventionnelles     -> conventionnel·le·s
# conventuel           / conventuelle         -> conventuel·le
# conventuels          / conventuelles        -> conventuel·le·s
# conversationnel      / conversationnelle    -> conversationnel·le
# conversationnels     / conversationnelles   -> conversationnel·le·s
# corporel             / corporelle           -> corporel·le
# corporels            / corporelles          -> corporel·le·s
# correctionnel        / correctionnelle      -> correctionnel·le
# correctionnels       / correctionnelles     -> correctionnel·le·s
# criminel             / criminelle           -> criminel·le
# criminels            / criminelles          -> criminel·le·s
# cruel                / cruelle              -> cruel·le
# cruels               / cruelles             -> cruel·le·s
# culturel             / culturelle           -> culturel·le
# culturels            / culturelles          -> culturel·le·s
# décisionnel          / décisionnelle        -> décisionnel·le
# décisionnels         / décisionnelles       -> décisionnel·le·s
# démentiel            / démentielle          -> démentiel·le
# démentiels           / démentielles         -> démentiel·le·s
# détail               / détaille             -> détail·le
# détails              / détailles            -> détail·le·s
# différentiel         / différentielle       -> différentiel·le
# différentiels        / différentielles      -> différentiel·le·s
# émotionnel           / émotionnelle         -> émotionnel·le
# émotionnels          / émotionnelles        -> émotionnel·le·s
# essentiel            / essentielle          -> essentiel·le
# essentiels           / essentielles         -> essentiel·le·s
# éternel              / éternelle            -> éternel·le
# éternels             / éternelles           -> éternel·le·s
# éveil                / éveille              -> éveil·le
# éveils               / éveilles             -> éveil·le·s
# événementiel         / événementielle       -> événementiel·le
# événementiels        / événementielles      -> événementiel·le·s
# éventuel             / éventuelle           -> éventuel·le
# éventuels            / éventuelles          -> éventuel·le·s
# exceptionnel         / exceptionnelle       -> exceptionnel·le
# exceptionnels        / exceptionnelles      -> exceptionnel·le·s
# existentiel          / existentielle        -> existentiel·le
# existentiels         / existentielles       -> existentiel·le·s
# exponentiel          / exponentielle        -> exponentiel·le
# exponentiels         / exponentielles       -> exponentiel·le·s
# factuel              / factuelle            -> factuel·le
# factuels             / factuelles           -> factuel·le·s
# fil                  / fille                -> fil·le
# fils                 / filles               -> fil·le·s
# flexionnel           / flexionnelle         -> flexionnel·le
# flexionnels          / flexionnelles        -> flexionnel·le·s
# fonctionnel          / fonctionnelle        -> fonctionnel·le
# fonctionnels         / fonctionnelles       -> fonctionnel·le·s
# formel               / formelle             -> formel·le
# formels              / formelles            -> formel·le·s
# fractionnel          / fractionnelle        -> fractionnel·le
# fractionnels         / fractionnelles       -> fractionnel·le·s
# fraternel            / fraternelle          -> fraternel·le
# fraternels           / fraternelles         -> fraternel·le·s
# fusil                / fusille              -> fusil·le
# fusils               / fusilles             -> fusil·le·s
# gentil               / gentille             -> gentil·le
# gentils              / gentilles            -> gentil·le·s
# gestuel              / gestuelle            -> gestuel·le
# gestuels             / gestuelles           -> gestuel·le·s
# graduel              / graduelle            -> graduel·le
# graduels             / graduelles           -> graduel·le·s
# gravitationnel       / gravitationnelle     -> gravitationnel·le
# gravitationnels      / gravitationnelles    -> gravitationnel·le·s
# gril                 / grille               -> gril·le
# grils                / grilles              -> gril·le·s
# habituel             / habituelle           -> habituel·le
# habituels            / habituelles          -> habituel·le·s
# hétérosexuel         / hétérosexuelle       -> hétérosexuel·le
# hétérosexuels        / hétérosexuelles      -> hétérosexuel·le·s
# homosexuel           / homosexuelle         -> homosexuel·le
# homosexuels          / homosexuelles        -> homosexuel·le·s
# immatériel           / immatérielle         -> immatériel·le
# immatériels          / immatérielles        -> immatériel·le·s
# immortel             / immortelle           -> immortel·le
# immortels            / immortelles          -> immortel·le·s
# impersonnel          / impersonnelle        -> impersonnel·le
# impersonnels         / impersonnelles       -> impersonnel·le·s
# inactuel             / inactuelle           -> inactuel·le
# inactuels            / inactuelles          -> inactuel·le·s
# inconditionnel       / inconditionnelle     -> inconditionnel·le
# inconditionnels      / inconditionnelles    -> inconditionnel·le·s
# inconstitutionnel    / inconstitutionnelle  -> inconstitutionnel·le
# inconstitutionnels   / inconstitutionnelles -> inconstitutionnel·le·s
# incorporel           / incorporelle         -> incorporel·le
# incorporels          / incorporelles        -> incorporel·le·s
# indiciel             / indicielle           -> indiciel·le
# indiciels            / indicielles          -> indiciel·le·s
# individuel           / individuelle         -> individuel·le
# individuels          / individuelles        -> individuel·le·s
# industriel           / industrielle         -> industriel·le
# industriels          / industrielles        -> industriel·le·s
# informationnel       / informationnelle     -> informationnel·le
# informationnels      / informationnelles    -> informationnel·le·s
# informel             / informelle           -> informel·le
# informels            / informelles          -> informel·le·s
# inhabituel           / inhabituelle         -> inhabituel·le
# inhabituels          / inhabituelles        -> inhabituel·le·s
# institutionnel       / institutionnelle     -> institutionnel·le
# institutionnels      / institutionnelles    -> institutionnel·le·s
# insurrectionnel      / insurrectionnelle    -> insurrectionnel·le
# insurrectionnels     / insurrectionnelles   -> insurrectionnel·le·s
# intellectuel         / intellectuelle       -> intellectuel·le
# intellectuels        / intellectuelles      -> intellectuel·le·s
# intemporel           / intemporelle         -> intemporel·le
# intemporels          / intemporelles        -> intemporel·le·s
# intentionnel         / intentionnelle       -> intentionnel·le
# intentionnels        / intentionnelles      -> intentionnel·le·s
# interministériel     / interministérielle   -> interministériel·le
# interministériels    / interministérielles  -> interministériel·le·s
# interpersonnel       / interpersonnelle     -> interpersonnel·le
# interpersonnels      / interpersonnelles    -> interpersonnel·le·s
# interprofessionnel   / interprofessionnelle -> interprofessionnel·le
# interprofessionnels  / interprofessionnelles -> interprofessionnel·le·s
# intersectoriel       / intersectorielle     -> intersectoriel·le
# intersectoriels      / intersectorielles    -> intersectoriel·le·s
# irrationnel          / irrationnelle        -> irrationnel·le
# irrationnels         / irrationnelles       -> irrationnel·le·s
# irréel               / irréelle             -> irréel·le
# irréels              / irréelles            -> irréel·le·s
# juridictionnel       / juridictionnelle     -> juridictionnel·le
# juridictionnels      / juridictionnelles    -> juridictionnel·le·s
# jurisprudentiel      / jurisprudentielle    -> jurisprudentiel·le
# jurisprudentiels     / jurisprudentielles   -> jurisprudentiel·le·s
# lésionnel            / lésionnelle          -> lésionnel·le
# lésionnels           / lésionnelles         -> lésionnel·le·s
# logiciel             / logicielle           -> logiciel·le
# logiciels            / logicielles          -> logiciel·le·s
# manuel               / manuelle             -> manuel·le
# manuels              / manuelles            -> manuel·le·s
# matériel             / matérielle           -> matériel·le
# matériels            / matérielles          -> matériel·le·s
# maternel             / maternelle           -> maternel·le
# maternels            / maternelles          -> maternel·le·s
# matriciel            / matricielle          -> matriciel·le
# matriciels           / matricielles         -> matriciel·le·s
# médico-professionnel / médico-professionnelle -> médico-professionnel·le
# médico-professionnels / médico-professionnelles -> médico-professionnel·le·s
# mémoriel             / mémorielle           -> mémoriel·le
# mémoriels            / mémorielles          -> mémoriel·le·s
# menstruel            / menstruelle          -> menstruel·le
# menstruels           / menstruelles         -> menstruel·le·s
# mensuel              / mensuelle            -> mensuel·le
# mensuels             / mensuelles           -> mensuel·le·s
# ministériel          / ministérielle        -> ministériel·le
# ministériels         / ministérielles       -> ministériel·le·s
# mortel               / mortelle             -> mortel·le
# mortels              / mortelles            -> mortel·le·s
# mutuel               / mutuelle             -> mutuel·le
# mutuels              / mutuelles            -> mutuel·le·s
# naturel              / naturelle            -> naturel·le
# naturels             / naturelles           -> naturel·le·s
# nul                  / nulle                -> nul·le
# nuls                 / nulles               -> nul·le·s
# nutritionnel         / nutritionnelle       -> nutritionnel·le
# nutritionnels        / nutritionnelles      -> nutritionnel·le·s
# obsessionnel         / obsessionnelle       -> obsessionnel·le
# obsessionnels        / obsessionnelles      -> obsessionnel·le·s
# occasionnel          / occasionnelle        -> occasionnel·le
# occasionnels         / occasionnelles       -> occasionnel·le·s
# officiel             / officielle           -> officiel·le
# officiels            / officielles          -> officiel·le·s
# opérationnel         / opérationnelle       -> opérationnel·le
# opérationnels        / opérationnelles      -> opérationnel·le·s
# oppositionnel        / oppositionnelle      -> oppositionnel·le
# oppositionnels       / oppositionnelles     -> oppositionnel·le·s
# optionnel            / optionnelle          -> optionnel·le
# optionnels           / optionnelles         -> optionnel·le·s
# originel             / originelle           -> originel·le
# originels            / originelles          -> originel·le·s
# pareil               / pareille             -> pareil·le
# pareils              / pareilles            -> pareil·le·s
# partiel              / partielle            -> partiel·le
# partiels             / partielles           -> partiel·le·s
# passionnel           / passionnelle         -> passionnel·le
# passionnels          / passionnelles        -> passionnel·le·s
# paternel             / paternelle           -> paternel·le
# paternels            / paternelles          -> paternel·le·s
# perpétuel            / perpétuelle          -> perpétuel·le
# perpétuels           / perpétuelles         -> perpétuel·le·s
# personnel            / personnelle          -> personnel·le
# personnels           / personnelles         -> personnel·le·s
# pestilentiel         / pestilentielle       -> pestilentiel·le
# pestilentiels        / pestilentielles      -> pestilentiel·le·s
# pluriel              / plurielle            -> pluriel·le
# pluriels             / plurielles           -> pluriel·le·s
# ponctuel             / ponctuelle           -> ponctuel·le
# ponctuels            / ponctuelles          -> ponctuel·le·s
# potentiel            / potentielle          -> potentiel·le
# potentiels           / potentielles         -> potentiel·le·s
# préférentiel         / préférentielle       -> préférentiel·le
# préférentiels        / préférentielles      -> préférentiel·le·s
# préjudiciel          / préjudicielle        -> préjudiciel·le
# préjudiciels         / préjudicielles       -> préjudiciel·le·s
# présidentiel         / présidentielle       -> présidentiel·le
# présidentiels        / présidentielles      -> présidentiel·le·s
# prévisionnel         / prévisionnelle       -> prévisionnel·le
# prévisionnels        / prévisionnelles      -> prévisionnel·le·s
# professionnel        / professionnelle      -> professionnel·le
# professionnels       / professionnelles     -> professionnel·le·s
# promotionnel         / promotionnelle       -> promotionnel·le
# promotionnels        / promotionnelles      -> promotionnel·le·s
# proportionnel        / proportionnelle      -> proportionnel·le
# proportionnels       / proportionnelles     -> proportionnel·le·s
# providentiel         / providentielle       -> providentiel·le
# providentiels        / providentielles      -> providentiel·le·s
# provisionnel         / provisionnelle       -> provisionnel·le
# provisionnels        / provisionnelles      -> provisionnel·le·s
# quel                 / quelle               -> quel·le
# quels                / quelles              -> quel·le·s
# rail                 / raille               -> rail·le
# rails                / railles              -> rail·le·s
# rappel               / rappelle             -> rappel·le
# rappels              / rappelles            -> rappel·le·s
# rationnel            / rationnelle          -> rationnel·le
# rationnels           / rationnelles         -> rationnel·le·s
# recueil              / recueille            -> recueil·le
# recueils             / recueilles           -> recueil·le·s
# rédactionnel         / rédactionnelle       -> rédactionnel·le
# rédactionnels        / rédactionnelles      -> rédactionnel·le·s
# réel                 / réelle               -> réel·le
# réels                / réelles              -> réel·le·s
# relationnel          / relationnelle        -> relationnel·le
# relationnels         / relationnelles       -> relationnel·le·s
# résidentiel          / résidentielle        -> résidentiel·le
# résidentiels         / résidentielles       -> résidentiel·le·s
# résiduel             / résiduelle           -> résiduel·le
# résiduels            / résiduelles          -> résiduel·le·s
# réveil               / réveille             -> réveil·le
# réveils              / réveilles            -> réveil·le·s
# rituel               / rituelle             -> rituel·le
# rituels              / rituelles            -> rituel·le·s
# romanichel           / romanichelle         -> romanichel·le
# romanichels          / romanichelles        -> romanichel·le·s
# sacramentel          / sacramentelle        -> sacramentel·le
# sacramentels         / sacramentelles       -> sacramentel·le·s
# sectoriel            / sectorielle          -> sectoriel·le
# sectoriels           / sectorielles         -> sectoriel·le·s
# sel                  / selle                -> sel·le
# sels                 / selles               -> sel·le·s
# semestriel           / semestrielle         -> semestriel·le
# semestriels          / semestrielles        -> semestriel·le·s
# sempiternel          / sempiternelle        -> sempiternel·le
# sempiternels         / sempiternelles       -> sempiternel·le·s
# sensationnel         / sensationnelle       -> sensationnel·le
# sensationnels        / sensationnelles      -> sensationnel·le·s
# sensoriel            / sensorielle          -> sensoriel·le
# sensoriels           / sensorielles         -> sensoriel·le·s
# sensuel              / sensuelle            -> sensuel·le
# sensuels             / sensuelles           -> sensuel·le·s
# séquentiel           / séquentielle         -> séquentiel·le
# séquentiels          / séquentielles        -> séquentiel·le·s
# sériel               / sérielle             -> sériel·le
# sériels              / sérielles            -> sériel·le·s
# sexuel               / sexuelle             -> sexuel·le
# sexuels              / sexuelles            -> sexuel·le·s
# socioculturel        / socioculturelle      -> socioculturel·le
# socioculturels       / socioculturelles     -> socioculturel·le·s
# socioprofessionnel   / socioprofessionnelle -> socioprofessionnel·le
# socioprofessionnels  / socioprofessionnelles -> socioprofessionnel·le·s
# solennel             / solennelle           -> solennel·le
# solennels            / solennelles          -> solennel·le·s
# sommeil              / sommeille            -> sommeil·le
# sommeils             / sommeilles           -> sommeil·le·s
# spirituel            / spirituelle          -> spirituel·le
# spirituels           / spirituelles         -> spirituel·le·s
# structurel           / structurelle         -> structurel·le
# structurels          / structurelles        -> structurel·le·s
# substantiel          / substantielle        -> substantiel·le
# substantiels         / substantielles       -> substantiel·le·s
# superficiel          / superficielle        -> superficiel·le
# superficiels         / superficielles       -> superficiel·le·s
# surnaturel           / surnaturelle         -> surnaturel·le
# surnaturels          / surnaturelles        -> surnaturel·le·s
# tel                  / telle                -> tel·le
# tels                 / telles               -> tel·le·s
# télévisuel           / télévisuelle         -> télévisuel·le
# télévisuels          / télévisuelles        -> télévisuel·le·s
# temporel             / temporelle           -> temporel·le
# temporels            / temporelles          -> temporel·le·s
# textuel              / textuelle            -> textuel·le
# textuels             / textuelles           -> textuel·le·s
# torrentiel           / torrentielle         -> torrentiel·le
# torrentiels          / torrentielles        -> torrentiel·le·s
# traditionnel         / traditionnelle       -> traditionnel·le
# traditionnels        / traditionnelles      -> traditionnel·le·s
# transactionnel       / transactionnelle     -> transactionnel·le
# transactionnels      / transactionnelles    -> transactionnel·le·s
# tridimensionnel      / tridimensionnelle    -> tridimensionnel·le
# tridimensionnels     / tridimensionnelles   -> tridimensionnel·le·s
# trimestriel          / trimestrielle        -> trimestriel·le
# trimestriels         / trimestrielles       -> trimestriel·le·s
# trisannuel           / trisannuelle         -> trisannuel·le
# trisannuels          / trisannuelles        -> trisannuel·le·s
# unidimensionnel      / unidimensionnelle    -> unidimensionnel·le
# unidimensionnels     / unidimensionnelles   -> unidimensionnel·le·s
# unidirectionnel      / unidirectionnelle    -> unidirectionnel·le
# unidirectionnels     / unidirectionnelles   -> unidirectionnel·le·s
# universel            / universelle          -> universel·le
# universels           / universelles         -> universel·le·s
# usuel                / usuelle              -> usuel·le
# usuels               / usuelles             -> usuel·le·s
# vectoriel            / vectorielle          -> vectoriel·le
# vectoriels           / vectorielles         -> vectoriel·le·s
# véniel               / vénielle             -> véniel·le
# véniels              / vénielles            -> véniel·le·s
# vermeil              / vermeille            -> vermeil·le
# vermeils             / vermeilles           -> vermeil·le·s
# vieil                / vieille              -> vieil·le
# vieils               / vieilles             -> vieil·le·s
# vil                  / ville                -> vil·le
# vils                 / villes               -> vil·le·s
# virtuel              / virtuelle            -> virtuel·le
# virtuels             / virtuelles           -> virtuel·le·s
# visuel               / visuelle             -> visuel·le
# visuels              / visuelles            -> visuel·le·s
#
# Cela a donné 201 nouveaux mots singuliers.
# Cela a donné 201 nouveaux mots pluriels.

# %% [markdown]
# On voit que là aussi ça donne des erreurs :
#
# - accueil              / accueille            -> accueil·le
# - appareil             / appareille           -> appareil·le
# - appel                / appelle              -> appel·le
# - bal                  / balle                -> bal·le
# - chenil               / chenille             -> chenil·le
# - col                  / colle                -> col·le
# - conseil              / conseille            -> conseil·le
# - détail               / détaille             -> détail·le
# - éveil                / éveille              -> éveil·le
# - fil                  / fille                -> fil·le
# - fils                 / filles               -> fil·le·s
# - fusil                / fusille              -> fusil·le
# - gril                 / grille               -> gril·le
# - rail                 / raille               -> rail·le
# - recueil              / recueille            -> recueil·le
# - réveil               / réveille             -> réveil·le
# - sel                  / selle                -> sel·le
# - vil                  / ville                -> vil·le
#
# Ces erreurs pourraient être évitées si on disposait d'étiquettes sur chaque mot (verbe, nom, adjectif, etc).

# %%
del_alternatives([
    "accueil", "accueille", "accueils", "accueilles",
    "appareil", "appareille", "appareils", "appareilles",
    "appel", "appelle", "appels", "appelles",
    "bal", "balle", "bals", "balles",
    "chenil", "chenille", "chenils", "chenilles",
    "col", "colle", "cols", "colles",
    "conseil", "conseille", "conseils", "conseilles",
    "détail", "détaille", "détails", "détailles",
    "éveil", "éveille", "éveils", "éveilles",
    "fil", "fille", "fils", "filles",
    "fusil", "fusille", "fusils", "fusilles",
    "gril", "grille", "grils", "grilles",
    "rail", "raille", "rails", "railles",
    "recueil", "recueille", "recueils", "recueilles",
    "réveil", "réveille", "réveils", "réveilles",
    "sel", "selle", "sels", "selles",
    "vil", "ville", "vils", "villes",
])

# %% [markdown]
# On a effacé l'alternative à fils/fille, il faut la rajouter manuellement :

# %%
alternatives["fils"] |= {"fils·lle", "fils·lles"}
alternatives["fille"] |= {"fils·lle"}
alternatives["filles"] |= {"fils·lles"}

# %% [markdown]
# ### Ajouter les cas spéciaux à la main

# %%
alternatives["il"] |= {"iel", "ielle"}
alternatives["ils"] |= {"iels", "ielles"}
alternatives["elle"] |= {"iel", "ielle"}
alternatives["elles"] |= {"iels", "ielles"}

# %% [markdown]
# J'ai des doutes sur ce cas là : celleux est le mot que j'utilise mais quid du cas singulier ?

# %%
alternatives["celui"] |= {"celleu", "ceulle", "ceului"}  # ?
alternatives["ceux"] |= {"celleux", "ceulles"}
alternatives["celle"] |= {"celleu", "ceulle", "ceului"}  # ?
alternatives["celles"] |= {"celleux", "ceulles"}

# %%
alternatives["tous"] |= {"toustes"}
alternatives["toutes"] |= {"toustes"}

# %%
alternatives["loup"] |= {"loup·ve"}
alternatives["louve"] |= {"loup·ve"}
alternatives["loups"] |= {"loup·ve·s"}
alternatives["louves"] |= {"loup·ve·s"}

# %% [markdown]
# <span style="color: red;">TODO</span> ajouter les mots qu'il manque ?

# %% [markdown]
# ### Prendre un mot et proposer des variantes
#
# C'est trivial, maintenant qu'on a construit le dictionnaire `alternatives` :

# %% [markdown]
# On a construit BEAUCOUP de mots alternatifs :

# %%
len(alternatives)
# Out:
# 24852

# %%
pprint(alternatives)
# Out:
# defaultdict(<function <lambda> at 0x7fad5bbe2598>,
#             {'abaissé': {'abaissé·e'},
#              'abaissée': {'abaissé·e'},
#              'abaissées': {'abaissé·e·s'},
#              'abaissés': {'abaissé·e·s'},
#              'abandonné': {'abandonné·e'},
#              'abandonnée': {'abandonné·e'},
#              'abandonnées': {'abandonné·e·s'},
#              'abandonnés': {'abandonné·e·s'},
#              'abasourdi': {'abasourdi·e'},
#              'abasourdie': {'abasourdi·e'},
#              'abasourdies': {'abasourdi·e·s'},
#              'abasourdis': {'abasourdi·e·s'},
#              'abasourdissant': {'abasourdissant·e'},
#              'abasourdissante': {'abasourdissant·e'},
#              'abasourdissantes': {'abasourdissant·e·s'},
#              'abasourdissants': {'abasourdissant·e·s'},
#              'abattu': {'abattu·e'},
#              'abattue': {'abattu·e'},
#              'abattues': {'abattu·e·s'},
#              'abattus': {'abattu·e·s'},
#              'abdiqué': {'abdiqué·e'},
#              'abdiquée': {'abdiqué·e'},
#              'abdiquées': {'abdiqué·e·s'},
#              'abdiqués': {'abdiqué·e·s'},
#              'abdominal': {'abdominal·e'},
#              'abdominale': {'abdominal·e'},
#              'aberrant': {'aberrant·e'},
#              'aberrante': {'aberrant·e'},
#              'aberrantes': {'aberrant·e·s'},
#              'aberrants': {'aberrant·e·s'},
#              'abject': {'abject·e'},
#              'abjecte': {'abject·e'},
#              'abjectes': {'abject·e·s'},
#              'abjects': {'abject·e·s'},
#              'aboli': {'aboli·e'},
#              'abolie': {'aboli·e'},
#              'abolies': {'aboli·e·s'},
#              'abolis': {'aboli·e·s'},
#              'abondant': {'abondant·e'},
#              'abondante': {'abondant·e'},
#              'abondantes': {'abondant·e·s'},
#              'abondants': {'abondant·e·s'},
#              'abonné': {'abonné·e'},
#              'abonnée': {'abonné·e'},
#              'abonnées': {'abonné·e·s'},
#              'abonnés': {'abonné·e·s'},
#              'abordé': {'abordé·e'},
#              'abordée': {'abordé·e'},
#              'abordées': {'abordé·e·s'},
#              'abordés': {'abordé·e·s'},
#              'abouti': {'abouti·e'},
#              'aboutie': {'abouti·e'},
#              'abouties': {'abouti·e·s'},
#              'aboutis': {'abouti·e·s'},
#              'aboyé': {'aboyé·e'},
#              'aboyée': {'aboyé·e'},
#              'aboyées': {'aboyé·e·s'},
#              'aboyés': {'aboyé·e·s'},
#              'abracadabrant': {'abracadabrant·e'},
#              'abracadabrante': {'abracadabrant·e'},
#              'abracadabrantes': {'abracadabrant·e·s'},
#              'abracadabrants': {'abracadabrant·e·s'},
#              'abrité': {'abrité·e'},
#              'abritée': {'abrité·e'},
#              'abritées': {'abrité·e·s'},
#              'abrités': {'abrité·e·s'},
#              'abrogé': {'abrogé·e'},
#              'abrogée': {'abrogé·e'},
#              'abrogées': {'abrogé·e·s'},
#              'abrogés': {'abrogé·e·s'},
#              'abrupt': {'abrupt·e'},
#              'abrupte': {'abrupt·e'},
#              'abruptes': {'abrupt·e·s'},
#              'abrupts': {'abrupt·e·s'},
#              'abruti': {'abruti·e'},
#              'abrutie': {'abruti·e'},
#              'abruties': {'abruti·e·s'},
#              'abrutis': {'abruti·e·s'},
#              'abrutissant': {'abrutissant·e'},
#              'abrutissante': {'abrutissant·e'},
#              'abrutissantes': {'abrutissant·e·s'},
#              'abrutissants': {'abrutissant·e·s'},
#              'abrégé': {'abrégé·e'},
#              'abrégée': {'abrégé·e'},
#              'abrégées': {'abrégé·e·s'},
#              'abrégés': {'abrégé·e·s'},
#              'absent': {'absent·e'},
#              'absente': {'absent·e'},
#              'absentes': {'absent·e·s'},
#              'absents': {'absent·e·s'},
#              'absenté': {'absenté·e'},
#              'absentée': {'absenté·e'},
#              'absentées': {'absenté·e·s'},
#              'absentés': {'absenté·e·s'},
#              'absolu': {'absolu·e'},
#              'absolue': {'absolu·e'},
#              'absolues': {'absolu·e·s'},
#              'absolus': {'absolu·e·s'},
#              'absorbant': {'absorbant·e'},
#              'absorbante': {'absorbant·e'},
#              'absorbantes': {'absorbant·e·s'},
#              'absorbants': {'absorbant·e·s'},
#              'absorbé': {'absorbé·e'},
#              'absorbée': {'absorbé·e'},
#              'absorbées': {'absorbé·e·s'},
#              'absorbés': {'absorbé·e·s'},
#              'abstenu': {'abstenu·e'},
#              'abstenue': {'abstenu·e'},
#              'abstenues': {'abstenu·e·s'},
#              'abstenus': {'abstenu·e·s'},
#              'abstinent': {'abstinent·e'},
#              'abstinente': {'abstinent·e'},
#              'abstinentes': {'abstinent·e·s'},
#              'abstinents': {'abstinent·e·s'},
#              'abstrait': {'abstrait·e'},
#              'abstraite': {'abstrait·e'},
#              'abstraites': {'abstrait·e·s'},
#              'abstraits': {'abstrait·e·s'},
#              'abusé': {'abusé·e'},
#              'abusée': {'abusé·e'},
#              'abusées': {'abusé·e·s'},
#              'abusés': {'abusé·e·s'},
#              'abîmé': {'abîmé·e'},
#              'abîmée': {'abîmé·e'},
#              'abîmées': {'abîmé·e·s'},
#              'abîmés': {'abîmé·e·s'},
#              'académicien': {'académicien·ne'},
#              'académicienne': {'académicien·ne'},
#              'académiciennes': {'académicien·ne·s'},
#              'académiciens': {'académicien·ne·s'},
#              'accablant': {'accablant·e'},
#              'accablante': {'accablant·e'},
#              'accablantes': {'accablant·e·s'},
#              'accablants': {'accablant·e·s'},
#              'accablé': {'accablé·e'},
#              'accablée': {'accablé·e'},
#              'accablées': {'accablé·e·s'},
#              'accablés': {'accablé·e·s'},
#              'accaparé': {'accaparé·e'},
#              'accaparée': {'accaparé·e'},
#              'accaparées': {'accaparé·e·s'},
#              'accaparés': {'accaparé·e·s'},
#              'accentué': {'accentué·e'},
#              'accentuée': {'accentué·e'},
#              'accentuées': {'accentué·e·s'},
#              'accentués': {'accentué·e·s'},
#              'accepté': {'accepté·e'},
#              'acceptée': {'accepté·e'},
#              'acceptées': {'accepté·e·s'},
#              'acceptés': {'accepté·e·s'},
#              'accidentel': {'accidentel·le'},
#              'accidentelle': {'accidentel·le'},
#              'accidentelles': {'accidentel·le·s'},
#              'accidentels': {'accidentel·le·s'},
#              'accidenté': {'accidenté·e'},
#              'accidentée': {'accidenté·e'},
#              'accidentées': {'accidenté·e·s'},
#              'accidentés': {'accidenté·e·s'},
#              'acclamé': {'acclamé·e'},
#              'acclamée': {'acclamé·e'},
#              'acclamées': {'acclamé·e·s'},
#              'acclamés': {'acclamé·e·s'},
#              'acclimaté': {'acclimaté·e'},
#              'acclimatée': {'acclimaté·e'},
#              'acclimatées': {'acclimaté·e·s'},
#              'acclimatés': {'acclimaté·e·s'},
#              'accolé': {'accolé·e'},
#              'accolée': {'accolé·e'},
#              'accolées': {'accolé·e·s'},
#              'accolés': {'accolé·e·s'},
#              'accommodant': {'accommodant·e'},
#              'accommodante': {'accommodant·e'},
#              'accommodantes': {'accommodant·e·s'},
#              'accommodants': {'accommodant·e·s'},
#              'accommodé': {'accommodé·e'},
#              'accommodée': {'accommodé·e'},
#              'accommodées': {'accommodé·e·s'},
#              'accommodés': {'accommodé·e·s'},
#              'accompagnateur': {'accompagnateur·trice', 'accompagnatrice·teur'},
#              'accompagnateurs': {'accompagnateur·trice·s',
#                                  'accompagnatrice·teur·s'},
#              'accompagnatrice': {'accompagnateur·trice',
#                                  'accompagnatrice·teur'},
#              'accompagnatrices': {'accompagnateur·trice·s',
#                                   'accompagnatrice·teur·s'},
#              'accompagné': {'accompagné·e'},
#              'accompagnée': {'accompagné·e'},
#              'accompagnées': {'accompagné·e·s'},
#              'accompagnés': {'accompagné·e·s'},
#              'accompli': {'accompli·e'},
#              'accomplie': {'accompli·e'},
#              'accomplies': {'accompli·e·s'},
#              'accomplis': {'accompli·e·s'},
#              'accordé': {'accordé·e'},
#              'accordée': {'accordé·e'},
#              'accordées': {'accordé·e·s'},
#              'accordés': {'accordé·e·s'},
#              'accosté': {'accosté·e'},
#              'accostée': {'accosté·e'},
#              'accostées': {'accosté·e·s'},
#              'accostés': {'accosté·e·s'},
#              'accouché': {'accouché·e'},
#              'accouchée': {'accouché·e'},
#              'accouchées': {'accouché·e·s'},
#              'accouchés': {'accouché·e·s'},
#              'accoudé': {'accoudé·e'},
#              'accoudée': {'accoudé·e'},
#              'accoudées': {'accoudé·e·s'},
#              'accoudés': {'accoudé·e·s'},
#              'accouplé': {'accouplé·e'},
#              'accouplée': {'accouplé·e'},
#              'accouplées': {'accouplé·e·s'},
#              'accouplés': {'accouplé·e·s'},
#              'accouru': {'accouru·e'},
#              'accourue': {'accouru·e'},
#              'accourues': {'accouru·e·s'},
#              'accourus': {'accouru·e·s'},
#              'accoutumé': {'accoutumé·e'},
#              'accoutumée': {'accoutumé·e'},
#              'accoutumées': {'accoutumé·e·s'},
#              'accoutumés': {'accoutumé·e·s'},
#              'accrochant': {'accrochant·e'},
#              'accrochante': {'accrochant·e'},
#              'accroché': {'accroché·e'},
#              'accrochée': {'accroché·e'},
#              'accrochées': {'accroché·e·s'},
#              'accrochés': {'accroché·e·s'},
#              'accru': {'accru·e'},
#              'accrue': {'accru·e'},
#              'accrues': {'accru·e·s'},
#              'accrus': {'accru·e·s'},
#              'accrédité': {'accrédité·e'},
#              'accréditée': {'accrédité·e'},
#              'accréditées': {'accrédité·e·s'},
#              'accrédités': {'accrédité·e·s'},
#              'accueillant': {'accueillant·e'},
#              'accueillante': {'accueillant·e'},
#              'accueillantes': {'accueillant·e·s'},
#              'accueillants': {'accueillant·e·s'},
#              'accueilli': {'accueilli·e'},
#              'accueillie': {'accueilli·e'},
#              'accueillies': {'accueilli·e·s'},
#              'accueillis': {'accueilli·e·s'},
#              'acculé': {'acculé·e'},
#              'acculée': {'acculé·e'},
#              'acculées': {'acculé·e·s'},
#              'acculés': {'acculé·e·s'},
#              'accumulé': {'accumulé·e'},
#              'accumulée': {'accumulé·e'},
#              'accumulées': {'accumulé·e·s'},
#              'accumulés': {'accumulé·e·s'},
#              'accusateur': {'accusateur·trice', 'accusatrice·teur'},
#              'accusateurs': {'accusateur·trice·s', 'accusatrice·teur·s'},
#              'accusatrice': {'accusateur·trice', 'accusatrice·teur'},
#              'accusatrices': {'accusateur·trice·s', 'accusatrice·teur·s'},
#              'accusé': {'accusé·e'},
#              'accusée': {'accusé·e'},
#              'accusées': {'accusé·e·s'},
#              'accusés': {'accusé·e·s'},
#              'accélérateur': {'accélératrice·teur', 'accélérateur·trice'},
#              'accélérateurs': {'accélérateur·trice·s', 'accélératrice·teur·s'},
#              'accélératrice': {'accélératrice·teur', 'accélérateur·trice'},
#              'accélératrices': {'accélérateur·trice·s', 'accélératrice·teur·s'},
#              'accéléré': {'accéléré·e'},
#              'accélérée': {'accéléré·e'},
#              'accélérées': {'accéléré·e·s'},
#              'accélérés': {'accéléré·e·s'},
#              'achalandé': {'achalandé·e'},
#              'achalandée': {'achalandé·e'},
#              'achalandées': {'achalandé·e·s'},
#              'achalandés': {'achalandé·e·s'},
#              'acharné': {'acharné·e'},
#              'acharnée': {'acharné·e'},
#              'acharnées': {'acharné·e·s'},
#              'acharnés': {'acharné·e·s'},
#              'acheminé': {'acheminé·e'},
#              'acheminée': {'acheminé·e'},
#              'acheminées': {'acheminé·e·s'},
#              'acheminés': {'acheminé·e·s'},
#              'acheté': {'acheté·e'},
#              'achetée': {'acheté·e'},
#              'achetées': {'acheté·e·s'},
#              'achetés': {'acheté·e·s'},
#              'achevé': {'achevé·e'},
#              'achevée': {'achevé·e'},
#              'achevées': {'achevé·e·s'},
#              'achevés': {'achevé·e·s'},
#              'acidulé': {'acidulé·e'},
#              'acidulée': {'acidulé·e'},
#              'acidulées': {'acidulé·e·s'},
#              'acidulés': {'acidulé·e·s'},
#              'acquis': {'acquis·e'},
#              'acquise': {'acquis·e'},
#              'acquitté': {'acquitté·e'},
#              'acquittée': {'acquitté·e'},
#              'acquittées': {'acquitté·e·s'},
#              'acquittés': {'acquitté·e·s'},
#              'acteur': {'acteur·trice', 'actrice·teur'},
#              'acteurs': {'actrice·teur·s', 'acteur·trice·s'},
#              'actionné': {'actionné·e'},
#              'actionnée': {'actionné·e'},
#              'actionnées': {'actionné·e·s'},
#              'actionnés': {'actionné·e·s'},
#              'activé': {'activé·e'},
#              'activée': {'activé·e'},
#              'activées': {'activé·e·s'},
#              'activés': {'activé·e·s'},
#              'actrice': {'acteur·trice', 'actrice·teur'},
#              'actrices': {'actrice·teur·s', 'acteur·trice·s'},
#              'actualisé': {'actualisé·e'},
#              'actualisée': {'actualisé·e'},
#              'actualisées': {'actualisé·e·s'},
#              'actualisés': {'actualisé·e·s'},
#              'actuariel': {'actuariel·le'},
#              'actuarielle': {'actuariel·le'},
#              'actuarielles': {'actuariel·le·s'},
#              'actuariels': {'actuariel·le·s'},
#              'actuel': {'actuel·le'},
#              'actuelle': {'actuel·le'},
#              'actuelles': {'actuel·le·s'},
#              'actuels': {'actuel·le·s'},
#              'acuponcteur': {'acuponcteur·trice', 'acuponctrice·teur'},
#              'acuponcteurs': {'acuponcteur·trice·s', 'acuponctrice·teur·s'},
#              'acuponctrice': {'acuponcteur·trice', 'acuponctrice·teur'},
#              'acuponctrices': {'acuponcteur·trice·s', 'acuponctrice·teur·s'},
#              'acupuncteur': {'acupuncteur·trice', 'acupunctrice·teur'},
#              'acupuncteurs': {'acupuncteur·trice·s', 'acupunctrice·teur·s'},
#              'acupunctrice': {'acupuncteur·trice', 'acupunctrice·teur'},
#              'acupunctrices': {'acupuncteur·trice·s', 'acupunctrice·teur·s'},
#              'acéré': {'acéré·e'},
#              'acérée': {'acéré·e'},
#              'acérées': {'acéré·e·s'},
#              'acérés': {'acéré·e·s'},
#              'adaptateur': {'adaptatrice·teur', 'adaptateur·trice'},
#              'adaptateurs': {'adaptatrice·teur·s', 'adaptateur·trice·s'},
#              'adaptatrice': {'adaptatrice·teur', 'adaptateur·trice'},
#              'adaptatrices': {'adaptatrice·teur·s', 'adaptateur·trice·s'},
#              'adapté': {'adapté·e'},
#              'adaptée': {'adapté·e'},
#              'adaptées': {'adapté·e·s'},
#              'adaptés': {'adapté·e·s'},
#              'additionnel': {'additionnel·le'},
#              'additionnelle': {'additionnel·le'},
#              'additionnelles': {'additionnel·le·s'},
#              'additionnels': {'additionnel·le·s'},
#              'additionné': {'additionné·e'},
#              'additionnée': {'additionné·e'},
#              'additionnées': {'additionné·e·s'},
#              'additionnés': {'additionné·e·s'},
#              'adhérent': {'adhérent·e'},
#              'adhérente': {'adhérent·e'},
#              'adhérentes': {'adhérent·e·s'},
#              'adhérents': {'adhérent·e·s'},
#              'adipeuse': {'adipeux·se'},
#              'adipeuses': {'adipeux·se·s'},
#              'adipeux': {'adipeux·se·s', 'adipeux·se'},
#              'adjacent': {'adjacent·e'},
#              'adjacente': {'adjacent·e'},
#              'adjacentes': {'adjacent·e·s'},
#              'adjacents': {'adjacent·e·s'},
#              'adjectival': {'adjectival·e'},
#              'adjectivale': {'adjectival·e'},
#              'adjoint': {'adjoint·e'},
#              'adjointe': {'adjoint·e'},
#              'adjointes': {'adjoint·e·s'},
#              'adjoints': {'adjoint·e·s'},
#              'adjugé': {'adjugé·e'},
#              'adjugée': {'adjugé·e'},
#              'adjugées': {'adjugé·e·s'},
#              'adjugés': {'adjugé·e·s'},
#              'adjuré': {'adjuré·e'},
#              'adjurée': {'adjuré·e'},
#              'adjurées': {'adjuré·e·s'},
#              'adjurés': {'adjuré·e·s'},
#              'adjuvant': {'adjuvant·e'},
#              'adjuvante': {'adjuvant·e'},
#              'adjuvantes': {'adjuvant·e·s'},
#              'adjuvants': {'adjuvant·e·s'},
#              'administrateur': {'administrateur·trice', 'administratrice·teur'},
#              'administrateurs': {'administrateur·trice·s',
#                                  'administratrice·teur·s'},
#              'administratrice': {'administrateur·trice',
#                                  'administratrice·teur'},
#              'administratrices': {'administrateur·trice·s',
#                                   'administratrice·teur·s'},
#              'administré': {'administré·e'},
#              'administrée': {'administré·e'},
#              'administrées': {'administré·e·s'},
#              'administrés': {'administré·e·s'},
#              'admirateur': {'admiratrice·teur', 'admirateur·trice'},
#              'admirateurs': {'admiratrice·teur·s', 'admirateur·trice·s'},
#              'admiratrice': {'admiratrice·teur', 'admirateur·trice'},
#              'admiratrices': {'admiratrice·teur·s', 'admirateur·trice·s'},
#              'admiré': {'admiré·e'},
#              'admirée': {'admiré·e'},
#              'admirées': {'admiré·e·s'},
#              'admirés': {'admiré·e·s'},
#              'admis': {'admis·e'},
#              'admise': {'admis·e'},
#              'adolescent': {'adolescent·e'},
#              'adolescente': {'adolescent·e'},
#              'adolescentes': {'adolescent·e·s'},
#              'adolescents': {'adolescent·e·s'},
#              'adonné': {'adonné·e'},
#              'adonnée': {'adonné·e'},
#              'adonnées': {'adonné·e·s'},
#              'adonnés': {'adonné·e·s'},
#              'adopté': {'adopté·e'},
#              'adoptée': {'adopté·e'},
#              'adoptées': {'adopté·e·s'},
#              'adoptés': {'adopté·e·s'},
#              'adorateur': {'adoratrice·teur', 'adorateur·trice'},
#              'adorateurs': {'adoratrice·teur·s', 'adorateur·trice·s'},
#              'adoratrice': {'adoratrice·teur', 'adorateur·trice'},
#              'adoratrices': {'adoratrice·teur·s', 'adorateur·trice·s'},
#              'adoré': {'adoré·e'},
#              'adorée': {'adoré·e'},
#              'adorées': {'adoré·e·s'},
#              'adorés': {'adoré·e·s'},
#              'adossé': {'adossé·e'},
#              'adossée': {'adossé·e'},
#              'adossées': {'adossé·e·s'},
#              'adossés': {'adossé·e·s'},
#              'adouci': {'adouci·e'},
#              'adoucie': {'adouci·e'},
#              'adoucies': {'adouci·e·s'},
#              'adoucis': {'adouci·e·s'},
#              'adoucissant': {'adoucissant·e'},
#              'adoucissante': {'adoucissant·e'},
#              'adoucissantes': {'adoucissant·e·s'},
#              'adoucissants': {'adoucissant·e·s'},
#              'adressé': {'adressé·e'},
#              'adressée': {'adressé·e'},
#              'adressées': {'adressé·e·s'},
#              'adressés': {'adressé·e·s'},
#              'adroit': {'adroit·e'},
#              'adroite': {'adroit·e'},
#              'adroites': {'adroit·e·s'},
#              'adroits': {'adroit·e·s'},
#              'adultérin': {'adultérin·e'},
#              'adultérine': {'adultérin·e'},
#              'adultérines': {'adultérin·e·s'},
#              'adultérins': {'adultérin·e·s'},
#              'advenu': {'advenu·e'},
#              'advenue': {'advenu·e'},
#              'advenues': {'advenu·e·s'},
#              'advenus': {'advenu·e·s'},
#              'adverbial': {'adverbial·e'},
#              'adverbiale': {'adverbial·e'},
#              'adéquat': {'adéquat·e'},
#              'adéquate': {'adéquat·e'},
#              'adéquates': {'adéquat·e·s'},
#              'adéquats': {'adéquat·e·s'},
#              'affacturé': {'affacturé·e'},
#              'affacturée': {'affacturé·e'},
#              'affacturées': {'affacturé·e·s'},
#              'affacturés': {'affacturé·e·s'},
#              'affaibli': {'affaibli·e'},
#              'affaiblie': {'affaibli·e'},
#              'affaiblies': {'affaibli·e·s'},
#              'affaiblis': {'affaibli·e·s'},
#              'affairé': {'affairé·e'},
#              'affairée': {'affairé·e'},
#              'affairées': {'affairé·e·s'},
#              'affairés': {'affairé·e·s'},
#              'affaissé': {'affaissé·e'},
#              'affaissée': {'affaissé·e'},
#              'affaissées': {'affaissé·e·s'},
#              'affaissés': {'affaissé·e·s'},
#              'affamé': {'affamé·e'},
#              'affamée': {'affamé·e'},
#              'affamées': {'affamé·e·s'},
#              'affamés': {'affamé·e·s'},
#              'affectionné': {'affectionné·e'},
#              'affectionnée': {'affectionné·e'},
#              'affectionnées': {'affectionné·e·s'},
#              'affectionnés': {'affectionné·e·s'},
#              'affectueuse': {'affectueux·se'},
#              'affectueuses': {'affectueux·se·s'},
#              'affectueux': {'affectueux·se', 'affectueux·se·s'},
#              'affecté': {'affecté·e'},
#              'affectée': {'affecté·e'},
#              'affectées': {'affecté·e·s'},
#              'affectés': {'affecté·e·s'},
#              'affermi': {'affermi·e'},
#              'affermie': {'affermi·e'},
#              'affermies': {'affermi·e·s'},
#              'affermis': {'affermi·e·s'},
#              'affiché': {'affiché·e'},
#              'affichée': {'affiché·e'},
#              'affichées': {'affiché·e·s'},
#              'affichés': {'affiché·e·s'},
#              'affilié': {'affilié·e'},
#              'affiliée': {'affilié·e'},
#              'affiliées': {'affilié·e·s'},
#              'affiliés': {'affilié·e·s'},
#              'affiné': {'affiné·e'},
#              'affinée': {'affiné·e'},
#              'affinées': {'affiné·e·s'},
#              'affinés': {'affiné·e·s'},
#              'affirmé': {'affirmé·e'},
#              'affirmée': {'affirmé·e'},
#              'affirmées': {'affirmé·e·s'},
#              'affirmés': {'affirmé·e·s'},
#              'affleuré': {'affleuré·e'},
#              'affleurée': {'affleuré·e'},
#              'affleurées': {'affleuré·e·s'},
#              'affleurés': {'affleuré·e·s'},
#              'affligeant': {'affligeant·e'},
#              'affligeante': {'affligeant·e'},
#              'affligeantes': {'affligeant·e·s'},
#              'affligeants': {'affligeant·e·s'},
#              'affligé': {'affligé·e'},
#              'affligée': {'affligé·e'},
#              'affligées': {'affligé·e·s'},
#              'affligés': {'affligé·e·s'},
#              'affluent': {'affluent·e'},
#              'affluente': {'affluent·e'},
#              'affluentes': {'affluent·e·s'},
#              'affluents': {'affluent·e·s'},
#              'affolant': {'affolant·e'},
#              'affolante': {'affolant·e'},
#              'affolantes': {'affolant·e·s'},
#              'affolants': {'affolant·e·s'},
#              'affolé': {'affolé·e'},
#              'affolée': {'affolé·e'},
#              'affolées': {'affolé·e·s'},
#              'affolés': {'affolé·e·s'},
#              'affranchi': {'affranchi·e'},
#              'affranchie': {'affranchi·e'},
#              'affranchies': {'affranchi·e·s'},
#              'affranchis': {'affranchi·e·s'},
#              'affreuse': {'affreux·se'},
#              'affreuses': {'affreux·se·s'},
#              'affreux': {'affreux·se', 'affreux·se·s'},
#              'affront': {'affront·e'},
#              'affronte': {'affront·e'},
#              'affrontes': {'affront·e·s'},
#              'affronts': {'affront·e·s'},
#              'affronté': {'affronté·e'},
#              'affrontée': {'affronté·e'},
#              'affrontées': {'affronté·e·s'},
#              'affrontés': {'affronté·e·s'},
#              'affrété': {'affrété·e'},
#              'affrétée': {'affrété·e'},
#              'affrétées': {'affrété·e·s'},
#              'affrétés': {'affrété·e·s'},
#              'affublé': {'affublé·e'},
#              'affublée': {'affublé·e'},
#              'affublées': {'affublé·e·s'},
#              'affublés': {'affublé·e·s'},
#              'afférent': {'afférent·e'},
#              'afférente': {'afférent·e'},
#              'afférentes': {'afférent·e·s'},
#              'afférents': {'afférent·e·s'},
#              'affûté': {'affûté·e'},
#              'affûtée': {'affûté·e'},
#              'affûtées': {'affûté·e·s'},
#              'affûtés': {'affûté·e·s'},
#              'africain': {'africain·e'},
#              'africaine': {'africain·e'},
#              'africaines': {'africain·e·s'},
#              'africains': {'africain·e·s'},
#              'agacé': {'agacé·e'},
#              'agacée': {'agacé·e'},
#              'agacées': {'agacé·e·s'},
#              'agacés': {'agacé·e·s'},
#              'agaçant': {'agaçant·e'},
#              'agaçante': {'agaçant·e'},
#              'agaçantes': {'agaçant·e·s'},
#              'agaçants': {'agaçant·e·s'},
#              'agencé': {'agencé·e'},
#              'agencée': {'agencé·e'},
#              'agencées': {'agencé·e·s'},
#              'agencés': {'agencé·e·s'},
#              'agenouillé': {'agenouillé·e'},
#              'agenouillée': {'agenouillé·e'},
#              'agenouillées': {'agenouillé·e·s'},
#              'agenouillés': {'agenouillé·e·s'},
#              'aggloméré': {'aggloméré·e'},
#              'agglomérée': {'aggloméré·e'},
#              'agglomérées': {'aggloméré·e·s'},
#              'agglomérés': {'aggloméré·e·s'},
#              'agglutiné': {'agglutiné·e'},
#              'agglutinée': {'agglutiné·e'},
#              'agglutinées': {'agglutiné·e·s'},
#              'agglutinés': {'agglutiné·e·s'},
#              'aggravant': {'aggravant·e'},
#              'aggravante': {'aggravant·e'},
#              'aggravantes': {'aggravant·e·s'},
#              'aggravants': {'aggravant·e·s'},
#              'aggravé': {'aggravé·e'},
#              'aggravée': {'aggravé·e'},
#              'aggravées': {'aggravé·e·s'},
#              'aggravés': {'aggravé·e·s'},
#              'agissant': {'agissant·e'},
#              'agissante': {'agissant·e'},
#              'agissantes': {'agissant·e·s'},
#              'agissants': {'agissant·e·s'},
#              'agité': {'agité·e'},
#              'agitée': {'agité·e'},
#              'agitées': {'agité·e·s'},
#              'agités': {'agité·e·s'},
#              'agonisant': {'agonisant·e'},
#              'agonisante': {'agonisant·e'},
#              'agonisantes': {'agonisant·e·s'},
#              'agonisants': {'agonisant·e·s'},
#              'agrafé': {'agrafé·e'},
#              'agrafée': {'agrafé·e'},
#              'agrafées': {'agrafé·e·s'},
#              'agrafés': {'agrafé·e·s'},
#              'agrandi': {'agrandi·e'},
#              'agrandie': {'agrandi·e'},
#              'agrandies': {'agrandi·e·s'},
#              'agrandis': {'agrandi·e·s'},
#              'agressé': {'agressé·e'},
#              'agressée': {'agressé·e'},
#              'agressées': {'agressé·e·s'},
#              'agressés': {'agressé·e·s'},
#              'agriculteur': {'agricultrice·teur', 'agriculteur·trice'},
#              'agriculteurs': {'agriculteur·trice·s', 'agricultrice·teur·s'},
#              'agricultrice': {'agricultrice·teur', 'agriculteur·trice'},
#              'agricultrices': {'agriculteur·trice·s', 'agricultrice·teur·s'},
#              'agrippé': {'agrippé·e'},
#              'agrippée': {'agrippé·e'},
#              'agrippées': {'agrippé·e·s'},
#              'agrippés': {'agrippé·e·s'},
#              'agrégé': {'agrégé·e'},
#              'agrégée': {'agrégé·e'},
#              'agrégées': {'agrégé·e·s'},
#              'agrégés': {'agrégé·e·s'},
#              'agrémenté': {'agrémenté·e'},
#              'agrémentée': {'agrémenté·e'},
#              'agrémentées': {'agrémenté·e·s'},
#              'agrémentés': {'agrémenté·e·s'},
#              'agréé': {'agréé·e'},
#              'agréée': {'agréé·e'},
#              'agréées': {'agréé·e·s'},
#              'agréés': {'agréé·e·s'},
#              'aguerri': {'aguerri·e'},
#              'aguerrie': {'aguerri·e'},
#              'aguerries': {'aguerri·e·s'},
#              'aguerris': {'aguerri·e·s'},
#              'ahuri': {'ahuri·e'},
#              'ahurie': {'ahuri·e'},
#              'ahuries': {'ahuri·e·s'},
#              'ahuris': {'ahuri·e·s'},
#              'ahurissant': {'ahurissant·e'},
#              'ahurissante': {'ahurissant·e'},
#              'ahurissantes': {'ahurissant·e·s'},
#              'ahurissants': {'ahurissant·e·s'},
#              'aidé': {'aidé·e'},
#              'aidée': {'aidé·e'},
#              'aidées': {'aidé·e·s'},
#              'aidés': {'aidé·e·s'},
#              'aigri': {'aigri·e'},
#              'aigrie': {'aigri·e'},
#              'aigries': {'aigri·e·s'},
#              'aigris': {'aigri·e·s'},
#              'aiguillon': {'aiguillon·ne'},
#              'aiguillonne': {'aiguillon·ne'},
#              'aiguillonnes': {'aiguillon·ne·s'},
#              'aiguillonné': {'aiguillonné·e'},
#              'aiguillonnée': {'aiguillonné·e'},
#              'aiguillonnées': {'aiguillonné·e·s'},
#              'aiguillonnés': {'aiguillonné·e·s'},
#              'aiguillons': {'aiguillon·ne·s'},
#              'aiguillé': {'aiguillé·e'},
#              'aiguillée': {'aiguillé·e'},
#              'aiguillées': {'aiguillé·e·s'},
#              'aiguillés': {'aiguillé·e·s'},
#              'aiguisé': {'aiguisé·e'},
#              'aiguisée': {'aiguisé·e'},
#              'aiguisées': {'aiguisé·e·s'},
#              'aiguisés': {'aiguisé·e·s'},
#              'ailé': {'ailé·e'},
#              'ailée': {'ailé·e'},
#              'ailées': {'ailé·e·s'},
#              'ailés': {'ailé·e·s'},
#              'aimant': {'aimant·e'},
#              'aimante': {'aimant·e'},
#              'aimantes': {'aimant·e·s'},
#              'aimants': {'aimant·e·s'},
#              'aimé': {'aimé·e'},
#              'aimée': {'aimé·e'},
#              'aimées': {'aimé·e·s'},
#              'aimés': {'aimé·e·s'},
#              'aisé': {'aisé·e'},
#              'aisée': {'aisé·e'},
#              'aisées': {'aisé·e·s'},
#              'aisés': {'aisé·e·s'},
#              'ajourné': {'ajourné·e'},
#              'ajournée': {'ajourné·e'},
#              'ajournées': {'ajourné·e·s'},
#              'ajournés': {'ajourné·e·s'},
#              'ajouré': {'ajouré·e'},
#              'ajourée': {'ajouré·e'},
#              'ajourées': {'ajouré·e·s'},
#              'ajourés': {'ajouré·e·s'},
#              'ajouté': {'ajouté·e'},
#              'ajoutée': {'ajouté·e'},
#              'ajoutées': {'ajouté·e·s'},
#              'ajoutés': {'ajouté·e·s'},
#              'ajusté': {'ajusté·e'},
#              'ajustée': {'ajusté·e'},
#              'ajustées': {'ajusté·e·s'},
#              'ajustés': {'ajusté·e·s'},
#              'alambiqué': {'alambiqué·e'},
#              'alambiquée': {'alambiqué·e'},
#              'alambiquées': {'alambiqué·e·s'},
#              'alambiqués': {'alambiqué·e·s'},
#              'alangui': {'alangui·e'},
#              'alanguie': {'alangui·e'},
#              'alanguies': {'alangui·e·s'},
#              'alanguis': {'alangui·e·s'},
#              'alarmant': {'alarmant·e'},
#              'alarmante': {'alarmant·e'},
#              'alarmantes': {'alarmant·e·s'},
#              'alarmants': {'alarmant·e·s'},
#              'alarmé': {'alarmé·e'},
#              'alarmée': {'alarmé·e'},
#              'alarmées': {'alarmé·e·s'},
#              'alarmés': {'alarmé·e·s'},
#              'albanais': {'albanais·e'},
#              'albanaise': {'albanais·e'},
#              'alcalin': {'alcalin·e'},
#              'alcaline': {'alcalin·e'},
#              'alcalines': {'alcalin·e·s'},
#              'alcalins': {'alcalin·e·s'},
#              'alcoolisé': {'alcoolisé·e'},
#              'alcoolisée': {'alcoolisé·e'},
#              'alcoolisées': {'alcoolisé·e·s'},
#              'alcoolisés': {'alcoolisé·e·s'},
#              'alerté': {'alerté·e'},
#              'alertée': {'alerté·e'},
#              'alertées': {'alerté·e·s'},
#              'alertés': {'alerté·e·s'},
#              'alezan': {'alezan·e'},
#              'alezane': {'alezan·e'},
#              'alezanes': {'alezan·e·s'},
#              'alezans': {'alezan·e·s'},
#              'algérien': {'algérien·ne'},
#              'algérienne': {'algérien·ne'},
#              'algériennes': {'algérien·ne·s'},
#              'algériens': {'algérien·ne·s'},
#              'aligné': {'aligné·e'},
#              'alignée': {'aligné·e'},
#              'alignées': {'aligné·e·s'},
#              'alignés': {'aligné·e·s'},
#              'alimenté': {'alimenté·e'},
#              'alimentée': {'alimenté·e'},
#              'alimentées': {'alimenté·e·s'},
#              'alimentés': {'alimenté·e·s'},
#              'alité': {'alité·e'},
#              'alitée': {'alité·e'},
#              'alitées': {'alité·e·s'},
#              'alités': {'alité·e·s'},
#              'aliénant': {'aliénant·e'},
#              'aliénante': {'aliénant·e'},
#              'aliénantes': {'aliénant·e·s'},
#              'aliénants': {'aliénant·e·s'},
#              'aliéné': {'aliéné·e'},
#              'aliénée': {'aliéné·e'},
#              'aliénées': {'aliéné·e·s'},
#              'aliénés': {'aliéné·e·s'},
#              'allaité': {'allaité·e'},
#              'allaitée': {'allaité·e'},
#              'allaitées': {'allaité·e·s'},
#              'allaités': {'allaité·e·s'},
#              'allant': {'allant·e'},
#              'allante': {'allant·e'},
#              'allantes': {'allant·e·s'},
#              'allants': {'allant·e·s'},
#              'allemand': {'allemand·e'},
#              'allemande': {'allemand·e'},
#              'allemandes': {'allemand·e·s'},
#              'allemands': {'allemand·e·s'},
#              'allié': {'allié·e'},
#              'alliée': {'allié·e'},
#              'alliées': {'allié·e·s'},
#              'alliés': {'allié·e·s'},
#              'allongé': {'allongé·e'},
#              'allongée': {'allongé·e'},
#              'allongées': {'allongé·e·s'},
#              'allongés': {'allongé·e·s'},
#              'alloué': {'alloué·e'},
#              'allouée': {'alloué·e'},
#              'allouées': {'alloué·e·s'},
#              'alloués': {'alloué·e·s'},
#              'allumé': {'allumé·e'},
#              'allumée': {'allumé·e'},
#              'allumées': {'allumé·e·s'},
#              'allumés': {'allumé·e·s'},
#              'allé': {'allé·e'},
#              'alléchant': {'alléchant·e'},
#              'alléchante': {'alléchant·e'},
#              'alléchantes': {'alléchant·e·s'},
#              'alléchants': {'alléchant·e·s'},
#              'alléché': {'alléché·e'},
#              'alléchée': {'alléché·e'},
#              'alléchées': {'alléché·e·s'},
#              'alléchés': {'alléché·e·s'},
#              'allée': {'allé·e'},
#              'allées': {'allé·e·s'},
#              'allégué': {'allégué·e'},
#              'alléguée': {'allégué·e'},
#              'alléguées': {'allégué·e·s'},
#              'allégués': {'allégué·e·s'},
#              'allégé': {'allégé·e'},
#              'allégée': {'allégé·e'},
#              'allégées': {'allégé·e·s'},
#              'allégés': {'allégé·e·s'},
#              'allés': {'allé·e·s'},
#              'alourdi': {'alourdi·e'},
#              'alourdie': {'alourdi·e'},
#              'alourdies': {'alourdi·e·s'},
#              'alourdis': {'alourdi·e·s'},
#              'alpin': {'alpin·e'},
#              'alpine': {'alpin·e'},
#              'alpines': {'alpin·e·s'},
#              'alpins': {'alpin·e·s'},
#              'alsacien': {'alsacien·ne'},
#              'alsacienne': {'alsacien·ne'},
#              'alterné': {'alterné·e'},
#              'alternée': {'alterné·e'},
#              'alternées': {'alterné·e·s'},
#              'alternés': {'alterné·e·s'},
#              'altier': {'altier·ère'},
#              'altiers': {'altier·ère·s'},
#              'altière': {'altier·ère'},
#              'altières': {'altier·ère·s'},
#              'altéré': {'altéré·e'},
#              'altérée': {'altéré·e'},
#              'altérées': {'altéré·e·s'},
#              'altérés': {'altéré·e·s'},
#              'amadoué': {'amadoué·e'},
#              'amadouée': {'amadoué·e'},
#              'amadouées': {'amadoué·e·s'},
#              'amadoués': {'amadoué·e·s'},
#              'amaigri': {'amaigri·e'},
#              'amaigrie': {'amaigri·e'},
#              'amaigries': {'amaigri·e·s'},
#              'amaigris': {'amaigri·e·s'},
#              'amaigrissant': {'amaigrissant·e'},
#              'amaigrissante': {'amaigrissant·e'},
#              'amaigrissantes': {'amaigrissant·e·s'},
#              'amaigrissants': {'amaigrissant·e·s'},
#              'amalgamé': {'amalgamé·e'},
#              'amalgamée': {'amalgamé·e'},
#              'amalgamées': {'amalgamé·e·s'},
#              'amalgamés': {'amalgamé·e·s'},
#              'amarré': {'amarré·e'},
#              'amarrée': {'amarré·e'},
#              'amarrées': {'amarré·e·s'},
#              'amarrés': {'amarré·e·s'},
#              'amassé': {'amassé·e'},
#              'amassée': {'amassé·e'},
#              'amassées': {'amassé·e·s'},
#              'amassés': {'amassé·e·s'},
#              'ambiant': {'ambiant·e'},
#              'ambiante': {'ambiant·e'},
#              'ambiantes': {'ambiant·e·s'},
#              'ambiants': {'ambiant·e·s'},
#              'ambitieuse': {'ambitieux·se'},
#              'ambitieuses': {'ambitieux·se·s'},
#              'ambitieux': {'ambitieux·se', 'ambitieux·se·s'},
#              'ambitionné': {'ambitionné·e'},
#              'ambitionnée': {'ambitionné·e'},
#              'ambitionnées': {'ambitionné·e·s'},
#              'ambitionnés': {'ambitionné·e·s'},
#              'ambré': {'ambré·e'},
#              'ambrée': {'ambré·e'},
#              'ambrées': {'ambré·e·s'},
#              'ambrés': {'ambré·e·s'},
#              'ambulant': {'ambulant·e'},
#              'ambulante': {'ambulant·e'},
#              'ambulantes': {'ambulant·e·s'},
#              'ambulants': {'ambulant·e·s'},
#              'amendé': {'amendé·e'},
#              'amendée': {'amendé·e'},
#              'amendées': {'amendé·e·s'},
#              'amendés': {'amendé·e·s'},
#              'amenuisé': {'amenuisé·e'},
#              'amenuisée': {'amenuisé·e'},
#              'amenuisées': {'amenuisé·e·s'},
#              'amenuisés': {'amenuisé·e·s'},
#              'amené': {'amené·e'},
#              'amenée': {'amené·e'},
#              'amenées': {'amené·e·s'},
#              'amenés': {'amené·e·s'},
#              'amer': {'amer·ère'},
#              'amers': {'amer·ère·s'},
#              'ameuté': {'ameuté·e'},
#              'ameutée': {'ameuté·e'},
#              'ameutées': {'ameuté·e·s'},
#              'ameutés': {'ameuté·e·s'},
#              'ami': {'ami·e'},
#              'amical': {'amical·e'},
#              'amicale': {'amical·e'},
#              'amidonné': {'amidonné·e'},
#              'amidonnée': {'amidonné·e'},
#              'amidonnées': {'amidonné·e·s'},
#              'amidonnés': {'amidonné·e·s'},
#              'amie': {'ami·e'},
#              'amies': {'ami·e·s'},
#              'aminci': {'aminci·e'},
#              'amincie': {'aminci·e'},
#              'amincies': {'aminci·e·s'},
#              'amincis': {'aminci·e·s'},
#              'amincissant': {'amincissant·e'},
#              'amincissante': {'amincissant·e'},
#              'amincissantes': {'amincissant·e·s'},
#              'amincissants': {'amincissant·e·s'},
#              'amis': {'ami·e·s'},
#              'amnistié': {'amnistié·e'},
#              'amnistiée': {'amnistié·e'},
#              'amnistiées': {'amnistié·e·s'},
#              'amnistiés': {'amnistié·e·s'},
#              'amoindri': {'amoindri·e'},
#              'amoindrie': {'amoindri·e'},
#              'amoindries': {'amoindri·e·s'},
#              'amoindris': {'amoindri·e·s'},
#              'amolli': {'amolli·e'},
#              'amollie': {'amolli·e'},
#              'amollies': {'amolli·e·s'},
#              'amollis': {'amolli·e·s'},
#              'amollissant': {'amollissant·e'},
#              'amollissante': {'amollissant·e'},
#              'amollissantes': {'amollissant·e·s'},
#              'amollissants': {'amollissant·e·s'},
#              'amoncelé': {'amoncelé·e'},
#              'amoncelée': {'amoncelé·e'},
#              'amoncelées': {'amoncelé·e·s'},
#              'amoncelés': {'amoncelé·e·s'},
#              'amoral': {'amoral·e'},
#              'amorale': {'amoral·e'},
#              'amorcé': {'amorcé·e'},
#              'amorcée': {'amorcé·e'},
#              'amorcées': {'amorcé·e·s'},
#              'amorcés': {'amorcé·e·s'},
#              'amorti': {'amorti·e'},
#              'amortie': {'amorti·e'},
#              'amorties': {'amorti·e·s'},
#              'amortis': {'amorti·e·s'},
#              'amoureuse': {'amoureux·se'},
#              'amoureuses': {'amoureux·se·s'},
#              'amoureux': {'amoureux·se·s', 'amoureux·se'},
#              'amplificateur': {'amplificatrice·teur', 'amplificateur·trice'},
#              'amplificateurs': {'amplificateur·trice·s',
#                                 'amplificatrice·teur·s'},
#              'amplificatrice': {'amplificatrice·teur', 'amplificateur·trice'},
#              'amplificatrices': {'amplificateur·trice·s',
#                                  'amplificatrice·teur·s'},
#              'amplifié': {'amplifié·e'},
#              'amplifiée': {'amplifié·e'},
#              'amplifiées': {'amplifié·e·s'},
#              'amplifiés': {'amplifié·e·s'},
#              'ampoulé': {'ampoulé·e'},
#              'ampoulée': {'ampoulé·e'},
#              'ampoulées': {'ampoulé·e·s'},
#              'ampoulés': {'ampoulé·e·s'},
#              'amputé': {'amputé·e'},
#              'amputée': {'amputé·e'},
#              'amputées': {'amputé·e·s'},
#              'amputés': {'amputé·e·s'},
#              'amusant': {'amusant·e'},
#              'amusante': {'amusant·e'},
#              'amusantes': {'amusant·e·s'},
#              'amusants': {'amusant·e·s'},
#              'amusé': {'amusé·e'},
#              'amusée': {'amusé·e'},
#              'amusées': {'amusé·e·s'},
#              'amusés': {'amusé·e·s'},
#              'amère': {'amer·ère'},
#              'amères': {'amer·ère·s'},
#              'amélioré': {'amélioré·e'},
#              'améliorée': {'amélioré·e'},
#              'améliorées': {'amélioré·e·s'},
#              'améliorés': {'amélioré·e·s'},
#              'aménagé': {'aménagé·e'},
#              'aménagée': {'aménagé·e'},
#              'aménagées': {'aménagé·e·s'},
#              'aménagés': {'aménagé·e·s'},
#              'américain': {'américain·e'},
#              'américaine': {'américain·e'},
#              'américaines': {'américain·e·s'},
#              'américains': {'américain·e·s'},
#              'américanisé': {'américanisé·e'},
#              'américanisée': {'américanisé·e'},
#              'américanisées': {'américanisé·e·s'},
#              'américanisés': {'américanisé·e·s'},
#              'analysé': {'analysé·e'},
#              'analysée': {'analysé·e'},
#              'analysées': {'analysé·e·s'},
#              'analysés': {'analysé·e·s'},
#              'ancestral': {'ancestral·e'},
#              'ancestrale': {'ancestral·e'},
#              'ancien': {'ancien·ne'},
#              'ancienne': {'ancien·ne'},
#              'anciennes': {'ancien·ne·s'},
#              'anciens': {'ancien·ne·s'},
#              'ancré': {'ancré·e'},
#              'ancrée': {'ancré·e'},
#              'ancrées': {'ancré·e·s'},
#              'ancrés': {'ancré·e·s'},
#              'anesthésié': {'anesthésié·e'},
#              'anesthésiée': {'anesthésié·e'},
#              'anesthésiées': {'anesthésié·e·s'},
#              'anesthésiés': {'anesthésié·e·s'},
#              'anglais': {'anglais·e'},
#              'anglaise': {'anglais·e'},
#              'anglican': {'anglican·e'},
#              'anglicane': {'anglican·e'},
#              'anglicanes': {'anglican·e·s'},
#              'anglicans': {'anglican·e·s'},
#              'anglicisé': {'anglicisé·e'},
#              'anglicisée': {'anglicisé·e'},
#              'anglicisées': {'anglicisé·e·s'},
#              'anglicisés': {'anglicisé·e·s'},
#              'anglo-saxon': {'anglo-saxon·ne'},
#              'anglo-saxonne': {'anglo-saxon·ne'},
#              'anglo-saxonnes': {'anglo-saxon·ne·s'},
#              'anglo-saxons': {'anglo-saxon·ne·s'},
#              'angoissant': {'angoissant·e'},
#              'angoissante': {'angoissant·e'},
#              'angoissantes': {'angoissant·e·s'},
#              'angoissants': {'angoissant·e·s'},
#              'angoissé': {'angoissé·e'},
#              'angoissée': {'angoissé·e'},
#              'angoissées': {'angoissé·e·s'},
#              'angoissés': {'angoissé·e·s'},
#              'anguleuse': {'anguleux·se'},
#              'anguleuses': {'anguleux·se·s'},
#              'anguleux': {'anguleux·se·s', 'anguleux·se'},
#              'animal': {'animal·e'},
#              'animale': {'animal·e'},
#              'animateur': {'animatrice·teur', 'animateur·trice'},
#              'animateurs': {'animateur·trice·s', 'animatrice·teur·s'},
#              'animatrice': {'animatrice·teur', 'animateur·trice'},
#              'animatrices': {'animateur·trice·s', 'animatrice·teur·s'},
#              'animé': {'animé·e'},
#              'animée': {'animé·e'},
#              'animées': {'animé·e·s'},
#              'animés': {'animé·e·s'},
#              'ankylosé': {'ankylosé·e'},
#              'ankylosée': {'ankylosé·e'},
#              'ankylosées': {'ankylosé·e·s'},
#              'ankylosés': {'ankylosé·e·s'},
#              'annexé': {'annexé·e'},
#              'annexée': {'annexé·e'},
#              'annexées': {'annexé·e·s'},
#              'annexés': {'annexé·e·s'},
#              'annihilé': {'annihilé·e'},
#              'annihilée': {'annihilé·e'},
#              'annihilées': {'annihilé·e·s'},
#              'annihilés': {'annihilé·e·s'},
#              'annonciateur': {'annonciatrice·teur', 'annonciateur·trice'},
#              'annonciateurs': {'annonciatrice·teur·s', 'annonciateur·trice·s'},
#              'annonciatrice': {'annonciatrice·teur', 'annonciateur·trice'},
#              'annonciatrices': {'annonciatrice·teur·s', 'annonciateur·trice·s'},
#              'annoncé': {'annoncé·e'},
#              'annoncée': {'annoncé·e'},
#              'annoncées': {'annoncé·e·s'},
#              'annoncés': {'annoncé·e·s'},
#              'annoté': {'annoté·e'},
#              'annotée': {'annoté·e'},
#              'annotées': {'annoté·e·s'},
#              'annotés': {'annoté·e·s'},
#              'annuel': {'annuel·le'},
#              'annuelle': {'annuel·le'},
#              'annuelles': {'annuel·le·s'},
#              'annuels': {'annuel·le·s'},
#              'annulé': {'annulé·e'},
#              'annulée': {'annulé·e'},
#              'annulées': {'annulé·e·s'},
#              'annulés': {'annulé·e·s'},
#              'anodin': {'anodin·e'},
#              'anodine': {'anodin·e'},
#              'anodines': {'anodin·e·s'},
#              'anodins': {'anodin·e·s'},
#              'anormal': {'anormal·e'},
#              'anormale': {'anormal·e'},
#              'antiaérien': {'antiaérien·ne'},
#              'antiaérienne': {'antiaérien·ne'},
#              'antiaériennes': {'antiaérien·ne·s'},
#              'antiaériens': {'antiaérien·ne·s'},
#              'anticancéreuse': {'anticancéreux·se'},
#              'anticancéreuses': {'anticancéreux·se·s'},
#              'anticancéreux': {'anticancéreux·se', 'anticancéreux·se·s'},
#              'anticipé': {'anticipé·e'},
#              'anticipée': {'anticipé·e'},
#              'anticipées': {'anticipé·e·s'},
#              'anticipés': {'anticipé·e·s'},
#              'anticlérical': {'anticlérical·e'},
#              'anticléricale': {'anticlérical·e'},
#              'anticoagulant': {'anticoagulant·e'},
#              'anticoagulante': {'anticoagulant·e'},
#              'anticoagulantes': {'anticoagulant·e·s'},
#              'anticoagulants': {'anticoagulant·e·s'},
#              'anticonceptionnel': {'anticonceptionnel·le'},
# ...
#              'épatées': {'épaté·e·s'},
#              'épatés': {'épaté·e·s'},
#              'épaulé': {'épaulé·e'},
#              'épaulée': {'épaulé·e'},
#              'épaulées': {'épaulé·e·s'},
#              'épaulés': {'épaulé·e·s'},
#              'épelé': {'épelé·e'},
#              'épelée': {'épelé·e'},
#              'épelées': {'épelé·e·s'},
#              'épelés': {'épelé·e·s'},
#              'éperdu': {'éperdu·e'},
#              'éperdue': {'éperdu·e'},
#              'éperdues': {'éperdu·e·s'},
#              'éperdus': {'éperdu·e·s'},
#              'épicier': {'épicier·ère'},
#              'épiciers': {'épicier·ère·s'},
#              'épicière': {'épicier·ère'},
#              'épicières': {'épicier·ère·s'},
#              'épicurien': {'épicurien·ne'},
#              'épicurienne': {'épicurien·ne'},
#              'épicuriennes': {'épicurien·ne·s'},
#              'épicuriens': {'épicurien·ne·s'},
#              'épicé': {'épicé·e'},
#              'épicée': {'épicé·e'},
#              'épicées': {'épicé·e·s'},
#              'épicés': {'épicé·e·s'},
#              'épilé': {'épilé·e'},
#              'épilée': {'épilé·e'},
#              'épilées': {'épilé·e·s'},
#              'épilés': {'épilé·e·s'},
#              'épineuse': {'épineux·se'},
#              'épineuses': {'épineux·se·s'},
#              'épineux': {'épineux·se·s', 'épineux·se'},
#              'épinglé': {'épinglé·e'},
#              'épinglée': {'épinglé·e'},
#              'épinglées': {'épinglé·e·s'},
#              'épinglés': {'épinglé·e·s'},
#              'épiscopal': {'épiscopal·e'},
#              'épiscopale': {'épiscopal·e'},
#              'épié': {'épié·e'},
#              'épiée': {'épié·e'},
#              'épiées': {'épié·e·s'},
#              'épiés': {'épié·e·s'},
#              'éploré': {'éploré·e'},
#              'éplorée': {'éploré·e'},
#              'éplorées': {'éploré·e·s'},
#              'éplorés': {'éploré·e·s'},
#              'épluché': {'épluché·e'},
#              'épluchée': {'épluché·e'},
#              'épluchées': {'épluché·e·s'},
#              'épluchés': {'épluché·e·s'},
#              'épongé': {'épongé·e'},
#              'épongée': {'épongé·e'},
#              'épongées': {'épongé·e·s'},
#              'épongés': {'épongé·e·s'},
#              'épouse': {'époux·se'},
#              'épouses': {'époux·se·s'},
#              'épousseté': {'épousseté·e'},
#              'époussetée': {'épousseté·e'},
#              'époussetées': {'épousseté·e·s'},
#              'époussetés': {'épousseté·e·s'},
#              'époustouflant': {'époustouflant·e'},
#              'époustouflante': {'époustouflant·e'},
#              'époustouflantes': {'époustouflant·e·s'},
#              'époustouflants': {'époustouflant·e·s'},
#              'épousé': {'épousé·e'},
#              'épousée': {'épousé·e'},
#              'épousées': {'épousé·e·s'},
#              'épousés': {'épousé·e·s'},
#              'épouvanté': {'épouvanté·e'},
#              'épouvantée': {'épouvanté·e'},
#              'épouvantées': {'épouvanté·e·s'},
#              'épouvantés': {'épouvanté·e·s'},
#              'époux': {'époux·se', 'époux·se·s'},
#              'épris': {'épris·e'},
#              'éprise': {'épris·e'},
#              'éprouvant': {'éprouvant·e'},
#              'éprouvante': {'éprouvant·e'},
#              'éprouvantes': {'éprouvant·e·s'},
#              'éprouvants': {'éprouvant·e·s'},
#              'éprouvé': {'éprouvé·e'},
#              'éprouvée': {'éprouvé·e'},
#              'éprouvées': {'éprouvé·e·s'},
#              'éprouvés': {'éprouvé·e·s'},
#              'épuisant': {'épuisant·e'},
#              'épuisante': {'épuisant·e'},
#              'épuisantes': {'épuisant·e·s'},
#              'épuisants': {'épuisant·e·s'},
#              'épuisé': {'épuisé·e'},
#              'épuisée': {'épuisé·e'},
#              'épuisées': {'épuisé·e·s'},
#              'épuisés': {'épuisé·e·s'},
#              'épuré': {'épuré·e'},
#              'épurée': {'épuré·e'},
#              'épurées': {'épuré·e·s'},
#              'épurés': {'épuré·e·s'},
#              'équatorial': {'équatorial·e'},
#              'équatoriale': {'équatorial·e'},
#              'équidistant': {'équidistant·e'},
#              'équidistante': {'équidistant·e'},
#              'équidistantes': {'équidistant·e·s'},
#              'équidistants': {'équidistant·e·s'},
#              'équilatéral': {'équilatéral·e'},
#              'équilatérale': {'équilatéral·e'},
#              'équilibré': {'équilibré·e'},
#              'équilibrée': {'équilibré·e'},
#              'équilibrées': {'équilibré·e·s'},
#              'équilibrés': {'équilibré·e·s'},
#              'équipier': {'équipier·ère'},
#              'équipiers': {'équipier·ère·s'},
#              'équipière': {'équipier·ère'},
#              'équipières': {'équipier·ère·s'},
#              'équipé': {'équipé·e'},
#              'équipée': {'équipé·e'},
#              'équipées': {'équipé·e·s'},
#              'équipés': {'équipé·e·s'},
#              'équivalent': {'équivalent·e'},
#              'équivalente': {'équivalent·e'},
#              'équivalentes': {'équivalent·e·s'},
#              'équivalents': {'équivalent·e·s'},
#              'éradiqué': {'éradiqué·e'},
#              'éradiquée': {'éradiqué·e'},
#              'éradiquées': {'éradiqué·e·s'},
#              'éradiqués': {'éradiqué·e·s'},
#              'éraflé': {'éraflé·e'},
#              'éraflée': {'éraflé·e'},
#              'éraflées': {'éraflé·e·s'},
#              'éraflés': {'éraflé·e·s'},
#              'éraillé': {'éraillé·e'},
#              'éraillée': {'éraillé·e'},
#              'éraillées': {'éraillé·e·s'},
#              'éraillés': {'éraillé·e·s'},
#              'éreintant': {'éreintant·e'},
#              'éreintante': {'éreintant·e'},
#              'éreintantes': {'éreintant·e·s'},
#              'éreintants': {'éreintant·e·s'},
#              'éreinté': {'éreinté·e'},
#              'éreintée': {'éreinté·e'},
#              'éreintées': {'éreinté·e·s'},
#              'éreintés': {'éreinté·e·s'},
#              'érigé': {'érigé·e'},
#              'érigée': {'érigé·e'},
#              'érigées': {'érigé·e·s'},
#              'érigés': {'érigé·e·s'},
#              'érudit': {'érudit·e'},
#              'érudite': {'érudit·e'},
#              'érudites': {'érudit·e·s'},
#              'érudits': {'érudit·e·s'},
#              'établi': {'établi·e'},
#              'établie': {'établi·e'},
#              'établies': {'établi·e·s'},
#              'établis': {'établi·e·s'},
#              'étager': {'étager·ère'},
#              'étagers': {'étager·ère·s'},
#              'étagère': {'étager·ère'},
#              'étagères': {'étager·ère·s'},
#              'étagé': {'étagé·e'},
#              'étagée': {'étagé·e'},
#              'étagées': {'étagé·e·s'},
#              'étagés': {'étagé·e·s'},
#              'étalon': {'étalon·ne'},
#              'étalonne': {'étalon·ne'},
#              'étalonnes': {'étalon·ne·s'},
#              'étalonné': {'étalonné·e'},
#              'étalonnée': {'étalonné·e'},
#              'étalonnées': {'étalonné·e·s'},
#              'étalonnés': {'étalonné·e·s'},
#              'étalons': {'étalon·ne·s'},
#              'étalé': {'étalé·e'},
#              'étalée': {'étalé·e'},
#              'étalées': {'étalé·e·s'},
#              'étalés': {'étalé·e·s'},
#              'étanché': {'étanché·e'},
#              'étanchée': {'étanché·e'},
#              'étanchées': {'étanché·e·s'},
#              'étanchés': {'étanché·e·s'},
#              'étatisé': {'étatisé·e'},
#              'étatisée': {'étatisé·e'},
#              'étatisées': {'étatisé·e·s'},
#              'étatisés': {'étatisé·e·s'},
#              'étayé': {'étayé·e'},
#              'étayée': {'étayé·e'},
#              'étayées': {'étayé·e·s'},
#              'étayés': {'étayé·e·s'},
#              'éteint': {'éteint·e'},
#              'éteinte': {'éteint·e'},
#              'éteintes': {'éteint·e·s'},
#              'éteints': {'éteint·e·s'},
#              'étendu': {'étendu·e'},
#              'étendue': {'étendu·e'},
#              'étendues': {'étendu·e·s'},
#              'étendus': {'étendu·e·s'},
#              'éternel': {'éternel·le'},
#              'éternelle': {'éternel·le'},
#              'éternelles': {'éternel·le·s'},
#              'éternels': {'éternel·le·s'},
#              'éternisé': {'éternisé·e'},
#              'éternisée': {'éternisé·e'},
#              'éternisées': {'éternisé·e·s'},
#              'éternisés': {'éternisé·e·s'},
#              'éthéré': {'éthéré·e'},
#              'éthérée': {'éthéré·e'},
#              'éthérées': {'éthéré·e·s'},
#              'éthérés': {'éthéré·e·s'},
#              'étincelant': {'étincelant·e'},
#              'étincelante': {'étincelant·e'},
#              'étincelantes': {'étincelant·e·s'},
#              'étincelants': {'étincelant·e·s'},
#              'étiolé': {'étiolé·e'},
#              'étiolée': {'étiolé·e'},
#              'étiolées': {'étiolé·e·s'},
#              'étiolés': {'étiolé·e·s'},
#              'étiqueté': {'étiqueté·e'},
#              'étiquetée': {'étiqueté·e'},
#              'étiquetées': {'étiqueté·e·s'},
#              'étiquetés': {'étiqueté·e·s'},
#              'étiré': {'étiré·e'},
#              'étirée': {'étiré·e'},
#              'étirées': {'étiré·e·s'},
#              'étirés': {'étiré·e·s'},
#              'étoffé': {'étoffé·e'},
#              'étoffée': {'étoffé·e'},
#              'étoffées': {'étoffé·e·s'},
#              'étoffés': {'étoffé·e·s'},
#              'étoilé': {'étoilé·e'},
#              'étoilée': {'étoilé·e'},
#              'étoilées': {'étoilé·e·s'},
#              'étoilés': {'étoilé·e·s'},
#              'étonnant': {'étonnant·e'},
#              'étonnante': {'étonnant·e'},
#              'étonnantes': {'étonnant·e·s'},
#              'étonnants': {'étonnant·e·s'},
#              'étonné': {'étonné·e'},
#              'étonnée': {'étonné·e'},
#              'étonnées': {'étonné·e·s'},
#              'étonnés': {'étonné·e·s'},
#              'étouffant': {'étouffant·e'},
#              'étouffante': {'étouffant·e'},
#              'étouffantes': {'étouffant·e·s'},
#              'étouffants': {'étouffant·e·s'},
#              'étouffé': {'étouffé·e'},
#              'étouffée': {'étouffé·e'},
#              'étouffées': {'étouffé·e·s'},
#              'étouffés': {'étouffé·e·s'},
#              'étourdi': {'étourdi·e'},
#              'étourdie': {'étourdi·e'},
#              'étourdies': {'étourdi·e·s'},
#              'étourdis': {'étourdi·e·s'},
#              'étourdissant': {'étourdissant·e'},
#              'étourdissante': {'étourdissant·e'},
#              'étourdissantes': {'étourdissant·e·s'},
#              'étourdissants': {'étourdissant·e·s'},
#              'étranger': {'étranger·ère'},
#              'étrangers': {'étranger·ère·s'},
#              'étranglé': {'étranglé·e'},
#              'étranglée': {'étranglé·e'},
#              'étranglées': {'étranglé·e·s'},
#              'étranglés': {'étranglé·e·s'},
#              'étrangère': {'étranger·ère'},
#              'étrangères': {'étranger·ère·s'},
#              'étreint': {'étreint·e'},
#              'étreinte': {'étreint·e'},
#              'étreintes': {'étreint·e·s'},
#              'étreints': {'étreint·e·s'},
#              'étrenné': {'étrenné·e'},
#              'étrennée': {'étrenné·e'},
#              'étrennées': {'étrenné·e·s'},
#              'étrennés': {'étrenné·e·s'},
#              'étriqué': {'étriqué·e'},
#              'étriquée': {'étriqué·e'},
#              'étriquées': {'étriqué·e·s'},
#              'étriqués': {'étriqué·e·s'},
#              'étroit': {'étroit·e'},
#              'étroite': {'étroit·e'},
#              'étroites': {'étroit·e·s'},
#              'étroits': {'étroit·e·s'},
#              'étudiant': {'étudiant·e'},
#              'étudiante': {'étudiant·e'},
#              'étudiantes': {'étudiant·e·s'},
#              'étudiants': {'étudiant·e·s'},
#              'étudié': {'étudié·e'},
#              'étudiée': {'étudié·e'},
#              'étudiées': {'étudié·e·s'},
#              'étudiés': {'étudié·e·s'},
#              'évacuateur': {'évacuateur·trice', 'évacuatrice·teur'},
#              'évacuateurs': {'évacuateur·trice·s', 'évacuatrice·teur·s'},
#              'évacuatrice': {'évacuateur·trice', 'évacuatrice·teur'},
#              'évacuatrices': {'évacuateur·trice·s', 'évacuatrice·teur·s'},
#              'évacué': {'évacué·e'},
#              'évacuée': {'évacué·e'},
#              'évacuées': {'évacué·e·s'},
#              'évacués': {'évacué·e·s'},
#              'évadé': {'évadé·e'},
#              'évadée': {'évadé·e'},
#              'évadées': {'évadé·e·s'},
#              'évadés': {'évadé·e·s'},
#              'évalué': {'évalué·e'},
#              'évaluée': {'évalué·e'},
#              'évaluées': {'évalué·e·s'},
#              'évalués': {'évalué·e·s'},
#              'évanescent': {'évanescent·e'},
#              'évanescente': {'évanescent·e'},
#              'évanescentes': {'évanescent·e·s'},
#              'évanescents': {'évanescent·e·s'},
#              'évangélisateur': {'évangélisateur·trice', 'évangélisatrice·teur'},
#              'évangélisateurs': {'évangélisateur·trice·s',
#                                  'évangélisatrice·teur·s'},
#              'évangélisatrice': {'évangélisateur·trice',
#                                  'évangélisatrice·teur'},
#              'évangélisatrices': {'évangélisateur·trice·s',
#                                   'évangélisatrice·teur·s'},
#              'évanoui': {'évanoui·e'},
#              'évanouie': {'évanoui·e'},
#              'évanouies': {'évanoui·e·s'},
#              'évanouis': {'évanoui·e·s'},
#              'évaporé': {'évaporé·e'},
#              'évaporée': {'évaporé·e'},
#              'évaporées': {'évaporé·e·s'},
#              'évaporés': {'évaporé·e·s'},
#              'évasé': {'évasé·e'},
#              'évasée': {'évasé·e'},
#              'évasées': {'évasé·e·s'},
#              'évasés': {'évasé·e·s'},
#              'éveillé': {'éveillé·e'},
#              'éveillée': {'éveillé·e'},
#              'éveillées': {'éveillé·e·s'},
#              'éveillés': {'éveillé·e·s'},
#              'éventré': {'éventré·e'},
#              'éventrée': {'éventré·e'},
#              'éventrées': {'éventré·e·s'},
#              'éventrés': {'éventré·e·s'},
#              'éventuel': {'éventuel·le'},
#              'éventuelle': {'éventuel·le'},
#              'éventuelles': {'éventuel·le·s'},
#              'éventuels': {'éventuel·le·s'},
#              'éventé': {'éventé·e'},
#              'éventée': {'éventé·e'},
#              'éventées': {'éventé·e·s'},
#              'éventés': {'éventé·e·s'},
#              'évertué': {'évertué·e'},
#              'évertuée': {'évertué·e'},
#              'évertuées': {'évertué·e·s'},
#              'évertués': {'évertué·e·s'},
#              'évident': {'évident·e'},
#              'évidente': {'évident·e'},
#              'évidentes': {'évident·e·s'},
#              'évidents': {'évident·e·s'},
#              'évidé': {'évidé·e'},
#              'évidée': {'évidé·e'},
#              'évidées': {'évidé·e·s'},
#              'évidés': {'évidé·e·s'},
#              'évincé': {'évincé·e'},
#              'évincée': {'évincé·e'},
#              'évincées': {'évincé·e·s'},
#              'évincés': {'évincé·e·s'},
#              'évité': {'évité·e'},
#              'évitée': {'évité·e'},
#              'évitées': {'évité·e·s'},
#              'évités': {'évité·e·s'},
#              'évocateur': {'évocateur·trice', 'évocatrice·teur'},
#              'évocateurs': {'évocatrice·teur·s', 'évocateur·trice·s'},
#              'évocatrice': {'évocateur·trice', 'évocatrice·teur'},
#              'évocatrices': {'évocatrice·teur·s', 'évocateur·trice·s'},
#              'évolué': {'évolué·e'},
#              'évoluée': {'évolué·e'},
#              'évoluées': {'évolué·e·s'},
#              'évolués': {'évolué·e·s'},
#              'évoqué': {'évoqué·e'},
#              'évoquée': {'évoqué·e'},
#              'évoquées': {'évoqué·e·s'},
#              'évoqués': {'évoqué·e·s'},
#              'événementiel': {'événementiel·le'},
#              'événementielle': {'événementiel·le'},
#              'événementielles': {'événementiel·le·s'},
#              'événementiels': {'événementiel·le·s'},
#              'ôté': {'ôté·e'},
#              'ôtée': {'ôté·e'},
#              'ôtées': {'ôté·e·s'},
#              'ôtés': {'ôté·e·s'}})

# %% [markdown]
# La fonction est HYPER simple :

# %%
def proposer_variante(mot):
    return alternatives[mot]

# %% [markdown]
# Quelques exemples :

# %%
from numpy import random

# %%
for mot in sorted(random.choice(list(alternatives.keys()), size=50, replace=False)):
    variantes = proposer_variante(mot)
    if len(variantes) > 1:
        print(f"Le mot {mot} a les variantes suivantes : {', '.join(variantes)}")
    else:
        print(f"Le mot {mot} a la variante suivante : {', '.join(variantes)}")
# Out:
# Le mot aimant a la variante suivante : aimant·e
# Le mot amenuisées a la variante suivante : amenuisé·e·s
# Le mot arboricultrices a les variantes suivantes : arboricultrice·teur·s, arboriculteur·trice·s
# Le mot attirantes a la variante suivante : attirant·e·s
# Le mot aveuglé a la variante suivante : aveuglé·e
# Le mot battantes a la variante suivante : battant·e·s
# Le mot berné a la variante suivante : berné·e
# Le mot bilieux a les variantes suivantes : bilieux·se·s, bilieux·se
# Le mot boguées a la variante suivante : bogué·e·s
# Le mot bénit a la variante suivante : bénit·e
# Le mot charcutées a la variante suivante : charcuté·e·s
# Le mot coagulés a la variante suivante : coagulé·e·s
# Le mot contre-attaqué a la variante suivante : contre-attaqué·e
# Le mot contés a la variante suivante : conté·e·s
# Le mot convenues a la variante suivante : convenu·e·s
# Le mot court-circuitées a la variante suivante : court-circuité·e·s
# Le mot directoriale a la variante suivante : directorial·e
# Le mot diététicien a la variante suivante : diététicien·ne
# Le mot déformants a la variante suivante : déformant·e·s
# Le mot déluré a la variante suivante : déluré·e
# Le mot démêlés a la variante suivante : démêlé·e·s
# Le mot désapprovisionné a la variante suivante : désapprovisionné·e
# Le mot détractrices a les variantes suivantes : détracteur·trice·s, détractrice·teur·s
# Le mot empaillée a la variante suivante : empaillé·e
# Le mot espérés a la variante suivante : espéré·e·s
# Le mot inattendu a la variante suivante : inattendu·e
# Le mot interrompu a la variante suivante : interrompu·e
# Le mot manuscrits a la variante suivante : manuscrit·e·s
# Le mot momentanés a la variante suivante : momentané·e·s
# Le mot montant a la variante suivante : montant·e
# Le mot munie a la variante suivante : muni·e
# Le mot noyautés a la variante suivante : noyauté·e·s
# Le mot omnisciente a la variante suivante : omniscient·e
# Le mot paraphés a la variante suivante : paraphé·e·s
# Le mot persévérants a la variante suivante : persévérant·e·s
# Le mot propagatrices a les variantes suivantes : propagateur·trice·s, propagatrice·teur·s
# Le mot préméditées a la variante suivante : prémédité·e·s
# Le mot quantifiés a la variante suivante : quantifié·e·s
# Le mot radoucies a la variante suivante : radouci·e·s
# Le mot reclouée a la variante suivante : recloué·e
# Le mot renversants a la variante suivante : renversant·e·s
# Le mot respectueuses a la variante suivante : respectueux·se·s
# Le mot réhabitué a la variante suivante : réhabitué·e
# Le mot révérencieuses a la variante suivante : révérencieux·se·s
# Le mot sculptés a la variante suivante : sculpté·e·s
# Le mot sous-alimenté a la variante suivante : sous-alimenté·e
# Le mot substantielle a la variante suivante : substantiel·le
# Le mot verdis a la variante suivante : verdi·e·s
# Le mot visionnés a la variante suivante : visionné·e·s
# Le mot vivifiantes a la variante suivante : vivifiant·e·s

# %% [markdown]
# ### Ajouter ces mots dans un fichier

# %%
# !ls french_inclusive
# !mv -vf french_inclusive /tmp/
# Out:
# ls: impossible d'accéder à 'french_inclusive': Aucun fichier ou dossier de ce type
# mv: impossible d'évaluer 'french_inclusive': Aucun fichier ou dossier de ce type

# %%
with open("french_inclusive", "w") as f:
    for mot, alts in alternatives.items():
        for alt in alts:
            f.write(alt + "\n")
            f.write(alt.replace("·", "-") + "\n")

# %%
# !ls -larth french_inclusive
# !wc french_inclusive
# Out:
# -rw-r--r-- 1 lilian lilian 712K sept. 28 14:51 french_inclusive
#  52210  52210 728898 french_inclusive

# %% [markdown]
# On a rajouté quelques 50 000 mots à une liste qui en contenait 138 000 ! C'est DINGUE !

# %%
# !head french_inclusive
# !tail french_inclusive
# Out:
# abaissé·e
# abaissé-e
# abaissé·e
# abaissé-e
# abandonné·e
# abandonné-e
# abandonné·e
# abandonné-e
# abasourdi·e
# abasourdi-e
# ceulles
# ceulles
# toustes
# toustes
# toustes
# toustes
# loup·ve
# loup-ve
# loup·ve
# loup-ve

# %%
# !cat french_inclusive | shuf -n10
# Out:
# préfacé·e
# coopté·e·s
# maniéré·e
# paupérisé-e
# débraillé·e
# rassasié·e·s
# accouché·e
# commandé·e·s
# dévissé·e·s
# encombré·e

# %% [markdown]
# Cette liste peut être utilisée pour ajouter ces mots au dictionnaire (`/usr/share/dict/french`) et permettre à la correction orthographique du système d'accepter les mots comme "abaissé-e" ou "abasourdi·e".

# %% [markdown]
# ### Conclusion
# Fin pour aujourd'hui !
